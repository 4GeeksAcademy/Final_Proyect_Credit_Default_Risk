# %%
import pandas as pd
from sklearn.utils import resample
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import numpy as np
from sklearn.impute import SimpleImputer
import joblib
from xgboost import XGBClassifier
import optuna
from optuna.samplers import TPESampler

# %%
#load dataset
df = pd.read_csv("../data/processed/home_credit_train_ready.csv")

# %%
#rebalance dataset
class_0 = df[df['TARGET'] == 0]
class_1 = df[df['TARGET'] == 1]

# balance mayority class with minority
sub_class = resample(class_0, replace=False, n_samples=len(class_1), random_state=42)

# combine
df = pd.concat([sub_class, class_1])

# %%
y = df['TARGET']
X = df.drop(columns=['TARGET', 'SK_ID_CURR'])  #adde sk_id_curr

# %%
#manages divided by 0 values
X.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
#divide categorical and numerical to impute the values
cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

num_imputer = SimpleImputer(strategy="constant", fill_value= 0)  #fill nan's as 0
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

# %%
#change object to category to use in the threelike model
for col in X.select_dtypes("object"):
    X[col] = X[col].astype("category")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y ,random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train ,random_state=42)

# %%
#create params for optuna study
xgb_params = {
    # Objective y métrica
    'objective': 'binary:logistic',
    'eval_metric': ['aucpr', 'auc'],  # AUCPR es mejor para desbalanceo


    # Parámetros de boosting - MÁS AGRESIVOS
    'n_estimators': 3000,  # Reducir de 5000 (early stopping lo maneja)
    'learning_rate': 0.01,  # Más bajo = más refinado
    'max_depth': 6,  # Aumentar de 5 (más capacidad)

    # Regularización - BALANCEADA
    'min_child_weight': 5,  # Reducir de 7 (menos restrictivo)
    'gamma': 0.2,  # Reducir de 0.3
    'subsample': 0.8,  # Aumentar de 0.7
    'colsample_bytree': 0.8,  # Aumentar de 0.7
    'colsample_bylevel': 0.8,  # Aumentar de 0.7
    'colsample_bynode': 0.8,  # NUEVO: muestreo por nodo

    # Regularización L1/L2 - MÁS SUAVE
    'reg_alpha': 0.5,  # Reducir de 1.0
    'reg_lambda': 2.0,  # Reducir de 3.0

    # Parámetros adicionales IMPORTANTES
    'max_delta_step': 1,  # Ayuda con desbalanceo extremo
    'tree_method': 'hist',
    'grow_policy': 'depthwise',  # vs lossguide

    # Sampling method para desbalanceo
    'sampling_method': 'gradient_based',  # Alternativa: 'uniform'

    # Control
    'random_state': 42,
    'n_jobs': -1,
    'device': 'cuda',
    'early_stopping_rounds': 200,  # Reducir de 300 (más rápido)
    'verbosity': 1,
    'enable_categorical': True,
}

# %%
model = XGBClassifier(**xgb_params)
model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)
# Out:
# [0]	validation_0-aucpr:0.70933	validation_0-auc:0.72336
# [1]	validation_0-aucpr:0.71924	validation_0-auc:0.73238
# [2]	validation_0-aucpr:0.72451	validation_0-auc:0.73664
# [3]	validation_0-aucpr:0.72609	validation_0-auc:0.73744
# [4]	validation_0-aucpr:0.72634	validation_0-auc:0.73772
# [5]	validation_0-aucpr:0.72764	validation_0-auc:0.73876
# [6]	validation_0-aucpr:0.72970	validation_0-auc:0.74092
# [7]	validation_0-aucpr:0.72965	validation_0-auc:0.74139
# [8]	validation_0-aucpr:0.72952	validation_0-auc:0.74157
# [9]	validation_0-aucpr:0.73008	validation_0-auc:0.74162
# [10]	validation_0-aucpr:0.73051	validation_0-auc:0.74232
# [11]	validation_0-aucpr:0.73090	validation_0-auc:0.74256
# [12]	validation_0-aucpr:0.73235	validation_0-auc:0.74360
# [13]	validation_0-aucpr:0.73202	validation_0-auc:0.74343
# [14]	validation_0-aucpr:0.73216	validation_0-auc:0.74342
# [15]	validation_0-aucpr:0.73274	validation_0-auc:0.74406
# [16]	validation_0-aucpr:0.73295	validation_0-auc:0.74414
# [17]	validation_0-aucpr:0.73325	validation_0-auc:0.74448
# [18]	validation_0-aucpr:0.73347	validation_0-auc:0.74450
# [19]	validation_0-aucpr:0.73322	validation_0-auc:0.74454
# [20]	validation_0-aucpr:0.73265	validation_0-auc:0.74450
# [21]	validation_0-aucpr:0.73302	validation_0-auc:0.74476
# [22]	validation_0-aucpr:0.73275	validation_0-auc:0.74462
# [23]	validation_0-aucpr:0.73323	validation_0-auc:0.74482
# [24]	validation_0-aucpr:0.73365	validation_0-auc:0.74529
# [25]	validation_0-aucpr:0.73444	validation_0-auc:0.74566
# [26]	validation_0-aucpr:0.73495	validation_0-auc:0.74589
# [27]	validation_0-aucpr:0.73517	validation_0-auc:0.74622
# [28]	validation_0-aucpr:0.73587	validation_0-auc:0.74627
# [29]	validation_0-aucpr:0.73659	validation_0-auc:0.74677
# [30]	validation_0-aucpr:0.73678	validation_0-auc:0.74692
# [31]	validation_0-aucpr:0.73672	validation_0-auc:0.74675
# [32]	validation_0-aucpr:0.73684	validation_0-auc:0.74679
# [33]	validation_0-aucpr:0.73674	validation_0-auc:0.74685
# [34]	validation_0-aucpr:0.73714	validation_0-auc:0.74715
# [35]	validation_0-aucpr:0.73751	validation_0-auc:0.74728
# [36]	validation_0-aucpr:0.73792	validation_0-auc:0.74740
# [37]	validation_0-aucpr:0.73788	validation_0-auc:0.74753
# [38]	validation_0-aucpr:0.73805	validation_0-auc:0.74774
# [39]	validation_0-aucpr:0.73836	validation_0-auc:0.74798
# [40]	validation_0-aucpr:0.73855	validation_0-auc:0.74818
# [41]	validation_0-aucpr:0.73853	validation_0-auc:0.74823
# [42]	validation_0-aucpr:0.73864	validation_0-auc:0.74837
# [43]	validation_0-aucpr:0.73873	validation_0-auc:0.74848
# [44]	validation_0-aucpr:0.73870	validation_0-auc:0.74848
# [45]	validation_0-aucpr:0.73900	validation_0-auc:0.74858
# [46]	validation_0-aucpr:0.73915	validation_0-auc:0.74874
# [47]	validation_0-aucpr:0.73899	validation_0-auc:0.74876
# [48]	validation_0-aucpr:0.73945	validation_0-auc:0.74889
# [49]	validation_0-aucpr:0.73940	validation_0-auc:0.74888
# [50]	validation_0-aucpr:0.73949	validation_0-auc:0.74890
# [51]	validation_0-aucpr:0.73993	validation_0-auc:0.74918
# [52]	validation_0-aucpr:0.74002	validation_0-auc:0.74914
# [53]	validation_0-aucpr:0.74004	validation_0-auc:0.74907
# [54]	validation_0-aucpr:0.74013	validation_0-auc:0.74910
# [55]	validation_0-aucpr:0.74028	validation_0-auc:0.74922
# [56]	validation_0-aucpr:0.74042	validation_0-auc:0.74937
# [57]	validation_0-aucpr:0.74079	validation_0-auc:0.74965
# [58]	validation_0-aucpr:0.74100	validation_0-auc:0.74972
# [59]	validation_0-aucpr:0.74124	validation_0-auc:0.74992
# [60]	validation_0-aucpr:0.74132	validation_0-auc:0.74994
# [61]	validation_0-aucpr:0.74138	validation_0-auc:0.75002
# [62]	validation_0-aucpr:0.74157	validation_0-auc:0.75021
# [63]	validation_0-aucpr:0.74168	validation_0-auc:0.75031
# [64]	validation_0-aucpr:0.74164	validation_0-auc:0.75040
# [65]	validation_0-aucpr:0.74160	validation_0-auc:0.75051
# [66]	validation_0-aucpr:0.74183	validation_0-auc:0.75060
# [67]	validation_0-aucpr:0.74190	validation_0-auc:0.75071
# [68]	validation_0-aucpr:0.74209	validation_0-auc:0.75083
# [69]	validation_0-aucpr:0.74206	validation_0-auc:0.75077
# [70]	validation_0-aucpr:0.74234	validation_0-auc:0.75078
# [71]	validation_0-aucpr:0.74252	validation_0-auc:0.75085
# [72]	validation_0-aucpr:0.74260	validation_0-auc:0.75100
# [73]	validation_0-aucpr:0.74269	validation_0-auc:0.75104
# [74]	validation_0-aucpr:0.74273	validation_0-auc:0.75107
# [75]	validation_0-aucpr:0.74274	validation_0-auc:0.75107
# [76]	validation_0-aucpr:0.74277	validation_0-auc:0.75115
# [77]	validation_0-aucpr:0.74291	validation_0-auc:0.75124
# [78]	validation_0-aucpr:0.74293	validation_0-auc:0.75132
# [79]	validation_0-aucpr:0.74309	validation_0-auc:0.75132
# [80]	validation_0-aucpr:0.74326	validation_0-auc:0.75146
# [81]	validation_0-aucpr:0.74318	validation_0-auc:0.75150
# [82]	validation_0-aucpr:0.74323	validation_0-auc:0.75164
# [83]	validation_0-aucpr:0.74326	validation_0-auc:0.75166
# [84]	validation_0-aucpr:0.74336	validation_0-auc:0.75177
# [85]	validation_0-aucpr:0.74358	validation_0-auc:0.75195
# [86]	validation_0-aucpr:0.74367	validation_0-auc:0.75201
# [87]	validation_0-aucpr:0.74367	validation_0-auc:0.75207
# [88]	validation_0-aucpr:0.74361	validation_0-auc:0.75212
# [89]	validation_0-aucpr:0.74369	validation_0-auc:0.75224
# [90]	validation_0-aucpr:0.74387	validation_0-auc:0.75237
# [91]	validation_0-aucpr:0.74397	validation_0-auc:0.75243
# [92]	validation_0-aucpr:0.74404	validation_0-auc:0.75243
# [93]	validation_0-aucpr:0.74413	validation_0-auc:0.75248
# [94]	validation_0-aucpr:0.74410	validation_0-auc:0.75250
# [95]	validation_0-aucpr:0.74409	validation_0-auc:0.75256
# [96]	validation_0-aucpr:0.74421	validation_0-auc:0.75264
# [97]	validation_0-aucpr:0.74439	validation_0-auc:0.75277
# [98]	validation_0-aucpr:0.74433	validation_0-auc:0.75280
# [99]	validation_0-aucpr:0.74432	validation_0-auc:0.75286
# [100]	validation_0-aucpr:0.74432	validation_0-auc:0.75290
# [101]	validation_0-aucpr:0.74432	validation_0-auc:0.75297
# [102]	validation_0-aucpr:0.74446	validation_0-auc:0.75304
# [103]	validation_0-aucpr:0.74439	validation_0-auc:0.75308
# [104]	validation_0-aucpr:0.74445	validation_0-auc:0.75312
# [105]	validation_0-aucpr:0.74463	validation_0-auc:0.75323
# [106]	validation_0-aucpr:0.74480	validation_0-auc:0.75334
# [107]	validation_0-aucpr:0.74494	validation_0-auc:0.75340
# [108]	validation_0-aucpr:0.74502	validation_0-auc:0.75348
# [109]	validation_0-aucpr:0.74510	validation_0-auc:0.75359
# [110]	validation_0-aucpr:0.74517	validation_0-auc:0.75368
# [111]	validation_0-aucpr:0.74519	validation_0-auc:0.75379
# [112]	validation_0-aucpr:0.74536	validation_0-auc:0.75393
# [113]	validation_0-aucpr:0.74547	validation_0-auc:0.75406
# [114]	validation_0-aucpr:0.74553	validation_0-auc:0.75416
# [115]	validation_0-aucpr:0.74561	validation_0-auc:0.75420
# [116]	validation_0-aucpr:0.74583	validation_0-auc:0.75439
# [117]	validation_0-aucpr:0.74594	validation_0-auc:0.75447
# [118]	validation_0-aucpr:0.74612	validation_0-auc:0.75459
# [119]	validation_0-aucpr:0.74614	validation_0-auc:0.75465
# [120]	validation_0-aucpr:0.74619	validation_0-auc:0.75474
# [121]	validation_0-aucpr:0.74627	validation_0-auc:0.75479
# [122]	validation_0-aucpr:0.74650	validation_0-auc:0.75489
# [123]	validation_0-aucpr:0.74655	validation_0-auc:0.75500
# [124]	validation_0-aucpr:0.74662	validation_0-auc:0.75509
# [125]	validation_0-aucpr:0.74677	validation_0-auc:0.75518
# [126]	validation_0-aucpr:0.74677	validation_0-auc:0.75525
# [127]	validation_0-aucpr:0.74699	validation_0-auc:0.75535
# [128]	validation_0-aucpr:0.74710	validation_0-auc:0.75546
# [129]	validation_0-aucpr:0.74715	validation_0-auc:0.75550
# [130]	validation_0-aucpr:0.74716	validation_0-auc:0.75552
# [131]	validation_0-aucpr:0.74723	validation_0-auc:0.75562
# [132]	validation_0-aucpr:0.74726	validation_0-auc:0.75566
# [133]	validation_0-aucpr:0.74729	validation_0-auc:0.75567
# [134]	validation_0-aucpr:0.74751	validation_0-auc:0.75578
# [135]	validation_0-aucpr:0.74759	validation_0-auc:0.75585
# [136]	validation_0-aucpr:0.74766	validation_0-auc:0.75593
# [137]	validation_0-aucpr:0.74775	validation_0-auc:0.75605
# [138]	validation_0-aucpr:0.74786	validation_0-auc:0.75615
# [139]	validation_0-aucpr:0.74783	validation_0-auc:0.75620
# [140]	validation_0-aucpr:0.74792	validation_0-auc:0.75627
# [141]	validation_0-aucpr:0.74789	validation_0-auc:0.75627
# [142]	validation_0-aucpr:0.74798	validation_0-auc:0.75634
# [143]	validation_0-aucpr:0.74800	validation_0-auc:0.75643
# [144]	validation_0-aucpr:0.74810	validation_0-auc:0.75655
# [145]	validation_0-aucpr:0.74807	validation_0-auc:0.75659
# [146]	validation_0-aucpr:0.74818	validation_0-auc:0.75663
# [147]	validation_0-aucpr:0.74833	validation_0-auc:0.75675
# [148]	validation_0-aucpr:0.74833	validation_0-auc:0.75680
# [149]	validation_0-aucpr:0.74829	validation_0-auc:0.75689
# [150]	validation_0-aucpr:0.74835	validation_0-auc:0.75694
# [151]	validation_0-aucpr:0.74843	validation_0-auc:0.75696
# [152]	validation_0-aucpr:0.74851	validation_0-auc:0.75704
# [153]	validation_0-aucpr:0.74856	validation_0-auc:0.75708
# [154]	validation_0-aucpr:0.74853	validation_0-auc:0.75710
# [155]	validation_0-aucpr:0.74862	validation_0-auc:0.75719
# [156]	validation_0-aucpr:0.74875	validation_0-auc:0.75729
# [157]	validation_0-aucpr:0.74888	validation_0-auc:0.75740
# [158]	validation_0-aucpr:0.74898	validation_0-auc:0.75742
# [159]	validation_0-aucpr:0.74907	validation_0-auc:0.75748
# [160]	validation_0-aucpr:0.74909	validation_0-auc:0.75755
# [161]	validation_0-aucpr:0.74913	validation_0-auc:0.75760
# [162]	validation_0-aucpr:0.74938	validation_0-auc:0.75772
# [163]	validation_0-aucpr:0.74951	validation_0-auc:0.75778
# [164]	validation_0-aucpr:0.74960	validation_0-auc:0.75785
# [165]	validation_0-aucpr:0.74971	validation_0-auc:0.75792
# [166]	validation_0-aucpr:0.74970	validation_0-auc:0.75793
# [167]	validation_0-aucpr:0.74987	validation_0-auc:0.75799
# [168]	validation_0-aucpr:0.74989	validation_0-auc:0.75805
# [169]	validation_0-aucpr:0.74999	validation_0-auc:0.75810
# [170]	validation_0-aucpr:0.75010	validation_0-auc:0.75818
# [171]	validation_0-aucpr:0.75023	validation_0-auc:0.75830
# [172]	validation_0-aucpr:0.75033	validation_0-auc:0.75840
# [173]	validation_0-aucpr:0.75034	validation_0-auc:0.75842
# [174]	validation_0-aucpr:0.75045	validation_0-auc:0.75851
# [175]	validation_0-aucpr:0.75050	validation_0-auc:0.75853
# [176]	validation_0-aucpr:0.75062	validation_0-auc:0.75861
# [177]	validation_0-aucpr:0.75078	validation_0-auc:0.75874
# [178]	validation_0-aucpr:0.75084	validation_0-auc:0.75881
# [179]	validation_0-aucpr:0.75100	validation_0-auc:0.75891
# [180]	validation_0-aucpr:0.75112	validation_0-auc:0.75909
# [181]	validation_0-aucpr:0.75112	validation_0-auc:0.75911
# [182]	validation_0-aucpr:0.75121	validation_0-auc:0.75918
# [183]	validation_0-aucpr:0.75118	validation_0-auc:0.75921
# [184]	validation_0-aucpr:0.75120	validation_0-auc:0.75932
# [185]	validation_0-aucpr:0.75130	validation_0-auc:0.75936
# [186]	validation_0-aucpr:0.75135	validation_0-auc:0.75944
# [187]	validation_0-aucpr:0.75152	validation_0-auc:0.75950
# [188]	validation_0-aucpr:0.75159	validation_0-auc:0.75954
# [189]	validation_0-aucpr:0.75174	validation_0-auc:0.75960
# [190]	validation_0-aucpr:0.75180	validation_0-auc:0.75965
# [191]	validation_0-aucpr:0.75183	validation_0-auc:0.75972
# [192]	validation_0-aucpr:0.75189	validation_0-auc:0.75974
# [193]	validation_0-aucpr:0.75199	validation_0-auc:0.75984
# [194]	validation_0-aucpr:0.75204	validation_0-auc:0.75991
# [195]	validation_0-aucpr:0.75205	validation_0-auc:0.75994
# [196]	validation_0-aucpr:0.75207	validation_0-auc:0.75998
# [197]	validation_0-aucpr:0.75227	validation_0-auc:0.76007
# [198]	validation_0-aucpr:0.75239	validation_0-auc:0.76017
# [199]	validation_0-aucpr:0.75252	validation_0-auc:0.76033
# [200]	validation_0-aucpr:0.75258	validation_0-auc:0.76035
# [201]	validation_0-aucpr:0.75263	validation_0-auc:0.76039
# [202]	validation_0-aucpr:0.75278	validation_0-auc:0.76050
# [203]	validation_0-aucpr:0.75284	validation_0-auc:0.76054
# [204]	validation_0-aucpr:0.75294	validation_0-auc:0.76058
# [205]	validation_0-aucpr:0.75309	validation_0-auc:0.76066
# [206]	validation_0-aucpr:0.75307	validation_0-auc:0.76072
# [207]	validation_0-aucpr:0.75317	validation_0-auc:0.76080
# [208]	validation_0-aucpr:0.75328	validation_0-auc:0.76088
# [209]	validation_0-aucpr:0.75338	validation_0-auc:0.76094
# [210]	validation_0-aucpr:0.75351	validation_0-auc:0.76104
# [211]	validation_0-aucpr:0.75346	validation_0-auc:0.76103
# [212]	validation_0-aucpr:0.75349	validation_0-auc:0.76106
# [213]	validation_0-aucpr:0.75356	validation_0-auc:0.76113
# [214]	validation_0-aucpr:0.75367	validation_0-auc:0.76121
# [215]	validation_0-aucpr:0.75381	validation_0-auc:0.76131
# [216]	validation_0-aucpr:0.75383	validation_0-auc:0.76138
# [217]	validation_0-aucpr:0.75391	validation_0-auc:0.76145
# [218]	validation_0-aucpr:0.75402	validation_0-auc:0.76153
# [219]	validation_0-aucpr:0.75407	validation_0-auc:0.76157
# [220]	validation_0-aucpr:0.75418	validation_0-auc:0.76165
# [221]	validation_0-aucpr:0.75421	validation_0-auc:0.76174
# [222]	validation_0-aucpr:0.75429	validation_0-auc:0.76186
# [223]	validation_0-aucpr:0.75443	validation_0-auc:0.76192
# [224]	validation_0-aucpr:0.75453	validation_0-auc:0.76200
# [225]	validation_0-aucpr:0.75462	validation_0-auc:0.76206
# [226]	validation_0-aucpr:0.75469	validation_0-auc:0.76210
# [227]	validation_0-aucpr:0.75471	validation_0-auc:0.76213
# [228]	validation_0-aucpr:0.75469	validation_0-auc:0.76212
# [229]	validation_0-aucpr:0.75481	validation_0-auc:0.76220
# [230]	validation_0-aucpr:0.75481	validation_0-auc:0.76225
# [231]	validation_0-aucpr:0.75489	validation_0-auc:0.76232
# [232]	validation_0-aucpr:0.75497	validation_0-auc:0.76235
# [233]	validation_0-aucpr:0.75503	validation_0-auc:0.76248
# [234]	validation_0-aucpr:0.75512	validation_0-auc:0.76250
# [235]	validation_0-aucpr:0.75515	validation_0-auc:0.76257
# [236]	validation_0-aucpr:0.75525	validation_0-auc:0.76264
# [237]	validation_0-aucpr:0.75527	validation_0-auc:0.76269
# [238]	validation_0-aucpr:0.75534	validation_0-auc:0.76275
# [239]	validation_0-aucpr:0.75537	validation_0-auc:0.76279
# [240]	validation_0-aucpr:0.75534	validation_0-auc:0.76278
# [241]	validation_0-aucpr:0.75543	validation_0-auc:0.76286
# [242]	validation_0-aucpr:0.75560	validation_0-auc:0.76297
# [243]	validation_0-aucpr:0.75559	validation_0-auc:0.76297
# [244]	validation_0-aucpr:0.75567	validation_0-auc:0.76305
# [245]	validation_0-aucpr:0.75573	validation_0-auc:0.76311
# [246]	validation_0-aucpr:0.75576	validation_0-auc:0.76317
# [247]	validation_0-aucpr:0.75582	validation_0-auc:0.76322
# [248]	validation_0-aucpr:0.75587	validation_0-auc:0.76327
# [249]	validation_0-aucpr:0.75599	validation_0-auc:0.76332
# [250]	validation_0-aucpr:0.75600	validation_0-auc:0.76338
# [251]	validation_0-aucpr:0.75604	validation_0-auc:0.76340
# [252]	validation_0-aucpr:0.75613	validation_0-auc:0.76346
# [253]	validation_0-aucpr:0.75624	validation_0-auc:0.76357
# [254]	validation_0-aucpr:0.75629	validation_0-auc:0.76363
# [255]	validation_0-aucpr:0.75642	validation_0-auc:0.76373
# [256]	validation_0-aucpr:0.75643	validation_0-auc:0.76378
# [257]	validation_0-aucpr:0.75647	validation_0-auc:0.76384
# [258]	validation_0-aucpr:0.75657	validation_0-auc:0.76389
# [259]	validation_0-aucpr:0.75666	validation_0-auc:0.76397
# [260]	validation_0-aucpr:0.75666	validation_0-auc:0.76399
# [261]	validation_0-aucpr:0.75676	validation_0-auc:0.76410
# [262]	validation_0-aucpr:0.75686	validation_0-auc:0.76421
# [263]	validation_0-aucpr:0.75693	validation_0-auc:0.76429
# [264]	validation_0-aucpr:0.75700	validation_0-auc:0.76437
# [265]	validation_0-aucpr:0.75705	validation_0-auc:0.76444
# [266]	validation_0-aucpr:0.75711	validation_0-auc:0.76447
# [267]	validation_0-aucpr:0.75712	validation_0-auc:0.76451
# [268]	validation_0-aucpr:0.75716	validation_0-auc:0.76456
# [269]	validation_0-aucpr:0.75718	validation_0-auc:0.76458
# [270]	validation_0-aucpr:0.75726	validation_0-auc:0.76463
# [271]	validation_0-aucpr:0.75730	validation_0-auc:0.76470
# [272]	validation_0-aucpr:0.75732	validation_0-auc:0.76474
# [273]	validation_0-aucpr:0.75735	validation_0-auc:0.76474
# [274]	validation_0-aucpr:0.75739	validation_0-auc:0.76480
# [275]	validation_0-aucpr:0.75753	validation_0-auc:0.76490
# [276]	validation_0-aucpr:0.75768	validation_0-auc:0.76499
# [277]	validation_0-aucpr:0.75773	validation_0-auc:0.76505
# [278]	validation_0-aucpr:0.75781	validation_0-auc:0.76511
# [279]	validation_0-aucpr:0.75787	validation_0-auc:0.76520
# [280]	validation_0-aucpr:0.75789	validation_0-auc:0.76524
# [281]	validation_0-aucpr:0.75800	validation_0-auc:0.76532
# [282]	validation_0-aucpr:0.75806	validation_0-auc:0.76536
# [283]	validation_0-aucpr:0.75815	validation_0-auc:0.76544
# [284]	validation_0-aucpr:0.75825	validation_0-auc:0.76549
# [285]	validation_0-aucpr:0.75828	validation_0-auc:0.76552
# [286]	validation_0-aucpr:0.75840	validation_0-auc:0.76558
# [287]	validation_0-aucpr:0.75847	validation_0-auc:0.76561
# [288]	validation_0-aucpr:0.75856	validation_0-auc:0.76567
# [289]	validation_0-aucpr:0.75857	validation_0-auc:0.76570
# [290]	validation_0-aucpr:0.75863	validation_0-auc:0.76576
# [291]	validation_0-aucpr:0.75875	validation_0-auc:0.76582
# [292]	validation_0-aucpr:0.75884	validation_0-auc:0.76587
# [293]	validation_0-aucpr:0.75886	validation_0-auc:0.76590
# [294]	validation_0-aucpr:0.75894	validation_0-auc:0.76594
# [295]	validation_0-aucpr:0.75901	validation_0-auc:0.76599
# [296]	validation_0-aucpr:0.75909	validation_0-auc:0.76609
# [297]	validation_0-aucpr:0.75911	validation_0-auc:0.76616
# [298]	validation_0-aucpr:0.75913	validation_0-auc:0.76623
# [299]	validation_0-aucpr:0.75927	validation_0-auc:0.76633
# [300]	validation_0-aucpr:0.75923	validation_0-auc:0.76634
# [301]	validation_0-aucpr:0.75933	validation_0-auc:0.76643
# [302]	validation_0-aucpr:0.75937	validation_0-auc:0.76648
# [303]	validation_0-aucpr:0.75941	validation_0-auc:0.76656
# [304]	validation_0-aucpr:0.75941	validation_0-auc:0.76656
# [305]	validation_0-aucpr:0.75948	validation_0-auc:0.76658
# [306]	validation_0-aucpr:0.75956	validation_0-auc:0.76663
# [307]	validation_0-aucpr:0.75958	validation_0-auc:0.76666
# [308]	validation_0-aucpr:0.75966	validation_0-auc:0.76669
# [309]	validation_0-aucpr:0.75974	validation_0-auc:0.76678
# [310]	validation_0-aucpr:0.75974	validation_0-auc:0.76682
# [311]	validation_0-aucpr:0.75979	validation_0-auc:0.76686
# [312]	validation_0-aucpr:0.75979	validation_0-auc:0.76689
# [313]	validation_0-aucpr:0.75984	validation_0-auc:0.76695
# [314]	validation_0-aucpr:0.75985	validation_0-auc:0.76698
# [315]	validation_0-aucpr:0.75989	validation_0-auc:0.76706
# [316]	validation_0-aucpr:0.75991	validation_0-auc:0.76712
# [317]	validation_0-aucpr:0.76004	validation_0-auc:0.76723
# [318]	validation_0-aucpr:0.76018	validation_0-auc:0.76728
# [319]	validation_0-aucpr:0.76015	validation_0-auc:0.76727
# [320]	validation_0-aucpr:0.76025	validation_0-auc:0.76733
# [321]	validation_0-aucpr:0.76027	validation_0-auc:0.76736
# [322]	validation_0-aucpr:0.76030	validation_0-auc:0.76743
# [323]	validation_0-aucpr:0.76036	validation_0-auc:0.76746
# [324]	validation_0-aucpr:0.76038	validation_0-auc:0.76751
# [325]	validation_0-aucpr:0.76041	validation_0-auc:0.76754
# [326]	validation_0-aucpr:0.76045	validation_0-auc:0.76760
# [327]	validation_0-aucpr:0.76053	validation_0-auc:0.76766
# [328]	validation_0-aucpr:0.76055	validation_0-auc:0.76771
# [329]	validation_0-aucpr:0.76052	validation_0-auc:0.76774
# [330]	validation_0-aucpr:0.76061	validation_0-auc:0.76781
# [331]	validation_0-aucpr:0.76067	validation_0-auc:0.76785
# [332]	validation_0-aucpr:0.76075	validation_0-auc:0.76793
# [333]	validation_0-aucpr:0.76091	validation_0-auc:0.76802
# [334]	validation_0-aucpr:0.76099	validation_0-auc:0.76809
# [335]	validation_0-aucpr:0.76102	validation_0-auc:0.76814
# [336]	validation_0-aucpr:0.76113	validation_0-auc:0.76821
# [337]	validation_0-aucpr:0.76119	validation_0-auc:0.76826
# [338]	validation_0-aucpr:0.76124	validation_0-auc:0.76831
# [339]	validation_0-aucpr:0.76132	validation_0-auc:0.76838
# [340]	validation_0-aucpr:0.76141	validation_0-auc:0.76844
# [341]	validation_0-aucpr:0.76143	validation_0-auc:0.76848
# [342]	validation_0-aucpr:0.76150	validation_0-auc:0.76854
# [343]	validation_0-aucpr:0.76155	validation_0-auc:0.76857
# [344]	validation_0-aucpr:0.76157	validation_0-auc:0.76858
# [345]	validation_0-aucpr:0.76166	validation_0-auc:0.76865
# [346]	validation_0-aucpr:0.76170	validation_0-auc:0.76868
# [347]	validation_0-aucpr:0.76165	validation_0-auc:0.76870
# [348]	validation_0-aucpr:0.76170	validation_0-auc:0.76875
# [349]	validation_0-aucpr:0.76174	validation_0-auc:0.76879
# [350]	validation_0-aucpr:0.76181	validation_0-auc:0.76884
# [351]	validation_0-aucpr:0.76187	validation_0-auc:0.76890
# [352]	validation_0-aucpr:0.76186	validation_0-auc:0.76892
# [353]	validation_0-aucpr:0.76194	validation_0-auc:0.76899
# [354]	validation_0-aucpr:0.76198	validation_0-auc:0.76902
# [355]	validation_0-aucpr:0.76206	validation_0-auc:0.76908
# [356]	validation_0-aucpr:0.76211	validation_0-auc:0.76913
# [357]	validation_0-aucpr:0.76214	validation_0-auc:0.76917
# [358]	validation_0-aucpr:0.76220	validation_0-auc:0.76920
# [359]	validation_0-aucpr:0.76223	validation_0-auc:0.76923
# [360]	validation_0-aucpr:0.76226	validation_0-auc:0.76928
# [361]	validation_0-aucpr:0.76228	validation_0-auc:0.76928
# [362]	validation_0-aucpr:0.76229	validation_0-auc:0.76933
# [363]	validation_0-aucpr:0.76234	validation_0-auc:0.76936
# [364]	validation_0-aucpr:0.76233	validation_0-auc:0.76939
# [365]	validation_0-aucpr:0.76236	validation_0-auc:0.76945
# [366]	validation_0-aucpr:0.76244	validation_0-auc:0.76949
# [367]	validation_0-aucpr:0.76249	validation_0-auc:0.76953
# [368]	validation_0-aucpr:0.76260	validation_0-auc:0.76960
# [369]	validation_0-aucpr:0.76262	validation_0-auc:0.76962
# [370]	validation_0-aucpr:0.76265	validation_0-auc:0.76966
# [371]	validation_0-aucpr:0.76276	validation_0-auc:0.76971
# [372]	validation_0-aucpr:0.76269	validation_0-auc:0.76974
# [373]	validation_0-aucpr:0.76271	validation_0-auc:0.76977
# [374]	validation_0-aucpr:0.76272	validation_0-auc:0.76980
# [375]	validation_0-aucpr:0.76276	validation_0-auc:0.76984
# [376]	validation_0-aucpr:0.76275	validation_0-auc:0.76985
# [377]	validation_0-aucpr:0.76274	validation_0-auc:0.76987
# [378]	validation_0-aucpr:0.76271	validation_0-auc:0.76986
# [379]	validation_0-aucpr:0.76275	validation_0-auc:0.76989
# [380]	validation_0-aucpr:0.76282	validation_0-auc:0.76994
# [381]	validation_0-aucpr:0.76285	validation_0-auc:0.76998
# [382]	validation_0-aucpr:0.76288	validation_0-auc:0.76998
# [383]	validation_0-aucpr:0.76287	validation_0-auc:0.77000
# [384]	validation_0-aucpr:0.76288	validation_0-auc:0.77001
# [385]	validation_0-aucpr:0.76300	validation_0-auc:0.77004
# [386]	validation_0-aucpr:0.76304	validation_0-auc:0.77009
# [387]	validation_0-aucpr:0.76310	validation_0-auc:0.77014
# [388]	validation_0-aucpr:0.76310	validation_0-auc:0.77016
# [389]	validation_0-aucpr:0.76311	validation_0-auc:0.77018
# [390]	validation_0-aucpr:0.76312	validation_0-auc:0.77019
# [391]	validation_0-aucpr:0.76311	validation_0-auc:0.77020
# [392]	validation_0-aucpr:0.76314	validation_0-auc:0.77024
# [393]	validation_0-aucpr:0.76317	validation_0-auc:0.77028
# [394]	validation_0-aucpr:0.76322	validation_0-auc:0.77031
# [395]	validation_0-aucpr:0.76321	validation_0-auc:0.77032
# [396]	validation_0-aucpr:0.76325	validation_0-auc:0.77036
# [397]	validation_0-aucpr:0.76332	validation_0-auc:0.77039
# [398]	validation_0-aucpr:0.76339	validation_0-auc:0.77045
# [399]	validation_0-aucpr:0.76344	validation_0-auc:0.77051
# [400]	validation_0-aucpr:0.76348	validation_0-auc:0.77055
# [401]	validation_0-aucpr:0.76349	validation_0-auc:0.77056
# [402]	validation_0-aucpr:0.76350	validation_0-auc:0.77060
# [403]	validation_0-aucpr:0.76354	validation_0-auc:0.77065
# [404]	validation_0-aucpr:0.76365	validation_0-auc:0.77069
# [405]	validation_0-aucpr:0.76370	validation_0-auc:0.77072
# [406]	validation_0-aucpr:0.76367	validation_0-auc:0.77071
# [407]	validation_0-aucpr:0.76365	validation_0-auc:0.77072
# [408]	validation_0-aucpr:0.76376	validation_0-auc:0.77077
# [409]	validation_0-aucpr:0.76384	validation_0-auc:0.77082
# [410]	validation_0-aucpr:0.76386	validation_0-auc:0.77086
# [411]	validation_0-aucpr:0.76384	validation_0-auc:0.77087
# [412]	validation_0-aucpr:0.76389	validation_0-auc:0.77090
# [413]	validation_0-aucpr:0.76393	validation_0-auc:0.77095
# [414]	validation_0-aucpr:0.76397	validation_0-auc:0.77100
# [415]	validation_0-aucpr:0.76401	validation_0-auc:0.77104
# [416]	validation_0-aucpr:0.76406	validation_0-auc:0.77107
# [417]	validation_0-aucpr:0.76410	validation_0-auc:0.77111
# [418]	validation_0-aucpr:0.76416	validation_0-auc:0.77115
# [419]	validation_0-aucpr:0.76420	validation_0-auc:0.77119
# [420]	validation_0-aucpr:0.76421	validation_0-auc:0.77119
# [421]	validation_0-aucpr:0.76422	validation_0-auc:0.77121
# [422]	validation_0-aucpr:0.76421	validation_0-auc:0.77123
# [423]	validation_0-aucpr:0.76426	validation_0-auc:0.77127
# [424]	validation_0-aucpr:0.76437	validation_0-auc:0.77133
# [425]	validation_0-aucpr:0.76441	validation_0-auc:0.77136
# [426]	validation_0-aucpr:0.76446	validation_0-auc:0.77140
# [427]	validation_0-aucpr:0.76445	validation_0-auc:0.77142
# [428]	validation_0-aucpr:0.76448	validation_0-auc:0.77144
# [429]	validation_0-aucpr:0.76453	validation_0-auc:0.77147
# [430]	validation_0-aucpr:0.76456	validation_0-auc:0.77151
# [431]	validation_0-aucpr:0.76457	validation_0-auc:0.77153
# [432]	validation_0-aucpr:0.76458	validation_0-auc:0.77158
# [433]	validation_0-aucpr:0.76461	validation_0-auc:0.77163
# [434]	validation_0-aucpr:0.76461	validation_0-auc:0.77164
# [435]	validation_0-aucpr:0.76472	validation_0-auc:0.77170
# [436]	validation_0-aucpr:0.76468	validation_0-auc:0.77168
# [437]	validation_0-aucpr:0.76474	validation_0-auc:0.77169
# [438]	validation_0-aucpr:0.76471	validation_0-auc:0.77170
# [439]	validation_0-aucpr:0.76479	validation_0-auc:0.77176
# [440]	validation_0-aucpr:0.76482	validation_0-auc:0.77177
# [441]	validation_0-aucpr:0.76484	validation_0-auc:0.77179
# [442]	validation_0-aucpr:0.76489	validation_0-auc:0.77182
# [443]	validation_0-aucpr:0.76486	validation_0-auc:0.77184
# [444]	validation_0-aucpr:0.76489	validation_0-auc:0.77188
# [445]	validation_0-aucpr:0.76495	validation_0-auc:0.77192
# [446]	validation_0-aucpr:0.76495	validation_0-auc:0.77192
# [447]	validation_0-aucpr:0.76499	validation_0-auc:0.77195
# [448]	validation_0-aucpr:0.76502	validation_0-auc:0.77200
# [449]	validation_0-aucpr:0.76509	validation_0-auc:0.77200
# [450]	validation_0-aucpr:0.76512	validation_0-auc:0.77202
# [451]	validation_0-aucpr:0.76512	validation_0-auc:0.77205
# [452]	validation_0-aucpr:0.76513	validation_0-auc:0.77208
# [453]	validation_0-aucpr:0.76518	validation_0-auc:0.77210
# [454]	validation_0-aucpr:0.76521	validation_0-auc:0.77212
# [455]	validation_0-aucpr:0.76523	validation_0-auc:0.77211
# [456]	validation_0-aucpr:0.76522	validation_0-auc:0.77212
# [457]	validation_0-aucpr:0.76521	validation_0-auc:0.77211
# [458]	validation_0-aucpr:0.76522	validation_0-auc:0.77211
# [459]	validation_0-aucpr:0.76524	validation_0-auc:0.77214
# [460]	validation_0-aucpr:0.76525	validation_0-auc:0.77216
# [461]	validation_0-aucpr:0.76530	validation_0-auc:0.77219
# [462]	validation_0-aucpr:0.76530	validation_0-auc:0.77221
# [463]	validation_0-aucpr:0.76532	validation_0-auc:0.77222
# [464]	validation_0-aucpr:0.76539	validation_0-auc:0.77228
# [465]	validation_0-aucpr:0.76543	validation_0-auc:0.77230
# [466]	validation_0-aucpr:0.76546	validation_0-auc:0.77231
# [467]	validation_0-aucpr:0.76551	validation_0-auc:0.77237
# [468]	validation_0-aucpr:0.76556	validation_0-auc:0.77243
# [469]	validation_0-aucpr:0.76559	validation_0-auc:0.77244
# [470]	validation_0-aucpr:0.76565	validation_0-auc:0.77249
# [471]	validation_0-aucpr:0.76567	validation_0-auc:0.77250
# [472]	validation_0-aucpr:0.76572	validation_0-auc:0.77252
# [473]	validation_0-aucpr:0.76573	validation_0-auc:0.77253
# [474]	validation_0-aucpr:0.76580	validation_0-auc:0.77258
# [475]	validation_0-aucpr:0.76581	validation_0-auc:0.77262
# [476]	validation_0-aucpr:0.76583	validation_0-auc:0.77265
# [477]	validation_0-aucpr:0.76581	validation_0-auc:0.77267
# [478]	validation_0-aucpr:0.76579	validation_0-auc:0.77267
# [479]	validation_0-aucpr:0.76578	validation_0-auc:0.77265
# [480]	validation_0-aucpr:0.76578	validation_0-auc:0.77266
# [481]	validation_0-aucpr:0.76577	validation_0-auc:0.77268
# [482]	validation_0-aucpr:0.76577	validation_0-auc:0.77268
# [483]	validation_0-aucpr:0.76584	validation_0-auc:0.77271
# [484]	validation_0-aucpr:0.76584	validation_0-auc:0.77274
# [485]	validation_0-aucpr:0.76588	validation_0-auc:0.77275
# [486]	validation_0-aucpr:0.76584	validation_0-auc:0.77277
# [487]	validation_0-aucpr:0.76587	validation_0-auc:0.77280
# [488]	validation_0-aucpr:0.76586	validation_0-auc:0.77282
# [489]	validation_0-aucpr:0.76591	validation_0-auc:0.77284
# [490]	validation_0-aucpr:0.76594	validation_0-auc:0.77285
# [491]	validation_0-aucpr:0.76597	validation_0-auc:0.77287
# [492]	validation_0-aucpr:0.76603	validation_0-auc:0.77291
# [493]	validation_0-aucpr:0.76608	validation_0-auc:0.77294
# [494]	validation_0-aucpr:0.76608	validation_0-auc:0.77297
# [495]	validation_0-aucpr:0.76608	validation_0-auc:0.77299
# [496]	validation_0-aucpr:0.76615	validation_0-auc:0.77302
# [497]	validation_0-aucpr:0.76617	validation_0-auc:0.77303
# [498]	validation_0-aucpr:0.76618	validation_0-auc:0.77304
# [499]	validation_0-aucpr:0.76618	validation_0-auc:0.77305
# [500]	validation_0-aucpr:0.76618	validation_0-auc:0.77307
# [501]	validation_0-aucpr:0.76615	validation_0-auc:0.77307
# [502]	validation_0-aucpr:0.76616	validation_0-auc:0.77309
# [503]	validation_0-aucpr:0.76623	validation_0-auc:0.77313
# [504]	validation_0-aucpr:0.76629	validation_0-auc:0.77318
# [505]	validation_0-aucpr:0.76630	validation_0-auc:0.77319
# [506]	validation_0-aucpr:0.76630	validation_0-auc:0.77321
# [507]	validation_0-aucpr:0.76630	validation_0-auc:0.77322
# [508]	validation_0-aucpr:0.76631	validation_0-auc:0.77323
# [509]	validation_0-aucpr:0.76633	validation_0-auc:0.77326
# [510]	validation_0-aucpr:0.76639	validation_0-auc:0.77330
# [511]	validation_0-aucpr:0.76638	validation_0-auc:0.77329
# [512]	validation_0-aucpr:0.76642	validation_0-auc:0.77331
# [513]	validation_0-aucpr:0.76636	validation_0-auc:0.77332
# [514]	validation_0-aucpr:0.76640	validation_0-auc:0.77333
# [515]	validation_0-aucpr:0.76642	validation_0-auc:0.77334
# [516]	validation_0-aucpr:0.76641	validation_0-auc:0.77335
# [517]	validation_0-aucpr:0.76639	validation_0-auc:0.77338
# [518]	validation_0-aucpr:0.76640	validation_0-auc:0.77340
# [519]	validation_0-aucpr:0.76645	validation_0-auc:0.77344
# [520]	validation_0-aucpr:0.76644	validation_0-auc:0.77343
# [521]	validation_0-aucpr:0.76645	validation_0-auc:0.77345
# [522]	validation_0-aucpr:0.76651	validation_0-auc:0.77345
# [523]	validation_0-aucpr:0.76651	validation_0-auc:0.77345
# [524]	validation_0-aucpr:0.76651	validation_0-auc:0.77349
# [525]	validation_0-aucpr:0.76657	validation_0-auc:0.77352
# [526]	validation_0-aucpr:0.76655	validation_0-auc:0.77354
# [527]	validation_0-aucpr:0.76660	validation_0-auc:0.77356
# [528]	validation_0-aucpr:0.76662	validation_0-auc:0.77357
# [529]	validation_0-aucpr:0.76666	validation_0-auc:0.77359
# [530]	validation_0-aucpr:0.76664	validation_0-auc:0.77360
# [531]	validation_0-aucpr:0.76669	validation_0-auc:0.77363
# [532]	validation_0-aucpr:0.76672	validation_0-auc:0.77367
# [533]	validation_0-aucpr:0.76672	validation_0-auc:0.77369
# [534]	validation_0-aucpr:0.76673	validation_0-auc:0.77370
# [535]	validation_0-aucpr:0.76679	validation_0-auc:0.77375
# [536]	validation_0-aucpr:0.76679	validation_0-auc:0.77376
# [537]	validation_0-aucpr:0.76681	validation_0-auc:0.77379
# [538]	validation_0-aucpr:0.76683	validation_0-auc:0.77382
# [539]	validation_0-aucpr:0.76684	validation_0-auc:0.77384
# [540]	validation_0-aucpr:0.76690	validation_0-auc:0.77385
# [541]	validation_0-aucpr:0.76686	validation_0-auc:0.77384
# [542]	validation_0-aucpr:0.76691	validation_0-auc:0.77388
# [543]	validation_0-aucpr:0.76692	validation_0-auc:0.77390
# [544]	validation_0-aucpr:0.76694	validation_0-auc:0.77391
# [545]	validation_0-aucpr:0.76696	validation_0-auc:0.77393
# [546]	validation_0-aucpr:0.76696	validation_0-auc:0.77393
# [547]	validation_0-aucpr:0.76700	validation_0-auc:0.77396
# [548]	validation_0-aucpr:0.76703	validation_0-auc:0.77397
# [549]	validation_0-aucpr:0.76705	validation_0-auc:0.77399
# [550]	validation_0-aucpr:0.76706	validation_0-auc:0.77405
# [551]	validation_0-aucpr:0.76710	validation_0-auc:0.77408
# [552]	validation_0-aucpr:0.76711	validation_0-auc:0.77410
# [553]	validation_0-aucpr:0.76709	validation_0-auc:0.77410
# [554]	validation_0-aucpr:0.76711	validation_0-auc:0.77411
# [555]	validation_0-aucpr:0.76711	validation_0-auc:0.77412
# [556]	validation_0-aucpr:0.76706	validation_0-auc:0.77410
# [557]	validation_0-aucpr:0.76703	validation_0-auc:0.77412
# [558]	validation_0-aucpr:0.76702	validation_0-auc:0.77413
# [559]	validation_0-aucpr:0.76707	validation_0-auc:0.77416
# [560]	validation_0-aucpr:0.76711	validation_0-auc:0.77420
# [561]	validation_0-aucpr:0.76715	validation_0-auc:0.77424
# [562]	validation_0-aucpr:0.76714	validation_0-auc:0.77425
# [563]	validation_0-aucpr:0.76714	validation_0-auc:0.77425
# [564]	validation_0-aucpr:0.76715	validation_0-auc:0.77427
# [565]	validation_0-aucpr:0.76716	validation_0-auc:0.77427
# [566]	validation_0-aucpr:0.76722	validation_0-auc:0.77430
# [567]	validation_0-aucpr:0.76727	validation_0-auc:0.77433
# [568]	validation_0-aucpr:0.76729	validation_0-auc:0.77436
# [569]	validation_0-aucpr:0.76731	validation_0-auc:0.77440
# [570]	validation_0-aucpr:0.76734	validation_0-auc:0.77438
# [571]	validation_0-aucpr:0.76734	validation_0-auc:0.77440
# [572]	validation_0-aucpr:0.76734	validation_0-auc:0.77441
# [573]	validation_0-aucpr:0.76739	validation_0-auc:0.77444
# [574]	validation_0-aucpr:0.76740	validation_0-auc:0.77445
# [575]	validation_0-aucpr:0.76741	validation_0-auc:0.77447
# [576]	validation_0-aucpr:0.76743	validation_0-auc:0.77448
# [577]	validation_0-aucpr:0.76744	validation_0-auc:0.77449
# [578]	validation_0-aucpr:0.76751	validation_0-auc:0.77451
# [579]	validation_0-aucpr:0.76752	validation_0-auc:0.77452
# [580]	validation_0-aucpr:0.76757	validation_0-auc:0.77455
# [581]	validation_0-aucpr:0.76758	validation_0-auc:0.77457
# [582]	validation_0-aucpr:0.76761	validation_0-auc:0.77463
# [583]	validation_0-aucpr:0.76767	validation_0-auc:0.77464
# [584]	validation_0-aucpr:0.76768	validation_0-auc:0.77466
# [585]	validation_0-aucpr:0.76770	validation_0-auc:0.77467
# [586]	validation_0-aucpr:0.76770	validation_0-auc:0.77468
# [587]	validation_0-aucpr:0.76777	validation_0-auc:0.77470
# [588]	validation_0-aucpr:0.76779	validation_0-auc:0.77472
# [589]	validation_0-aucpr:0.76780	validation_0-auc:0.77474
# [590]	validation_0-aucpr:0.76779	validation_0-auc:0.77475
# [591]	validation_0-aucpr:0.76782	validation_0-auc:0.77475
# [592]	validation_0-aucpr:0.76783	validation_0-auc:0.77475
# [593]	validation_0-aucpr:0.76780	validation_0-auc:0.77475
# [594]	validation_0-aucpr:0.76783	validation_0-auc:0.77477
# [595]	validation_0-aucpr:0.76782	validation_0-auc:0.77478
# [596]	validation_0-aucpr:0.76784	validation_0-auc:0.77480
# [597]	validation_0-aucpr:0.76783	validation_0-auc:0.77481
# [598]	validation_0-aucpr:0.76784	validation_0-auc:0.77482
# [599]	validation_0-aucpr:0.76783	validation_0-auc:0.77481
# [600]	validation_0-aucpr:0.76777	validation_0-auc:0.77480
# [601]	validation_0-aucpr:0.76778	validation_0-auc:0.77482
# [602]	validation_0-aucpr:0.76778	validation_0-auc:0.77483
# [603]	validation_0-aucpr:0.76782	validation_0-auc:0.77486
# [604]	validation_0-aucpr:0.76784	validation_0-auc:0.77488
# [605]	validation_0-aucpr:0.76789	validation_0-auc:0.77491
# [606]	validation_0-aucpr:0.76786	validation_0-auc:0.77492
# [607]	validation_0-aucpr:0.76789	validation_0-auc:0.77493
# [608]	validation_0-aucpr:0.76792	validation_0-auc:0.77496
# [609]	validation_0-aucpr:0.76793	validation_0-auc:0.77497
# [610]	validation_0-aucpr:0.76800	validation_0-auc:0.77500
# [611]	validation_0-aucpr:0.76801	validation_0-auc:0.77502
# [612]	validation_0-aucpr:0.76804	validation_0-auc:0.77503
# [613]	validation_0-aucpr:0.76805	validation_0-auc:0.77506
# [614]	validation_0-aucpr:0.76804	validation_0-auc:0.77506
# [615]	validation_0-aucpr:0.76805	validation_0-auc:0.77510
# [616]	validation_0-aucpr:0.76808	validation_0-auc:0.77512
# [617]	validation_0-aucpr:0.76807	validation_0-auc:0.77512
# [618]	validation_0-aucpr:0.76811	validation_0-auc:0.77517
# [619]	validation_0-aucpr:0.76813	validation_0-auc:0.77518
# [620]	validation_0-aucpr:0.76816	validation_0-auc:0.77521
# [621]	validation_0-aucpr:0.76817	validation_0-auc:0.77521
# [622]	validation_0-aucpr:0.76816	validation_0-auc:0.77523
# [623]	validation_0-aucpr:0.76820	validation_0-auc:0.77525
# [624]	validation_0-aucpr:0.76823	validation_0-auc:0.77525
# [625]	validation_0-aucpr:0.76825	validation_0-auc:0.77528
# [626]	validation_0-aucpr:0.76825	validation_0-auc:0.77530
# [627]	validation_0-aucpr:0.76828	validation_0-auc:0.77533
# [628]	validation_0-aucpr:0.76829	validation_0-auc:0.77533
# [629]	validation_0-aucpr:0.76833	validation_0-auc:0.77537
# [630]	validation_0-aucpr:0.76833	validation_0-auc:0.77539
# [631]	validation_0-aucpr:0.76833	validation_0-auc:0.77540
# [632]	validation_0-aucpr:0.76834	validation_0-auc:0.77540
# [633]	validation_0-aucpr:0.76832	validation_0-auc:0.77538
# [634]	validation_0-aucpr:0.76837	validation_0-auc:0.77542
# [635]	validation_0-aucpr:0.76836	validation_0-auc:0.77544
# [636]	validation_0-aucpr:0.76837	validation_0-auc:0.77545
# [637]	validation_0-aucpr:0.76832	validation_0-auc:0.77544
# [638]	validation_0-aucpr:0.76831	validation_0-auc:0.77545
# [639]	validation_0-aucpr:0.76834	validation_0-auc:0.77548
# [640]	validation_0-aucpr:0.76836	validation_0-auc:0.77551
# [641]	validation_0-aucpr:0.76838	validation_0-auc:0.77553
# [642]	validation_0-aucpr:0.76839	validation_0-auc:0.77555
# [643]	validation_0-aucpr:0.76835	validation_0-auc:0.77556
# [644]	validation_0-aucpr:0.76832	validation_0-auc:0.77555
# [645]	validation_0-aucpr:0.76831	validation_0-auc:0.77556
# [646]	validation_0-aucpr:0.76835	validation_0-auc:0.77555
# [647]	validation_0-aucpr:0.76839	validation_0-auc:0.77557
# [648]	validation_0-aucpr:0.76841	validation_0-auc:0.77560
# [649]	validation_0-aucpr:0.76846	validation_0-auc:0.77563
# [650]	validation_0-aucpr:0.76847	validation_0-auc:0.77564
# [651]	validation_0-aucpr:0.76846	validation_0-auc:0.77563
# [652]	validation_0-aucpr:0.76844	validation_0-auc:0.77563
# [653]	validation_0-aucpr:0.76847	validation_0-auc:0.77564
# [654]	validation_0-aucpr:0.76849	validation_0-auc:0.77565
# [655]	validation_0-aucpr:0.76848	validation_0-auc:0.77564
# [656]	validation_0-aucpr:0.76848	validation_0-auc:0.77566
# [657]	validation_0-aucpr:0.76846	validation_0-auc:0.77564
# [658]	validation_0-aucpr:0.76850	validation_0-auc:0.77566
# [659]	validation_0-aucpr:0.76852	validation_0-auc:0.77565
# [660]	validation_0-aucpr:0.76855	validation_0-auc:0.77568
# [661]	validation_0-aucpr:0.76856	validation_0-auc:0.77568
# [662]	validation_0-aucpr:0.76857	validation_0-auc:0.77569
# [663]	validation_0-aucpr:0.76857	validation_0-auc:0.77569
# [664]	validation_0-aucpr:0.76855	validation_0-auc:0.77569
# [665]	validation_0-aucpr:0.76853	validation_0-auc:0.77571
# [666]	validation_0-aucpr:0.76858	validation_0-auc:0.77573
# [667]	validation_0-aucpr:0.76857	validation_0-auc:0.77573
# [668]	validation_0-aucpr:0.76858	validation_0-auc:0.77575
# [669]	validation_0-aucpr:0.76853	validation_0-auc:0.77576
# [670]	validation_0-aucpr:0.76854	validation_0-auc:0.77577
# [671]	validation_0-aucpr:0.76859	validation_0-auc:0.77579
# [672]	validation_0-aucpr:0.76860	validation_0-auc:0.77579
# [673]	validation_0-aucpr:0.76861	validation_0-auc:0.77580
# [674]	validation_0-aucpr:0.76860	validation_0-auc:0.77582
# [675]	validation_0-aucpr:0.76860	validation_0-auc:0.77584
# [676]	validation_0-aucpr:0.76862	validation_0-auc:0.77587
# [677]	validation_0-aucpr:0.76864	validation_0-auc:0.77588
# [678]	validation_0-aucpr:0.76866	validation_0-auc:0.77590
# [679]	validation_0-aucpr:0.76871	validation_0-auc:0.77592
# [680]	validation_0-aucpr:0.76872	validation_0-auc:0.77592
# [681]	validation_0-aucpr:0.76873	validation_0-auc:0.77593
# [682]	validation_0-aucpr:0.76872	validation_0-auc:0.77593
# [683]	validation_0-aucpr:0.76871	validation_0-auc:0.77594
# [684]	validation_0-aucpr:0.76873	validation_0-auc:0.77597
# [685]	validation_0-aucpr:0.76879	validation_0-auc:0.77599
# [686]	validation_0-aucpr:0.76880	validation_0-auc:0.77600
# [687]	validation_0-aucpr:0.76880	validation_0-auc:0.77600
# [688]	validation_0-aucpr:0.76880	validation_0-auc:0.77602
# [689]	validation_0-aucpr:0.76883	validation_0-auc:0.77604
# [690]	validation_0-aucpr:0.76884	validation_0-auc:0.77604
# [691]	validation_0-aucpr:0.76889	validation_0-auc:0.77607
# [692]	validation_0-aucpr:0.76891	validation_0-auc:0.77608
# [693]	validation_0-aucpr:0.76888	validation_0-auc:0.77609
# [694]	validation_0-aucpr:0.76888	validation_0-auc:0.77610
# [695]	validation_0-aucpr:0.76891	validation_0-auc:0.77613
# [696]	validation_0-aucpr:0.76892	validation_0-auc:0.77614
# [697]	validation_0-aucpr:0.76888	validation_0-auc:0.77611
# [698]	validation_0-aucpr:0.76890	validation_0-auc:0.77613
# [699]	validation_0-aucpr:0.76892	validation_0-auc:0.77615
# [700]	validation_0-aucpr:0.76888	validation_0-auc:0.77614
# [701]	validation_0-aucpr:0.76889	validation_0-auc:0.77616
# [702]	validation_0-aucpr:0.76893	validation_0-auc:0.77620
# [703]	validation_0-aucpr:0.76889	validation_0-auc:0.77620
# [704]	validation_0-aucpr:0.76895	validation_0-auc:0.77624
# [705]	validation_0-aucpr:0.76897	validation_0-auc:0.77625
# [706]	validation_0-aucpr:0.76898	validation_0-auc:0.77625
# [707]	validation_0-aucpr:0.76898	validation_0-auc:0.77626
# [708]	validation_0-aucpr:0.76894	validation_0-auc:0.77626
# [709]	validation_0-aucpr:0.76891	validation_0-auc:0.77625
# [710]	validation_0-aucpr:0.76893	validation_0-auc:0.77627
# [711]	validation_0-aucpr:0.76886	validation_0-auc:0.77628
# [712]	validation_0-aucpr:0.76887	validation_0-auc:0.77629
# [713]	validation_0-aucpr:0.76885	validation_0-auc:0.77628
# [714]	validation_0-aucpr:0.76884	validation_0-auc:0.77627
# [715]	validation_0-aucpr:0.76885	validation_0-auc:0.77629
# [716]	validation_0-aucpr:0.76886	validation_0-auc:0.77630
# [717]	validation_0-aucpr:0.76890	validation_0-auc:0.77632
# [718]	validation_0-aucpr:0.76899	validation_0-auc:0.77634
# [719]	validation_0-aucpr:0.76904	validation_0-auc:0.77637
# [720]	validation_0-aucpr:0.76902	validation_0-auc:0.77635
# [721]	validation_0-aucpr:0.76906	validation_0-auc:0.77638
# [722]	validation_0-aucpr:0.76909	validation_0-auc:0.77639
# [723]	validation_0-aucpr:0.76913	validation_0-auc:0.77641
# [724]	validation_0-aucpr:0.76917	validation_0-auc:0.77643
# [725]	validation_0-aucpr:0.76917	validation_0-auc:0.77644
# [726]	validation_0-aucpr:0.76915	validation_0-auc:0.77643
# [727]	validation_0-aucpr:0.76917	validation_0-auc:0.77644
# [728]	validation_0-aucpr:0.76917	validation_0-auc:0.77644
# [729]	validation_0-aucpr:0.76916	validation_0-auc:0.77645
# [730]	validation_0-aucpr:0.76917	validation_0-auc:0.77646
# [731]	validation_0-aucpr:0.76913	validation_0-auc:0.77647
# [732]	validation_0-aucpr:0.76918	validation_0-auc:0.77649
# [733]	validation_0-aucpr:0.76916	validation_0-auc:0.77651
# [734]	validation_0-aucpr:0.76918	validation_0-auc:0.77653
# [735]	validation_0-aucpr:0.76915	validation_0-auc:0.77651
# [736]	validation_0-aucpr:0.76913	validation_0-auc:0.77650
# [737]	validation_0-aucpr:0.76913	validation_0-auc:0.77652
# [738]	validation_0-aucpr:0.76914	validation_0-auc:0.77652
# [739]	validation_0-aucpr:0.76916	validation_0-auc:0.77651
# [740]	validation_0-aucpr:0.76916	validation_0-auc:0.77652
# [741]	validation_0-aucpr:0.76915	validation_0-auc:0.77652
# [742]	validation_0-aucpr:0.76915	validation_0-auc:0.77652
# [743]	validation_0-aucpr:0.76915	validation_0-auc:0.77652
# [744]	validation_0-aucpr:0.76918	validation_0-auc:0.77653
# [745]	validation_0-aucpr:0.76920	validation_0-auc:0.77654
# [746]	validation_0-aucpr:0.76925	validation_0-auc:0.77656
# [747]	validation_0-aucpr:0.76926	validation_0-auc:0.77658
# [748]	validation_0-aucpr:0.76927	validation_0-auc:0.77658
# [749]	validation_0-aucpr:0.76925	validation_0-auc:0.77657
# [750]	validation_0-aucpr:0.76930	validation_0-auc:0.77660
# [751]	validation_0-aucpr:0.76930	validation_0-auc:0.77659
# [752]	validation_0-aucpr:0.76934	validation_0-auc:0.77663
# [753]	validation_0-aucpr:0.76940	validation_0-auc:0.77663
# [754]	validation_0-aucpr:0.76941	validation_0-auc:0.77665
# [755]	validation_0-aucpr:0.76943	validation_0-auc:0.77668
# [756]	validation_0-aucpr:0.76942	validation_0-auc:0.77672
# [757]	validation_0-aucpr:0.76944	validation_0-auc:0.77672
# [758]	validation_0-aucpr:0.76943	validation_0-auc:0.77673
# [759]	validation_0-aucpr:0.76941	validation_0-auc:0.77671
# [760]	validation_0-aucpr:0.76944	validation_0-auc:0.77672
# [761]	validation_0-aucpr:0.76945	validation_0-auc:0.77673
# [762]	validation_0-aucpr:0.76947	validation_0-auc:0.77673
# [763]	validation_0-aucpr:0.76946	validation_0-auc:0.77674
# [764]	validation_0-aucpr:0.76950	validation_0-auc:0.77678
# [765]	validation_0-aucpr:0.76950	validation_0-auc:0.77680
# [766]	validation_0-aucpr:0.76951	validation_0-auc:0.77681
# [767]	validation_0-aucpr:0.76951	validation_0-auc:0.77681
# [768]	validation_0-aucpr:0.76953	validation_0-auc:0.77682
# [769]	validation_0-aucpr:0.76955	validation_0-auc:0.77683
# [770]	validation_0-aucpr:0.76951	validation_0-auc:0.77681
# [771]	validation_0-aucpr:0.76951	validation_0-auc:0.77680
# [772]	validation_0-aucpr:0.76950	validation_0-auc:0.77680
# [773]	validation_0-aucpr:0.76955	validation_0-auc:0.77681
# [774]	validation_0-aucpr:0.76952	validation_0-auc:0.77679
# [775]	validation_0-aucpr:0.76946	validation_0-auc:0.77679
# [776]	validation_0-aucpr:0.76948	validation_0-auc:0.77680
# [777]	validation_0-aucpr:0.76949	validation_0-auc:0.77680
# [778]	validation_0-aucpr:0.76950	validation_0-auc:0.77682
# [779]	validation_0-aucpr:0.76953	validation_0-auc:0.77683
# [780]	validation_0-aucpr:0.76954	validation_0-auc:0.77685
# [781]	validation_0-aucpr:0.76955	validation_0-auc:0.77687
# [782]	validation_0-aucpr:0.76954	validation_0-auc:0.77687
# [783]	validation_0-aucpr:0.76954	validation_0-auc:0.77687
# [784]	validation_0-aucpr:0.76955	validation_0-auc:0.77688
# [785]	validation_0-aucpr:0.76957	validation_0-auc:0.77689
# [786]	validation_0-aucpr:0.76956	validation_0-auc:0.77690
# [787]	validation_0-aucpr:0.76959	validation_0-auc:0.77691
# [788]	validation_0-aucpr:0.76960	validation_0-auc:0.77693
# [789]	validation_0-aucpr:0.76961	validation_0-auc:0.77694
# [790]	validation_0-aucpr:0.76962	validation_0-auc:0.77695
# [791]	validation_0-aucpr:0.76962	validation_0-auc:0.77695
# [792]	validation_0-aucpr:0.76962	validation_0-auc:0.77696
# [793]	validation_0-aucpr:0.76965	validation_0-auc:0.77698
# [794]	validation_0-aucpr:0.76962	validation_0-auc:0.77699
# [795]	validation_0-aucpr:0.76965	validation_0-auc:0.77700
# [796]	validation_0-aucpr:0.76967	validation_0-auc:0.77702
# [797]	validation_0-aucpr:0.76967	validation_0-auc:0.77701
# [798]	validation_0-aucpr:0.76969	validation_0-auc:0.77702
# [799]	validation_0-aucpr:0.76972	validation_0-auc:0.77704
# [800]	validation_0-aucpr:0.76973	validation_0-auc:0.77707
# [801]	validation_0-aucpr:0.76975	validation_0-auc:0.77710
# [802]	validation_0-aucpr:0.76973	validation_0-auc:0.77709
# [803]	validation_0-aucpr:0.76976	validation_0-auc:0.77711
# [804]	validation_0-aucpr:0.76976	validation_0-auc:0.77712
# [805]	validation_0-aucpr:0.76980	validation_0-auc:0.77714
# [806]	validation_0-aucpr:0.76979	validation_0-auc:0.77711
# [807]	validation_0-aucpr:0.76982	validation_0-auc:0.77712
# [808]	validation_0-aucpr:0.76983	validation_0-auc:0.77713
# [809]	validation_0-aucpr:0.76984	validation_0-auc:0.77713
# [810]	validation_0-aucpr:0.76978	validation_0-auc:0.77713
# [811]	validation_0-aucpr:0.76982	validation_0-auc:0.77715
# [812]	validation_0-aucpr:0.76988	validation_0-auc:0.77719
# [813]	validation_0-aucpr:0.76990	validation_0-auc:0.77720
# [814]	validation_0-aucpr:0.76991	validation_0-auc:0.77720
# [815]	validation_0-aucpr:0.76990	validation_0-auc:0.77721
# [816]	validation_0-aucpr:0.76987	validation_0-auc:0.77721
# [817]	validation_0-aucpr:0.76987	validation_0-auc:0.77722
# [818]	validation_0-aucpr:0.76993	validation_0-auc:0.77727
# [819]	validation_0-aucpr:0.76994	validation_0-auc:0.77727
# [820]	validation_0-aucpr:0.76995	validation_0-auc:0.77727
# [821]	validation_0-aucpr:0.76994	validation_0-auc:0.77729
# [822]	validation_0-aucpr:0.76996	validation_0-auc:0.77732
# [823]	validation_0-aucpr:0.76998	validation_0-auc:0.77733
# [824]	validation_0-aucpr:0.76997	validation_0-auc:0.77732
# [825]	validation_0-aucpr:0.77001	validation_0-auc:0.77734
# [826]	validation_0-aucpr:0.77002	validation_0-auc:0.77733
# [827]	validation_0-aucpr:0.77005	validation_0-auc:0.77736
# [828]	validation_0-aucpr:0.77004	validation_0-auc:0.77736
# ...
# [1788]	validation_0-aucpr:0.77258	validation_0-auc:0.78078
# [1789]	validation_0-aucpr:0.77256	validation_0-auc:0.78077
# [1790]	validation_0-aucpr:0.77256	validation_0-auc:0.78079
# [1791]	validation_0-aucpr:0.77257	validation_0-auc:0.78081
# [1792]	validation_0-aucpr:0.77256	validation_0-auc:0.78080
# [1793]	validation_0-aucpr:0.77258	validation_0-auc:0.78081
# [1794]	validation_0-aucpr:0.77258	validation_0-auc:0.78080
# [1795]	validation_0-aucpr:0.77257	validation_0-auc:0.78081
# [1796]	validation_0-aucpr:0.77259	validation_0-auc:0.78083
# [1797]	validation_0-aucpr:0.77259	validation_0-auc:0.78082
# [1798]	validation_0-aucpr:0.77258	validation_0-auc:0.78082
# [1799]	validation_0-aucpr:0.77261	validation_0-auc:0.78083
# [1800]	validation_0-aucpr:0.77259	validation_0-auc:0.78082
# [1801]	validation_0-aucpr:0.77256	validation_0-auc:0.78081
# [1802]	validation_0-aucpr:0.77259	validation_0-auc:0.78082
# [1803]	validation_0-aucpr:0.77259	validation_0-auc:0.78082
# [1804]	validation_0-aucpr:0.77258	validation_0-auc:0.78081
# [1805]	validation_0-aucpr:0.77256	validation_0-auc:0.78081
# [1806]	validation_0-aucpr:0.77257	validation_0-auc:0.78082
# [1807]	validation_0-aucpr:0.77256	validation_0-auc:0.78082
# [1808]	validation_0-aucpr:0.77258	validation_0-auc:0.78082
# [1809]	validation_0-aucpr:0.77258	validation_0-auc:0.78082
# [1810]	validation_0-aucpr:0.77256	validation_0-auc:0.78082
# [1811]	validation_0-aucpr:0.77254	validation_0-auc:0.78080
# [1812]	validation_0-aucpr:0.77252	validation_0-auc:0.78080
# [1813]	validation_0-aucpr:0.77252	validation_0-auc:0.78081
# [1814]	validation_0-aucpr:0.77250	validation_0-auc:0.78081
# [1815]	validation_0-aucpr:0.77248	validation_0-auc:0.78080
# [1816]	validation_0-aucpr:0.77249	validation_0-auc:0.78081
# [1817]	validation_0-aucpr:0.77249	validation_0-auc:0.78081
# [1818]	validation_0-aucpr:0.77249	validation_0-auc:0.78080
# [1819]	validation_0-aucpr:0.77250	validation_0-auc:0.78081
# [1820]	validation_0-aucpr:0.77249	validation_0-auc:0.78080
# [1821]	validation_0-aucpr:0.77249	validation_0-auc:0.78080
# [1822]	validation_0-aucpr:0.77249	validation_0-auc:0.78081
# [1823]	validation_0-aucpr:0.77250	validation_0-auc:0.78081
# [1824]	validation_0-aucpr:0.77249	validation_0-auc:0.78081
# [1825]	validation_0-aucpr:0.77248	validation_0-auc:0.78080
# [1826]	validation_0-aucpr:0.77246	validation_0-auc:0.78080
# [1827]	validation_0-aucpr:0.77244	validation_0-auc:0.78078
# [1828]	validation_0-aucpr:0.77244	validation_0-auc:0.78079
# [1829]	validation_0-aucpr:0.77243	validation_0-auc:0.78079
# [1830]	validation_0-aucpr:0.77243	validation_0-auc:0.78080
# [1831]	validation_0-aucpr:0.77241	validation_0-auc:0.78078
# [1832]	validation_0-aucpr:0.77240	validation_0-auc:0.78079
# [1833]	validation_0-aucpr:0.77240	validation_0-auc:0.78079
# [1834]	validation_0-aucpr:0.77239	validation_0-auc:0.78079
# [1835]	validation_0-aucpr:0.77237	validation_0-auc:0.78078
# [1836]	validation_0-aucpr:0.77237	validation_0-auc:0.78079
# [1837]	validation_0-aucpr:0.77237	validation_0-auc:0.78079
# [1838]	validation_0-aucpr:0.77237	validation_0-auc:0.78079
# [1839]	validation_0-aucpr:0.77239	validation_0-auc:0.78080
# [1840]	validation_0-aucpr:0.77238	validation_0-auc:0.78079
# [1841]	validation_0-aucpr:0.77241	validation_0-auc:0.78081
# [1842]	validation_0-aucpr:0.77241	validation_0-auc:0.78082
# [1843]	validation_0-aucpr:0.77242	validation_0-auc:0.78083
# [1844]	validation_0-aucpr:0.77245	validation_0-auc:0.78084
# [1845]	validation_0-aucpr:0.77247	validation_0-auc:0.78085
# [1846]	validation_0-aucpr:0.77247	validation_0-auc:0.78085
# [1847]	validation_0-aucpr:0.77247	validation_0-auc:0.78085
# [1848]	validation_0-aucpr:0.77245	validation_0-auc:0.78084
# [1849]	validation_0-aucpr:0.77246	validation_0-auc:0.78085
# [1850]	validation_0-aucpr:0.77245	validation_0-auc:0.78085
# [1851]	validation_0-aucpr:0.77244	validation_0-auc:0.78084
# [1852]	validation_0-aucpr:0.77244	validation_0-auc:0.78082
# [1853]	validation_0-aucpr:0.77245	validation_0-auc:0.78083
# [1854]	validation_0-aucpr:0.77243	validation_0-auc:0.78084
# [1855]	validation_0-aucpr:0.77244	validation_0-auc:0.78084
# [1856]	validation_0-aucpr:0.77244	validation_0-auc:0.78084
# [1857]	validation_0-aucpr:0.77242	validation_0-auc:0.78082
# [1858]	validation_0-aucpr:0.77243	validation_0-auc:0.78082
# [1859]	validation_0-aucpr:0.77242	validation_0-auc:0.78082
# [1860]	validation_0-aucpr:0.77241	validation_0-auc:0.78079
# [1861]	validation_0-aucpr:0.77237	validation_0-auc:0.78078
# [1862]	validation_0-aucpr:0.77238	validation_0-auc:0.78078
# [1863]	validation_0-aucpr:0.77239	validation_0-auc:0.78080
# [1864]	validation_0-aucpr:0.77240	validation_0-auc:0.78080
# [1865]	validation_0-aucpr:0.77240	validation_0-auc:0.78080
# [1866]	validation_0-aucpr:0.77240	validation_0-auc:0.78080
# [1867]	validation_0-aucpr:0.77239	validation_0-auc:0.78079
# [1868]	validation_0-aucpr:0.77239	validation_0-auc:0.78078
# [1869]	validation_0-aucpr:0.77238	validation_0-auc:0.78079
# [1870]	validation_0-aucpr:0.77236	validation_0-auc:0.78077
# [1871]	validation_0-aucpr:0.77235	validation_0-auc:0.78076
# [1872]	validation_0-aucpr:0.77236	validation_0-auc:0.78075
# [1873]	validation_0-aucpr:0.77236	validation_0-auc:0.78074
# [1874]	validation_0-aucpr:0.77234	validation_0-auc:0.78074
# [1875]	validation_0-aucpr:0.77234	validation_0-auc:0.78075
# [1876]	validation_0-aucpr:0.77234	validation_0-auc:0.78076
# [1877]	validation_0-aucpr:0.77233	validation_0-auc:0.78076
# [1878]	validation_0-aucpr:0.77236	validation_0-auc:0.78079
# [1879]	validation_0-aucpr:0.77237	validation_0-auc:0.78080
# [1880]	validation_0-aucpr:0.77237	validation_0-auc:0.78079
# [1881]	validation_0-aucpr:0.77233	validation_0-auc:0.78079
# [1882]	validation_0-aucpr:0.77236	validation_0-auc:0.78077
# [1883]	validation_0-aucpr:0.77236	validation_0-auc:0.78078
# [1884]	validation_0-aucpr:0.77236	validation_0-auc:0.78078
# [1885]	validation_0-aucpr:0.77237	validation_0-auc:0.78078
# [1886]	validation_0-aucpr:0.77236	validation_0-auc:0.78076
# [1887]	validation_0-aucpr:0.77236	validation_0-auc:0.78077
# [1888]	validation_0-aucpr:0.77239	validation_0-auc:0.78076
# [1889]	validation_0-aucpr:0.77238	validation_0-auc:0.78076
# [1890]	validation_0-aucpr:0.77237	validation_0-auc:0.78076
# [1891]	validation_0-aucpr:0.77237	validation_0-auc:0.78077
# [1892]	validation_0-aucpr:0.77237	validation_0-auc:0.78077
# [1893]	validation_0-aucpr:0.77236	validation_0-auc:0.78077
# [1894]	validation_0-aucpr:0.77237	validation_0-auc:0.78077
# [1895]	validation_0-aucpr:0.77236	validation_0-auc:0.78077
# [1896]	validation_0-aucpr:0.77235	validation_0-auc:0.78075
# [1897]	validation_0-aucpr:0.77234	validation_0-auc:0.78075
# [1898]	validation_0-aucpr:0.77234	validation_0-auc:0.78076
# [1899]	validation_0-aucpr:0.77235	validation_0-auc:0.78075
# [1900]	validation_0-aucpr:0.77234	validation_0-auc:0.78075
# [1901]	validation_0-aucpr:0.77232	validation_0-auc:0.78075
# [1902]	validation_0-aucpr:0.77234	validation_0-auc:0.78076
# [1903]	validation_0-aucpr:0.77231	validation_0-auc:0.78074
# [1904]	validation_0-aucpr:0.77230	validation_0-auc:0.78074
# [1905]	validation_0-aucpr:0.77230	validation_0-auc:0.78074
# [1906]	validation_0-aucpr:0.77231	validation_0-auc:0.78074
# [1907]	validation_0-aucpr:0.77231	validation_0-auc:0.78074
# [1908]	validation_0-aucpr:0.77230	validation_0-auc:0.78073
# [1909]	validation_0-aucpr:0.77229	validation_0-auc:0.78073
# [1910]	validation_0-aucpr:0.77227	validation_0-auc:0.78074
# [1911]	validation_0-aucpr:0.77227	validation_0-auc:0.78074
# [1912]	validation_0-aucpr:0.77228	validation_0-auc:0.78074
# [1913]	validation_0-aucpr:0.77229	validation_0-auc:0.78074
# [1914]	validation_0-aucpr:0.77227	validation_0-auc:0.78074
# [1915]	validation_0-aucpr:0.77227	validation_0-auc:0.78073
# [1916]	validation_0-aucpr:0.77228	validation_0-auc:0.78073
# [1917]	validation_0-aucpr:0.77226	validation_0-auc:0.78073
# [1918]	validation_0-aucpr:0.77226	validation_0-auc:0.78073
# [1919]	validation_0-aucpr:0.77226	validation_0-auc:0.78073
# [1920]	validation_0-aucpr:0.77226	validation_0-auc:0.78073
# [1921]	validation_0-aucpr:0.77228	validation_0-auc:0.78074
# [1922]	validation_0-aucpr:0.77228	validation_0-auc:0.78075
# [1923]	validation_0-aucpr:0.77224	validation_0-auc:0.78074
# [1924]	validation_0-aucpr:0.77225	validation_0-auc:0.78074
# [1925]	validation_0-aucpr:0.77223	validation_0-auc:0.78073
# [1926]	validation_0-aucpr:0.77227	validation_0-auc:0.78074
# [1927]	validation_0-aucpr:0.77230	validation_0-auc:0.78076
# [1928]	validation_0-aucpr:0.77227	validation_0-auc:0.78074
# [1929]	validation_0-aucpr:0.77227	validation_0-auc:0.78074
# [1930]	validation_0-aucpr:0.77227	validation_0-auc:0.78075
# [1931]	validation_0-aucpr:0.77227	validation_0-auc:0.78076
# [1932]	validation_0-aucpr:0.77227	validation_0-auc:0.78075
# [1933]	validation_0-aucpr:0.77226	validation_0-auc:0.78076
# [1934]	validation_0-aucpr:0.77225	validation_0-auc:0.78075
# [1935]	validation_0-aucpr:0.77223	validation_0-auc:0.78076
# [1936]	validation_0-aucpr:0.77222	validation_0-auc:0.78075
# [1937]	validation_0-aucpr:0.77221	validation_0-auc:0.78075
# [1938]	validation_0-aucpr:0.77222	validation_0-auc:0.78076
# [1939]	validation_0-aucpr:0.77222	validation_0-auc:0.78075
# [1940]	validation_0-aucpr:0.77223	validation_0-auc:0.78074
# [1941]	validation_0-aucpr:0.77223	validation_0-auc:0.78075
# [1942]	validation_0-aucpr:0.77223	validation_0-auc:0.78074
# [1943]	validation_0-aucpr:0.77223	validation_0-auc:0.78074
# [1944]	validation_0-aucpr:0.77222	validation_0-auc:0.78073
# [1945]	validation_0-aucpr:0.77222	validation_0-auc:0.78072
# [1946]	validation_0-aucpr:0.77220	validation_0-auc:0.78071
# [1947]	validation_0-aucpr:0.77219	validation_0-auc:0.78070
# [1948]	validation_0-aucpr:0.77219	validation_0-auc:0.78070
# [1949]	validation_0-aucpr:0.77219	validation_0-auc:0.78069
# [1950]	validation_0-aucpr:0.77219	validation_0-auc:0.78069
# [1951]	validation_0-aucpr:0.77219	validation_0-auc:0.78068
# [1952]	validation_0-aucpr:0.77220	validation_0-auc:0.78069
# [1953]	validation_0-aucpr:0.77220	validation_0-auc:0.78070
# [1954]	validation_0-aucpr:0.77220	validation_0-auc:0.78070
# [1955]	validation_0-aucpr:0.77218	validation_0-auc:0.78069
# [1956]	validation_0-aucpr:0.77216	validation_0-auc:0.78069
# [1957]	validation_0-aucpr:0.77217	validation_0-auc:0.78070
# [1958]	validation_0-aucpr:0.77215	validation_0-auc:0.78071
# [1959]	validation_0-aucpr:0.77215	validation_0-auc:0.78070
# [1960]	validation_0-aucpr:0.77215	validation_0-auc:0.78070
# [1961]	validation_0-aucpr:0.77214	validation_0-auc:0.78070
# [1962]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1963]	validation_0-aucpr:0.77215	validation_0-auc:0.78071
# [1964]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1965]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1966]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1967]	validation_0-aucpr:0.77214	validation_0-auc:0.78072
# [1968]	validation_0-aucpr:0.77214	validation_0-auc:0.78071
# [1969]	validation_0-aucpr:0.77213	validation_0-auc:0.78071
# [1970]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1971]	validation_0-aucpr:0.77212	validation_0-auc:0.78070
# [1972]	validation_0-aucpr:0.77212	validation_0-auc:0.78070
# [1973]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1974]	validation_0-aucpr:0.77213	validation_0-auc:0.78070
# [1975]	validation_0-aucpr:0.77214	validation_0-auc:0.78071
# [1976]	validation_0-aucpr:0.77216	validation_0-auc:0.78073
# [1977]	validation_0-aucpr:0.77215	validation_0-auc:0.78071
# [1978]	validation_0-aucpr:0.77214	validation_0-auc:0.78071
# [1979]	validation_0-aucpr:0.77214	validation_0-auc:0.78071
# [1980]	validation_0-aucpr:0.77213	validation_0-auc:0.78069
# [1981]	validation_0-aucpr:0.77213	validation_0-auc:0.78069
# [1982]	validation_0-aucpr:0.77212	validation_0-auc:0.78069
# [1983]	validation_0-aucpr:0.77212	validation_0-auc:0.78069
# [1984]	validation_0-aucpr:0.77213	validation_0-auc:0.78069
# [1985]	validation_0-aucpr:0.77212	validation_0-auc:0.78069
# [1986]	validation_0-aucpr:0.77214	validation_0-auc:0.78070
# [1987]	validation_0-aucpr:0.77214	validation_0-auc:0.78070
# [1988]	validation_0-aucpr:0.77214	validation_0-auc:0.78070
# [1989]	validation_0-aucpr:0.77218	validation_0-auc:0.78072
# [1990]	validation_0-aucpr:0.77217	validation_0-auc:0.78071
# [1991]	validation_0-aucpr:0.77216	validation_0-auc:0.78071
# [1992]	validation_0-aucpr:0.77216	validation_0-auc:0.78071
# [1993]	validation_0-aucpr:0.77219	validation_0-auc:0.78071
# [1994]	validation_0-aucpr:0.77217	validation_0-auc:0.78070
# [1995]	validation_0-aucpr:0.77219	validation_0-auc:0.78069
# [1996]	validation_0-aucpr:0.77219	validation_0-auc:0.78070
# [1997]	validation_0-aucpr:0.77218	validation_0-auc:0.78069
# [1998]	validation_0-aucpr:0.77216	validation_0-auc:0.78069
# [1999]	validation_0-aucpr:0.77217	validation_0-auc:0.78070
# [2000]	validation_0-aucpr:0.77216	validation_0-auc:0.78070
# [2001]	validation_0-aucpr:0.77216	validation_0-auc:0.78070
# [2002]	validation_0-aucpr:0.77215	validation_0-auc:0.78069
# [2003]	validation_0-aucpr:0.77214	validation_0-auc:0.78069
# [2004]	validation_0-aucpr:0.77211	validation_0-auc:0.78068
# [2005]	validation_0-aucpr:0.77211	validation_0-auc:0.78067
# [2006]	validation_0-aucpr:0.77211	validation_0-auc:0.78067
# [2007]	validation_0-aucpr:0.77211	validation_0-auc:0.78067
# [2008]	validation_0-aucpr:0.77209	validation_0-auc:0.78067
# [2009]	validation_0-aucpr:0.77207	validation_0-auc:0.78065
# [2010]	validation_0-aucpr:0.77208	validation_0-auc:0.78066
# [2011]	validation_0-aucpr:0.77209	validation_0-auc:0.78065
# [2012]	validation_0-aucpr:0.77209	validation_0-auc:0.78065
# [2013]	validation_0-aucpr:0.77209	validation_0-auc:0.78066
# [2014]	validation_0-aucpr:0.77209	validation_0-auc:0.78066
# [2015]	validation_0-aucpr:0.77210	validation_0-auc:0.78067
# [2016]	validation_0-aucpr:0.77211	validation_0-auc:0.78067
# [2017]	validation_0-aucpr:0.77212	validation_0-auc:0.78067
# [2018]	validation_0-aucpr:0.77211	validation_0-auc:0.78068
# [2019]	validation_0-aucpr:0.77213	validation_0-auc:0.78068
# [2020]	validation_0-aucpr:0.77213	validation_0-auc:0.78068
# [2021]	validation_0-aucpr:0.77210	validation_0-auc:0.78067
# [2022]	validation_0-aucpr:0.77212	validation_0-auc:0.78067
# [2023]	validation_0-aucpr:0.77214	validation_0-auc:0.78068
# [2024]	validation_0-aucpr:0.77211	validation_0-auc:0.78067
# [2025]	validation_0-aucpr:0.77210	validation_0-auc:0.78066
# [2026]	validation_0-aucpr:0.77207	validation_0-auc:0.78065
# [2027]	validation_0-aucpr:0.77207	validation_0-auc:0.78065
# [2028]	validation_0-aucpr:0.77206	validation_0-auc:0.78066
# [2029]	validation_0-aucpr:0.77208	validation_0-auc:0.78067
# [2030]	validation_0-aucpr:0.77207	validation_0-auc:0.78067
# [2031]	validation_0-aucpr:0.77207	validation_0-auc:0.78066
# [2032]	validation_0-aucpr:0.77208	validation_0-auc:0.78065
# [2033]	validation_0-aucpr:0.77208	validation_0-auc:0.78066
# [2034]	validation_0-aucpr:0.77209	validation_0-auc:0.78067
# [2035]	validation_0-aucpr:0.77209	validation_0-auc:0.78067
# [2036]	validation_0-aucpr:0.77208	validation_0-auc:0.78067
# [2037]	validation_0-aucpr:0.77207	validation_0-auc:0.78066
# [2038]	validation_0-aucpr:0.77208	validation_0-auc:0.78066
# [2039]	validation_0-aucpr:0.77209	validation_0-auc:0.78067
# [2040]	validation_0-aucpr:0.77208	validation_0-auc:0.78067
# [2041]	validation_0-aucpr:0.77208	validation_0-auc:0.78068
# [2042]	validation_0-aucpr:0.77208	validation_0-auc:0.78067
# [2043]	validation_0-aucpr:0.77209	validation_0-auc:0.78068
# [2044]	validation_0-aucpr:0.77210	validation_0-auc:0.78068
# [2045]	validation_0-aucpr:0.77209	validation_0-auc:0.78068
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.8, colsample_bynode=0.8, colsample_bytree=0.8,
#               device='cuda', early_stopping_rounds=200, enable_categorical=True,
#               eval_metric=['aucpr', 'auc'], feature_types=None,
#               feature_weights=None, gamma=0.2, grow_policy='depthwise',
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=1, max_depth=6,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=3000,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Probabilidades (idéntico conceptualmente)
y_test_proba = model.predict_proba(X_test)[:, 1]

# AUC (esto es lo importante)
auc = roc_auc_score(y_test, y_test_proba)

#optimal threshold based on expected loss
cost_FN = 10000   # default
cost_FP = 1000    # lost good client

thresholds = np.linspace(0, 1, 101)
losses = []

for t in thresholds:
    y_pred = (y_test_proba >= t).astype(int)

    FP = np.sum((y_test == 0) & (y_pred == 1))
    FN = np.sum((y_test == 1) & (y_pred == 0))

    loss = FP * cost_FP + FN * cost_FN
    losses.append(loss)

optimal_threshold = thresholds[np.argmin(losses)]

#Threshold (solo para métricas de clasificación)
adj_threshold = optimal_threshold

y_test_pred = (y_test_proba >= adj_threshold).astype(int)

# Classification report
report = classification_report(y_test, y_test_pred)

#Confusion matrix manual
TP = np.sum((y_test == 1) & (y_test_pred == 1))
FP = np.sum((y_test == 0) & (y_test_pred == 1))
TN = np.sum((y_test == 0) & (y_test_pred == 0))
FN = np.sum((y_test == 1) & (y_test_pred == 0))

FPR = FP / (FP + TN)
Precision = TP / (TP + FP)

print(f"Threshold: {optimal_threshold}")
print(f"FPR: {FPR:.4f}")
print(f"Precision (PPV): {Precision:.4f}")
print(f"AUC validación: {auc:.5f}")
print(report)

cm = confusion_matrix(y_test, y_test_pred)
print(f"\n📊 Matriz de Confusión:")
print(f"                 Predicho")
print(f"               No Def  Default")
print(f"Real No Def    {cm[0, 0]:6d}   {cm[0, 1]:6d}")
print(f"Real Default   {cm[1, 0]:6d}   {cm[1, 1]:6d}")
# Out:
# C:\Users\usuario\Desktop\4geeks\Final_Proyect_Credit_Default_Risk-main\.venv\Lib\site-packages\xgboost\core.py:774: UserWarning: [19:18:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# Threshold: 0.1
# FPR: 0.9276
# Precision (PPV): 0.5175
# AUC validación: 0.78085
#               precision    recall  f1-score   support
#
#            0       0.93      0.07      0.13      4367
#            1       0.52      0.99      0.68      4367
#
#     accuracy                           0.53      8734
#    macro avg       0.73      0.53      0.41      8734
# weighted avg       0.73      0.53      0.41      8734
#
#
# 📊 Matriz de Confusión:
#                  Predicho
#                No Def  Default
# Real No Def       316     4051
# Real Default       22     4345

# %%
df = pd.read_csv("../data/processed/home_credit_train_ready.csv")

y = df['TARGET']
X = df.drop(columns = ['TARGET', 'SK_ID_CURR'])

X.replace([np.inf, -np.inf], np.nan, inplace=True)

cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

num_imputer = SimpleImputer(strategy="constant", fill_value= 0)  #change median for mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

for col in X.select_dtypes("object"):
    X[col] = X[col].astype("category")

# Probabilidades (idéntico conceptualmente)
y_test_proba = model.predict_proba(X)[:, 1]

# AUC (esto es lo importante)
auc = roc_auc_score(y, y_test_proba)

#optimal threshold based on expected loss
cost_FN = 10000   # default
cost_FP = 1000    # lost good client

thresholds = np.linspace(0, 1, 101)
losses = []

for t in thresholds:
    y_pred = (y_test_proba >= t).astype(int)

    FP = np.sum((y == 0) & (y_pred == 1))
    FN = np.sum((y == 1) & (y_pred == 0))

    loss = FP * cost_FP + FN * cost_FN
    losses.append(loss)

optimal_threshold = thresholds[np.argmin(losses)]


#Threshold (solo para métricas de clasificación)
adj_threshold = optimal_threshold

y_test_pred = (y_test_proba >= adj_threshold).astype(int)

# Classification report
report = classification_report(y, y_test_pred)

#Confusion matrix manual
TP = np.sum((y == 1) & (y_test_pred == 1))
FP = np.sum((y == 0) & (y_test_pred == 1))
TN = np.sum((y == 0) & (y_test_pred == 0))
FN = np.sum((y == 1) & (y_test_pred == 0))

FPR = FP / (FP + TN)
Precision = TP / (TP + FP)

print(f'used threshold: {adj_threshold}')
print(f"FPR: {FPR:.4f}")
print(f"Precision (PPV): {Precision:.4f}")
print(f"AUC validación: {auc:.5f}")
print(report)

cm = confusion_matrix(y, y_test_pred)
print(f"\n📊 Matriz de Confusión:")
print(f"                 Predicho")
print(f"               No Def  Default")
print(f"Real No Def    {cm[0, 0]:6d}   {cm[0, 1]:6d}")
print(f"Real Default   {cm[1, 0]:6d}   {cm[1, 1]:6d}")
# Out:
# used threshold: 0.53
# FPR: 0.2541
# Precision (PPV): 0.2218
# AUC validación: 0.83239
#               precision    recall  f1-score   support
#
#            0       0.97      0.75      0.84    230302
#            1       0.22      0.76      0.34     21835
#
#     accuracy                           0.75    252137
#    macro avg       0.60      0.75      0.59    252137
# weighted avg       0.91      0.75      0.80    252137
#
#
# 📊 Matriz de Confusión:
#                  Predicho
#                No Def  Default
# Real No Def    171778    58524
# Real Default     5155    16680

# %%
joblib.dump(model, '../models/xgb_new_dataset.pkl')
# Out:
# ['../models/xgb_new_dataset.pkl']

# %%
58524/171778
# Out:
# 0.3406955489061463
