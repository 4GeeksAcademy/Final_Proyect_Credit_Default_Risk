# %%
import pandas as pd
from sklearn.utils import resample
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score
import numpy as np
from sklearn.impute import SimpleImputer
import joblib
from xgboost import XGBClassifier
import optuna
from optuna.samplers import TPESampler

# %%
#load dataset
df = pd.read_csv("../data/processed/home_credit_train_ready.csv")

# %%
#rebalance dataset
class_0 = df[df['TARGET'] == 0]
class_1 = df[df['TARGET'] == 1]

# balance mayority class with minority
sub_class = resample(class_0, replace=False, n_samples=len(class_1), random_state=42)

# combine
df = pd.concat([sub_class, class_1])

# %%
y = df['TARGET']
X = df.drop(columns=['TARGET', 'SK_ID_CURR'])  #adde sk_id_curr

# %%
#manages divided by 0 values
X.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
#divide categorical and numerical to impute the values
cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

num_imputer = SimpleImputer(strategy="median")  #change median for mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

# %%
#change object to category to use in the threelike model
for col in X.select_dtypes("object"):
    X[col] = X[col].astype("category")

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, stratify=y ,random_state=42)

# %%
#create params for optuna study
xgb_params = {
    # Objective y métrica
    'objective': 'binary:logistic',
    'eval_metric': ['aucpr', 'auc'],  # AUCPR es mejor para desbalanceo


    # Parámetros de boosting - MÁS AGRESIVOS
    'n_estimators': 3000,  # Reducir de 5000 (early stopping lo maneja)
    'learning_rate': 0.01,  # Más bajo = más refinado
    'max_depth': 6,  # Aumentar de 5 (más capacidad)

    # Regularización - BALANCEADA
    'min_child_weight': 5,  # Reducir de 7 (menos restrictivo)
    'gamma': 0.2,  # Reducir de 0.3
    'subsample': 0.8,  # Aumentar de 0.7
    'colsample_bytree': 0.8,  # Aumentar de 0.7
    'colsample_bylevel': 0.8,  # Aumentar de 0.7
    'colsample_bynode': 0.8,  # NUEVO: muestreo por nodo

    # Regularización L1/L2 - MÁS SUAVE
    'reg_alpha': 0.5,  # Reducir de 1.0
    'reg_lambda': 2.0,  # Reducir de 3.0

    # Parámetros adicionales IMPORTANTES
    'max_delta_step': 1,  # Ayuda con desbalanceo extremo
    'tree_method': 'hist',
    'grow_policy': 'depthwise',  # vs lossguide

    # Sampling method para desbalanceo
    'sampling_method': 'gradient_based',  # Alternativa: 'uniform'

    # Control
    'random_state': 42,
    'n_jobs': -1,
    'device': 'cuda',
    'early_stopping_rounds': 200,  # Reducir de 300 (más rápido)
    'verbosity': 1,
    'enable_categorical': True,
}

# %%
model = XGBClassifier(**xgb_params)
model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)
# Out:
# [0]	validation_0-aucpr:0.70516	validation_0-auc:0.72221
# [1]	validation_0-aucpr:0.72143	validation_0-auc:0.73423
# [2]	validation_0-aucpr:0.72325	validation_0-auc:0.73564
# [3]	validation_0-aucpr:0.72622	validation_0-auc:0.73961
# [4]	validation_0-aucpr:0.72443	validation_0-auc:0.74004
# [5]	validation_0-aucpr:0.72380	validation_0-auc:0.73975
# [6]	validation_0-aucpr:0.72342	validation_0-auc:0.74024
# [7]	validation_0-aucpr:0.72398	validation_0-auc:0.74106
# [8]	validation_0-aucpr:0.72438	validation_0-auc:0.74136
# [9]	validation_0-aucpr:0.72400	validation_0-auc:0.74091
# [10]	validation_0-aucpr:0.72470	validation_0-auc:0.74135
# [11]	validation_0-aucpr:0.72474	validation_0-auc:0.74148
# [12]	validation_0-aucpr:0.72461	validation_0-auc:0.74154
# [13]	validation_0-aucpr:0.72508	validation_0-auc:0.74212
# [14]	validation_0-aucpr:0.72520	validation_0-auc:0.74224
# [15]	validation_0-aucpr:0.72556	validation_0-auc:0.74265
# [16]	validation_0-aucpr:0.72601	validation_0-auc:0.74315
# [17]	validation_0-aucpr:0.72717	validation_0-auc:0.74298
# [18]	validation_0-aucpr:0.72674	validation_0-auc:0.74304
# [19]	validation_0-aucpr:0.72675	validation_0-auc:0.74318
# [20]	validation_0-aucpr:0.72683	validation_0-auc:0.74350
# [21]	validation_0-aucpr:0.72711	validation_0-auc:0.74373
# [22]	validation_0-aucpr:0.72736	validation_0-auc:0.74383
# [23]	validation_0-aucpr:0.72757	validation_0-auc:0.74367
# [24]	validation_0-aucpr:0.72780	validation_0-auc:0.74369
# [25]	validation_0-aucpr:0.72807	validation_0-auc:0.74350
# [26]	validation_0-aucpr:0.72771	validation_0-auc:0.74336
# [27]	validation_0-aucpr:0.72799	validation_0-auc:0.74354
# [28]	validation_0-aucpr:0.72807	validation_0-auc:0.74374
# [29]	validation_0-aucpr:0.72823	validation_0-auc:0.74392
# [30]	validation_0-aucpr:0.72807	validation_0-auc:0.74384
# [31]	validation_0-aucpr:0.72840	validation_0-auc:0.74396
# [32]	validation_0-aucpr:0.72860	validation_0-auc:0.74404
# [33]	validation_0-aucpr:0.72830	validation_0-auc:0.74416
# [34]	validation_0-aucpr:0.72860	validation_0-auc:0.74436
# [35]	validation_0-aucpr:0.72895	validation_0-auc:0.74462
# [36]	validation_0-aucpr:0.72897	validation_0-auc:0.74464
# [37]	validation_0-aucpr:0.72895	validation_0-auc:0.74465
# [38]	validation_0-aucpr:0.72916	validation_0-auc:0.74456
# [39]	validation_0-aucpr:0.72884	validation_0-auc:0.74451
# [40]	validation_0-aucpr:0.72880	validation_0-auc:0.74456
# [41]	validation_0-aucpr:0.72897	validation_0-auc:0.74466
# [42]	validation_0-aucpr:0.72932	validation_0-auc:0.74481
# [43]	validation_0-aucpr:0.72931	validation_0-auc:0.74489
# [44]	validation_0-aucpr:0.72913	validation_0-auc:0.74498
# [45]	validation_0-aucpr:0.72915	validation_0-auc:0.74515
# [46]	validation_0-aucpr:0.72912	validation_0-auc:0.74527
# [47]	validation_0-aucpr:0.72946	validation_0-auc:0.74546
# [48]	validation_0-aucpr:0.72955	validation_0-auc:0.74543
# [49]	validation_0-aucpr:0.72962	validation_0-auc:0.74551
# [50]	validation_0-aucpr:0.72992	validation_0-auc:0.74567
# [51]	validation_0-aucpr:0.73006	validation_0-auc:0.74571
# [52]	validation_0-aucpr:0.73020	validation_0-auc:0.74583
# [53]	validation_0-aucpr:0.73028	validation_0-auc:0.74605
# [54]	validation_0-aucpr:0.73045	validation_0-auc:0.74632
# [55]	validation_0-aucpr:0.73031	validation_0-auc:0.74638
# [56]	validation_0-aucpr:0.73052	validation_0-auc:0.74661
# [57]	validation_0-aucpr:0.73050	validation_0-auc:0.74669
# [58]	validation_0-aucpr:0.73088	validation_0-auc:0.74684
# [59]	validation_0-aucpr:0.73076	validation_0-auc:0.74690
# [60]	validation_0-aucpr:0.73091	validation_0-auc:0.74714
# [61]	validation_0-aucpr:0.73098	validation_0-auc:0.74726
# [62]	validation_0-aucpr:0.73146	validation_0-auc:0.74739
# [63]	validation_0-aucpr:0.73161	validation_0-auc:0.74759
# [64]	validation_0-aucpr:0.73186	validation_0-auc:0.74773
# [65]	validation_0-aucpr:0.73199	validation_0-auc:0.74782
# [66]	validation_0-aucpr:0.73222	validation_0-auc:0.74782
# [67]	validation_0-aucpr:0.73215	validation_0-auc:0.74789
# [68]	validation_0-aucpr:0.73211	validation_0-auc:0.74801
# [69]	validation_0-aucpr:0.73240	validation_0-auc:0.74813
# [70]	validation_0-aucpr:0.73225	validation_0-auc:0.74819
# [71]	validation_0-aucpr:0.73242	validation_0-auc:0.74819
# [72]	validation_0-aucpr:0.73242	validation_0-auc:0.74828
# [73]	validation_0-aucpr:0.73252	validation_0-auc:0.74833
# [74]	validation_0-aucpr:0.73271	validation_0-auc:0.74842
# [75]	validation_0-aucpr:0.73306	validation_0-auc:0.74862
# [76]	validation_0-aucpr:0.73300	validation_0-auc:0.74868
# [77]	validation_0-aucpr:0.73315	validation_0-auc:0.74884
# [78]	validation_0-aucpr:0.73320	validation_0-auc:0.74897
# [79]	validation_0-aucpr:0.73348	validation_0-auc:0.74908
# [80]	validation_0-aucpr:0.73364	validation_0-auc:0.74919
# [81]	validation_0-aucpr:0.73372	validation_0-auc:0.74924
# [82]	validation_0-aucpr:0.73385	validation_0-auc:0.74934
# [83]	validation_0-aucpr:0.73390	validation_0-auc:0.74937
# [84]	validation_0-aucpr:0.73410	validation_0-auc:0.74951
# [85]	validation_0-aucpr:0.73405	validation_0-auc:0.74962
# [86]	validation_0-aucpr:0.73401	validation_0-auc:0.74961
# [87]	validation_0-aucpr:0.73415	validation_0-auc:0.74976
# [88]	validation_0-aucpr:0.73415	validation_0-auc:0.74979
# [89]	validation_0-aucpr:0.73424	validation_0-auc:0.74993
# [90]	validation_0-aucpr:0.73438	validation_0-auc:0.75009
# [91]	validation_0-aucpr:0.73438	validation_0-auc:0.75020
# [92]	validation_0-aucpr:0.73452	validation_0-auc:0.75021
# [93]	validation_0-aucpr:0.73447	validation_0-auc:0.75024
# [94]	validation_0-aucpr:0.73454	validation_0-auc:0.75023
# [95]	validation_0-aucpr:0.73457	validation_0-auc:0.75034
# [96]	validation_0-aucpr:0.73468	validation_0-auc:0.75041
# [97]	validation_0-aucpr:0.73483	validation_0-auc:0.75052
# [98]	validation_0-aucpr:0.73489	validation_0-auc:0.75054
# [99]	validation_0-aucpr:0.73507	validation_0-auc:0.75062
# [100]	validation_0-aucpr:0.73512	validation_0-auc:0.75078
# [101]	validation_0-aucpr:0.73504	validation_0-auc:0.75088
# [102]	validation_0-aucpr:0.73503	validation_0-auc:0.75091
# [103]	validation_0-aucpr:0.73509	validation_0-auc:0.75100
# [104]	validation_0-aucpr:0.73507	validation_0-auc:0.75098
# [105]	validation_0-aucpr:0.73506	validation_0-auc:0.75099
# [106]	validation_0-aucpr:0.73528	validation_0-auc:0.75106
# [107]	validation_0-aucpr:0.73533	validation_0-auc:0.75109
# [108]	validation_0-aucpr:0.73531	validation_0-auc:0.75113
# [109]	validation_0-aucpr:0.73560	validation_0-auc:0.75123
# [110]	validation_0-aucpr:0.73565	validation_0-auc:0.75135
# [111]	validation_0-aucpr:0.73567	validation_0-auc:0.75143
# [112]	validation_0-aucpr:0.73569	validation_0-auc:0.75147
# [113]	validation_0-aucpr:0.73585	validation_0-auc:0.75161
# [114]	validation_0-aucpr:0.73595	validation_0-auc:0.75164
# [115]	validation_0-aucpr:0.73604	validation_0-auc:0.75170
# [116]	validation_0-aucpr:0.73600	validation_0-auc:0.75171
# [117]	validation_0-aucpr:0.73598	validation_0-auc:0.75180
# [118]	validation_0-aucpr:0.73594	validation_0-auc:0.75185
# [119]	validation_0-aucpr:0.73614	validation_0-auc:0.75192
# [120]	validation_0-aucpr:0.73637	validation_0-auc:0.75195
# [121]	validation_0-aucpr:0.73668	validation_0-auc:0.75199
# [122]	validation_0-aucpr:0.73668	validation_0-auc:0.75207
# [123]	validation_0-aucpr:0.73669	validation_0-auc:0.75212
# [124]	validation_0-aucpr:0.73686	validation_0-auc:0.75222
# [125]	validation_0-aucpr:0.73696	validation_0-auc:0.75231
# [126]	validation_0-aucpr:0.73711	validation_0-auc:0.75243
# [127]	validation_0-aucpr:0.73713	validation_0-auc:0.75247
# [128]	validation_0-aucpr:0.73731	validation_0-auc:0.75257
# [129]	validation_0-aucpr:0.73754	validation_0-auc:0.75264
# [130]	validation_0-aucpr:0.73756	validation_0-auc:0.75272
# [131]	validation_0-aucpr:0.73791	validation_0-auc:0.75277
# [132]	validation_0-aucpr:0.73800	validation_0-auc:0.75288
# [133]	validation_0-aucpr:0.73806	validation_0-auc:0.75300
# [134]	validation_0-aucpr:0.73819	validation_0-auc:0.75306
# [135]	validation_0-aucpr:0.73835	validation_0-auc:0.75317
# [136]	validation_0-aucpr:0.73835	validation_0-auc:0.75317
# [137]	validation_0-aucpr:0.73835	validation_0-auc:0.75323
# [138]	validation_0-aucpr:0.73842	validation_0-auc:0.75325
# [139]	validation_0-aucpr:0.73859	validation_0-auc:0.75339
# [140]	validation_0-aucpr:0.73849	validation_0-auc:0.75340
# [141]	validation_0-aucpr:0.73852	validation_0-auc:0.75348
# [142]	validation_0-aucpr:0.73852	validation_0-auc:0.75352
# [143]	validation_0-aucpr:0.73851	validation_0-auc:0.75363
# [144]	validation_0-aucpr:0.73856	validation_0-auc:0.75372
# [145]	validation_0-aucpr:0.73867	validation_0-auc:0.75385
# [146]	validation_0-aucpr:0.73877	validation_0-auc:0.75393
# [147]	validation_0-aucpr:0.73900	validation_0-auc:0.75402
# [148]	validation_0-aucpr:0.73915	validation_0-auc:0.75403
# [149]	validation_0-aucpr:0.73904	validation_0-auc:0.75402
# [150]	validation_0-aucpr:0.73929	validation_0-auc:0.75414
# [151]	validation_0-aucpr:0.73935	validation_0-auc:0.75425
# [152]	validation_0-aucpr:0.73936	validation_0-auc:0.75427
# [153]	validation_0-aucpr:0.73955	validation_0-auc:0.75444
# [154]	validation_0-aucpr:0.73950	validation_0-auc:0.75443
# [155]	validation_0-aucpr:0.73957	validation_0-auc:0.75453
# [156]	validation_0-aucpr:0.73969	validation_0-auc:0.75455
# [157]	validation_0-aucpr:0.73984	validation_0-auc:0.75471
# [158]	validation_0-aucpr:0.73995	validation_0-auc:0.75477
# [159]	validation_0-aucpr:0.74009	validation_0-auc:0.75485
# [160]	validation_0-aucpr:0.74017	validation_0-auc:0.75496
# [161]	validation_0-aucpr:0.74026	validation_0-auc:0.75505
# [162]	validation_0-aucpr:0.74025	validation_0-auc:0.75510
# [163]	validation_0-aucpr:0.74023	validation_0-auc:0.75512
# [164]	validation_0-aucpr:0.74032	validation_0-auc:0.75518
# [165]	validation_0-aucpr:0.74041	validation_0-auc:0.75520
# [166]	validation_0-aucpr:0.74049	validation_0-auc:0.75531
# [167]	validation_0-aucpr:0.74056	validation_0-auc:0.75541
# [168]	validation_0-aucpr:0.74063	validation_0-auc:0.75551
# [169]	validation_0-aucpr:0.74089	validation_0-auc:0.75558
# [170]	validation_0-aucpr:0.74084	validation_0-auc:0.75566
# [171]	validation_0-aucpr:0.74091	validation_0-auc:0.75577
# [172]	validation_0-aucpr:0.74090	validation_0-auc:0.75587
# [173]	validation_0-aucpr:0.74109	validation_0-auc:0.75593
# [174]	validation_0-aucpr:0.74109	validation_0-auc:0.75597
# [175]	validation_0-aucpr:0.74105	validation_0-auc:0.75600
# [176]	validation_0-aucpr:0.74099	validation_0-auc:0.75607
# [177]	validation_0-aucpr:0.74106	validation_0-auc:0.75614
# [178]	validation_0-aucpr:0.74124	validation_0-auc:0.75620
# [179]	validation_0-aucpr:0.74132	validation_0-auc:0.75623
# [180]	validation_0-aucpr:0.74161	validation_0-auc:0.75634
# [181]	validation_0-aucpr:0.74167	validation_0-auc:0.75640
# [182]	validation_0-aucpr:0.74182	validation_0-auc:0.75654
# [183]	validation_0-aucpr:0.74174	validation_0-auc:0.75659
# [184]	validation_0-aucpr:0.74175	validation_0-auc:0.75665
# [185]	validation_0-aucpr:0.74183	validation_0-auc:0.75672
# [186]	validation_0-aucpr:0.74180	validation_0-auc:0.75676
# [187]	validation_0-aucpr:0.74181	validation_0-auc:0.75679
# [188]	validation_0-aucpr:0.74191	validation_0-auc:0.75686
# [189]	validation_0-aucpr:0.74188	validation_0-auc:0.75686
# [190]	validation_0-aucpr:0.74195	validation_0-auc:0.75693
# [191]	validation_0-aucpr:0.74214	validation_0-auc:0.75699
# [192]	validation_0-aucpr:0.74225	validation_0-auc:0.75700
# [193]	validation_0-aucpr:0.74228	validation_0-auc:0.75708
# [194]	validation_0-aucpr:0.74256	validation_0-auc:0.75721
# [195]	validation_0-aucpr:0.74270	validation_0-auc:0.75729
# [196]	validation_0-aucpr:0.74271	validation_0-auc:0.75734
# [197]	validation_0-aucpr:0.74274	validation_0-auc:0.75739
# [198]	validation_0-aucpr:0.74290	validation_0-auc:0.75747
# [199]	validation_0-aucpr:0.74288	validation_0-auc:0.75748
# [200]	validation_0-aucpr:0.74283	validation_0-auc:0.75757
# [201]	validation_0-aucpr:0.74287	validation_0-auc:0.75759
# [202]	validation_0-aucpr:0.74299	validation_0-auc:0.75763
# [203]	validation_0-aucpr:0.74312	validation_0-auc:0.75770
# [204]	validation_0-aucpr:0.74322	validation_0-auc:0.75780
# [205]	validation_0-aucpr:0.74336	validation_0-auc:0.75788
# [206]	validation_0-aucpr:0.74348	validation_0-auc:0.75795
# [207]	validation_0-aucpr:0.74359	validation_0-auc:0.75804
# [208]	validation_0-aucpr:0.74381	validation_0-auc:0.75820
# [209]	validation_0-aucpr:0.74389	validation_0-auc:0.75829
# [210]	validation_0-aucpr:0.74391	validation_0-auc:0.75834
# [211]	validation_0-aucpr:0.74388	validation_0-auc:0.75837
# [212]	validation_0-aucpr:0.74390	validation_0-auc:0.75841
# [213]	validation_0-aucpr:0.74394	validation_0-auc:0.75848
# [214]	validation_0-aucpr:0.74412	validation_0-auc:0.75856
# [215]	validation_0-aucpr:0.74417	validation_0-auc:0.75859
# [216]	validation_0-aucpr:0.74433	validation_0-auc:0.75864
# [217]	validation_0-aucpr:0.74447	validation_0-auc:0.75879
# [218]	validation_0-aucpr:0.74445	validation_0-auc:0.75884
# [219]	validation_0-aucpr:0.74455	validation_0-auc:0.75893
# [220]	validation_0-aucpr:0.74444	validation_0-auc:0.75893
# [221]	validation_0-aucpr:0.74451	validation_0-auc:0.75897
# [222]	validation_0-aucpr:0.74452	validation_0-auc:0.75900
# [223]	validation_0-aucpr:0.74475	validation_0-auc:0.75913
# [224]	validation_0-aucpr:0.74479	validation_0-auc:0.75920
# [225]	validation_0-aucpr:0.74483	validation_0-auc:0.75925
# [226]	validation_0-aucpr:0.74478	validation_0-auc:0.75925
# [227]	validation_0-aucpr:0.74493	validation_0-auc:0.75932
# [228]	validation_0-aucpr:0.74502	validation_0-auc:0.75942
# [229]	validation_0-aucpr:0.74511	validation_0-auc:0.75950
# [230]	validation_0-aucpr:0.74520	validation_0-auc:0.75959
# [231]	validation_0-aucpr:0.74525	validation_0-auc:0.75964
# [232]	validation_0-aucpr:0.74538	validation_0-auc:0.75979
# [233]	validation_0-aucpr:0.74552	validation_0-auc:0.75989
# [234]	validation_0-aucpr:0.74556	validation_0-auc:0.75993
# [235]	validation_0-aucpr:0.74561	validation_0-auc:0.75995
# [236]	validation_0-aucpr:0.74571	validation_0-auc:0.76002
# [237]	validation_0-aucpr:0.74577	validation_0-auc:0.76004
# [238]	validation_0-aucpr:0.74582	validation_0-auc:0.76010
# [239]	validation_0-aucpr:0.74587	validation_0-auc:0.76018
# [240]	validation_0-aucpr:0.74591	validation_0-auc:0.76024
# [241]	validation_0-aucpr:0.74606	validation_0-auc:0.76026
# [242]	validation_0-aucpr:0.74610	validation_0-auc:0.76031
# [243]	validation_0-aucpr:0.74619	validation_0-auc:0.76040
# [244]	validation_0-aucpr:0.74624	validation_0-auc:0.76046
# [245]	validation_0-aucpr:0.74635	validation_0-auc:0.76054
# [246]	validation_0-aucpr:0.74647	validation_0-auc:0.76066
# [247]	validation_0-aucpr:0.74659	validation_0-auc:0.76075
# [248]	validation_0-aucpr:0.74676	validation_0-auc:0.76080
# [249]	validation_0-aucpr:0.74689	validation_0-auc:0.76089
# [250]	validation_0-aucpr:0.74704	validation_0-auc:0.76097
# [251]	validation_0-aucpr:0.74710	validation_0-auc:0.76105
# [252]	validation_0-aucpr:0.74715	validation_0-auc:0.76110
# [253]	validation_0-aucpr:0.74716	validation_0-auc:0.76118
# [254]	validation_0-aucpr:0.74720	validation_0-auc:0.76123
# [255]	validation_0-aucpr:0.74735	validation_0-auc:0.76131
# [256]	validation_0-aucpr:0.74742	validation_0-auc:0.76138
# [257]	validation_0-aucpr:0.74744	validation_0-auc:0.76140
# [258]	validation_0-aucpr:0.74743	validation_0-auc:0.76148
# [259]	validation_0-aucpr:0.74749	validation_0-auc:0.76153
# [260]	validation_0-aucpr:0.74759	validation_0-auc:0.76158
# [261]	validation_0-aucpr:0.74768	validation_0-auc:0.76169
# [262]	validation_0-aucpr:0.74778	validation_0-auc:0.76174
# [263]	validation_0-aucpr:0.74776	validation_0-auc:0.76181
# [264]	validation_0-aucpr:0.74787	validation_0-auc:0.76188
# [265]	validation_0-aucpr:0.74791	validation_0-auc:0.76195
# [266]	validation_0-aucpr:0.74803	validation_0-auc:0.76200
# [267]	validation_0-aucpr:0.74813	validation_0-auc:0.76211
# [268]	validation_0-aucpr:0.74807	validation_0-auc:0.76208
# [269]	validation_0-aucpr:0.74803	validation_0-auc:0.76208
# [270]	validation_0-aucpr:0.74805	validation_0-auc:0.76214
# [271]	validation_0-aucpr:0.74820	validation_0-auc:0.76220
# [272]	validation_0-aucpr:0.74825	validation_0-auc:0.76223
# [273]	validation_0-aucpr:0.74825	validation_0-auc:0.76231
# [274]	validation_0-aucpr:0.74840	validation_0-auc:0.76240
# [275]	validation_0-aucpr:0.74844	validation_0-auc:0.76247
# [276]	validation_0-aucpr:0.74841	validation_0-auc:0.76249
# [277]	validation_0-aucpr:0.74848	validation_0-auc:0.76256
# [278]	validation_0-aucpr:0.74854	validation_0-auc:0.76261
# [279]	validation_0-aucpr:0.74866	validation_0-auc:0.76270
# [280]	validation_0-aucpr:0.74860	validation_0-auc:0.76272
# [281]	validation_0-aucpr:0.74872	validation_0-auc:0.76281
# [282]	validation_0-aucpr:0.74883	validation_0-auc:0.76289
# [283]	validation_0-aucpr:0.74891	validation_0-auc:0.76292
# [284]	validation_0-aucpr:0.74902	validation_0-auc:0.76300
# [285]	validation_0-aucpr:0.74899	validation_0-auc:0.76304
# [286]	validation_0-aucpr:0.74919	validation_0-auc:0.76314
# [287]	validation_0-aucpr:0.74928	validation_0-auc:0.76324
# [288]	validation_0-aucpr:0.74932	validation_0-auc:0.76327
# [289]	validation_0-aucpr:0.74945	validation_0-auc:0.76331
# [290]	validation_0-aucpr:0.74945	validation_0-auc:0.76335
# [291]	validation_0-aucpr:0.74952	validation_0-auc:0.76345
# [292]	validation_0-aucpr:0.74968	validation_0-auc:0.76353
# [293]	validation_0-aucpr:0.74974	validation_0-auc:0.76357
# [294]	validation_0-aucpr:0.74985	validation_0-auc:0.76367
# [295]	validation_0-aucpr:0.74990	validation_0-auc:0.76369
# [296]	validation_0-aucpr:0.74994	validation_0-auc:0.76377
# [297]	validation_0-aucpr:0.75002	validation_0-auc:0.76386
# [298]	validation_0-aucpr:0.75004	validation_0-auc:0.76391
# [299]	validation_0-aucpr:0.75017	validation_0-auc:0.76399
# [300]	validation_0-aucpr:0.75019	validation_0-auc:0.76404
# [301]	validation_0-aucpr:0.75032	validation_0-auc:0.76413
# [302]	validation_0-aucpr:0.75033	validation_0-auc:0.76413
# [303]	validation_0-aucpr:0.75043	validation_0-auc:0.76428
# [304]	validation_0-aucpr:0.75049	validation_0-auc:0.76433
# [305]	validation_0-aucpr:0.75056	validation_0-auc:0.76437
# [306]	validation_0-aucpr:0.75063	validation_0-auc:0.76445
# [307]	validation_0-aucpr:0.75074	validation_0-auc:0.76452
# [308]	validation_0-aucpr:0.75077	validation_0-auc:0.76457
# [309]	validation_0-aucpr:0.75079	validation_0-auc:0.76461
# [310]	validation_0-aucpr:0.75088	validation_0-auc:0.76465
# [311]	validation_0-aucpr:0.75094	validation_0-auc:0.76471
# [312]	validation_0-aucpr:0.75105	validation_0-auc:0.76478
# [313]	validation_0-aucpr:0.75107	validation_0-auc:0.76482
# [314]	validation_0-aucpr:0.75117	validation_0-auc:0.76490
# [315]	validation_0-aucpr:0.75127	validation_0-auc:0.76496
# [316]	validation_0-aucpr:0.75146	validation_0-auc:0.76509
# [317]	validation_0-aucpr:0.75146	validation_0-auc:0.76513
# [318]	validation_0-aucpr:0.75154	validation_0-auc:0.76518
# [319]	validation_0-aucpr:0.75155	validation_0-auc:0.76523
# [320]	validation_0-aucpr:0.75155	validation_0-auc:0.76524
# [321]	validation_0-aucpr:0.75158	validation_0-auc:0.76528
# [322]	validation_0-aucpr:0.75162	validation_0-auc:0.76534
# [323]	validation_0-aucpr:0.75168	validation_0-auc:0.76538
# [324]	validation_0-aucpr:0.75169	validation_0-auc:0.76541
# [325]	validation_0-aucpr:0.75177	validation_0-auc:0.76548
# [326]	validation_0-aucpr:0.75184	validation_0-auc:0.76555
# [327]	validation_0-aucpr:0.75183	validation_0-auc:0.76559
# [328]	validation_0-aucpr:0.75186	validation_0-auc:0.76562
# [329]	validation_0-aucpr:0.75184	validation_0-auc:0.76563
# [330]	validation_0-aucpr:0.75191	validation_0-auc:0.76567
# [331]	validation_0-aucpr:0.75192	validation_0-auc:0.76570
# [332]	validation_0-aucpr:0.75195	validation_0-auc:0.76572
# [333]	validation_0-aucpr:0.75206	validation_0-auc:0.76580
# [334]	validation_0-aucpr:0.75206	validation_0-auc:0.76581
# [335]	validation_0-aucpr:0.75217	validation_0-auc:0.76585
# [336]	validation_0-aucpr:0.75213	validation_0-auc:0.76588
# [337]	validation_0-aucpr:0.75221	validation_0-auc:0.76594
# [338]	validation_0-aucpr:0.75218	validation_0-auc:0.76595
# [339]	validation_0-aucpr:0.75220	validation_0-auc:0.76598
# [340]	validation_0-aucpr:0.75228	validation_0-auc:0.76604
# [341]	validation_0-aucpr:0.75227	validation_0-auc:0.76608
# [342]	validation_0-aucpr:0.75242	validation_0-auc:0.76618
# [343]	validation_0-aucpr:0.75250	validation_0-auc:0.76627
# [344]	validation_0-aucpr:0.75258	validation_0-auc:0.76639
# [345]	validation_0-aucpr:0.75274	validation_0-auc:0.76644
# [346]	validation_0-aucpr:0.75271	validation_0-auc:0.76646
# [347]	validation_0-aucpr:0.75268	validation_0-auc:0.76649
# [348]	validation_0-aucpr:0.75268	validation_0-auc:0.76651
# [349]	validation_0-aucpr:0.75273	validation_0-auc:0.76654
# [350]	validation_0-aucpr:0.75274	validation_0-auc:0.76662
# [351]	validation_0-aucpr:0.75282	validation_0-auc:0.76663
# [352]	validation_0-aucpr:0.75293	validation_0-auc:0.76666
# [353]	validation_0-aucpr:0.75288	validation_0-auc:0.76671
# [354]	validation_0-aucpr:0.75291	validation_0-auc:0.76675
# [355]	validation_0-aucpr:0.75314	validation_0-auc:0.76682
# [356]	validation_0-aucpr:0.75324	validation_0-auc:0.76684
# [357]	validation_0-aucpr:0.75328	validation_0-auc:0.76685
# [358]	validation_0-aucpr:0.75327	validation_0-auc:0.76686
# [359]	validation_0-aucpr:0.75322	validation_0-auc:0.76686
# [360]	validation_0-aucpr:0.75328	validation_0-auc:0.76687
# [361]	validation_0-aucpr:0.75333	validation_0-auc:0.76692
# [362]	validation_0-aucpr:0.75340	validation_0-auc:0.76699
# [363]	validation_0-aucpr:0.75340	validation_0-auc:0.76703
# [364]	validation_0-aucpr:0.75345	validation_0-auc:0.76705
# [365]	validation_0-aucpr:0.75355	validation_0-auc:0.76709
# [366]	validation_0-aucpr:0.75360	validation_0-auc:0.76714
# [367]	validation_0-aucpr:0.75357	validation_0-auc:0.76717
# [368]	validation_0-aucpr:0.75360	validation_0-auc:0.76718
# [369]	validation_0-aucpr:0.75369	validation_0-auc:0.76723
# [370]	validation_0-aucpr:0.75376	validation_0-auc:0.76729
# [371]	validation_0-aucpr:0.75375	validation_0-auc:0.76730
# [372]	validation_0-aucpr:0.75390	validation_0-auc:0.76733
# [373]	validation_0-aucpr:0.75395	validation_0-auc:0.76739
# [374]	validation_0-aucpr:0.75399	validation_0-auc:0.76743
# [375]	validation_0-aucpr:0.75401	validation_0-auc:0.76746
# [376]	validation_0-aucpr:0.75417	validation_0-auc:0.76755
# [377]	validation_0-aucpr:0.75421	validation_0-auc:0.76759
# [378]	validation_0-aucpr:0.75424	validation_0-auc:0.76762
# [379]	validation_0-aucpr:0.75430	validation_0-auc:0.76767
# [380]	validation_0-aucpr:0.75434	validation_0-auc:0.76772
# [381]	validation_0-aucpr:0.75432	validation_0-auc:0.76772
# [382]	validation_0-aucpr:0.75430	validation_0-auc:0.76775
# [383]	validation_0-aucpr:0.75437	validation_0-auc:0.76780
# [384]	validation_0-aucpr:0.75452	validation_0-auc:0.76783
# [385]	validation_0-aucpr:0.75460	validation_0-auc:0.76785
# [386]	validation_0-aucpr:0.75462	validation_0-auc:0.76790
# [387]	validation_0-aucpr:0.75471	validation_0-auc:0.76794
# [388]	validation_0-aucpr:0.75481	validation_0-auc:0.76799
# [389]	validation_0-aucpr:0.75475	validation_0-auc:0.76804
# [390]	validation_0-aucpr:0.75477	validation_0-auc:0.76807
# [391]	validation_0-aucpr:0.75481	validation_0-auc:0.76809
# [392]	validation_0-aucpr:0.75492	validation_0-auc:0.76813
# [393]	validation_0-aucpr:0.75496	validation_0-auc:0.76816
# [394]	validation_0-aucpr:0.75493	validation_0-auc:0.76818
# [395]	validation_0-aucpr:0.75506	validation_0-auc:0.76824
# [396]	validation_0-aucpr:0.75508	validation_0-auc:0.76825
# [397]	validation_0-aucpr:0.75514	validation_0-auc:0.76829
# [398]	validation_0-aucpr:0.75516	validation_0-auc:0.76832
# [399]	validation_0-aucpr:0.75523	validation_0-auc:0.76838
# [400]	validation_0-aucpr:0.75526	validation_0-auc:0.76844
# [401]	validation_0-aucpr:0.75531	validation_0-auc:0.76849
# [402]	validation_0-aucpr:0.75534	validation_0-auc:0.76850
# [403]	validation_0-aucpr:0.75535	validation_0-auc:0.76852
# [404]	validation_0-aucpr:0.75534	validation_0-auc:0.76855
# [405]	validation_0-aucpr:0.75537	validation_0-auc:0.76854
# [406]	validation_0-aucpr:0.75546	validation_0-auc:0.76859
# [407]	validation_0-aucpr:0.75553	validation_0-auc:0.76863
# [408]	validation_0-aucpr:0.75555	validation_0-auc:0.76863
# [409]	validation_0-aucpr:0.75561	validation_0-auc:0.76870
# [410]	validation_0-aucpr:0.75565	validation_0-auc:0.76873
# [411]	validation_0-aucpr:0.75566	validation_0-auc:0.76877
# [412]	validation_0-aucpr:0.75575	validation_0-auc:0.76882
# [413]	validation_0-aucpr:0.75576	validation_0-auc:0.76885
# [414]	validation_0-aucpr:0.75577	validation_0-auc:0.76888
# [415]	validation_0-aucpr:0.75580	validation_0-auc:0.76891
# [416]	validation_0-aucpr:0.75585	validation_0-auc:0.76894
# [417]	validation_0-aucpr:0.75593	validation_0-auc:0.76898
# [418]	validation_0-aucpr:0.75598	validation_0-auc:0.76902
# [419]	validation_0-aucpr:0.75598	validation_0-auc:0.76903
# [420]	validation_0-aucpr:0.75604	validation_0-auc:0.76907
# [421]	validation_0-aucpr:0.75608	validation_0-auc:0.76911
# [422]	validation_0-aucpr:0.75609	validation_0-auc:0.76913
# [423]	validation_0-aucpr:0.75624	validation_0-auc:0.76919
# [424]	validation_0-aucpr:0.75630	validation_0-auc:0.76921
# [425]	validation_0-aucpr:0.75630	validation_0-auc:0.76925
# [426]	validation_0-aucpr:0.75635	validation_0-auc:0.76927
# [427]	validation_0-aucpr:0.75630	validation_0-auc:0.76930
# [428]	validation_0-aucpr:0.75631	validation_0-auc:0.76932
# [429]	validation_0-aucpr:0.75635	validation_0-auc:0.76937
# [430]	validation_0-aucpr:0.75633	validation_0-auc:0.76940
# [431]	validation_0-aucpr:0.75637	validation_0-auc:0.76942
# [432]	validation_0-aucpr:0.75639	validation_0-auc:0.76942
# [433]	validation_0-aucpr:0.75634	validation_0-auc:0.76943
# [434]	validation_0-aucpr:0.75640	validation_0-auc:0.76943
# [435]	validation_0-aucpr:0.75645	validation_0-auc:0.76946
# [436]	validation_0-aucpr:0.75642	validation_0-auc:0.76951
# [437]	validation_0-aucpr:0.75647	validation_0-auc:0.76955
# [438]	validation_0-aucpr:0.75650	validation_0-auc:0.76959
# [439]	validation_0-aucpr:0.75654	validation_0-auc:0.76963
# [440]	validation_0-aucpr:0.75656	validation_0-auc:0.76970
# [441]	validation_0-aucpr:0.75661	validation_0-auc:0.76974
# [442]	validation_0-aucpr:0.75671	validation_0-auc:0.76977
# [443]	validation_0-aucpr:0.75670	validation_0-auc:0.76980
# [444]	validation_0-aucpr:0.75677	validation_0-auc:0.76985
# [445]	validation_0-aucpr:0.75675	validation_0-auc:0.76986
# [446]	validation_0-aucpr:0.75679	validation_0-auc:0.76991
# [447]	validation_0-aucpr:0.75690	validation_0-auc:0.76997
# [448]	validation_0-aucpr:0.75689	validation_0-auc:0.76999
# [449]	validation_0-aucpr:0.75691	validation_0-auc:0.77004
# [450]	validation_0-aucpr:0.75694	validation_0-auc:0.77009
# [451]	validation_0-aucpr:0.75699	validation_0-auc:0.77009
# [452]	validation_0-aucpr:0.75701	validation_0-auc:0.77012
# [453]	validation_0-aucpr:0.75706	validation_0-auc:0.77017
# [454]	validation_0-aucpr:0.75716	validation_0-auc:0.77020
# [455]	validation_0-aucpr:0.75719	validation_0-auc:0.77020
# [456]	validation_0-aucpr:0.75722	validation_0-auc:0.77021
# [457]	validation_0-aucpr:0.75725	validation_0-auc:0.77022
# [458]	validation_0-aucpr:0.75724	validation_0-auc:0.77026
# [459]	validation_0-aucpr:0.75729	validation_0-auc:0.77032
# [460]	validation_0-aucpr:0.75733	validation_0-auc:0.77036
# [461]	validation_0-aucpr:0.75737	validation_0-auc:0.77041
# [462]	validation_0-aucpr:0.75742	validation_0-auc:0.77043
# [463]	validation_0-aucpr:0.75742	validation_0-auc:0.77047
# [464]	validation_0-aucpr:0.75739	validation_0-auc:0.77050
# [465]	validation_0-aucpr:0.75739	validation_0-auc:0.77052
# [466]	validation_0-aucpr:0.75747	validation_0-auc:0.77056
# [467]	validation_0-aucpr:0.75747	validation_0-auc:0.77056
# [468]	validation_0-aucpr:0.75750	validation_0-auc:0.77060
# [469]	validation_0-aucpr:0.75762	validation_0-auc:0.77065
# [470]	validation_0-aucpr:0.75760	validation_0-auc:0.77068
# [471]	validation_0-aucpr:0.75759	validation_0-auc:0.77070
# [472]	validation_0-aucpr:0.75764	validation_0-auc:0.77071
# [473]	validation_0-aucpr:0.75765	validation_0-auc:0.77070
# [474]	validation_0-aucpr:0.75767	validation_0-auc:0.77074
# [475]	validation_0-aucpr:0.75769	validation_0-auc:0.77075
# [476]	validation_0-aucpr:0.75777	validation_0-auc:0.77081
# [477]	validation_0-aucpr:0.75783	validation_0-auc:0.77083
# [478]	validation_0-aucpr:0.75787	validation_0-auc:0.77084
# [479]	validation_0-aucpr:0.75793	validation_0-auc:0.77090
# [480]	validation_0-aucpr:0.75798	validation_0-auc:0.77093
# [481]	validation_0-aucpr:0.75803	validation_0-auc:0.77096
# [482]	validation_0-aucpr:0.75806	validation_0-auc:0.77096
# [483]	validation_0-aucpr:0.75808	validation_0-auc:0.77094
# [484]	validation_0-aucpr:0.75809	validation_0-auc:0.77096
# [485]	validation_0-aucpr:0.75810	validation_0-auc:0.77099
# [486]	validation_0-aucpr:0.75814	validation_0-auc:0.77103
# [487]	validation_0-aucpr:0.75821	validation_0-auc:0.77110
# [488]	validation_0-aucpr:0.75827	validation_0-auc:0.77113
# [489]	validation_0-aucpr:0.75821	validation_0-auc:0.77112
# [490]	validation_0-aucpr:0.75819	validation_0-auc:0.77118
# [491]	validation_0-aucpr:0.75822	validation_0-auc:0.77119
# [492]	validation_0-aucpr:0.75826	validation_0-auc:0.77123
# [493]	validation_0-aucpr:0.75827	validation_0-auc:0.77124
# [494]	validation_0-aucpr:0.75831	validation_0-auc:0.77126
# [495]	validation_0-aucpr:0.75834	validation_0-auc:0.77130
# [496]	validation_0-aucpr:0.75835	validation_0-auc:0.77133
# [497]	validation_0-aucpr:0.75834	validation_0-auc:0.77137
# [498]	validation_0-aucpr:0.75836	validation_0-auc:0.77140
# [499]	validation_0-aucpr:0.75839	validation_0-auc:0.77139
# [500]	validation_0-aucpr:0.75846	validation_0-auc:0.77143
# [501]	validation_0-aucpr:0.75848	validation_0-auc:0.77146
# [502]	validation_0-aucpr:0.75847	validation_0-auc:0.77147
# [503]	validation_0-aucpr:0.75850	validation_0-auc:0.77150
# [504]	validation_0-aucpr:0.75859	validation_0-auc:0.77154
# [505]	validation_0-aucpr:0.75860	validation_0-auc:0.77157
# [506]	validation_0-aucpr:0.75863	validation_0-auc:0.77158
# [507]	validation_0-aucpr:0.75862	validation_0-auc:0.77157
# [508]	validation_0-aucpr:0.75867	validation_0-auc:0.77159
# [509]	validation_0-aucpr:0.75871	validation_0-auc:0.77159
# [510]	validation_0-aucpr:0.75870	validation_0-auc:0.77163
# [511]	validation_0-aucpr:0.75875	validation_0-auc:0.77166
# [512]	validation_0-aucpr:0.75875	validation_0-auc:0.77167
# [513]	validation_0-aucpr:0.75892	validation_0-auc:0.77174
# [514]	validation_0-aucpr:0.75894	validation_0-auc:0.77177
# [515]	validation_0-aucpr:0.75895	validation_0-auc:0.77180
# [516]	validation_0-aucpr:0.75897	validation_0-auc:0.77184
# [517]	validation_0-aucpr:0.75907	validation_0-auc:0.77188
# [518]	validation_0-aucpr:0.75910	validation_0-auc:0.77192
# [519]	validation_0-aucpr:0.75908	validation_0-auc:0.77197
# [520]	validation_0-aucpr:0.75917	validation_0-auc:0.77201
# [521]	validation_0-aucpr:0.75920	validation_0-auc:0.77204
# [522]	validation_0-aucpr:0.75926	validation_0-auc:0.77209
# [523]	validation_0-aucpr:0.75929	validation_0-auc:0.77211
# [524]	validation_0-aucpr:0.75936	validation_0-auc:0.77215
# [525]	validation_0-aucpr:0.75945	validation_0-auc:0.77220
# [526]	validation_0-aucpr:0.75955	validation_0-auc:0.77222
# [527]	validation_0-aucpr:0.75950	validation_0-auc:0.77223
# [528]	validation_0-aucpr:0.75964	validation_0-auc:0.77228
# [529]	validation_0-aucpr:0.75966	validation_0-auc:0.77229
# [530]	validation_0-aucpr:0.75966	validation_0-auc:0.77228
# [531]	validation_0-aucpr:0.75972	validation_0-auc:0.77233
# [532]	validation_0-aucpr:0.75974	validation_0-auc:0.77234
# [533]	validation_0-aucpr:0.75968	validation_0-auc:0.77235
# [534]	validation_0-aucpr:0.75972	validation_0-auc:0.77238
# [535]	validation_0-aucpr:0.75972	validation_0-auc:0.77237
# [536]	validation_0-aucpr:0.75974	validation_0-auc:0.77239
# [537]	validation_0-aucpr:0.75979	validation_0-auc:0.77240
# [538]	validation_0-aucpr:0.75979	validation_0-auc:0.77242
# [539]	validation_0-aucpr:0.75984	validation_0-auc:0.77248
# [540]	validation_0-aucpr:0.75986	validation_0-auc:0.77253
# [541]	validation_0-aucpr:0.75985	validation_0-auc:0.77252
# [542]	validation_0-aucpr:0.75985	validation_0-auc:0.77255
# [543]	validation_0-aucpr:0.75985	validation_0-auc:0.77254
# [544]	validation_0-aucpr:0.75990	validation_0-auc:0.77255
# [545]	validation_0-aucpr:0.75995	validation_0-auc:0.77259
# [546]	validation_0-aucpr:0.76003	validation_0-auc:0.77263
# [547]	validation_0-aucpr:0.76006	validation_0-auc:0.77267
# [548]	validation_0-aucpr:0.76016	validation_0-auc:0.77272
# [549]	validation_0-aucpr:0.76018	validation_0-auc:0.77275
# [550]	validation_0-aucpr:0.76017	validation_0-auc:0.77278
# [551]	validation_0-aucpr:0.76019	validation_0-auc:0.77281
# [552]	validation_0-aucpr:0.76022	validation_0-auc:0.77284
# [553]	validation_0-aucpr:0.76022	validation_0-auc:0.77283
# [554]	validation_0-aucpr:0.76023	validation_0-auc:0.77285
# [555]	validation_0-aucpr:0.76024	validation_0-auc:0.77287
# [556]	validation_0-aucpr:0.76024	validation_0-auc:0.77288
# [557]	validation_0-aucpr:0.76027	validation_0-auc:0.77290
# [558]	validation_0-aucpr:0.76027	validation_0-auc:0.77290
# [559]	validation_0-aucpr:0.76026	validation_0-auc:0.77289
# [560]	validation_0-aucpr:0.76026	validation_0-auc:0.77290
# [561]	validation_0-aucpr:0.76029	validation_0-auc:0.77293
# [562]	validation_0-aucpr:0.76030	validation_0-auc:0.77294
# [563]	validation_0-aucpr:0.76035	validation_0-auc:0.77299
# [564]	validation_0-aucpr:0.76039	validation_0-auc:0.77304
# [565]	validation_0-aucpr:0.76046	validation_0-auc:0.77306
# [566]	validation_0-aucpr:0.76049	validation_0-auc:0.77309
# [567]	validation_0-aucpr:0.76052	validation_0-auc:0.77308
# [568]	validation_0-aucpr:0.76052	validation_0-auc:0.77312
# [569]	validation_0-aucpr:0.76052	validation_0-auc:0.77313
# [570]	validation_0-aucpr:0.76052	validation_0-auc:0.77312
# [571]	validation_0-aucpr:0.76056	validation_0-auc:0.77312
# [572]	validation_0-aucpr:0.76058	validation_0-auc:0.77316
# [573]	validation_0-aucpr:0.76068	validation_0-auc:0.77319
# [574]	validation_0-aucpr:0.76068	validation_0-auc:0.77319
# [575]	validation_0-aucpr:0.76069	validation_0-auc:0.77320
# [576]	validation_0-aucpr:0.76072	validation_0-auc:0.77322
# [577]	validation_0-aucpr:0.76077	validation_0-auc:0.77325
# [578]	validation_0-aucpr:0.76078	validation_0-auc:0.77328
# [579]	validation_0-aucpr:0.76083	validation_0-auc:0.77329
# [580]	validation_0-aucpr:0.76089	validation_0-auc:0.77333
# [581]	validation_0-aucpr:0.76087	validation_0-auc:0.77333
# [582]	validation_0-aucpr:0.76090	validation_0-auc:0.77337
# [583]	validation_0-aucpr:0.76094	validation_0-auc:0.77340
# [584]	validation_0-aucpr:0.76098	validation_0-auc:0.77342
# [585]	validation_0-aucpr:0.76099	validation_0-auc:0.77343
# [586]	validation_0-aucpr:0.76105	validation_0-auc:0.77347
# [587]	validation_0-aucpr:0.76105	validation_0-auc:0.77348
# [588]	validation_0-aucpr:0.76103	validation_0-auc:0.77351
# [589]	validation_0-aucpr:0.76108	validation_0-auc:0.77355
# [590]	validation_0-aucpr:0.76104	validation_0-auc:0.77356
# [591]	validation_0-aucpr:0.76107	validation_0-auc:0.77357
# [592]	validation_0-aucpr:0.76114	validation_0-auc:0.77357
# [593]	validation_0-aucpr:0.76114	validation_0-auc:0.77359
# [594]	validation_0-aucpr:0.76117	validation_0-auc:0.77361
# [595]	validation_0-aucpr:0.76124	validation_0-auc:0.77365
# [596]	validation_0-aucpr:0.76121	validation_0-auc:0.77364
# [597]	validation_0-aucpr:0.76122	validation_0-auc:0.77368
# [598]	validation_0-aucpr:0.76123	validation_0-auc:0.77368
# [599]	validation_0-aucpr:0.76123	validation_0-auc:0.77367
# [600]	validation_0-aucpr:0.76125	validation_0-auc:0.77370
# [601]	validation_0-aucpr:0.76128	validation_0-auc:0.77368
# [602]	validation_0-aucpr:0.76127	validation_0-auc:0.77369
# [603]	validation_0-aucpr:0.76125	validation_0-auc:0.77369
# [604]	validation_0-aucpr:0.76129	validation_0-auc:0.77373
# [605]	validation_0-aucpr:0.76131	validation_0-auc:0.77376
# [606]	validation_0-aucpr:0.76134	validation_0-auc:0.77375
# [607]	validation_0-aucpr:0.76135	validation_0-auc:0.77375
# [608]	validation_0-aucpr:0.76142	validation_0-auc:0.77375
# [609]	validation_0-aucpr:0.76140	validation_0-auc:0.77377
# [610]	validation_0-aucpr:0.76141	validation_0-auc:0.77379
# [611]	validation_0-aucpr:0.76144	validation_0-auc:0.77381
# [612]	validation_0-aucpr:0.76142	validation_0-auc:0.77381
# [613]	validation_0-aucpr:0.76145	validation_0-auc:0.77382
# [614]	validation_0-aucpr:0.76144	validation_0-auc:0.77384
# [615]	validation_0-aucpr:0.76141	validation_0-auc:0.77383
# [616]	validation_0-aucpr:0.76149	validation_0-auc:0.77385
# [617]	validation_0-aucpr:0.76147	validation_0-auc:0.77386
# [618]	validation_0-aucpr:0.76159	validation_0-auc:0.77389
# [619]	validation_0-aucpr:0.76159	validation_0-auc:0.77390
# [620]	validation_0-aucpr:0.76158	validation_0-auc:0.77390
# [621]	validation_0-aucpr:0.76155	validation_0-auc:0.77391
# [622]	validation_0-aucpr:0.76158	validation_0-auc:0.77392
# [623]	validation_0-aucpr:0.76159	validation_0-auc:0.77397
# [624]	validation_0-aucpr:0.76174	validation_0-auc:0.77400
# [625]	validation_0-aucpr:0.76169	validation_0-auc:0.77404
# [626]	validation_0-aucpr:0.76174	validation_0-auc:0.77408
# [627]	validation_0-aucpr:0.76177	validation_0-auc:0.77411
# [628]	validation_0-aucpr:0.76184	validation_0-auc:0.77415
# [629]	validation_0-aucpr:0.76182	validation_0-auc:0.77413
# [630]	validation_0-aucpr:0.76182	validation_0-auc:0.77414
# [631]	validation_0-aucpr:0.76188	validation_0-auc:0.77416
# [632]	validation_0-aucpr:0.76186	validation_0-auc:0.77418
# [633]	validation_0-aucpr:0.76188	validation_0-auc:0.77419
# [634]	validation_0-aucpr:0.76184	validation_0-auc:0.77418
# [635]	validation_0-aucpr:0.76191	validation_0-auc:0.77423
# [636]	validation_0-aucpr:0.76191	validation_0-auc:0.77427
# [637]	validation_0-aucpr:0.76197	validation_0-auc:0.77428
# [638]	validation_0-aucpr:0.76199	validation_0-auc:0.77430
# [639]	validation_0-aucpr:0.76200	validation_0-auc:0.77433
# [640]	validation_0-aucpr:0.76196	validation_0-auc:0.77432
# [641]	validation_0-aucpr:0.76200	validation_0-auc:0.77434
# [642]	validation_0-aucpr:0.76204	validation_0-auc:0.77437
# [643]	validation_0-aucpr:0.76211	validation_0-auc:0.77439
# [644]	validation_0-aucpr:0.76214	validation_0-auc:0.77443
# [645]	validation_0-aucpr:0.76217	validation_0-auc:0.77447
# [646]	validation_0-aucpr:0.76224	validation_0-auc:0.77450
# [647]	validation_0-aucpr:0.76226	validation_0-auc:0.77451
# [648]	validation_0-aucpr:0.76227	validation_0-auc:0.77455
# [649]	validation_0-aucpr:0.76231	validation_0-auc:0.77458
# [650]	validation_0-aucpr:0.76232	validation_0-auc:0.77460
# [651]	validation_0-aucpr:0.76235	validation_0-auc:0.77460
# [652]	validation_0-aucpr:0.76232	validation_0-auc:0.77460
# [653]	validation_0-aucpr:0.76236	validation_0-auc:0.77463
# [654]	validation_0-aucpr:0.76238	validation_0-auc:0.77464
# [655]	validation_0-aucpr:0.76239	validation_0-auc:0.77466
# [656]	validation_0-aucpr:0.76241	validation_0-auc:0.77467
# [657]	validation_0-aucpr:0.76244	validation_0-auc:0.77468
# [658]	validation_0-aucpr:0.76247	validation_0-auc:0.77469
# [659]	validation_0-aucpr:0.76248	validation_0-auc:0.77471
# [660]	validation_0-aucpr:0.76249	validation_0-auc:0.77472
# [661]	validation_0-aucpr:0.76255	validation_0-auc:0.77474
# [662]	validation_0-aucpr:0.76260	validation_0-auc:0.77476
# [663]	validation_0-aucpr:0.76259	validation_0-auc:0.77478
# [664]	validation_0-aucpr:0.76257	validation_0-auc:0.77478
# [665]	validation_0-aucpr:0.76258	validation_0-auc:0.77479
# [666]	validation_0-aucpr:0.76256	validation_0-auc:0.77480
# [667]	validation_0-aucpr:0.76261	validation_0-auc:0.77482
# [668]	validation_0-aucpr:0.76264	validation_0-auc:0.77485
# [669]	validation_0-aucpr:0.76271	validation_0-auc:0.77491
# [670]	validation_0-aucpr:0.76278	validation_0-auc:0.77494
# [671]	validation_0-aucpr:0.76274	validation_0-auc:0.77492
# [672]	validation_0-aucpr:0.76281	validation_0-auc:0.77494
# [673]	validation_0-aucpr:0.76284	validation_0-auc:0.77495
# [674]	validation_0-aucpr:0.76285	validation_0-auc:0.77497
# [675]	validation_0-aucpr:0.76282	validation_0-auc:0.77494
# [676]	validation_0-aucpr:0.76284	validation_0-auc:0.77494
# [677]	validation_0-aucpr:0.76287	validation_0-auc:0.77497
# [678]	validation_0-aucpr:0.76290	validation_0-auc:0.77498
# [679]	validation_0-aucpr:0.76291	validation_0-auc:0.77499
# [680]	validation_0-aucpr:0.76293	validation_0-auc:0.77500
# [681]	validation_0-aucpr:0.76292	validation_0-auc:0.77500
# [682]	validation_0-aucpr:0.76297	validation_0-auc:0.77504
# [683]	validation_0-aucpr:0.76297	validation_0-auc:0.77506
# [684]	validation_0-aucpr:0.76302	validation_0-auc:0.77509
# [685]	validation_0-aucpr:0.76306	validation_0-auc:0.77512
# [686]	validation_0-aucpr:0.76313	validation_0-auc:0.77518
# [687]	validation_0-aucpr:0.76311	validation_0-auc:0.77517
# [688]	validation_0-aucpr:0.76315	validation_0-auc:0.77518
# [689]	validation_0-aucpr:0.76310	validation_0-auc:0.77520
# [690]	validation_0-aucpr:0.76310	validation_0-auc:0.77520
# [691]	validation_0-aucpr:0.76312	validation_0-auc:0.77521
# [692]	validation_0-aucpr:0.76315	validation_0-auc:0.77524
# [693]	validation_0-aucpr:0.76314	validation_0-auc:0.77523
# [694]	validation_0-aucpr:0.76318	validation_0-auc:0.77525
# [695]	validation_0-aucpr:0.76321	validation_0-auc:0.77527
# [696]	validation_0-aucpr:0.76324	validation_0-auc:0.77530
# [697]	validation_0-aucpr:0.76327	validation_0-auc:0.77529
# [698]	validation_0-aucpr:0.76327	validation_0-auc:0.77530
# [699]	validation_0-aucpr:0.76328	validation_0-auc:0.77531
# [700]	validation_0-aucpr:0.76336	validation_0-auc:0.77533
# [701]	validation_0-aucpr:0.76342	validation_0-auc:0.77534
# [702]	validation_0-aucpr:0.76343	validation_0-auc:0.77538
# [703]	validation_0-aucpr:0.76347	validation_0-auc:0.77539
# [704]	validation_0-aucpr:0.76348	validation_0-auc:0.77541
# [705]	validation_0-aucpr:0.76347	validation_0-auc:0.77541
# [706]	validation_0-aucpr:0.76349	validation_0-auc:0.77544
# [707]	validation_0-aucpr:0.76350	validation_0-auc:0.77544
# [708]	validation_0-aucpr:0.76353	validation_0-auc:0.77547
# [709]	validation_0-aucpr:0.76346	validation_0-auc:0.77546
# [710]	validation_0-aucpr:0.76350	validation_0-auc:0.77548
# [711]	validation_0-aucpr:0.76358	validation_0-auc:0.77550
# [712]	validation_0-aucpr:0.76355	validation_0-auc:0.77552
# [713]	validation_0-aucpr:0.76355	validation_0-auc:0.77552
# [714]	validation_0-aucpr:0.76356	validation_0-auc:0.77555
# [715]	validation_0-aucpr:0.76361	validation_0-auc:0.77558
# [716]	validation_0-aucpr:0.76362	validation_0-auc:0.77560
# [717]	validation_0-aucpr:0.76361	validation_0-auc:0.77559
# [718]	validation_0-aucpr:0.76369	validation_0-auc:0.77563
# [719]	validation_0-aucpr:0.76371	validation_0-auc:0.77564
# [720]	validation_0-aucpr:0.76372	validation_0-auc:0.77565
# [721]	validation_0-aucpr:0.76375	validation_0-auc:0.77566
# [722]	validation_0-aucpr:0.76372	validation_0-auc:0.77566
# [723]	validation_0-aucpr:0.76374	validation_0-auc:0.77569
# [724]	validation_0-aucpr:0.76373	validation_0-auc:0.77569
# [725]	validation_0-aucpr:0.76378	validation_0-auc:0.77570
# [726]	validation_0-aucpr:0.76378	validation_0-auc:0.77570
# [727]	validation_0-aucpr:0.76379	validation_0-auc:0.77570
# [728]	validation_0-aucpr:0.76379	validation_0-auc:0.77572
# [729]	validation_0-aucpr:0.76380	validation_0-auc:0.77573
# [730]	validation_0-aucpr:0.76372	validation_0-auc:0.77574
# [731]	validation_0-aucpr:0.76381	validation_0-auc:0.77576
# [732]	validation_0-aucpr:0.76385	validation_0-auc:0.77577
# [733]	validation_0-aucpr:0.76387	validation_0-auc:0.77577
# [734]	validation_0-aucpr:0.76387	validation_0-auc:0.77578
# [735]	validation_0-aucpr:0.76380	validation_0-auc:0.77577
# [736]	validation_0-aucpr:0.76382	validation_0-auc:0.77578
# [737]	validation_0-aucpr:0.76377	validation_0-auc:0.77576
# [738]	validation_0-aucpr:0.76378	validation_0-auc:0.77577
# [739]	validation_0-aucpr:0.76385	validation_0-auc:0.77578
# [740]	validation_0-aucpr:0.76387	validation_0-auc:0.77582
# [741]	validation_0-aucpr:0.76387	validation_0-auc:0.77582
# [742]	validation_0-aucpr:0.76383	validation_0-auc:0.77581
# [743]	validation_0-aucpr:0.76383	validation_0-auc:0.77582
# [744]	validation_0-aucpr:0.76388	validation_0-auc:0.77582
# [745]	validation_0-aucpr:0.76384	validation_0-auc:0.77586
# [746]	validation_0-aucpr:0.76388	validation_0-auc:0.77589
# [747]	validation_0-aucpr:0.76393	validation_0-auc:0.77592
# [748]	validation_0-aucpr:0.76394	validation_0-auc:0.77592
# [749]	validation_0-aucpr:0.76394	validation_0-auc:0.77594
# [750]	validation_0-aucpr:0.76400	validation_0-auc:0.77596
# [751]	validation_0-aucpr:0.76398	validation_0-auc:0.77595
# [752]	validation_0-aucpr:0.76400	validation_0-auc:0.77599
# [753]	validation_0-aucpr:0.76405	validation_0-auc:0.77600
# [754]	validation_0-aucpr:0.76405	validation_0-auc:0.77599
# [755]	validation_0-aucpr:0.76402	validation_0-auc:0.77599
# [756]	validation_0-aucpr:0.76407	validation_0-auc:0.77601
# [757]	validation_0-aucpr:0.76408	validation_0-auc:0.77603
# [758]	validation_0-aucpr:0.76407	validation_0-auc:0.77602
# [759]	validation_0-aucpr:0.76410	validation_0-auc:0.77604
# [760]	validation_0-aucpr:0.76414	validation_0-auc:0.77608
# [761]	validation_0-aucpr:0.76415	validation_0-auc:0.77608
# [762]	validation_0-aucpr:0.76417	validation_0-auc:0.77610
# [763]	validation_0-aucpr:0.76414	validation_0-auc:0.77610
# [764]	validation_0-aucpr:0.76419	validation_0-auc:0.77612
# [765]	validation_0-aucpr:0.76418	validation_0-auc:0.77612
# [766]	validation_0-aucpr:0.76419	validation_0-auc:0.77614
# [767]	validation_0-aucpr:0.76421	validation_0-auc:0.77615
# [768]	validation_0-aucpr:0.76416	validation_0-auc:0.77614
# [769]	validation_0-aucpr:0.76422	validation_0-auc:0.77617
# [770]	validation_0-aucpr:0.76420	validation_0-auc:0.77617
# [771]	validation_0-aucpr:0.76417	validation_0-auc:0.77617
# [772]	validation_0-aucpr:0.76420	validation_0-auc:0.77619
# [773]	validation_0-aucpr:0.76426	validation_0-auc:0.77621
# [774]	validation_0-aucpr:0.76425	validation_0-auc:0.77621
# [775]	validation_0-aucpr:0.76427	validation_0-auc:0.77623
# [776]	validation_0-aucpr:0.76428	validation_0-auc:0.77622
# [777]	validation_0-aucpr:0.76437	validation_0-auc:0.77628
# [778]	validation_0-aucpr:0.76435	validation_0-auc:0.77628
# [779]	validation_0-aucpr:0.76442	validation_0-auc:0.77629
# [780]	validation_0-aucpr:0.76443	validation_0-auc:0.77630
# [781]	validation_0-aucpr:0.76441	validation_0-auc:0.77629
# [782]	validation_0-aucpr:0.76444	validation_0-auc:0.77632
# [783]	validation_0-aucpr:0.76444	validation_0-auc:0.77633
# [784]	validation_0-aucpr:0.76449	validation_0-auc:0.77635
# [785]	validation_0-aucpr:0.76457	validation_0-auc:0.77639
# [786]	validation_0-aucpr:0.76458	validation_0-auc:0.77639
# [787]	validation_0-aucpr:0.76462	validation_0-auc:0.77642
# [788]	validation_0-aucpr:0.76463	validation_0-auc:0.77644
# [789]	validation_0-aucpr:0.76456	validation_0-auc:0.77644
# [790]	validation_0-aucpr:0.76462	validation_0-auc:0.77649
# [791]	validation_0-aucpr:0.76462	validation_0-auc:0.77648
# [792]	validation_0-aucpr:0.76462	validation_0-auc:0.77649
# [793]	validation_0-aucpr:0.76464	validation_0-auc:0.77651
# [794]	validation_0-aucpr:0.76466	validation_0-auc:0.77653
# [795]	validation_0-aucpr:0.76465	validation_0-auc:0.77653
# [796]	validation_0-aucpr:0.76463	validation_0-auc:0.77653
# [797]	validation_0-aucpr:0.76464	validation_0-auc:0.77652
# [798]	validation_0-aucpr:0.76464	validation_0-auc:0.77652
# [799]	validation_0-aucpr:0.76465	validation_0-auc:0.77656
# [800]	validation_0-aucpr:0.76471	validation_0-auc:0.77657
# [801]	validation_0-aucpr:0.76466	validation_0-auc:0.77660
# [802]	validation_0-aucpr:0.76466	validation_0-auc:0.77659
# [803]	validation_0-aucpr:0.76462	validation_0-auc:0.77659
# [804]	validation_0-aucpr:0.76463	validation_0-auc:0.77658
# [805]	validation_0-aucpr:0.76462	validation_0-auc:0.77659
# [806]	validation_0-aucpr:0.76461	validation_0-auc:0.77655
# [807]	validation_0-aucpr:0.76458	validation_0-auc:0.77656
# [808]	validation_0-aucpr:0.76462	validation_0-auc:0.77658
# [809]	validation_0-aucpr:0.76465	validation_0-auc:0.77659
# [810]	validation_0-aucpr:0.76465	validation_0-auc:0.77661
# [811]	validation_0-aucpr:0.76461	validation_0-auc:0.77662
# [812]	validation_0-aucpr:0.76463	validation_0-auc:0.77662
# [813]	validation_0-aucpr:0.76462	validation_0-auc:0.77663
# [814]	validation_0-aucpr:0.76462	validation_0-auc:0.77663
# [815]	validation_0-aucpr:0.76461	validation_0-auc:0.77663
# [816]	validation_0-aucpr:0.76464	validation_0-auc:0.77666
# [817]	validation_0-aucpr:0.76464	validation_0-auc:0.77665
# [818]	validation_0-aucpr:0.76467	validation_0-auc:0.77665
# [819]	validation_0-aucpr:0.76468	validation_0-auc:0.77667
# [820]	validation_0-aucpr:0.76471	validation_0-auc:0.77668
# [821]	validation_0-aucpr:0.76470	validation_0-auc:0.77668
# [822]	validation_0-aucpr:0.76479	validation_0-auc:0.77673
# [823]	validation_0-aucpr:0.76474	validation_0-auc:0.77674
# [824]	validation_0-aucpr:0.76475	validation_0-auc:0.77675
# [825]	validation_0-aucpr:0.76478	validation_0-auc:0.77677
# [826]	validation_0-aucpr:0.76480	validation_0-auc:0.77678
# [827]	validation_0-aucpr:0.76484	validation_0-auc:0.77679
# [828]	validation_0-aucpr:0.76483	validation_0-auc:0.77682
# ...
# [2047]	validation_0-aucpr:0.76881	validation_0-auc:0.78152
# [2048]	validation_0-aucpr:0.76879	validation_0-auc:0.78154
# [2049]	validation_0-aucpr:0.76880	validation_0-auc:0.78155
# [2050]	validation_0-aucpr:0.76878	validation_0-auc:0.78153
# [2051]	validation_0-aucpr:0.76880	validation_0-auc:0.78154
# [2052]	validation_0-aucpr:0.76879	validation_0-auc:0.78154
# [2053]	validation_0-aucpr:0.76888	validation_0-auc:0.78155
# [2054]	validation_0-aucpr:0.76885	validation_0-auc:0.78155
# [2055]	validation_0-aucpr:0.76885	validation_0-auc:0.78156
# [2056]	validation_0-aucpr:0.76885	validation_0-auc:0.78156
# [2057]	validation_0-aucpr:0.76884	validation_0-auc:0.78156
# [2058]	validation_0-aucpr:0.76884	validation_0-auc:0.78156
# [2059]	validation_0-aucpr:0.76883	validation_0-auc:0.78155
# [2060]	validation_0-aucpr:0.76883	validation_0-auc:0.78155
# [2061]	validation_0-aucpr:0.76885	validation_0-auc:0.78156
# [2062]	validation_0-aucpr:0.76882	validation_0-auc:0.78156
# [2063]	validation_0-aucpr:0.76882	validation_0-auc:0.78158
# [2064]	validation_0-aucpr:0.76883	validation_0-auc:0.78157
# [2065]	validation_0-aucpr:0.76886	validation_0-auc:0.78157
# [2066]	validation_0-aucpr:0.76881	validation_0-auc:0.78156
# [2067]	validation_0-aucpr:0.76880	validation_0-auc:0.78157
# [2068]	validation_0-aucpr:0.76878	validation_0-auc:0.78157
# [2069]	validation_0-aucpr:0.76880	validation_0-auc:0.78158
# [2070]	validation_0-aucpr:0.76879	validation_0-auc:0.78158
# [2071]	validation_0-aucpr:0.76874	validation_0-auc:0.78158
# [2072]	validation_0-aucpr:0.76874	validation_0-auc:0.78157
# [2073]	validation_0-aucpr:0.76876	validation_0-auc:0.78159
# [2074]	validation_0-aucpr:0.76873	validation_0-auc:0.78156
# [2075]	validation_0-aucpr:0.76870	validation_0-auc:0.78155
# [2076]	validation_0-aucpr:0.76871	validation_0-auc:0.78156
# [2077]	validation_0-aucpr:0.76873	validation_0-auc:0.78156
# [2078]	validation_0-aucpr:0.76871	validation_0-auc:0.78156
# [2079]	validation_0-aucpr:0.76872	validation_0-auc:0.78156
# [2080]	validation_0-aucpr:0.76870	validation_0-auc:0.78156
# [2081]	validation_0-aucpr:0.76870	validation_0-auc:0.78156
# [2082]	validation_0-aucpr:0.76867	validation_0-auc:0.78157
# [2083]	validation_0-aucpr:0.76868	validation_0-auc:0.78158
# [2084]	validation_0-aucpr:0.76866	validation_0-auc:0.78157
# [2085]	validation_0-aucpr:0.76875	validation_0-auc:0.78160
# [2086]	validation_0-aucpr:0.76876	validation_0-auc:0.78162
# [2087]	validation_0-aucpr:0.76876	validation_0-auc:0.78161
# [2088]	validation_0-aucpr:0.76878	validation_0-auc:0.78163
# [2089]	validation_0-aucpr:0.76878	validation_0-auc:0.78164
# [2090]	validation_0-aucpr:0.76876	validation_0-auc:0.78164
# [2091]	validation_0-aucpr:0.76876	validation_0-auc:0.78164
# [2092]	validation_0-aucpr:0.76875	validation_0-auc:0.78163
# [2093]	validation_0-aucpr:0.76872	validation_0-auc:0.78161
# [2094]	validation_0-aucpr:0.76871	validation_0-auc:0.78160
# [2095]	validation_0-aucpr:0.76871	validation_0-auc:0.78160
# [2096]	validation_0-aucpr:0.76872	validation_0-auc:0.78160
# [2097]	validation_0-aucpr:0.76871	validation_0-auc:0.78160
# [2098]	validation_0-aucpr:0.76866	validation_0-auc:0.78160
# [2099]	validation_0-aucpr:0.76865	validation_0-auc:0.78159
# [2100]	validation_0-aucpr:0.76867	validation_0-auc:0.78160
# [2101]	validation_0-aucpr:0.76868	validation_0-auc:0.78160
# [2102]	validation_0-aucpr:0.76870	validation_0-auc:0.78161
# [2103]	validation_0-aucpr:0.76873	validation_0-auc:0.78164
# [2104]	validation_0-aucpr:0.76874	validation_0-auc:0.78164
# [2105]	validation_0-aucpr:0.76874	validation_0-auc:0.78164
# [2106]	validation_0-aucpr:0.76874	validation_0-auc:0.78162
# [2107]	validation_0-aucpr:0.76874	validation_0-auc:0.78161
# [2108]	validation_0-aucpr:0.76876	validation_0-auc:0.78162
# [2109]	validation_0-aucpr:0.76873	validation_0-auc:0.78161
# [2110]	validation_0-aucpr:0.76874	validation_0-auc:0.78160
# [2111]	validation_0-aucpr:0.76874	validation_0-auc:0.78161
# [2112]	validation_0-aucpr:0.76870	validation_0-auc:0.78160
# [2113]	validation_0-aucpr:0.76871	validation_0-auc:0.78160
# [2114]	validation_0-aucpr:0.76871	validation_0-auc:0.78160
# [2115]	validation_0-aucpr:0.76868	validation_0-auc:0.78161
# [2116]	validation_0-aucpr:0.76866	validation_0-auc:0.78161
# [2117]	validation_0-aucpr:0.76865	validation_0-auc:0.78159
# [2118]	validation_0-aucpr:0.76866	validation_0-auc:0.78158
# [2119]	validation_0-aucpr:0.76864	validation_0-auc:0.78158
# [2120]	validation_0-aucpr:0.76863	validation_0-auc:0.78158
# [2121]	validation_0-aucpr:0.76863	validation_0-auc:0.78157
# [2122]	validation_0-aucpr:0.76861	validation_0-auc:0.78156
# [2123]	validation_0-aucpr:0.76861	validation_0-auc:0.78155
# [2124]	validation_0-aucpr:0.76861	validation_0-auc:0.78155
# [2125]	validation_0-aucpr:0.76865	validation_0-auc:0.78155
# [2126]	validation_0-aucpr:0.76863	validation_0-auc:0.78154
# [2127]	validation_0-aucpr:0.76864	validation_0-auc:0.78155
# [2128]	validation_0-aucpr:0.76858	validation_0-auc:0.78153
# [2129]	validation_0-aucpr:0.76859	validation_0-auc:0.78153
# [2130]	validation_0-aucpr:0.76859	validation_0-auc:0.78153
# [2131]	validation_0-aucpr:0.76855	validation_0-auc:0.78152
# [2132]	validation_0-aucpr:0.76856	validation_0-auc:0.78153
# [2133]	validation_0-aucpr:0.76857	validation_0-auc:0.78153
# [2134]	validation_0-aucpr:0.76858	validation_0-auc:0.78155
# [2135]	validation_0-aucpr:0.76856	validation_0-auc:0.78154
# [2136]	validation_0-aucpr:0.76858	validation_0-auc:0.78154
# [2137]	validation_0-aucpr:0.76861	validation_0-auc:0.78155
# [2138]	validation_0-aucpr:0.76857	validation_0-auc:0.78154
# [2139]	validation_0-aucpr:0.76855	validation_0-auc:0.78153
# [2140]	validation_0-aucpr:0.76860	validation_0-auc:0.78154
# [2141]	validation_0-aucpr:0.76862	validation_0-auc:0.78155
# [2142]	validation_0-aucpr:0.76864	validation_0-auc:0.78155
# [2143]	validation_0-aucpr:0.76863	validation_0-auc:0.78157
# [2144]	validation_0-aucpr:0.76864	validation_0-auc:0.78159
# [2145]	validation_0-aucpr:0.76862	validation_0-auc:0.78158
# [2146]	validation_0-aucpr:0.76861	validation_0-auc:0.78157
# [2147]	validation_0-aucpr:0.76859	validation_0-auc:0.78156
# [2148]	validation_0-aucpr:0.76858	validation_0-auc:0.78155
# [2149]	validation_0-aucpr:0.76857	validation_0-auc:0.78154
# [2150]	validation_0-aucpr:0.76865	validation_0-auc:0.78157
# [2151]	validation_0-aucpr:0.76864	validation_0-auc:0.78156
# [2152]	validation_0-aucpr:0.76862	validation_0-auc:0.78155
# [2153]	validation_0-aucpr:0.76859	validation_0-auc:0.78155
# [2154]	validation_0-aucpr:0.76858	validation_0-auc:0.78155
# [2155]	validation_0-aucpr:0.76856	validation_0-auc:0.78154
# [2156]	validation_0-aucpr:0.76855	validation_0-auc:0.78156
# [2157]	validation_0-aucpr:0.76858	validation_0-auc:0.78158
# [2158]	validation_0-aucpr:0.76857	validation_0-auc:0.78160
# [2159]	validation_0-aucpr:0.76856	validation_0-auc:0.78159
# [2160]	validation_0-aucpr:0.76855	validation_0-auc:0.78160
# [2161]	validation_0-aucpr:0.76855	validation_0-auc:0.78160
# [2162]	validation_0-aucpr:0.76856	validation_0-auc:0.78159
# [2163]	validation_0-aucpr:0.76856	validation_0-auc:0.78160
# [2164]	validation_0-aucpr:0.76856	validation_0-auc:0.78159
# [2165]	validation_0-aucpr:0.76858	validation_0-auc:0.78160
# [2166]	validation_0-aucpr:0.76857	validation_0-auc:0.78160
# [2167]	validation_0-aucpr:0.76855	validation_0-auc:0.78158
# [2168]	validation_0-aucpr:0.76854	validation_0-auc:0.78157
# [2169]	validation_0-aucpr:0.76855	validation_0-auc:0.78158
# [2170]	validation_0-aucpr:0.76852	validation_0-auc:0.78156
# [2171]	validation_0-aucpr:0.76854	validation_0-auc:0.78158
# [2172]	validation_0-aucpr:0.76857	validation_0-auc:0.78160
# [2173]	validation_0-aucpr:0.76854	validation_0-auc:0.78157
# [2174]	validation_0-aucpr:0.76851	validation_0-auc:0.78156
# [2175]	validation_0-aucpr:0.76848	validation_0-auc:0.78156
# [2176]	validation_0-aucpr:0.76849	validation_0-auc:0.78155
# [2177]	validation_0-aucpr:0.76849	validation_0-auc:0.78156
# [2178]	validation_0-aucpr:0.76848	validation_0-auc:0.78155
# [2179]	validation_0-aucpr:0.76846	validation_0-auc:0.78153
# [2180]	validation_0-aucpr:0.76847	validation_0-auc:0.78154
# [2181]	validation_0-aucpr:0.76842	validation_0-auc:0.78153
# [2182]	validation_0-aucpr:0.76843	validation_0-auc:0.78153
# [2183]	validation_0-aucpr:0.76843	validation_0-auc:0.78153
# [2184]	validation_0-aucpr:0.76841	validation_0-auc:0.78153
# [2185]	validation_0-aucpr:0.76843	validation_0-auc:0.78152
# [2186]	validation_0-aucpr:0.76842	validation_0-auc:0.78151
# [2187]	validation_0-aucpr:0.76843	validation_0-auc:0.78151
# [2188]	validation_0-aucpr:0.76840	validation_0-auc:0.78149
# [2189]	validation_0-aucpr:0.76840	validation_0-auc:0.78148
# [2190]	validation_0-aucpr:0.76839	validation_0-auc:0.78149
# [2191]	validation_0-aucpr:0.76839	validation_0-auc:0.78147
# [2192]	validation_0-aucpr:0.76835	validation_0-auc:0.78147
# [2193]	validation_0-aucpr:0.76836	validation_0-auc:0.78148
# [2194]	validation_0-aucpr:0.76838	validation_0-auc:0.78149
# [2195]	validation_0-aucpr:0.76839	validation_0-auc:0.78150
# [2196]	validation_0-aucpr:0.76837	validation_0-auc:0.78148
# [2197]	validation_0-aucpr:0.76839	validation_0-auc:0.78148
# [2198]	validation_0-aucpr:0.76840	validation_0-auc:0.78149
# [2199]	validation_0-aucpr:0.76842	validation_0-auc:0.78150
# [2200]	validation_0-aucpr:0.76842	validation_0-auc:0.78149
# [2201]	validation_0-aucpr:0.76849	validation_0-auc:0.78152
# [2202]	validation_0-aucpr:0.76853	validation_0-auc:0.78152
# [2203]	validation_0-aucpr:0.76850	validation_0-auc:0.78153
# [2204]	validation_0-aucpr:0.76850	validation_0-auc:0.78152
# [2205]	validation_0-aucpr:0.76852	validation_0-auc:0.78152
# [2206]	validation_0-aucpr:0.76854	validation_0-auc:0.78152
# [2207]	validation_0-aucpr:0.76852	validation_0-auc:0.78151
# [2208]	validation_0-aucpr:0.76854	validation_0-auc:0.78151
# [2209]	validation_0-aucpr:0.76853	validation_0-auc:0.78151
# [2210]	validation_0-aucpr:0.76854	validation_0-auc:0.78149
# [2211]	validation_0-aucpr:0.76854	validation_0-auc:0.78151
# [2212]	validation_0-aucpr:0.76857	validation_0-auc:0.78152
# [2213]	validation_0-aucpr:0.76858	validation_0-auc:0.78150
# [2214]	validation_0-aucpr:0.76858	validation_0-auc:0.78151
# [2215]	validation_0-aucpr:0.76858	validation_0-auc:0.78153
# [2216]	validation_0-aucpr:0.76858	validation_0-auc:0.78151
# [2217]	validation_0-aucpr:0.76864	validation_0-auc:0.78152
# [2218]	validation_0-aucpr:0.76863	validation_0-auc:0.78153
# [2219]	validation_0-aucpr:0.76862	validation_0-auc:0.78155
# [2220]	validation_0-aucpr:0.76862	validation_0-auc:0.78153
# [2221]	validation_0-aucpr:0.76860	validation_0-auc:0.78152
# [2222]	validation_0-aucpr:0.76858	validation_0-auc:0.78153
# [2223]	validation_0-aucpr:0.76854	validation_0-auc:0.78153
# [2224]	validation_0-aucpr:0.76853	validation_0-auc:0.78152
# [2225]	validation_0-aucpr:0.76854	validation_0-auc:0.78150
# [2226]	validation_0-aucpr:0.76854	validation_0-auc:0.78150
# [2227]	validation_0-aucpr:0.76849	validation_0-auc:0.78150
# [2228]	validation_0-aucpr:0.76850	validation_0-auc:0.78151
# [2229]	validation_0-aucpr:0.76852	validation_0-auc:0.78150
# [2230]	validation_0-aucpr:0.76841	validation_0-auc:0.78150
# [2231]	validation_0-aucpr:0.76836	validation_0-auc:0.78148
# [2232]	validation_0-aucpr:0.76833	validation_0-auc:0.78148
# [2233]	validation_0-aucpr:0.76835	validation_0-auc:0.78148
# [2234]	validation_0-aucpr:0.76844	validation_0-auc:0.78151
# [2235]	validation_0-aucpr:0.76843	validation_0-auc:0.78151
# [2236]	validation_0-aucpr:0.76844	validation_0-auc:0.78152
# [2237]	validation_0-aucpr:0.76844	validation_0-auc:0.78152
# [2238]	validation_0-aucpr:0.76843	validation_0-auc:0.78153
# [2239]	validation_0-aucpr:0.76843	validation_0-auc:0.78153
# [2240]	validation_0-aucpr:0.76844	validation_0-auc:0.78154
# [2241]	validation_0-aucpr:0.76845	validation_0-auc:0.78154
# [2242]	validation_0-aucpr:0.76843	validation_0-auc:0.78153
# [2243]	validation_0-aucpr:0.76840	validation_0-auc:0.78154
# [2244]	validation_0-aucpr:0.76840	validation_0-auc:0.78155
# [2245]	validation_0-aucpr:0.76839	validation_0-auc:0.78154
# [2246]	validation_0-aucpr:0.76847	validation_0-auc:0.78155
# [2247]	validation_0-aucpr:0.76843	validation_0-auc:0.78155
# [2248]	validation_0-aucpr:0.76848	validation_0-auc:0.78156
# [2249]	validation_0-aucpr:0.76849	validation_0-auc:0.78157
# [2250]	validation_0-aucpr:0.76848	validation_0-auc:0.78156
# [2251]	validation_0-aucpr:0.76845	validation_0-auc:0.78156
# [2252]	validation_0-aucpr:0.76849	validation_0-auc:0.78157
# [2253]	validation_0-aucpr:0.76848	validation_0-auc:0.78157
# [2254]	validation_0-aucpr:0.76847	validation_0-auc:0.78158
# [2255]	validation_0-aucpr:0.76848	validation_0-auc:0.78160
# [2256]	validation_0-aucpr:0.76846	validation_0-auc:0.78159
# [2257]	validation_0-aucpr:0.76846	validation_0-auc:0.78159
# [2258]	validation_0-aucpr:0.76847	validation_0-auc:0.78160
# [2259]	validation_0-aucpr:0.76849	validation_0-auc:0.78160
# [2260]	validation_0-aucpr:0.76852	validation_0-auc:0.78161
# [2261]	validation_0-aucpr:0.76854	validation_0-auc:0.78160
# [2262]	validation_0-aucpr:0.76855	validation_0-auc:0.78160
# [2263]	validation_0-aucpr:0.76852	validation_0-auc:0.78159
# [2264]	validation_0-aucpr:0.76848	validation_0-auc:0.78159
# [2265]	validation_0-aucpr:0.76851	validation_0-auc:0.78159
# [2266]	validation_0-aucpr:0.76852	validation_0-auc:0.78160
# [2267]	validation_0-aucpr:0.76852	validation_0-auc:0.78161
# [2268]	validation_0-aucpr:0.76853	validation_0-auc:0.78161
# [2269]	validation_0-aucpr:0.76853	validation_0-auc:0.78161
# [2270]	validation_0-aucpr:0.76856	validation_0-auc:0.78161
# [2271]	validation_0-aucpr:0.76857	validation_0-auc:0.78161
# [2272]	validation_0-aucpr:0.76853	validation_0-auc:0.78158
# [2273]	validation_0-aucpr:0.76852	validation_0-auc:0.78158
# [2274]	validation_0-aucpr:0.76851	validation_0-auc:0.78157
# [2275]	validation_0-aucpr:0.76852	validation_0-auc:0.78158
# [2276]	validation_0-aucpr:0.76856	validation_0-auc:0.78159
# [2277]	validation_0-aucpr:0.76856	validation_0-auc:0.78159
# [2278]	validation_0-aucpr:0.76856	validation_0-auc:0.78159
# [2279]	validation_0-aucpr:0.76853	validation_0-auc:0.78159
# [2280]	validation_0-aucpr:0.76844	validation_0-auc:0.78158
# [2281]	validation_0-aucpr:0.76844	validation_0-auc:0.78159
# [2282]	validation_0-aucpr:0.76846	validation_0-auc:0.78160
# [2283]	validation_0-aucpr:0.76846	validation_0-auc:0.78160
# [2284]	validation_0-aucpr:0.76845	validation_0-auc:0.78159
# [2285]	validation_0-aucpr:0.76848	validation_0-auc:0.78159
# [2286]	validation_0-aucpr:0.76848	validation_0-auc:0.78158
# [2287]	validation_0-aucpr:0.76843	validation_0-auc:0.78158
# [2288]	validation_0-aucpr:0.76842	validation_0-auc:0.78157
# [2289]	validation_0-aucpr:0.76841	validation_0-auc:0.78157
# [2290]	validation_0-aucpr:0.76842	validation_0-auc:0.78156
# [2291]	validation_0-aucpr:0.76843	validation_0-auc:0.78157
# [2292]	validation_0-aucpr:0.76843	validation_0-auc:0.78159
# [2293]	validation_0-aucpr:0.76842	validation_0-auc:0.78159
# [2294]	validation_0-aucpr:0.76849	validation_0-auc:0.78159
# [2295]	validation_0-aucpr:0.76848	validation_0-auc:0.78159
# [2296]	validation_0-aucpr:0.76848	validation_0-auc:0.78159
# [2297]	validation_0-aucpr:0.76849	validation_0-auc:0.78158
# [2298]	validation_0-aucpr:0.76848	validation_0-auc:0.78159
# [2299]	validation_0-aucpr:0.76847	validation_0-auc:0.78158
# [2300]	validation_0-aucpr:0.76852	validation_0-auc:0.78158
# [2301]	validation_0-aucpr:0.76853	validation_0-auc:0.78159
# [2302]	validation_0-aucpr:0.76850	validation_0-auc:0.78159
# [2303]	validation_0-aucpr:0.76850	validation_0-auc:0.78159
# [2304]	validation_0-aucpr:0.76849	validation_0-auc:0.78161
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.8, colsample_bynode=0.8, colsample_bytree=0.8,
#               device='cuda', early_stopping_rounds=200, enable_categorical=True,
#               eval_metric=['aucpr', 'auc'], feature_types=None,
#               feature_weights=None, gamma=0.2, grow_policy='depthwise',
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=1, max_depth=6,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=3000,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
# Probabilidades (idéntico conceptualmente)
y_val_proba = model.predict_proba(X_val)[:, 1]

# AUC (esto es lo importante)
auc = roc_auc_score(y_val, y_val_proba)

#optimal threshold
thresholds = np.linspace(0.05, 0.6, 100)
f1_scores = [f1_score(y_val, y_val_proba >= t) for t in thresholds]


optimal_threshold = thresholds[np.argmax(f1_scores)]
print(f'optimal threshold: {optimal_threshold}')

#Threshold (solo para métricas de clasificación)
adj_threshold = optimal_threshold

y_val_pred = (y_val_proba >= adj_threshold).astype(int)

# Classification report
report = classification_report(y_val, y_val_pred)

#Confusion matrix manual
TP = np.sum((y_val == 1) & (y_val_pred == 1))
FP = np.sum((y_val == 0) & (y_val_pred == 1))
TN = np.sum((y_val == 0) & (y_val_pred == 0))
FN = np.sum((y_val == 1) & (y_val_pred == 0))

FPR = FP / (FP + TN)
Precision = TP / (TP + FP)

print(f"FPR: {FPR:.4f}")
print(f"Precision (PPV): {Precision:.4f}")
print(f"AUC validación: {auc:.5f}")
print(report)

cm = confusion_matrix(y_val, y_val_pred)
print(f"\n📊 Matriz de Confusión:")
print(f"                 Predicho")
print(f"               No Def  Default")
print(f"Real No Def    {cm[0, 0]:6d}   {cm[0, 1]:6d}")
print(f"Real Default   {cm[1, 0]:6d}   {cm[1, 1]:6d}")
# Out:
# optimal threshold: 0.38888888888888884
# FPR: 0.4382
# Precision (PPV): 0.6574
# AUC validación: 0.78164
#               precision    recall  f1-score   support
#
#            0       0.78      0.56      0.65      2184
#            1       0.66      0.84      0.74      2183
#
#     accuracy                           0.70      4367
#    macro avg       0.72      0.70      0.70      4367
# weighted avg       0.72      0.70      0.70      4367
#
#
# 📊 Matriz de Confusión:
#                  Predicho
#                No Def  Default
# Real No Def      1227      957
# Real Default      347     1836

# %%
df = pd.read_csv("../data/processed/home_credit_train_ready.csv")

y = df['TARGET']
X = df.drop(columns = ['TARGET', 'SK_ID_CURR'])

X.replace([np.inf, -np.inf], np.nan, inplace=True)

cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

num_imputer = SimpleImputer(strategy="median")  #change median for mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

for col in X.select_dtypes("object"):
    X[col] = X[col].astype("category")

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.6, stratify=y ,random_state=42)

# Probabilidades (idéntico conceptualmente)
y_val_proba = model.predict_proba(X_val)[:, 1]

# AUC (esto es lo importante)
auc = roc_auc_score(y_val, y_val_proba)

#optimal threshold based on expected loss
cost_FN = 10000   # default
cost_FP = 1000    # lost good client

losses = []

for t in thresholds:
    y_pred = (y_val_proba >= t).astype(int)

    FP = np.sum((y_val == 0) & (y_pred == 1))
    FN = np.sum((y_val == 1) & (y_pred == 0))

    loss = FP * cost_FP + FN * cost_FN
    losses.append(loss)

optimal_threshold = thresholds[np.argmin(losses)]


#Threshold (solo para métricas de clasificación)
adj_threshold = optimal_threshold

y_val_pred = (y_val_proba >= adj_threshold).astype(int)

# Classification report
report = classification_report(y_val, y_val_pred)

#Confusion matrix manual
TP = np.sum((y_val == 1) & (y_val_pred == 1))
FP = np.sum((y_val == 0) & (y_val_pred == 1))
TN = np.sum((y_val == 0) & (y_val_pred == 0))
FN = np.sum((y_val == 1) & (y_val_pred == 0))

FPR = FP / (FP + TN)
Precision = TP / (TP + FP)

print(f'used threshold: {adj_threshold}')
print(f"FPR: {FPR:.4f}")
print(f"Precision (PPV): {Precision:.4f}")
print(f"AUC validación: {auc:.5f}")
print(report)

cm = confusion_matrix(y_val, y_val_pred)
print(f"\n📊 Matriz de Confusión:")
print(f"                 Predicho")
print(f"               No Def  Default")
print(f"Real No Def    {cm[0, 0]:6d}   {cm[0, 1]:6d}")
print(f"Real Default   {cm[1, 0]:6d}   {cm[1, 1]:6d}")
# Out:
# used threshold: 0.5166666666666666
# FPR: 0.2518
# Precision (PPV): 0.2259
# AUC validación: 0.84252
#               precision    recall  f1-score   support
#
#            0       0.97      0.75      0.85    138182
#            1       0.23      0.78      0.35     13101
#
#     accuracy                           0.75    151283
#    macro avg       0.60      0.76      0.60    151283
# weighted avg       0.91      0.75      0.80    151283
#
#
# 📊 Matriz de Confusión:
#                  Predicho
#                No Def  Default
# Real No Def    103388    34794
# Real Default     2947    10154

# %%
joblib.dump(model, '../models/xgb_new_dataset.pkl')
# Out:
# ['../models/xgb_new_dataset.pkl']
