# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
import shap

# %%
app_train = pd.read_csv('../data/interim/aplicationtrainlimpio1.csv')
app_test = pd.read_csv('../data/raw/application_ts.csv')
bureau = pd.read_csv('../data/raw/bureau.csv')
bureau_balance = pd.read_csv('../data/raw/bureau_balance.csv')
previous = pd.read_csv('../data/raw/previous_application.csv')
pos_cash = pd.read_csv('../data/raw/POS_CASH_balance.csv')
credit_card = pd.read_csv('../data/raw/credit_card_balance.csv')
installments = pd.read_csv('../data/raw/installments_payments.csv')

# %%
bureau_full = bureau.merge(
    bureau_balance,
    on="SK_ID_BUREAU",
    how="left")

# %%
bureau_features = (
    bureau_full
    .groupby("SK_ID_CURR")
    .agg(
        bureau_loans=("SK_ID_BUREAU", "nunique"),
        bureau_days_credit_mean=("DAYS_CREDIT", "mean"),
        bureau_days_credit_min=("DAYS_CREDIT", "min"),
        bureau_credit_sum=("AMT_CREDIT_SUM", "sum"),
        bureau_credit_active=("CREDIT_ACTIVE", lambda x: (x == "Active").sum()),
        bureau_months_reported=("MONTHS_BALANCE", "count")
    )
    .reset_index()
)

# Créditos activos actuales (los que más pesan en riesgo)
active_bureau = bureau[bureau["CREDIT_ACTIVE"] == "Active"].groupby("SK_ID_CURR").agg(
    active_loans_count=("SK_ID_BUREAU", "count"),
    active_debt_sum=("AMT_CREDIT_SUM_DEBT", "sum"),
    active_overdue_sum=("AMT_CREDIT_SUM_OVERDUE", "sum")
).reset_index()

# Créditos cerrados recientemente (últimos 2 años)
recent_bureau = bureau[bureau["DAYS_CREDIT"] >= -730].groupby("SK_ID_CURR").agg(
    recent_loans_count=("SK_ID_BUREAU", "count"),
    recent_overdue_mean=("AMT_CREDIT_SUM_OVERDUE", "mean")
).reset_index()

# Unir al dataframe principal de bureau_features
bureau_features = bureau_features.merge(active_bureau, on="SK_ID_CURR", how="left")
bureau_features = bureau_features.merge(recent_bureau, on="SK_ID_CURR", how="left").fillna(0)

bureau_features.to_parquet("../data/interim/bureau_features.parquet")

# %%
prev_features = (
    previous
    .groupby("SK_ID_CURR")
    .agg(
        prev_apps=("SK_ID_PREV", "nunique"),
        prev_amt_mean=("AMT_APPLICATION", "mean"),
        prev_amt_max=("AMT_APPLICATION", "max"),
        prev_refused=("NAME_CONTRACT_STATUS", lambda x: (x == "Refused").sum()),
        prev_approved=("NAME_CONTRACT_STATUS", lambda x: (x == "Approved").sum()),
        prev_days_decision_mean=("DAYS_DECISION", "mean")
    )
    .reset_index()
)

prev_features.to_parquet("../data/interim/prev_features.parquet")

# %%
# 1. Definir qué es un pago atrasado
installments["late"] = (installments["DAYS_ENTRY_PAYMENT"] > installments["DAYS_INSTALMENT"]).astype(int)
installments["dbd"] = installments["DAYS_INSTALMENT"] - installments["DAYS_ENTRY_PAYMENT"] # Días de anticipación (Days Before Due)

# 2. Agregaciones generales (Toda la historia)
inst_features = installments.groupby("SK_ID_CURR").agg(
    inst_count_total=("SK_ID_PREV", "count"),
    inst_late_ratio_total=("late", "mean"),
    inst_dbd_mean_total=("dbd", "mean")
).reset_index()

# 3. Agregaciones RECIENTES (Último año: 365 días)
# Filtramos primero, luego agrupamos
recent_inst = installments[installments["DAYS_INSTALMENT"] >= -365].groupby("SK_ID_CURR").agg(
    inst_late_ratio_1y=("late", "mean"),
    inst_dbd_mean_1y=("dbd", "mean"),
    inst_amt_paid_1y=("AMT_PAYMENT", "sum")
).reset_index()

# 4. Unir ambas
inst_features = inst_features.merge(recent_inst, on="SK_ID_CURR", how="left").fillna(0)

# 5. Variable de TENDENCIA (¿Está empeorando?)
# Si el ratio de retrasos del último año es mayor al histórico, el riesgo sube.
inst_features['inst_late_trend'] = inst_features['inst_late_ratio_1y'] / (inst_features['inst_late_ratio_total'] + 0.001)
inst_features.to_parquet("../data/interim/installments_features.parquet")

# %%
pos_features = (
    pos_cash
    .groupby("SK_ID_CURR")
    .agg(
        pos_loans=("SK_ID_PREV", "nunique"),
        pos_months=("MONTHS_BALANCE", "count"),
        pos_dpd_mean=("SK_DPD", "mean"),
        pos_dpd_def_mean=("SK_DPD_DEF", "mean")
    )
    .reset_index()
)

# DPD máximo en los últimos 6 meses
pos_recent = pos_cash[pos_cash["MONTHS_BALANCE"] >= -6].groupby("SK_ID_CURR").agg(
    pos_recent_max_dpd=("SK_DPD", "max"),
    pos_recent_count_dpd=("SK_DPD", lambda x: (x > 0).sum())
).reset_index()

pos_features = pos_features.merge(pos_recent, on="SK_ID_CURR", how="left").fillna(0)

pos_features.to_parquet("../data/interim/pos_features.parquet")

# %%
cc_features = (
    credit_card
    .groupby("SK_ID_CURR")
    .agg(
        cc_loans=("SK_ID_PREV", "nunique"),
        cc_balance_mean=("AMT_BALANCE", "mean"),
        cc_limit_mean=("AMT_CREDIT_LIMIT_ACTUAL", "mean"),
        cc_utilization=("AMT_BALANCE", "mean")
    )
    .reset_index()
)

cc_features.to_parquet("../data/interim/cc_features.parquet")

# %%
df_train = (
    app_train
    .merge(bureau_features, on="SK_ID_CURR", how="left")
    .merge(prev_features, on="SK_ID_CURR", how="left")
    .merge(inst_features, on="SK_ID_CURR", how="left")
    .merge(pos_features, on="SK_ID_CURR", how="left")
    .merge(cc_features, on="SK_ID_CURR", how="left")
)

df_train.to_parquet("../data/interim/train_final.parquet")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 108 entries, SK_ID_CURR to cc_utilization
# dtypes: float64(56), int64(40), object(12)
# memory usage: 253.4+ MB

# %%
df_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  pos_loans pos_months pos_dpd_mean pos_dpd_def_mean pos_recent_max_dpd  \
# 0  ...        1.0       19.0          0.0              0.0                0.0
# 1  ...        3.0       28.0          0.0              0.0                0.0
# 2  ...        1.0        4.0          0.0              0.0                0.0
# 3  ...        3.0       21.0          0.0              0.0                0.0
# 4  ...        5.0       66.0          0.0              0.0                0.0
#
#   pos_recent_count_dpd  cc_loans  cc_balance_mean  cc_limit_mean  \
# 0                  0.0       NaN              NaN            NaN
# 1                  0.0       NaN              NaN            NaN
# 2                  0.0       NaN              NaN            NaN
# 3                  0.0       1.0              0.0       270000.0
# 4                  0.0       NaN              NaN            NaN
#
#    cc_utilization
# 0             NaN
# 1             NaN
# 2             NaN
# 3             0.0
# 4             NaN
#
# [5 rows x 108 columns]

# %%
TARGET = "TARGET"
y = df_train[TARGET]
X = df_train.drop(columns=[TARGET])

# %%
cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

print(f"Categóricas: {len(cat_cols)}")
print(f"Numéricas: {len(num_cols)}")
# Out:
# Categóricas: 12
# Numéricas: 95

# %%
num_imputer = SimpleImputer(strategy="mean") #change median for mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

# %%
X = pd.get_dummies(X, columns=cat_cols, drop_first=True)

# %%
print(X.isna().sum().sum())  # must be 0
print(X.shape)
# Out:
# 0
# (307511, 209)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=X_train.columns,
    index=X_train.index
)

X_val = pd.DataFrame(
    scaler.transform(X_val),
    columns=X_val.columns,
    index=X_val.index
)

# %%
'''
This library needs sklearn 1.3.2
and imblearn 0.11.0
'''

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline


# Combine over and under sampling
over = SMOTE(sampling_strategy=0.3)
under = RandomUnderSampler(sampling_strategy=0.7)
steps = [('over', over), ('under', under)]
pipeline = ImbPipeline(steps=steps)
X_train, y_train = pipeline.fit_resample(X_train, y_train)

# %%
X_train.shape
# Out:
# (164764, 209)

# %%
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif


#F-score (lineal)
selector_f = SelectKBest(score_func=f_classif, k=150)
X_train_f = selector_f.fit_transform(X_train, y_train)

'''
#Mutual Information (no lineal)
selector_mi = SelectKBest(score_func=mutual_info_classif, k=100)
X_train_mi = selector_mi.fit_transform(X_train, y_train)
'''
#Intersection
features_f = X_train.columns[selector_f.get_support()].tolist()
#features_mi = X_train.columns[selector_mi.get_support()].tolist()
#features_common = list(set(features_f) & set(features_mi))


X_train = X_train[features_f]
X_val = X_val[features_f]

print(f"Selected features: {len(features_f)}")
# Out:
# Selected features: 150

# %%
neg = (y_train == 0).sum()
pos = (y_train == 1).sum()

scale = neg / pos

# %%
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'tree_method': 'hist',

    # core
    'learning_rate': 0.03,
    'n_estimators': 5500,
    'max_depth': 3,
    'min_child_weight': 20,

    # sampling
    'subsample': 0.8,
    'colsample_bytree': 0.8,

    # imbalance
    'scale_pos_weight': scale,

    # regularization
    'reg_alpha': 0.5,
    'reg_lambda': 2.0,
    'gamma': 1.0,
}


xgb_model = XGBClassifier(**params, n_jobs=-1, random_state=42,  early_stopping_rounds=300)

# %%
xgb_model.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    verbose=True)
# Out:
# [0]	validation_0-auc:0.69111
# [1]	validation_0-auc:0.69366
# [2]	validation_0-auc:0.70314
# [3]	validation_0-auc:0.70160
# [4]	validation_0-auc:0.70688
# [5]	validation_0-auc:0.71187
# [6]	validation_0-auc:0.71363
# [7]	validation_0-auc:0.71887
# [8]	validation_0-auc:0.71859
# [9]	validation_0-auc:0.71785
# [10]	validation_0-auc:0.71803
# [11]	validation_0-auc:0.71827
# [12]	validation_0-auc:0.72009
# [13]	validation_0-auc:0.71956
# [14]	validation_0-auc:0.71991
# [15]	validation_0-auc:0.72244
# [16]	validation_0-auc:0.72273
# [17]	validation_0-auc:0.72248
# [18]	validation_0-auc:0.72313
# [19]	validation_0-auc:0.72334
# [20]	validation_0-auc:0.72327
# [21]	validation_0-auc:0.72343
# [22]	validation_0-auc:0.72356
# [23]	validation_0-auc:0.72402
# [24]	validation_0-auc:0.72498
# [25]	validation_0-auc:0.72522
# [26]	validation_0-auc:0.72511
# [27]	validation_0-auc:0.72513
# [28]	validation_0-auc:0.72543
# [29]	validation_0-auc:0.72626
# [30]	validation_0-auc:0.72610
# [31]	validation_0-auc:0.72613
# [32]	validation_0-auc:0.72678
# [33]	validation_0-auc:0.72694
# [34]	validation_0-auc:0.72735
# [35]	validation_0-auc:0.72809
# [36]	validation_0-auc:0.72820
# [37]	validation_0-auc:0.72841
# [38]	validation_0-auc:0.72874
# [39]	validation_0-auc:0.72879
# [40]	validation_0-auc:0.72898
# [41]	validation_0-auc:0.72923
# [42]	validation_0-auc:0.72952
# [43]	validation_0-auc:0.72961
# [44]	validation_0-auc:0.72970
# [45]	validation_0-auc:0.73012
# [46]	validation_0-auc:0.73048
# [47]	validation_0-auc:0.73112
# [48]	validation_0-auc:0.73145
# [49]	validation_0-auc:0.73176
# [50]	validation_0-auc:0.73209
# [51]	validation_0-auc:0.73222
# [52]	validation_0-auc:0.73249
# [53]	validation_0-auc:0.73310
# [54]	validation_0-auc:0.73330
# [55]	validation_0-auc:0.73356
# [56]	validation_0-auc:0.73379
# [57]	validation_0-auc:0.73413
# [58]	validation_0-auc:0.73451
# [59]	validation_0-auc:0.73473
# [60]	validation_0-auc:0.73516
# [61]	validation_0-auc:0.73549
# [62]	validation_0-auc:0.73590
# [63]	validation_0-auc:0.73627
# [64]	validation_0-auc:0.73637
# [65]	validation_0-auc:0.73691
# [66]	validation_0-auc:0.73732
# [67]	validation_0-auc:0.73774
# [68]	validation_0-auc:0.73786
# [69]	validation_0-auc:0.73802
# [70]	validation_0-auc:0.73850
# [71]	validation_0-auc:0.73893
# [72]	validation_0-auc:0.73927
# [73]	validation_0-auc:0.73968
# [74]	validation_0-auc:0.73993
# [75]	validation_0-auc:0.74013
# [76]	validation_0-auc:0.74056
# [77]	validation_0-auc:0.74075
# [78]	validation_0-auc:0.74106
# [79]	validation_0-auc:0.74146
# [80]	validation_0-auc:0.74183
# [81]	validation_0-auc:0.74204
# [82]	validation_0-auc:0.74223
# [83]	validation_0-auc:0.74257
# [84]	validation_0-auc:0.74292
# [85]	validation_0-auc:0.74321
# [86]	validation_0-auc:0.74364
# [87]	validation_0-auc:0.74382
# [88]	validation_0-auc:0.74397
# [89]	validation_0-auc:0.74414
# [90]	validation_0-auc:0.74436
# [91]	validation_0-auc:0.74467
# [92]	validation_0-auc:0.74499
# [93]	validation_0-auc:0.74528
# [94]	validation_0-auc:0.74547
# [95]	validation_0-auc:0.74573
# [96]	validation_0-auc:0.74611
# [97]	validation_0-auc:0.74635
# [98]	validation_0-auc:0.74667
# [99]	validation_0-auc:0.74688
# [100]	validation_0-auc:0.74710
# [101]	validation_0-auc:0.74722
# [102]	validation_0-auc:0.74742
# [103]	validation_0-auc:0.74759
# [104]	validation_0-auc:0.74774
# [105]	validation_0-auc:0.74790
# [106]	validation_0-auc:0.74808
# [107]	validation_0-auc:0.74818
# [108]	validation_0-auc:0.74831
# [109]	validation_0-auc:0.74851
# [110]	validation_0-auc:0.74875
# [111]	validation_0-auc:0.74898
# [112]	validation_0-auc:0.74921
# [113]	validation_0-auc:0.74953
# [114]	validation_0-auc:0.74976
# [115]	validation_0-auc:0.75006
# [116]	validation_0-auc:0.75021
# [117]	validation_0-auc:0.75041
# [118]	validation_0-auc:0.75056
# [119]	validation_0-auc:0.75097
# [120]	validation_0-auc:0.75104
# [121]	validation_0-auc:0.75116
# [122]	validation_0-auc:0.75136
# [123]	validation_0-auc:0.75157
# [124]	validation_0-auc:0.75182
# [125]	validation_0-auc:0.75201
# [126]	validation_0-auc:0.75224
# [127]	validation_0-auc:0.75231
# [128]	validation_0-auc:0.75240
# [129]	validation_0-auc:0.75257
# [130]	validation_0-auc:0.75274
# [131]	validation_0-auc:0.75286
# [132]	validation_0-auc:0.75300
# [133]	validation_0-auc:0.75311
# [134]	validation_0-auc:0.75324
# [135]	validation_0-auc:0.75339
# [136]	validation_0-auc:0.75346
# [137]	validation_0-auc:0.75357
# [138]	validation_0-auc:0.75372
# [139]	validation_0-auc:0.75386
# [140]	validation_0-auc:0.75395
# [141]	validation_0-auc:0.75405
# [142]	validation_0-auc:0.75408
# [143]	validation_0-auc:0.75413
# [144]	validation_0-auc:0.75433
# [145]	validation_0-auc:0.75446
# [146]	validation_0-auc:0.75470
# [147]	validation_0-auc:0.75484
# [148]	validation_0-auc:0.75496
# [149]	validation_0-auc:0.75510
# [150]	validation_0-auc:0.75524
# [151]	validation_0-auc:0.75534
# [152]	validation_0-auc:0.75560
# [153]	validation_0-auc:0.75572
# [154]	validation_0-auc:0.75586
# [155]	validation_0-auc:0.75588
# [156]	validation_0-auc:0.75594
# [157]	validation_0-auc:0.75599
# [158]	validation_0-auc:0.75612
# [159]	validation_0-auc:0.75624
# [160]	validation_0-auc:0.75636
# [161]	validation_0-auc:0.75646
# [162]	validation_0-auc:0.75657
# [163]	validation_0-auc:0.75672
# [164]	validation_0-auc:0.75685
# [165]	validation_0-auc:0.75695
# [166]	validation_0-auc:0.75705
# [167]	validation_0-auc:0.75713
# [168]	validation_0-auc:0.75722
# [169]	validation_0-auc:0.75735
# [170]	validation_0-auc:0.75743
# [171]	validation_0-auc:0.75756
# [172]	validation_0-auc:0.75763
# [173]	validation_0-auc:0.75773
# [174]	validation_0-auc:0.75780
# [175]	validation_0-auc:0.75784
# [176]	validation_0-auc:0.75807
# [177]	validation_0-auc:0.75821
# [178]	validation_0-auc:0.75824
# [179]	validation_0-auc:0.75837
# [180]	validation_0-auc:0.75845
# [181]	validation_0-auc:0.75854
# [182]	validation_0-auc:0.75859
# [183]	validation_0-auc:0.75867
# [184]	validation_0-auc:0.75878
# [185]	validation_0-auc:0.75886
# [186]	validation_0-auc:0.75892
# [187]	validation_0-auc:0.75898
# [188]	validation_0-auc:0.75908
# [189]	validation_0-auc:0.75916
# [190]	validation_0-auc:0.75922
# [191]	validation_0-auc:0.75927
# [192]	validation_0-auc:0.75935
# [193]	validation_0-auc:0.75939
# [194]	validation_0-auc:0.75946
# [195]	validation_0-auc:0.75954
# [196]	validation_0-auc:0.75965
# [197]	validation_0-auc:0.75971
# [198]	validation_0-auc:0.75976
# [199]	validation_0-auc:0.75981
# [200]	validation_0-auc:0.75989
# [201]	validation_0-auc:0.75997
# [202]	validation_0-auc:0.76002
# [203]	validation_0-auc:0.76018
# [204]	validation_0-auc:0.76039
# [205]	validation_0-auc:0.76049
# [206]	validation_0-auc:0.76056
# [207]	validation_0-auc:0.76069
# [208]	validation_0-auc:0.76077
# [209]	validation_0-auc:0.76084
# [210]	validation_0-auc:0.76093
# [211]	validation_0-auc:0.76099
# [212]	validation_0-auc:0.76109
# [213]	validation_0-auc:0.76117
# [214]	validation_0-auc:0.76121
# [215]	validation_0-auc:0.76128
# [216]	validation_0-auc:0.76133
# [217]	validation_0-auc:0.76142
# [218]	validation_0-auc:0.76147
# [219]	validation_0-auc:0.76152
# [220]	validation_0-auc:0.76161
# [221]	validation_0-auc:0.76165
# [222]	validation_0-auc:0.76170
# [223]	validation_0-auc:0.76174
# [224]	validation_0-auc:0.76182
# [225]	validation_0-auc:0.76197
# [226]	validation_0-auc:0.76213
# [227]	validation_0-auc:0.76220
# [228]	validation_0-auc:0.76226
# [229]	validation_0-auc:0.76231
# [230]	validation_0-auc:0.76232
# [231]	validation_0-auc:0.76239
# [232]	validation_0-auc:0.76246
# [233]	validation_0-auc:0.76258
# [234]	validation_0-auc:0.76264
# [235]	validation_0-auc:0.76271
# [236]	validation_0-auc:0.76274
# [237]	validation_0-auc:0.76281
# [238]	validation_0-auc:0.76287
# [239]	validation_0-auc:0.76295
# [240]	validation_0-auc:0.76302
# [241]	validation_0-auc:0.76304
# [242]	validation_0-auc:0.76307
# [243]	validation_0-auc:0.76313
# [244]	validation_0-auc:0.76318
# [245]	validation_0-auc:0.76322
# [246]	validation_0-auc:0.76328
# [247]	validation_0-auc:0.76336
# [248]	validation_0-auc:0.76343
# [249]	validation_0-auc:0.76343
# [250]	validation_0-auc:0.76347
# [251]	validation_0-auc:0.76350
# [252]	validation_0-auc:0.76354
# [253]	validation_0-auc:0.76358
# [254]	validation_0-auc:0.76371
# [255]	validation_0-auc:0.76373
# [256]	validation_0-auc:0.76384
# [257]	validation_0-auc:0.76388
# [258]	validation_0-auc:0.76394
# [259]	validation_0-auc:0.76403
# [260]	validation_0-auc:0.76406
# [261]	validation_0-auc:0.76410
# [262]	validation_0-auc:0.76415
# [263]	validation_0-auc:0.76421
# [264]	validation_0-auc:0.76427
# [265]	validation_0-auc:0.76429
# [266]	validation_0-auc:0.76438
# [267]	validation_0-auc:0.76441
# [268]	validation_0-auc:0.76446
# [269]	validation_0-auc:0.76449
# [270]	validation_0-auc:0.76452
# [271]	validation_0-auc:0.76457
# [272]	validation_0-auc:0.76461
# [273]	validation_0-auc:0.76467
# [274]	validation_0-auc:0.76472
# [275]	validation_0-auc:0.76475
# [276]	validation_0-auc:0.76485
# [277]	validation_0-auc:0.76495
# [278]	validation_0-auc:0.76499
# [279]	validation_0-auc:0.76502
# [280]	validation_0-auc:0.76510
# [281]	validation_0-auc:0.76516
# [282]	validation_0-auc:0.76518
# [283]	validation_0-auc:0.76523
# [284]	validation_0-auc:0.76528
# [285]	validation_0-auc:0.76533
# [286]	validation_0-auc:0.76546
# [287]	validation_0-auc:0.76550
# [288]	validation_0-auc:0.76553
# [289]	validation_0-auc:0.76557
# [290]	validation_0-auc:0.76560
# [291]	validation_0-auc:0.76566
# [292]	validation_0-auc:0.76573
# [293]	validation_0-auc:0.76578
# [294]	validation_0-auc:0.76582
# [295]	validation_0-auc:0.76589
# [296]	validation_0-auc:0.76594
# [297]	validation_0-auc:0.76600
# [298]	validation_0-auc:0.76604
# [299]	validation_0-auc:0.76606
# [300]	validation_0-auc:0.76610
# [301]	validation_0-auc:0.76614
# [302]	validation_0-auc:0.76618
# [303]	validation_0-auc:0.76619
# [304]	validation_0-auc:0.76622
# [305]	validation_0-auc:0.76623
# [306]	validation_0-auc:0.76626
# [307]	validation_0-auc:0.76630
# [308]	validation_0-auc:0.76630
# [309]	validation_0-auc:0.76633
# [310]	validation_0-auc:0.76636
# [311]	validation_0-auc:0.76640
# [312]	validation_0-auc:0.76647
# [313]	validation_0-auc:0.76651
# [314]	validation_0-auc:0.76651
# [315]	validation_0-auc:0.76653
# [316]	validation_0-auc:0.76655
# [317]	validation_0-auc:0.76659
# [318]	validation_0-auc:0.76670
# [319]	validation_0-auc:0.76676
# [320]	validation_0-auc:0.76676
# [321]	validation_0-auc:0.76678
# [322]	validation_0-auc:0.76682
# [323]	validation_0-auc:0.76684
# [324]	validation_0-auc:0.76687
# [325]	validation_0-auc:0.76692
# [326]	validation_0-auc:0.76696
# [327]	validation_0-auc:0.76706
# [328]	validation_0-auc:0.76710
# [329]	validation_0-auc:0.76712
# [330]	validation_0-auc:0.76718
# [331]	validation_0-auc:0.76723
# [332]	validation_0-auc:0.76728
# [333]	validation_0-auc:0.76728
# [334]	validation_0-auc:0.76729
# [335]	validation_0-auc:0.76733
# [336]	validation_0-auc:0.76738
# [337]	validation_0-auc:0.76739
# [338]	validation_0-auc:0.76743
# [339]	validation_0-auc:0.76745
# [340]	validation_0-auc:0.76748
# [341]	validation_0-auc:0.76749
# [342]	validation_0-auc:0.76751
# [343]	validation_0-auc:0.76756
# [344]	validation_0-auc:0.76761
# [345]	validation_0-auc:0.76763
# [346]	validation_0-auc:0.76766
# [347]	validation_0-auc:0.76770
# [348]	validation_0-auc:0.76773
# [349]	validation_0-auc:0.76777
# [350]	validation_0-auc:0.76787
# [351]	validation_0-auc:0.76790
# [352]	validation_0-auc:0.76793
# [353]	validation_0-auc:0.76796
# [354]	validation_0-auc:0.76798
# [355]	validation_0-auc:0.76801
# [356]	validation_0-auc:0.76804
# [357]	validation_0-auc:0.76805
# [358]	validation_0-auc:0.76807
# [359]	validation_0-auc:0.76808
# [360]	validation_0-auc:0.76817
# [361]	validation_0-auc:0.76818
# [362]	validation_0-auc:0.76824
# [363]	validation_0-auc:0.76825
# [364]	validation_0-auc:0.76827
# [365]	validation_0-auc:0.76829
# [366]	validation_0-auc:0.76833
# [367]	validation_0-auc:0.76837
# [368]	validation_0-auc:0.76842
# [369]	validation_0-auc:0.76845
# [370]	validation_0-auc:0.76846
# [371]	validation_0-auc:0.76850
# [372]	validation_0-auc:0.76853
# [373]	validation_0-auc:0.76853
# [374]	validation_0-auc:0.76855
# [375]	validation_0-auc:0.76858
# [376]	validation_0-auc:0.76860
# [377]	validation_0-auc:0.76862
# [378]	validation_0-auc:0.76864
# [379]	validation_0-auc:0.76867
# [380]	validation_0-auc:0.76869
# [381]	validation_0-auc:0.76872
# [382]	validation_0-auc:0.76874
# [383]	validation_0-auc:0.76876
# [384]	validation_0-auc:0.76879
# [385]	validation_0-auc:0.76881
# [386]	validation_0-auc:0.76883
# [387]	validation_0-auc:0.76883
# [388]	validation_0-auc:0.76886
# [389]	validation_0-auc:0.76890
# [390]	validation_0-auc:0.76894
# [391]	validation_0-auc:0.76893
# [392]	validation_0-auc:0.76897
# [393]	validation_0-auc:0.76900
# [394]	validation_0-auc:0.76904
# [395]	validation_0-auc:0.76905
# [396]	validation_0-auc:0.76906
# [397]	validation_0-auc:0.76910
# [398]	validation_0-auc:0.76911
# [399]	validation_0-auc:0.76913
# [400]	validation_0-auc:0.76915
# [401]	validation_0-auc:0.76915
# [402]	validation_0-auc:0.76918
# [403]	validation_0-auc:0.76920
# [404]	validation_0-auc:0.76921
# [405]	validation_0-auc:0.76924
# [406]	validation_0-auc:0.76923
# [407]	validation_0-auc:0.76929
# [408]	validation_0-auc:0.76939
# [409]	validation_0-auc:0.76944
# [410]	validation_0-auc:0.76945
# [411]	validation_0-auc:0.76948
# [412]	validation_0-auc:0.76950
# [413]	validation_0-auc:0.76952
# [414]	validation_0-auc:0.76952
# [415]	validation_0-auc:0.76954
# [416]	validation_0-auc:0.76955
# [417]	validation_0-auc:0.76961
# [418]	validation_0-auc:0.76961
# [419]	validation_0-auc:0.76966
# [420]	validation_0-auc:0.76967
# [421]	validation_0-auc:0.76969
# [422]	validation_0-auc:0.76978
# [423]	validation_0-auc:0.76978
# [424]	validation_0-auc:0.76980
# [425]	validation_0-auc:0.76983
# [426]	validation_0-auc:0.76984
# [427]	validation_0-auc:0.76986
# [428]	validation_0-auc:0.76989
# [429]	validation_0-auc:0.76993
# [430]	validation_0-auc:0.76995
# [431]	validation_0-auc:0.77001
# [432]	validation_0-auc:0.77002
# [433]	validation_0-auc:0.77003
# [434]	validation_0-auc:0.77006
# [435]	validation_0-auc:0.77010
# [436]	validation_0-auc:0.77018
# [437]	validation_0-auc:0.77020
# [438]	validation_0-auc:0.77021
# [439]	validation_0-auc:0.77021
# [440]	validation_0-auc:0.77023
# [441]	validation_0-auc:0.77023
# [442]	validation_0-auc:0.77024
# [443]	validation_0-auc:0.77025
# [444]	validation_0-auc:0.77026
# [445]	validation_0-auc:0.77030
# [446]	validation_0-auc:0.77040
# [447]	validation_0-auc:0.77043
# [448]	validation_0-auc:0.77044
# [449]	validation_0-auc:0.77045
# [450]	validation_0-auc:0.77050
# [451]	validation_0-auc:0.77051
# [452]	validation_0-auc:0.77052
# [453]	validation_0-auc:0.77054
# [454]	validation_0-auc:0.77058
# [455]	validation_0-auc:0.77058
# [456]	validation_0-auc:0.77062
# [457]	validation_0-auc:0.77065
# [458]	validation_0-auc:0.77066
# [459]	validation_0-auc:0.77069
# [460]	validation_0-auc:0.77070
# [461]	validation_0-auc:0.77070
# [462]	validation_0-auc:0.77071
# [463]	validation_0-auc:0.77074
# [464]	validation_0-auc:0.77075
# [465]	validation_0-auc:0.77076
# [466]	validation_0-auc:0.77078
# [467]	validation_0-auc:0.77079
# [468]	validation_0-auc:0.77078
# [469]	validation_0-auc:0.77078
# [470]	validation_0-auc:0.77083
# [471]	validation_0-auc:0.77085
# [472]	validation_0-auc:0.77090
# [473]	validation_0-auc:0.77090
# [474]	validation_0-auc:0.77092
# [475]	validation_0-auc:0.77095
# [476]	validation_0-auc:0.77098
# [477]	validation_0-auc:0.77100
# [478]	validation_0-auc:0.77103
# [479]	validation_0-auc:0.77106
# [480]	validation_0-auc:0.77111
# [481]	validation_0-auc:0.77113
# [482]	validation_0-auc:0.77113
# [483]	validation_0-auc:0.77114
# [484]	validation_0-auc:0.77115
# [485]	validation_0-auc:0.77116
# [486]	validation_0-auc:0.77116
# [487]	validation_0-auc:0.77122
# [488]	validation_0-auc:0.77128
# [489]	validation_0-auc:0.77131
# [490]	validation_0-auc:0.77133
# [491]	validation_0-auc:0.77134
# [492]	validation_0-auc:0.77138
# [493]	validation_0-auc:0.77140
# [494]	validation_0-auc:0.77141
# [495]	validation_0-auc:0.77145
# [496]	validation_0-auc:0.77145
# [497]	validation_0-auc:0.77146
# [498]	validation_0-auc:0.77146
# [499]	validation_0-auc:0.77148
# [500]	validation_0-auc:0.77149
# [501]	validation_0-auc:0.77151
# [502]	validation_0-auc:0.77152
# [503]	validation_0-auc:0.77154
# [504]	validation_0-auc:0.77157
# [505]	validation_0-auc:0.77158
# [506]	validation_0-auc:0.77160
# [507]	validation_0-auc:0.77163
# [508]	validation_0-auc:0.77166
# [509]	validation_0-auc:0.77169
# [510]	validation_0-auc:0.77170
# [511]	validation_0-auc:0.77173
# [512]	validation_0-auc:0.77176
# [513]	validation_0-auc:0.77176
# [514]	validation_0-auc:0.77177
# [515]	validation_0-auc:0.77179
# [516]	validation_0-auc:0.77179
# [517]	validation_0-auc:0.77180
# [518]	validation_0-auc:0.77184
# [519]	validation_0-auc:0.77187
# [520]	validation_0-auc:0.77188
# [521]	validation_0-auc:0.77188
# [522]	validation_0-auc:0.77189
# [523]	validation_0-auc:0.77190
# [524]	validation_0-auc:0.77191
# [525]	validation_0-auc:0.77192
# [526]	validation_0-auc:0.77192
# [527]	validation_0-auc:0.77194
# [528]	validation_0-auc:0.77197
# [529]	validation_0-auc:0.77199
# [530]	validation_0-auc:0.77200
# [531]	validation_0-auc:0.77201
# [532]	validation_0-auc:0.77203
# [533]	validation_0-auc:0.77203
# [534]	validation_0-auc:0.77207
# [535]	validation_0-auc:0.77209
# [536]	validation_0-auc:0.77211
# [537]	validation_0-auc:0.77212
# [538]	validation_0-auc:0.77215
# [539]	validation_0-auc:0.77219
# [540]	validation_0-auc:0.77220
# [541]	validation_0-auc:0.77221
# [542]	validation_0-auc:0.77223
# [543]	validation_0-auc:0.77225
# [544]	validation_0-auc:0.77224
# [545]	validation_0-auc:0.77226
# [546]	validation_0-auc:0.77226
# [547]	validation_0-auc:0.77227
# [548]	validation_0-auc:0.77230
# [549]	validation_0-auc:0.77232
# [550]	validation_0-auc:0.77233
# [551]	validation_0-auc:0.77236
# [552]	validation_0-auc:0.77239
# [553]	validation_0-auc:0.77241
# [554]	validation_0-auc:0.77243
# [555]	validation_0-auc:0.77243
# [556]	validation_0-auc:0.77244
# [557]	validation_0-auc:0.77245
# [558]	validation_0-auc:0.77250
# [559]	validation_0-auc:0.77251
# [560]	validation_0-auc:0.77254
# [561]	validation_0-auc:0.77256
# [562]	validation_0-auc:0.77257
# [563]	validation_0-auc:0.77260
# [564]	validation_0-auc:0.77260
# [565]	validation_0-auc:0.77259
# [566]	validation_0-auc:0.77261
# [567]	validation_0-auc:0.77262
# [568]	validation_0-auc:0.77264
# [569]	validation_0-auc:0.77264
# [570]	validation_0-auc:0.77263
# [571]	validation_0-auc:0.77265
# [572]	validation_0-auc:0.77264
# [573]	validation_0-auc:0.77265
# [574]	validation_0-auc:0.77264
# [575]	validation_0-auc:0.77266
# [576]	validation_0-auc:0.77269
# [577]	validation_0-auc:0.77272
# [578]	validation_0-auc:0.77272
# [579]	validation_0-auc:0.77272
# [580]	validation_0-auc:0.77273
# [581]	validation_0-auc:0.77275
# [582]	validation_0-auc:0.77277
# [583]	validation_0-auc:0.77279
# [584]	validation_0-auc:0.77281
# [585]	validation_0-auc:0.77281
# [586]	validation_0-auc:0.77283
# [587]	validation_0-auc:0.77284
# [588]	validation_0-auc:0.77286
# [589]	validation_0-auc:0.77287
# [590]	validation_0-auc:0.77292
# [591]	validation_0-auc:0.77293
# [592]	validation_0-auc:0.77293
# [593]	validation_0-auc:0.77295
# [594]	validation_0-auc:0.77298
# [595]	validation_0-auc:0.77300
# [596]	validation_0-auc:0.77301
# [597]	validation_0-auc:0.77301
# [598]	validation_0-auc:0.77302
# [599]	validation_0-auc:0.77304
# [600]	validation_0-auc:0.77305
# [601]	validation_0-auc:0.77306
# [602]	validation_0-auc:0.77309
# [603]	validation_0-auc:0.77312
# [604]	validation_0-auc:0.77314
# [605]	validation_0-auc:0.77316
# [606]	validation_0-auc:0.77318
# [607]	validation_0-auc:0.77319
# [608]	validation_0-auc:0.77319
# [609]	validation_0-auc:0.77321
# [610]	validation_0-auc:0.77322
# [611]	validation_0-auc:0.77322
# [612]	validation_0-auc:0.77324
# [613]	validation_0-auc:0.77324
# [614]	validation_0-auc:0.77325
# [615]	validation_0-auc:0.77326
# [616]	validation_0-auc:0.77327
# [617]	validation_0-auc:0.77326
# [618]	validation_0-auc:0.77326
# [619]	validation_0-auc:0.77327
# [620]	validation_0-auc:0.77329
# [621]	validation_0-auc:0.77334
# [622]	validation_0-auc:0.77335
# [623]	validation_0-auc:0.77336
# [624]	validation_0-auc:0.77338
# [625]	validation_0-auc:0.77343
# [626]	validation_0-auc:0.77343
# [627]	validation_0-auc:0.77344
# [628]	validation_0-auc:0.77343
# [629]	validation_0-auc:0.77346
# [630]	validation_0-auc:0.77346
# [631]	validation_0-auc:0.77349
# [632]	validation_0-auc:0.77351
# [633]	validation_0-auc:0.77351
# [634]	validation_0-auc:0.77351
# [635]	validation_0-auc:0.77351
# [636]	validation_0-auc:0.77351
# [637]	validation_0-auc:0.77352
# [638]	validation_0-auc:0.77352
# [639]	validation_0-auc:0.77353
# [640]	validation_0-auc:0.77355
# [641]	validation_0-auc:0.77356
# [642]	validation_0-auc:0.77355
# [643]	validation_0-auc:0.77358
# [644]	validation_0-auc:0.77361
# [645]	validation_0-auc:0.77361
# [646]	validation_0-auc:0.77362
# [647]	validation_0-auc:0.77363
# [648]	validation_0-auc:0.77365
# [649]	validation_0-auc:0.77366
# [650]	validation_0-auc:0.77366
# [651]	validation_0-auc:0.77365
# [652]	validation_0-auc:0.77367
# [653]	validation_0-auc:0.77368
# [654]	validation_0-auc:0.77369
# [655]	validation_0-auc:0.77370
# [656]	validation_0-auc:0.77371
# [657]	validation_0-auc:0.77371
# [658]	validation_0-auc:0.77373
# [659]	validation_0-auc:0.77374
# [660]	validation_0-auc:0.77374
# [661]	validation_0-auc:0.77375
# [662]	validation_0-auc:0.77378
# [663]	validation_0-auc:0.77380
# [664]	validation_0-auc:0.77384
# [665]	validation_0-auc:0.77384
# [666]	validation_0-auc:0.77384
# [667]	validation_0-auc:0.77387
# [668]	validation_0-auc:0.77391
# [669]	validation_0-auc:0.77390
# [670]	validation_0-auc:0.77391
# [671]	validation_0-auc:0.77393
# [672]	validation_0-auc:0.77394
# [673]	validation_0-auc:0.77393
# [674]	validation_0-auc:0.77396
# [675]	validation_0-auc:0.77396
# [676]	validation_0-auc:0.77396
# [677]	validation_0-auc:0.77397
# [678]	validation_0-auc:0.77400
# [679]	validation_0-auc:0.77399
# [680]	validation_0-auc:0.77401
# [681]	validation_0-auc:0.77402
# [682]	validation_0-auc:0.77402
# [683]	validation_0-auc:0.77402
# [684]	validation_0-auc:0.77406
# [685]	validation_0-auc:0.77409
# [686]	validation_0-auc:0.77409
# [687]	validation_0-auc:0.77412
# [688]	validation_0-auc:0.77412
# [689]	validation_0-auc:0.77410
# [690]	validation_0-auc:0.77412
# [691]	validation_0-auc:0.77413
# [692]	validation_0-auc:0.77415
# [693]	validation_0-auc:0.77417
# [694]	validation_0-auc:0.77419
# [695]	validation_0-auc:0.77420
# [696]	validation_0-auc:0.77420
# [697]	validation_0-auc:0.77421
# [698]	validation_0-auc:0.77422
# [699]	validation_0-auc:0.77424
# [700]	validation_0-auc:0.77426
# [701]	validation_0-auc:0.77427
# [702]	validation_0-auc:0.77430
# [703]	validation_0-auc:0.77431
# [704]	validation_0-auc:0.77433
# [705]	validation_0-auc:0.77433
# [706]	validation_0-auc:0.77436
# [707]	validation_0-auc:0.77436
# [708]	validation_0-auc:0.77436
# [709]	validation_0-auc:0.77436
# [710]	validation_0-auc:0.77438
# [711]	validation_0-auc:0.77441
# [712]	validation_0-auc:0.77441
# [713]	validation_0-auc:0.77441
# [714]	validation_0-auc:0.77443
# [715]	validation_0-auc:0.77445
# [716]	validation_0-auc:0.77446
# [717]	validation_0-auc:0.77448
# [718]	validation_0-auc:0.77450
# [719]	validation_0-auc:0.77451
# [720]	validation_0-auc:0.77452
# [721]	validation_0-auc:0.77453
# [722]	validation_0-auc:0.77454
# [723]	validation_0-auc:0.77458
# [724]	validation_0-auc:0.77460
# [725]	validation_0-auc:0.77462
# [726]	validation_0-auc:0.77464
# [727]	validation_0-auc:0.77465
# [728]	validation_0-auc:0.77466
# [729]	validation_0-auc:0.77466
# [730]	validation_0-auc:0.77466
# [731]	validation_0-auc:0.77466
# [732]	validation_0-auc:0.77466
# [733]	validation_0-auc:0.77465
# [734]	validation_0-auc:0.77468
# [735]	validation_0-auc:0.77469
# [736]	validation_0-auc:0.77471
# [737]	validation_0-auc:0.77474
# [738]	validation_0-auc:0.77475
# [739]	validation_0-auc:0.77477
# [740]	validation_0-auc:0.77478
# [741]	validation_0-auc:0.77480
# [742]	validation_0-auc:0.77479
# [743]	validation_0-auc:0.77481
# [744]	validation_0-auc:0.77483
# [745]	validation_0-auc:0.77484
# [746]	validation_0-auc:0.77487
# [747]	validation_0-auc:0.77491
# [748]	validation_0-auc:0.77492
# [749]	validation_0-auc:0.77496
# [750]	validation_0-auc:0.77498
# [751]	validation_0-auc:0.77498
# [752]	validation_0-auc:0.77501
# [753]	validation_0-auc:0.77504
# [754]	validation_0-auc:0.77505
# [755]	validation_0-auc:0.77505
# [756]	validation_0-auc:0.77505
# [757]	validation_0-auc:0.77504
# [758]	validation_0-auc:0.77505
# [759]	validation_0-auc:0.77505
# [760]	validation_0-auc:0.77505
# [761]	validation_0-auc:0.77506
# [762]	validation_0-auc:0.77506
# [763]	validation_0-auc:0.77508
# [764]	validation_0-auc:0.77510
# [765]	validation_0-auc:0.77512
# [766]	validation_0-auc:0.77512
# [767]	validation_0-auc:0.77513
# [768]	validation_0-auc:0.77514
# [769]	validation_0-auc:0.77517
# [770]	validation_0-auc:0.77518
# [771]	validation_0-auc:0.77518
# [772]	validation_0-auc:0.77520
# [773]	validation_0-auc:0.77524
# [774]	validation_0-auc:0.77524
# [775]	validation_0-auc:0.77525
# [776]	validation_0-auc:0.77525
# [777]	validation_0-auc:0.77527
# [778]	validation_0-auc:0.77529
# [779]	validation_0-auc:0.77530
# [780]	validation_0-auc:0.77530
# [781]	validation_0-auc:0.77531
# [782]	validation_0-auc:0.77533
# [783]	validation_0-auc:0.77535
# [784]	validation_0-auc:0.77536
# [785]	validation_0-auc:0.77539
# [786]	validation_0-auc:0.77541
# [787]	validation_0-auc:0.77541
# [788]	validation_0-auc:0.77540
# [789]	validation_0-auc:0.77541
# [790]	validation_0-auc:0.77540
# [791]	validation_0-auc:0.77543
# [792]	validation_0-auc:0.77546
# [793]	validation_0-auc:0.77548
# [794]	validation_0-auc:0.77548
# [795]	validation_0-auc:0.77549
# [796]	validation_0-auc:0.77551
# [797]	validation_0-auc:0.77551
# [798]	validation_0-auc:0.77551
# [799]	validation_0-auc:0.77554
# [800]	validation_0-auc:0.77554
# [801]	validation_0-auc:0.77555
# [802]	validation_0-auc:0.77556
# [803]	validation_0-auc:0.77557
# [804]	validation_0-auc:0.77557
# [805]	validation_0-auc:0.77559
# [806]	validation_0-auc:0.77559
# [807]	validation_0-auc:0.77559
# [808]	validation_0-auc:0.77563
# [809]	validation_0-auc:0.77566
# [810]	validation_0-auc:0.77569
# [811]	validation_0-auc:0.77570
# [812]	validation_0-auc:0.77570
# [813]	validation_0-auc:0.77570
# [814]	validation_0-auc:0.77570
# [815]	validation_0-auc:0.77570
# [816]	validation_0-auc:0.77570
# [817]	validation_0-auc:0.77570
# [818]	validation_0-auc:0.77573
# [819]	validation_0-auc:0.77573
# [820]	validation_0-auc:0.77574
# [821]	validation_0-auc:0.77575
# [822]	validation_0-auc:0.77577
# [823]	validation_0-auc:0.77579
# [824]	validation_0-auc:0.77578
# [825]	validation_0-auc:0.77577
# [826]	validation_0-auc:0.77577
# [827]	validation_0-auc:0.77577
# [828]	validation_0-auc:0.77579
# [829]	validation_0-auc:0.77580
# [830]	validation_0-auc:0.77580
# [831]	validation_0-auc:0.77580
# [832]	validation_0-auc:0.77580
# [833]	validation_0-auc:0.77579
# [834]	validation_0-auc:0.77580
# [835]	validation_0-auc:0.77581
# [836]	validation_0-auc:0.77582
# [837]	validation_0-auc:0.77582
# [838]	validation_0-auc:0.77582
# [839]	validation_0-auc:0.77582
# [840]	validation_0-auc:0.77583
# [841]	validation_0-auc:0.77583
# [842]	validation_0-auc:0.77583
# [843]	validation_0-auc:0.77584
# [844]	validation_0-auc:0.77585
# [845]	validation_0-auc:0.77585
# [846]	validation_0-auc:0.77585
# [847]	validation_0-auc:0.77587
# [848]	validation_0-auc:0.77589
# [849]	validation_0-auc:0.77589
# [850]	validation_0-auc:0.77591
# [851]	validation_0-auc:0.77593
# [852]	validation_0-auc:0.77594
# [853]	validation_0-auc:0.77596
# [854]	validation_0-auc:0.77598
# [855]	validation_0-auc:0.77601
# [856]	validation_0-auc:0.77602
# [857]	validation_0-auc:0.77603
# [858]	validation_0-auc:0.77605
# [859]	validation_0-auc:0.77605
# [860]	validation_0-auc:0.77607
# [861]	validation_0-auc:0.77607
# [862]	validation_0-auc:0.77607
# [863]	validation_0-auc:0.77608
# [864]	validation_0-auc:0.77609
# [865]	validation_0-auc:0.77609
# [866]	validation_0-auc:0.77609
# [867]	validation_0-auc:0.77610
# [868]	validation_0-auc:0.77612
# [869]	validation_0-auc:0.77613
# [870]	validation_0-auc:0.77613
# [871]	validation_0-auc:0.77614
# [872]	validation_0-auc:0.77615
# [873]	validation_0-auc:0.77618
# [874]	validation_0-auc:0.77618
# [875]	validation_0-auc:0.77619
# [876]	validation_0-auc:0.77618
# [877]	validation_0-auc:0.77619
# [878]	validation_0-auc:0.77619
# [879]	validation_0-auc:0.77621
# [880]	validation_0-auc:0.77622
# [881]	validation_0-auc:0.77624
# [882]	validation_0-auc:0.77624
# [883]	validation_0-auc:0.77625
# [884]	validation_0-auc:0.77625
# [885]	validation_0-auc:0.77625
# [886]	validation_0-auc:0.77626
# [887]	validation_0-auc:0.77628
# [888]	validation_0-auc:0.77629
# [889]	validation_0-auc:0.77630
# [890]	validation_0-auc:0.77631
# [891]	validation_0-auc:0.77632
# [892]	validation_0-auc:0.77632
# [893]	validation_0-auc:0.77633
# [894]	validation_0-auc:0.77635
# [895]	validation_0-auc:0.77636
# [896]	validation_0-auc:0.77638
# [897]	validation_0-auc:0.77639
# [898]	validation_0-auc:0.77640
# [899]	validation_0-auc:0.77642
# [900]	validation_0-auc:0.77642
# [901]	validation_0-auc:0.77642
# [902]	validation_0-auc:0.77642
# [903]	validation_0-auc:0.77643
# [904]	validation_0-auc:0.77643
# [905]	validation_0-auc:0.77643
# [906]	validation_0-auc:0.77645
# [907]	validation_0-auc:0.77645
# [908]	validation_0-auc:0.77644
# [909]	validation_0-auc:0.77644
# [910]	validation_0-auc:0.77645
# [911]	validation_0-auc:0.77645
# [912]	validation_0-auc:0.77646
# [913]	validation_0-auc:0.77645
# [914]	validation_0-auc:0.77644
# [915]	validation_0-auc:0.77647
# [916]	validation_0-auc:0.77649
# [917]	validation_0-auc:0.77649
# [918]	validation_0-auc:0.77648
# [919]	validation_0-auc:0.77649
# [920]	validation_0-auc:0.77649
# [921]	validation_0-auc:0.77650
# [922]	validation_0-auc:0.77652
# [923]	validation_0-auc:0.77652
# [924]	validation_0-auc:0.77653
# [925]	validation_0-auc:0.77655
# [926]	validation_0-auc:0.77655
# [927]	validation_0-auc:0.77655
# [928]	validation_0-auc:0.77656
# [929]	validation_0-auc:0.77656
# [930]	validation_0-auc:0.77659
# [931]	validation_0-auc:0.77660
# [932]	validation_0-auc:0.77661
# [933]	validation_0-auc:0.77661
# [934]	validation_0-auc:0.77661
# [935]	validation_0-auc:0.77663
# [936]	validation_0-auc:0.77664
# [937]	validation_0-auc:0.77665
# [938]	validation_0-auc:0.77666
# [939]	validation_0-auc:0.77667
# [940]	validation_0-auc:0.77668
# [941]	validation_0-auc:0.77670
# [942]	validation_0-auc:0.77670
# [1508]	validation_0-auc:0.77932
# [1509]	validation_0-auc:0.77932
# [1510]	validation_0-auc:0.77932
# [1511]	validation_0-auc:0.77933
# [1512]	validation_0-auc:0.77935
# [1513]	validation_0-auc:0.77934
# [1514]	validation_0-auc:0.77934
# [1515]	validation_0-auc:0.77935
# [1516]	validation_0-auc:0.77935
# [1517]	validation_0-auc:0.77935
# [1518]	validation_0-auc:0.77936
# [1519]	validation_0-auc:0.77937
# [1520]	validation_0-auc:0.77937
# [1521]	validation_0-auc:0.77938
# [1522]	validation_0-auc:0.77940
# [1523]	validation_0-auc:0.77940
# [1524]	validation_0-auc:0.77941
# [1525]	validation_0-auc:0.77942
# [1526]	validation_0-auc:0.77942
# [1527]	validation_0-auc:0.77943
# [1528]	validation_0-auc:0.77944
# [1529]	validation_0-auc:0.77944
# [1530]	validation_0-auc:0.77944
# [1531]	validation_0-auc:0.77944
# [1532]	validation_0-auc:0.77943
# [1533]	validation_0-auc:0.77944
# ...
# [2527]	validation_0-auc:0.78112
# [2528]	validation_0-auc:0.78112
# [2529]	validation_0-auc:0.78113
# [2530]	validation_0-auc:0.78113
# [2531]	validation_0-auc:0.78114
# [2532]	validation_0-auc:0.78115
# [2533]	validation_0-auc:0.78117
# [2534]	validation_0-auc:0.78117
# [2535]	validation_0-auc:0.78117
# [2536]	validation_0-auc:0.78117
# [2537]	validation_0-auc:0.78118
# [2538]	validation_0-auc:0.78117
# [2539]	validation_0-auc:0.78117
# [2540]	validation_0-auc:0.78118
# [2541]	validation_0-auc:0.78117
# [2542]	validation_0-auc:0.78117
# [2543]	validation_0-auc:0.78116
# [2544]	validation_0-auc:0.78116
# [2545]	validation_0-auc:0.78116
# [2546]	validation_0-auc:0.78116
# [2547]	validation_0-auc:0.78117
# [2548]	validation_0-auc:0.78116
# [2549]	validation_0-auc:0.78115
# [2550]	validation_0-auc:0.78116
# [2551]	validation_0-auc:0.78116
# [2552]	validation_0-auc:0.78116
# [2553]	validation_0-auc:0.78116
# [2554]	validation_0-auc:0.78115
# [2555]	validation_0-auc:0.78114
# [2556]	validation_0-auc:0.78113
# [2557]	validation_0-auc:0.78113
# [2558]	validation_0-auc:0.78114
# [2559]	validation_0-auc:0.78114
# [2560]	validation_0-auc:0.78114
# [2561]	validation_0-auc:0.78113
# [2562]	validation_0-auc:0.78113
# [2563]	validation_0-auc:0.78113
# [2564]	validation_0-auc:0.78113
# [2565]	validation_0-auc:0.78114
# [2566]	validation_0-auc:0.78114
# [2567]	validation_0-auc:0.78114
# [2568]	validation_0-auc:0.78115
# [2569]	validation_0-auc:0.78115
# [2570]	validation_0-auc:0.78115
# [2571]	validation_0-auc:0.78115
# [2572]	validation_0-auc:0.78115
# [2573]	validation_0-auc:0.78115
# [2574]	validation_0-auc:0.78115
# [2575]	validation_0-auc:0.78116
# [2576]	validation_0-auc:0.78116
# [2577]	validation_0-auc:0.78115
# [2578]	validation_0-auc:0.78116
# [2579]	validation_0-auc:0.78115
# [2580]	validation_0-auc:0.78114
# [2581]	validation_0-auc:0.78114
# [2582]	validation_0-auc:0.78114
# [2583]	validation_0-auc:0.78114
# [2584]	validation_0-auc:0.78114
# [2585]	validation_0-auc:0.78114
# [2586]	validation_0-auc:0.78112
# [2587]	validation_0-auc:0.78113
# [2588]	validation_0-auc:0.78114
# [2589]	validation_0-auc:0.78114
# [2590]	validation_0-auc:0.78114
# [2591]	validation_0-auc:0.78114
# [2592]	validation_0-auc:0.78115
# [2593]	validation_0-auc:0.78114
# [2594]	validation_0-auc:0.78115
# [2595]	validation_0-auc:0.78117
# [2596]	validation_0-auc:0.78118
# [2597]	validation_0-auc:0.78118
# [2598]	validation_0-auc:0.78118
# [2599]	validation_0-auc:0.78118
# [2600]	validation_0-auc:0.78118
# [2601]	validation_0-auc:0.78118
# [2602]	validation_0-auc:0.78117
# [2603]	validation_0-auc:0.78118
# [2604]	validation_0-auc:0.78118
# [2605]	validation_0-auc:0.78118
# [2606]	validation_0-auc:0.78119
# [2607]	validation_0-auc:0.78119
# [2608]	validation_0-auc:0.78120
# [2609]	validation_0-auc:0.78120
# [2610]	validation_0-auc:0.78120
# [2611]	validation_0-auc:0.78120
# [2612]	validation_0-auc:0.78120
# [2613]	validation_0-auc:0.78120
# [2614]	validation_0-auc:0.78119
# [2615]	validation_0-auc:0.78119
# [2616]	validation_0-auc:0.78120
# [2617]	validation_0-auc:0.78119
# [2618]	validation_0-auc:0.78118
# [2619]	validation_0-auc:0.78119
# [2620]	validation_0-auc:0.78118
# [2621]	validation_0-auc:0.78118
# [2622]	validation_0-auc:0.78117
# [2623]	validation_0-auc:0.78117
# [2624]	validation_0-auc:0.78118
# [2625]	validation_0-auc:0.78118
# [2626]	validation_0-auc:0.78118
# [2627]	validation_0-auc:0.78119
# [2628]	validation_0-auc:0.78118
# [2629]	validation_0-auc:0.78118
# [2630]	validation_0-auc:0.78118
# [2631]	validation_0-auc:0.78118
# [2632]	validation_0-auc:0.78117
# [2633]	validation_0-auc:0.78117
# [2634]	validation_0-auc:0.78117
# [2635]	validation_0-auc:0.78117
# [2636]	validation_0-auc:0.78118
# [2637]	validation_0-auc:0.78118
# [2638]	validation_0-auc:0.78118
# [2639]	validation_0-auc:0.78117
# [2640]	validation_0-auc:0.78118
# [2641]	validation_0-auc:0.78117
# [2642]	validation_0-auc:0.78119
# [2643]	validation_0-auc:0.78120
# [2644]	validation_0-auc:0.78119
# [2645]	validation_0-auc:0.78120
# [2646]	validation_0-auc:0.78120
# [2647]	validation_0-auc:0.78120
# [2648]	validation_0-auc:0.78121
# [2649]	validation_0-auc:0.78121
# [2650]	validation_0-auc:0.78121
# [2651]	validation_0-auc:0.78122
# [2652]	validation_0-auc:0.78122
# [2653]	validation_0-auc:0.78121
# [2654]	validation_0-auc:0.78122
# [2655]	validation_0-auc:0.78122
# [2656]	validation_0-auc:0.78121
# [2657]	validation_0-auc:0.78121
# [2658]	validation_0-auc:0.78121
# [2659]	validation_0-auc:0.78121
# [2660]	validation_0-auc:0.78121
# [2661]	validation_0-auc:0.78121
# [2662]	validation_0-auc:0.78121
# [2663]	validation_0-auc:0.78121
# [2664]	validation_0-auc:0.78121
# [2665]	validation_0-auc:0.78121
# [2666]	validation_0-auc:0.78122
# [2667]	validation_0-auc:0.78123
# [2668]	validation_0-auc:0.78123
# [2669]	validation_0-auc:0.78123
# [2670]	validation_0-auc:0.78124
# [2671]	validation_0-auc:0.78124
# [2672]	validation_0-auc:0.78123
# [2673]	validation_0-auc:0.78124
# [2674]	validation_0-auc:0.78124
# [2675]	validation_0-auc:0.78124
# [2676]	validation_0-auc:0.78124
# [2677]	validation_0-auc:0.78124
# [2678]	validation_0-auc:0.78125
# [2679]	validation_0-auc:0.78125
# [2680]	validation_0-auc:0.78124
# [2681]	validation_0-auc:0.78124
# [2682]	validation_0-auc:0.78124
# [2683]	validation_0-auc:0.78124
# [2684]	validation_0-auc:0.78124
# [2685]	validation_0-auc:0.78124
# [2686]	validation_0-auc:0.78124
# [2687]	validation_0-auc:0.78124
# [2688]	validation_0-auc:0.78124
# [2689]	validation_0-auc:0.78125
# [2690]	validation_0-auc:0.78124
# [2691]	validation_0-auc:0.78125
# [2692]	validation_0-auc:0.78125
# [2693]	validation_0-auc:0.78125
# [2694]	validation_0-auc:0.78125
# [2695]	validation_0-auc:0.78125
# [2696]	validation_0-auc:0.78124
# [2697]	validation_0-auc:0.78124
# [2698]	validation_0-auc:0.78126
# [2699]	validation_0-auc:0.78125
# [2700]	validation_0-auc:0.78127
# [2701]	validation_0-auc:0.78127
# [2702]	validation_0-auc:0.78127
# [2703]	validation_0-auc:0.78127
# [2704]	validation_0-auc:0.78127
# [2705]	validation_0-auc:0.78127
# [2706]	validation_0-auc:0.78127
# [2707]	validation_0-auc:0.78127
# [2708]	validation_0-auc:0.78127
# [2709]	validation_0-auc:0.78127
# [2710]	validation_0-auc:0.78127
# [2711]	validation_0-auc:0.78126
# [2712]	validation_0-auc:0.78126
# [2713]	validation_0-auc:0.78126
# [2714]	validation_0-auc:0.78125
# [2715]	validation_0-auc:0.78125
# [2716]	validation_0-auc:0.78126
# [2717]	validation_0-auc:0.78126
# [2718]	validation_0-auc:0.78125
# [2719]	validation_0-auc:0.78125
# [2720]	validation_0-auc:0.78125
# [2721]	validation_0-auc:0.78125
# [2722]	validation_0-auc:0.78125
# [2723]	validation_0-auc:0.78125
# [2724]	validation_0-auc:0.78126
# [2725]	validation_0-auc:0.78126
# [2726]	validation_0-auc:0.78126
# [2727]	validation_0-auc:0.78125
# [2728]	validation_0-auc:0.78125
# [2729]	validation_0-auc:0.78124
# [2730]	validation_0-auc:0.78124
# [2731]	validation_0-auc:0.78124
# [2732]	validation_0-auc:0.78125
# [2733]	validation_0-auc:0.78125
# [2734]	validation_0-auc:0.78125
# [2735]	validation_0-auc:0.78125
# [2736]	validation_0-auc:0.78125
# [2737]	validation_0-auc:0.78125
# [2738]	validation_0-auc:0.78125
# [2739]	validation_0-auc:0.78125
# [2740]	validation_0-auc:0.78125
# [2741]	validation_0-auc:0.78124
# [2742]	validation_0-auc:0.78124
# [2743]	validation_0-auc:0.78123
# [2744]	validation_0-auc:0.78124
# [2745]	validation_0-auc:0.78124
# [2746]	validation_0-auc:0.78125
# [2747]	validation_0-auc:0.78124
# [2748]	validation_0-auc:0.78125
# [2749]	validation_0-auc:0.78124
# [2750]	validation_0-auc:0.78125
# [2751]	validation_0-auc:0.78125
# [2752]	validation_0-auc:0.78124
# [2753]	validation_0-auc:0.78125
# [2754]	validation_0-auc:0.78125
# [2755]	validation_0-auc:0.78126
# [2756]	validation_0-auc:0.78126
# [2757]	validation_0-auc:0.78125
# [2758]	validation_0-auc:0.78124
# [2759]	validation_0-auc:0.78124
# [2760]	validation_0-auc:0.78124
# [2761]	validation_0-auc:0.78123
# [2762]	validation_0-auc:0.78123
# [2763]	validation_0-auc:0.78124
# [2764]	validation_0-auc:0.78123
# [2765]	validation_0-auc:0.78122
# [2766]	validation_0-auc:0.78121
# [2767]	validation_0-auc:0.78121
# [2768]	validation_0-auc:0.78121
# [2769]	validation_0-auc:0.78122
# [2770]	validation_0-auc:0.78121
# [2771]	validation_0-auc:0.78120
# [2772]	validation_0-auc:0.78120
# [2773]	validation_0-auc:0.78120
# [2774]	validation_0-auc:0.78120
# [2775]	validation_0-auc:0.78119
# [2776]	validation_0-auc:0.78119
# [2777]	validation_0-auc:0.78119
# [2778]	validation_0-auc:0.78119
# [2779]	validation_0-auc:0.78119
# [2780]	validation_0-auc:0.78119
# [2781]	validation_0-auc:0.78118
# [2782]	validation_0-auc:0.78120
# [2783]	validation_0-auc:0.78119
# [2784]	validation_0-auc:0.78119
# [2785]	validation_0-auc:0.78119
# [2786]	validation_0-auc:0.78119
# [2787]	validation_0-auc:0.78120
# [2788]	validation_0-auc:0.78120
# [2789]	validation_0-auc:0.78120
# [2790]	validation_0-auc:0.78119
# [2791]	validation_0-auc:0.78120
# [2792]	validation_0-auc:0.78119
# [2793]	validation_0-auc:0.78119
# [2794]	validation_0-auc:0.78119
# [2795]	validation_0-auc:0.78120
# [2796]	validation_0-auc:0.78121
# [2797]	validation_0-auc:0.78120
# [2798]	validation_0-auc:0.78120
# [2799]	validation_0-auc:0.78120
# [2800]	validation_0-auc:0.78119
# [2801]	validation_0-auc:0.78120
# [2802]	validation_0-auc:0.78120
# [2803]	validation_0-auc:0.78120
# [2804]	validation_0-auc:0.78120
# [2805]	validation_0-auc:0.78120
# [2806]	validation_0-auc:0.78121
# [2807]	validation_0-auc:0.78120
# [2808]	validation_0-auc:0.78121
# [2809]	validation_0-auc:0.78121
# [2810]	validation_0-auc:0.78120
# [2811]	validation_0-auc:0.78120
# [2812]	validation_0-auc:0.78120
# [2813]	validation_0-auc:0.78120
# [2814]	validation_0-auc:0.78120
# [2815]	validation_0-auc:0.78120
# [2816]	validation_0-auc:0.78120
# [2817]	validation_0-auc:0.78120
# [2818]	validation_0-auc:0.78120
# [2819]	validation_0-auc:0.78120
# [2820]	validation_0-auc:0.78119
# [2821]	validation_0-auc:0.78120
# [2822]	validation_0-auc:0.78121
# [2823]	validation_0-auc:0.78121
# [2824]	validation_0-auc:0.78121
# [2825]	validation_0-auc:0.78120
# [2826]	validation_0-auc:0.78120
# [2827]	validation_0-auc:0.78121
# [2828]	validation_0-auc:0.78121
# [2829]	validation_0-auc:0.78121
# [2830]	validation_0-auc:0.78120
# [2831]	validation_0-auc:0.78119
# [2832]	validation_0-auc:0.78119
# [2833]	validation_0-auc:0.78120
# [2834]	validation_0-auc:0.78120
# [2835]	validation_0-auc:0.78121
# [2836]	validation_0-auc:0.78121
# [2837]	validation_0-auc:0.78123
# [2838]	validation_0-auc:0.78123
# [2839]	validation_0-auc:0.78122
# [2840]	validation_0-auc:0.78123
# [2841]	validation_0-auc:0.78123
# [2842]	validation_0-auc:0.78123
# [2843]	validation_0-auc:0.78123
# [2844]	validation_0-auc:0.78124
# [2845]	validation_0-auc:0.78123
# [2846]	validation_0-auc:0.78121
# [2847]	validation_0-auc:0.78121
# [2848]	validation_0-auc:0.78121
# [2849]	validation_0-auc:0.78122
# [2850]	validation_0-auc:0.78120
# [2851]	validation_0-auc:0.78120
# [2852]	validation_0-auc:0.78119
# [2853]	validation_0-auc:0.78119
# [2854]	validation_0-auc:0.78119
# [2855]	validation_0-auc:0.78119
# [2856]	validation_0-auc:0.78118
# [2857]	validation_0-auc:0.78118
# [2858]	validation_0-auc:0.78118
# [2859]	validation_0-auc:0.78117
# [2860]	validation_0-auc:0.78117
# [2861]	validation_0-auc:0.78116
# [2862]	validation_0-auc:0.78115
# [2863]	validation_0-auc:0.78115
# [2864]	validation_0-auc:0.78116
# [2865]	validation_0-auc:0.78115
# [2866]	validation_0-auc:0.78115
# [2867]	validation_0-auc:0.78115
# [2868]	validation_0-auc:0.78115
# [2869]	validation_0-auc:0.78114
# [2870]	validation_0-auc:0.78114
# [2871]	validation_0-auc:0.78115
# [2872]	validation_0-auc:0.78115
# [2873]	validation_0-auc:0.78114
# [2874]	validation_0-auc:0.78114
# [2875]	validation_0-auc:0.78113
# [2876]	validation_0-auc:0.78113
# [2877]	validation_0-auc:0.78113
# [2878]	validation_0-auc:0.78114
# [2879]	validation_0-auc:0.78114
# [2880]	validation_0-auc:0.78115
# [2881]	validation_0-auc:0.78116
# [2882]	validation_0-auc:0.78117
# [2883]	validation_0-auc:0.78117
# [2884]	validation_0-auc:0.78117
# [2885]	validation_0-auc:0.78116
# [2886]	validation_0-auc:0.78115
# [2887]	validation_0-auc:0.78116
# [2888]	validation_0-auc:0.78116
# [2889]	validation_0-auc:0.78115
# [2890]	validation_0-auc:0.78116
# [2891]	validation_0-auc:0.78116
# [2892]	validation_0-auc:0.78115
# [2893]	validation_0-auc:0.78114
# [2894]	validation_0-auc:0.78115
# [2895]	validation_0-auc:0.78114
# [2896]	validation_0-auc:0.78114
# [2897]	validation_0-auc:0.78114
# [2898]	validation_0-auc:0.78114
# [2899]	validation_0-auc:0.78115
# [2900]	validation_0-auc:0.78116
# [2901]	validation_0-auc:0.78116
# [2902]	validation_0-auc:0.78116
# [2903]	validation_0-auc:0.78117
# [2904]	validation_0-auc:0.78116
# [2905]	validation_0-auc:0.78116
# [2906]	validation_0-auc:0.78116
# [2907]	validation_0-auc:0.78115
# [2908]	validation_0-auc:0.78115
# [2909]	validation_0-auc:0.78116
# [2910]	validation_0-auc:0.78117
# [2911]	validation_0-auc:0.78117
# [2912]	validation_0-auc:0.78117
# [2913]	validation_0-auc:0.78117
# [2914]	validation_0-auc:0.78117
# [2915]	validation_0-auc:0.78117
# [2916]	validation_0-auc:0.78119
# [2917]	validation_0-auc:0.78119
# [2918]	validation_0-auc:0.78120
# [2919]	validation_0-auc:0.78120
# [2920]	validation_0-auc:0.78121
# [2921]	validation_0-auc:0.78122
# [2922]	validation_0-auc:0.78121
# [2923]	validation_0-auc:0.78120
# [2924]	validation_0-auc:0.78119
# [2925]	validation_0-auc:0.78120
# [2926]	validation_0-auc:0.78120
# [2927]	validation_0-auc:0.78120
# [2928]	validation_0-auc:0.78120
# [2929]	validation_0-auc:0.78119
# [2930]	validation_0-auc:0.78120
# [2931]	validation_0-auc:0.78121
# [2932]	validation_0-auc:0.78121
# [2933]	validation_0-auc:0.78121
# [2934]	validation_0-auc:0.78121
# [2935]	validation_0-auc:0.78121
# [2936]	validation_0-auc:0.78120
# [2937]	validation_0-auc:0.78121
# [2938]	validation_0-auc:0.78122
# [2939]	validation_0-auc:0.78122
# [2940]	validation_0-auc:0.78123
# [2941]	validation_0-auc:0.78123
# [2942]	validation_0-auc:0.78123
# [2943]	validation_0-auc:0.78124
# [2944]	validation_0-auc:0.78124
# [2945]	validation_0-auc:0.78123
# [2946]	validation_0-auc:0.78124
# [2947]	validation_0-auc:0.78124
# [2948]	validation_0-auc:0.78123
# [2949]	validation_0-auc:0.78123
# [2950]	validation_0-auc:0.78122
# [2951]	validation_0-auc:0.78122
# [2952]	validation_0-auc:0.78122
# [2953]	validation_0-auc:0.78123
# [2954]	validation_0-auc:0.78122
# [2955]	validation_0-auc:0.78122
# [2956]	validation_0-auc:0.78121
# [2957]	validation_0-auc:0.78121
# [2958]	validation_0-auc:0.78121
# [2959]	validation_0-auc:0.78121
# [2960]	validation_0-auc:0.78121
# [2961]	validation_0-auc:0.78120
# [2962]	validation_0-auc:0.78121
# [2963]	validation_0-auc:0.78121
# [2964]	validation_0-auc:0.78121
# [2965]	validation_0-auc:0.78122
# [2966]	validation_0-auc:0.78122
# [2967]	validation_0-auc:0.78122
# [2968]	validation_0-auc:0.78122
# [2969]	validation_0-auc:0.78121
# [2970]	validation_0-auc:0.78121
# [2971]	validation_0-auc:0.78121
# [2972]	validation_0-auc:0.78119
# [2973]	validation_0-auc:0.78118
# [2974]	validation_0-auc:0.78119
# [2975]	validation_0-auc:0.78119
# [2976]	validation_0-auc:0.78120
# [2977]	validation_0-auc:0.78120
# [2978]	validation_0-auc:0.78119
# [2979]	validation_0-auc:0.78119
# [2980]	validation_0-auc:0.78119
# [2981]	validation_0-auc:0.78119
# [2982]	validation_0-auc:0.78118
# [2983]	validation_0-auc:0.78118
# [2984]	validation_0-auc:0.78117
# [2985]	validation_0-auc:0.78117
# [2986]	validation_0-auc:0.78117
# [2987]	validation_0-auc:0.78117
# [2988]	validation_0-auc:0.78118
# [2989]	validation_0-auc:0.78119
# [2990]	validation_0-auc:0.78119
# [2991]	validation_0-auc:0.78121
# [2992]	validation_0-auc:0.78121
# [2993]	validation_0-auc:0.78121
# [2994]	validation_0-auc:0.78121
# [2995]	validation_0-auc:0.78122
# [2996]	validation_0-auc:0.78122
# [2997]	validation_0-auc:0.78123
# [2998]	validation_0-auc:0.78121
# [2999]	validation_0-auc:0.78121
# [3000]	validation_0-auc:0.78120
# [3001]	validation_0-auc:0.78119
# [3002]	validation_0-auc:0.78118
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=300,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=1.0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=20, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=5500,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
'''
#search optim threshold
from sklearn.metrics import roc_curve
import numpy as np

y_val_proba = xgb_model.predict_proba(X_val)[:, 1]
fpr, tpr, thresholds = roc_curve(y_val, y_val_proba)

# finds threshold max (TPR - FPR)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print(f"Optimal Threshold: {optimal_threshold:.3f}")
'''
# Out:
# '\n#search optim threshold\nfrom sklearn.metrics import roc_curve\nimport numpy as np\n\ny_val_proba = xgb_model.predict_proba(X_val)[:, 1]\nfpr, tpr, thresholds = roc_curve(y_val, y_val_proba)\n\n# finds threshold max (TPR - FPR)\noptimal_idx = np.argmax(tpr - fpr)\noptimal_threshold = thresholds[optimal_idx]\nprint(f"Optimal Threshold: {optimal_threshold:.3f}")\n'

# %%
#optimal f1 threshold
from sklearn.metrics import f1_score
import numpy as np

y_val_proba = xgb_model.predict_proba(X_val)[:, 1]

thresholds = np.linspace(0.05, 0.6, 100)
f1_scores = [f1_score(y_val, y_val_proba >= t) for t in thresholds]

optimal_threshold = thresholds[np.argmax(f1_scores)]

print(f"Optimal Threshold (F1): {optimal_threshold:.3f}")
# Out:
# Optimal Threshold (F1): 0.600

# %%
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, roc_curve

y_val_pred = xgb_model.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_val_pred)

adj_threshold = 0.60

y_val_pred = (y_val_pred >= adj_threshold).astype(int)

classification_report = classification_report(y_val, y_val_pred)

#Confusion matrix manual
TP = np.sum((y_val == 1) & (y_val_pred == 1))
FP = np.sum((y_val == 0) & (y_val_pred == 1))
TN = np.sum((y_val == 0) & (y_val_pred == 0))
FN = np.sum((y_val == 1) & (y_val_pred == 0))

FPR = FP / (FP + TN)
Precision = TP / (TP + FP)

print(f"FPR: {FPR:.4f}")
print(f"Precision (PPV): {Precision:.4f}")
print(f"AUC validación: {auc:.5f}")
print(classification_report)
# Out:
# FPR: 0.1601
# Precision (PPV): 0.2324
# AUC validación: 0.78127
#               precision    recall  f1-score   support
#
#            0       0.96      0.84      0.89     56538
#            1       0.23      0.55      0.33      4965
#
#     accuracy                           0.82     61503
#    macro avg       0.59      0.70      0.61     61503
# weighted avg       0.90      0.82      0.85     61503
