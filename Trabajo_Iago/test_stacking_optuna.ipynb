# %%
import pandas as pd
import numpy as np
from sklearn.utils import resample
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
import optuna
from optuna.samplers import TPESampler
import warnings
warnings.filterwarnings('ignore')

# %%
def get_oof_predictions(model, X, y, cat_features=None, n_folds=5):
    """
    Genera predicciones out-of-fold para stacking
    """
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)
    oof_preds = np.zeros(len(X))

    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        X_train_fold = X.iloc[train_idx]
        y_train_fold = y.iloc[train_idx]
        X_val_fold = X.iloc[val_idx]

        if isinstance(model, CatBoostClassifier):
            fold_model = CatBoostClassifier(**model.get_params())
            fold_model.fit(
                X_train_fold, y_train_fold,
                eval_set=(X_val_fold, y.iloc[val_idx]),
                cat_features=cat_features,
                verbose=0
            )
            oof_preds[val_idx] = fold_model.predict_proba(X_val_fold)[:, 1]

        elif isinstance(model, (XGBClassifier)):

            params = model.get_params()

            params.pop("verbosity", None)
            params.pop("device", None)

            fold_model = XGBClassifier(**params)
            fold_model.fit(
                X_train_fold, y_train_fold,
                #eval_set=[(X_val_fold, y.iloc[val_idx])],
                verbose=False,
            )
            oof_preds[val_idx] = fold_model.predict_proba(X_val_fold)[:, 1]

        elif isinstance(model, LGBMClassifier):
            # NUEVO: Usar LGBMClassifier para LightGBM
            fold_model = LGBMClassifier(**model.get_params())
            fold_model.fit(
                X_train_fold, y_train_fold,
                eval_set=[(X_val_fold, y.iloc[val_idx])],
            )
            oof_preds[val_idx] = fold_model.predict_proba(X_val_fold)[:, 1]

    return oof_preds

# %%
df = pd.read_csv("../data/processed/home_credit_train_ready.csv")

# %%
"""
# Rebalanceo del dataset
class_0 = df[df['TARGET'] == 0]
class_1 = df[df['TARGET'] == 1]
sub_class = resample(class_0, replace=False, n_samples=len(class_1), random_state=42)
df = pd.concat([sub_class, class_1])
"""
# Out:
# "\n# Rebalanceo del dataset\nclass_0 = df[df['TARGET'] == 0]\nclass_1 = df[df['TARGET'] == 1]\nsub_class = resample(class_0, replace=False, n_samples=len(class_1), random_state=42)\ndf = pd.concat([sub_class, class_1])\n"

# %%
# Separar X e y
y = df['TARGET']
X = df.drop(columns=['TARGET', 'SK_ID_CURR'])

# %%
# Manejo de valores infinitos
X.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Imputación de valores
cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

num_imputer = SimpleImputer(fill_value="median")
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

# %%
# Convertir a categorías
for col in X.select_dtypes("object"):
    X[col] = X[col].astype("category")

# %%
# Split train/test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# Identificar features categóricas
cat_features = X_train.select_dtypes(include=['category', 'object']).columns.tolist()

# Calcular scale_pos_weight
neg_samples = (y_train == 0).sum()
pos_samples = (y_train == 1).sum()
scale_pos_weight = neg_samples / pos_samples

# %%
def objective_catboost(trial):
    """
    Función objetivo para optimizar CatBoost
    """
    # Decidir si usar GPU o CPU basado en si necesitamos rsm
    #use_gpu = trial.suggest_categorical('use_gpu', [True, False])
    use_gpu = True

    params = {
        'loss_function': 'Logloss',
        'eval_metric': 'AUC',
        'auto_class_weights': 'Balanced',  # IMPORTANTE para desbalanceo

        # Boosting - Más iteraciones
        'iterations': trial.suggest_int('iterations', 3000, 8000, step=500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'depth': trial.suggest_int('depth', 6, 10),

        # Regularización
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 15.0),
        'random_strength': trial.suggest_float('random_strength', 0.5, 5.0),

        # Bootstrap
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli']),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 2.0) if trial.params.get('bootstrap_type') == 'Bayesian' else None,
        'subsample': trial.suggest_float('subsample', 0.5, 0.9) if trial.params.get('bootstrap_type') == 'Bernoulli' else None,

        # RSM solo si usamos CPU
        'rsm': trial.suggest_float('rsm', 0.5, 1.0) if not use_gpu else None,

        # Growing
        'grow_policy': trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Depthwise', 'Lossguide']),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),

        # Categóricas
        'cat_features': cat_features,
        'one_hot_max_size': trial.suggest_int('one_hot_max_size', 2, 20),

        # GPU/CPU
        'task_type': 'GPU' if use_gpu else 'CPU',
        'devices': '0' if use_gpu else None,
        'thread_count': -1 if not use_gpu else None,

        'random_seed': 42,
        'verbose': 0,
    }

    # Limpiar None values
    params = {k: v for k, v in params.items() if v is not None}

    # Obtener predicciones OOF
    model = CatBoostClassifier(**params)
    oof_preds = get_oof_predictions(model, X_train, y_train, cat_features=cat_features, n_folds=5)

    # Calcular AUC
    auc = roc_auc_score(y_train, oof_preds)

    return auc

# OPTIMIZACIÓN CON OPTUNA - XGBOOST

def objective_xgboost(trial):
    """
    Función objetivo para optimizar XGBoost
    """
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'scale_pos_weight': scale_pos_weight,

        # Boosting - Más agresivo
        'n_estimators': trial.suggest_int('n_estimators', 3000, 8000, step=500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'max_depth': trial.suggest_int('max_depth', 6, 12),

        # Regularización
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'gamma': trial.suggest_float('gamma', 0.0, 1.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.5, 1.0),
        'colsample_bynode': trial.suggest_float('colsample_bynode', 0.5, 1.0),

        # L1/L2
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 5.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),

        # Otros
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 5),
        'tree_method': 'hist',
        'grow_policy': trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide']),

        # Control
        'random_state': 42,
        'n_jobs': -1,
        'device': 'cuda',
        'verbosity': 0,
        'enable_categorical': True,
    }

    # Obtener predicciones OOF
    model = XGBClassifier(**params)
    oof_preds = get_oof_predictions(model, X_train, y_train, n_folds=5)

    # Calcular AUC
    auc = roc_auc_score(y_train, oof_preds)

    return auc


# OPTIMIZACIÓN CON OPTUNA - LIGHTGBM

def objective_lightgbm(trial):
    """
    Función objetivo para optimizar LightGBM
    """
    params = {
        'objective': 'binary',
        'metric': 'auc',
        'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart']),
        'scale_pos_weight': scale_pos_weight,

        # Boosting
        'n_estimators': trial.suggest_int('n_estimators', 3000, 8000, step=500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 31, 255),
        'max_depth': trial.suggest_int('max_depth', 6, 12),

        # Regularización
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),

        # L1/L2
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 5.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),

        # DART specific
        'drop_rate': trial.suggest_float('drop_rate', 0.0, 0.5) if trial.params.get('boosting_type') == 'dart' else None,

        # Control
        'random_state': 42,
        'n_jobs': -1,
        'device': 'gpu',
        'verbosity': -1,
    }

    # Limpiar None values
    params = {k: v for k, v in params.items() if v is not None}

    # Obtener predicciones OOF
    model = LGBMClassifier(**params)
    oof_preds = get_oof_predictions(model, X_train, y_train, n_folds=5)

    # Calcular AUC
    auc = roc_auc_score(y_train, oof_preds)

    return auc

# ============================================================================
# OPTIMIZACIÓN CON OPTUNA - META-MODELO
# ============================================================================

def objective_meta_model(trial, cat_oof, xgb_oof, lgb_oof):
    """
    Función objetivo para optimizar el meta-modelo con 3 modelos
    """
    w_cat = trial.suggest_float("cat_weight", 0.0, 1.0)
    w_xgb = trial.suggest_float("xgb_weight", 0.0, 1.0)
    w_lgb = trial.suggest_float("lgb_weight", 0.0, 1.0)

    if w_lgb < 0:
        return 0.0

    preds = (
        w_cat * cat_oof +
        w_xgb * xgb_oof +
        w_lgb * lgb_oof
    )

    penalty = abs(w_cat - 0.33) + abs(w_xgb - 0.33) + abs(w_lgb - 0.33)
    auc = roc_auc_score(y_train, preds) - 0.001 * penalty


    return auc

# %%
# Optimizar CatBoost
study_catboost = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    study_name='catboost_optimization'
)
study_catboost.optimize(objective_catboost, n_trials=30, show_progress_bar=True)

print(f"\nMejor AUC CatBoost: {study_catboost.best_value:.5f}")
print(f"Mejores parámetros CatBoost:")
for key, value in study_catboost.best_params.items():
    print(f"  - {key}: {value}")
# Out:
# [I 2026-01-20 00:13:56,848] A new study created in memory with name: catboost_optimization
#   0%|          | 0/30 [00:00<?, ?it/s]
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 00:25:22,128] Trial 0 finished with value: 0.7657149618128862 and parameters: {'iterations': 5000, 'learning_rate': 0.08927180304353628, 'depth': 9, 'l2_leaf_reg': 9.381218778758512, 'random_strength': 1.2020838819909643, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7323522915498704, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 98, 'one_hot_max_size': 17}. Best is trial 0 with value: 0.7657149618128862.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 00:31:15,718] Trial 1 finished with value: 0.7839039409939824 and parameters: {'iterations': 4000, 'learning_rate': 0.015199348301309814, 'depth': 6, 'l2_leaf_reg': 5.259391401433528, 'random_strength': 2.86140394234507, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.223705789444759, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 51, 'one_hot_max_size': 16}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 00:42:08,876] Trial 2 finished with value: 0.7781575053613004 and parameters: {'iterations': 4000, 'learning_rate': 0.032676417657817626, 'depth': 8, 'l2_leaf_reg': 1.6503057780799681, 'random_strength': 3.2339518335564725, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.8977710745066665, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 18, 'one_hot_max_size': 15}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 00:51:11,407] Trial 3 finished with value: 0.7668937283408778 and parameters: {'iterations': 5000, 'learning_rate': 0.01324458134009936, 'depth': 8, 'l2_leaf_reg': 1.4814392956130575, 'random_strength': 4.59194180935452, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6246844304357644, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 98, 'one_hot_max_size': 16}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 01:03:24,195] Trial 4 finished with value: 0.7805005581996203 and parameters: {'iterations': 8000, 'learning_rate': 0.07849235338159358, 'depth': 8, 'l2_leaf_reg': 13.906239290323636, 'random_strength': 0.8982162592336378, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.6506606615265287, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 42, 'one_hot_max_size': 7}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 01:47:01,507] Trial 5 finished with value: 0.7738929849360359 and parameters: {'iterations': 5500, 'learning_rate': 0.013833249975219963, 'depth': 10, 'l2_leaf_reg': 2.0437090115167917, 'random_strength': 4.940991214702327, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.011044234247204798, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 80, 'one_hot_max_size': 3}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 01:54:17,005] Trial 6 finished with value: 0.7821782381693896 and parameters: {'iterations': 4500, 'learning_rate': 0.013057771348997228, 'depth': 10, 'l2_leaf_reg': 9.72617377558581, 'random_strength': 1.9890411118369213, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6300733288106988, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 52, 'one_hot_max_size': 4}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:04:12,669] Trial 7 finished with value: 0.7810569957213985 and parameters: {'iterations': 6500, 'learning_rate': 0.057648106701146694, 'depth': 8, 'l2_leaf_reg': 11.793540519363853, 'random_strength': 2.7220801836397586, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.05083825348819038, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 38, 'one_hot_max_size': 11}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:24:21,999] Trial 8 finished with value: 0.7820969116218157 and parameters: {'iterations': 7500, 'learning_rate': 0.017753837036522245, 'depth': 8, 'l2_leaf_reg': 11.577715939602681, 'random_strength': 1.529591744712301, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5644885149016018, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 89, 'one_hot_max_size': 17}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:30:22,193] Trial 9 finished with value: 0.7797007401051097 and parameters: {'iterations': 4000, 'learning_rate': 0.07808345085542412, 'depth': 8, 'l2_leaf_reg': 12.304162172296875, 'random_strength': 4.53241084965572, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.45587032508388337, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 10, 'one_hot_max_size': 11}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:34:36,884] Trial 10 finished with value: 0.7806589068774623 and parameters: {'iterations': 3000, 'learning_rate': 0.024854382110833333, 'depth': 6, 'l2_leaf_reg': 5.147316060606622, 'random_strength': 3.433399478501803, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8839082983781679, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 71, 'one_hot_max_size': 20}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:40:23,526] Trial 11 finished with value: 0.7813366396039202 and parameters: {'iterations': 4000, 'learning_rate': 0.010224204739011923, 'depth': 6, 'l2_leaf_reg': 6.5912200769488605, 'random_strength': 2.2490066145845318, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7667963710144704, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 57, 'one_hot_max_size': 2}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:45:54,289] Trial 12 finished with value: 0.7815268076605395 and parameters: {'iterations': 3500, 'learning_rate': 0.02338595250107362, 'depth': 10, 'l2_leaf_reg': 8.769787884323392, 'random_strength': 2.0643504372346215, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5042397419513477, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 56, 'one_hot_max_size': 7}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 02:52:27,568] Trial 13 finished with value: 0.7809503171408787 and parameters: {'iterations': 4500, 'learning_rate': 0.038433824191375664, 'depth': 7, 'l2_leaf_reg': 4.381769061724758, 'random_strength': 3.696887919029021, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7184200828646883, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 38, 'one_hot_max_size': 6}. Best is trial 1 with value: 0.7839039409939824.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:02:03,710] Trial 14 finished with value: 0.784051439917729 and parameters: {'iterations': 6500, 'learning_rate': 0.018081659456430418, 'depth': 7, 'l2_leaf_reg': 7.509157356683852, 'random_strength': 1.943825803789177, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.289231140858435, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 67, 'one_hot_max_size': 13}. Best is trial 14 with value: 0.784051439917729.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:12:02,621] Trial 15 finished with value: 0.7791976772957796 and parameters: {'iterations': 6500, 'learning_rate': 0.019754564808404824, 'depth': 7, 'l2_leaf_reg': 6.886058924470436, 'random_strength': 0.5213305384389031, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.363425441834631, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 70, 'one_hot_max_size': 13}. Best is trial 14 with value: 0.784051439917729.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:21:29,937] Trial 16 finished with value: 0.7821908838905701 and parameters: {'iterations': 6500, 'learning_rate': 0.04258179059731556, 'depth': 7, 'l2_leaf_reg': 3.9859666988357123, 'random_strength': 2.746870447686365, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.1727807202093594, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 68, 'one_hot_max_size': 13}. Best is trial 14 with value: 0.784051439917729.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:30:10,350] Trial 17 finished with value: 0.7841019115643509 and parameters: {'iterations': 6000, 'learning_rate': 0.017257341966192278, 'depth': 6, 'l2_leaf_reg': 7.071611279317964, 'random_strength': 3.8295096956577956, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.4504528425710896, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 27, 'one_hot_max_size': 20}. Best is trial 17 with value: 0.7841019115643509.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:41:06,594] Trial 18 finished with value: 0.7824515386837384 and parameters: {'iterations': 6000, 'learning_rate': 0.025355477090709816, 'depth': 7, 'l2_leaf_reg': 6.613527327131494, 'random_strength': 3.9232482403266205, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.493169176478417, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 25, 'one_hot_max_size': 20}. Best is trial 17 with value: 0.7841019115643509.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:49:54,297] Trial 19 finished with value: 0.7805378369454707 and parameters: {'iterations': 7000, 'learning_rate': 0.010086576565234193, 'depth': 6, 'l2_leaf_reg': 7.736381669103048, 'random_strength': 3.9797421846483223, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.8635862748877983, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 30, 'one_hot_max_size': 9}. Best is trial 17 with value: 0.7841019115643509.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 03:58:53,441] Trial 20 finished with value: 0.784615804241636 and parameters: {'iterations': 6000, 'learning_rate': 0.020264468308303578, 'depth': 7, 'l2_leaf_reg': 10.032658552941697, 'random_strength': 1.6991555670756433, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.551704656420381, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 64, 'one_hot_max_size': 19}. Best is trial 20 with value: 0.784615804241636.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:07:55,470] Trial 21 finished with value: 0.7850065143951975 and parameters: {'iterations': 6000, 'learning_rate': 0.01912693199266489, 'depth': 7, 'l2_leaf_reg': 10.331505281793332, 'random_strength': 1.5831849249961483, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.566326286968378, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 61, 'one_hot_max_size': 19}. Best is trial 21 with value: 0.7850065143951975.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:15:52,514] Trial 22 finished with value: 0.784374637555665 and parameters: {'iterations': 5500, 'learning_rate': 0.02123121205685313, 'depth': 6, 'l2_leaf_reg': 11.152261695791793, 'random_strength': 1.205785296836125, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.6006342044207873, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 61, 'one_hot_max_size': 19}. Best is trial 21 with value: 0.7850065143951975.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:24:09,636] Trial 23 finished with value: 0.785044390035991 and parameters: {'iterations': 5500, 'learning_rate': 0.029283777377060543, 'depth': 7, 'l2_leaf_reg': 10.437238653240708, 'random_strength': 1.5238135355014362, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.696188943505986, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 80, 'one_hot_max_size': 18}. Best is trial 23 with value: 0.785044390035991.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:33:15,896] Trial 24 finished with value: 0.7851042613020398 and parameters: {'iterations': 6000, 'learning_rate': 0.030065067238315705, 'depth': 7, 'l2_leaf_reg': 10.232217881271547, 'random_strength': 1.5630042938677005, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.934037357498665, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 80, 'one_hot_max_size': 18}. Best is trial 24 with value: 0.7851042613020398.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:41:11,756] Trial 25 finished with value: 0.7850673112989532 and parameters: {'iterations': 5000, 'learning_rate': 0.031127365059342837, 'depth': 9, 'l2_leaf_reg': 13.393357504340827, 'random_strength': 2.4200992555488696, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.8451024584048932, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 80, 'one_hot_max_size': 18}. Best is trial 24 with value: 0.7851042613020398.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:49:10,719] Trial 26 finished with value: 0.7851736421827313 and parameters: {'iterations': 5000, 'learning_rate': 0.02951564502586622, 'depth': 9, 'l2_leaf_reg': 14.36532868162059, 'random_strength': 2.3762458022633144, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.946782208042912, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 80, 'one_hot_max_size': 18}. Best is trial 26 with value: 0.7851736421827313.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 04:57:09,153] Trial 27 finished with value: 0.7846412917489158 and parameters: {'iterations': 5000, 'learning_rate': 0.04540566939900886, 'depth': 9, 'l2_leaf_reg': 14.365469490610426, 'random_strength': 2.469384561014156, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.9749513272743762, 'grow_policy': 'Lossguide', 'min_data_in_leaf': 78, 'one_hot_max_size': 15}. Best is trial 26 with value: 0.7851736421827313.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 05:08:29,469] Trial 28 finished with value: 0.7744811324628176 and parameters: {'iterations': 4500, 'learning_rate': 0.03206591430543421, 'depth': 9, 'l2_leaf_reg': 13.204062104065414, 'random_strength': 2.4078604308564526, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7956562676996013, 'grow_policy': 'Depthwise', 'min_data_in_leaf': 88, 'one_hot_max_size': 14}. Best is trial 26 with value: 0.7851736421827313.
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# Default metric period is 5 because AUC is/are not implemented for GPU
# [I 2026-01-20 05:28:39,644] Trial 29 finished with value: 0.7772202103365309 and parameters: {'iterations': 5000, 'learning_rate': 0.05413632365222081, 'depth': 9, 'l2_leaf_reg': 14.761802095361311, 'random_strength': 3.0259156012574224, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.9835815187841797, 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 100, 'one_hot_max_size': 17}. Best is trial 26 with value: 0.7851736421827313.
#
# Mejor AUC CatBoost: 0.78517
# Mejores parámetros CatBoost:
#   - iterations: 5000
#   - learning_rate: 0.02951564502586622
#   - depth: 9
#   - l2_leaf_reg: 14.36532868162059
#   - random_strength: 2.3762458022633144
#   - bootstrap_type: Bayesian
#   - bagging_temperature: 1.946782208042912
#   - grow_policy: Lossguide
#   - min_data_in_leaf: 80
#   - one_hot_max_size: 18

# %%
# Optimizar XGBoost
study_xgboost = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    study_name='xgboost_optimization'
)
study_xgboost.optimize(objective_xgboost, n_trials=30, show_progress_bar=True)

print(f"\nMejor AUC XGBoost: {study_xgboost.best_value:.5f}")
print(f"Mejores parámetros XGBoost:")
for key, value in study_xgboost.best_params.items():
    print(f"  - {key}: {value}")
# Out:
# [I 2026-01-20 05:28:39,730] A new study created in memory with name: xgboost_optimization
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2026-01-20 05:47:52,909] Trial 0 finished with value: 0.7544174852412241 and parameters: {'n_estimators': 5000, 'learning_rate': 0.08927180304353628, 'max_depth': 11, 'min_child_weight': 12, 'gamma': 0.15601864044243652, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'colsample_bylevel': 0.9330880728874675, 'colsample_bynode': 0.8005575058716043, 'reg_alpha': 3.540362888980227, 'reg_lambda': 0.20584494295802447, 'max_delta_step': 5, 'grow_policy': 'depthwise'}. Best is trial 0 with value: 0.7544174852412241.
# [I 2026-01-20 06:06:56,254] Trial 1 finished with value: 0.772312861711888 and parameters: {'n_estimators': 4000, 'learning_rate': 0.015254729458052608, 'max_depth': 8, 'min_child_weight': 11, 'gamma': 0.43194501864211576, 'subsample': 0.645614570099021, 'colsample_bytree': 0.8059264473611898, 'colsample_bylevel': 0.569746930326021, 'colsample_bynode': 0.6460723242676091, 'reg_alpha': 1.8318092164684585, 'reg_lambda': 4.56069984217036, 'max_delta_step': 4, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 0.772312861711888.
# [I 2026-01-20 07:12:39,025] Trial 2 finished with value: 0.7673504478974742 and parameters: {'n_estimators': 6000, 'learning_rate': 0.011128853174905732, 'max_depth': 10, 'min_child_weight': 4, 'gamma': 0.06505159298527952, 'subsample': 0.9744427686266666, 'colsample_bytree': 0.9828160165372797, 'colsample_bylevel': 0.9041986740582306, 'colsample_bynode': 0.6523068845866853, 'reg_alpha': 0.48836057003191935, 'reg_lambda': 6.842330265121569, 'max_delta_step': 2, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 0.772312861711888.
# [I 2026-01-20 07:22:12,488] Trial 3 finished with value: 0.7600625275013675 and parameters: {'n_estimators': 3000, 'learning_rate': 0.08115595675970502, 'max_depth': 7, 'min_child_weight': 14, 'gamma': 0.31171107608941095, 'subsample': 0.7600340105889054, 'colsample_bytree': 0.7733551396716398, 'colsample_bylevel': 0.5924272277627636, 'colsample_bynode': 0.9847923138822793, 'reg_alpha': 3.8756641168055728, 'reg_lambda': 9.394989415641891, 'max_delta_step': 5, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 0.772312861711888.
# [I 2026-01-20 07:28:43,830] Trial 4 finished with value: 0.7761750959192772 and parameters: {'n_estimators': 3000, 'learning_rate': 0.015703008378806716, 'max_depth': 6, 'min_child_weight': 7, 'gamma': 0.388677289689482, 'subsample': 0.6356745158869479, 'colsample_bytree': 0.9143687545759647, 'colsample_bylevel': 0.6783766633467947, 'colsample_bynode': 0.6404672548436904, 'reg_alpha': 2.7134804157912424, 'reg_lambda': 1.4092422497476265, 'max_delta_step': 4, 'grow_policy': 'lossguide'}. Best is trial 4 with value: 0.7761750959192772.
# [I 2026-01-20 07:40:20,676] Trial 5 finished with value: 0.7740212508544841 and parameters: {'n_estimators': 7000, 'learning_rate': 0.01580213186410389, 'max_depth': 6, 'min_child_weight': 17, 'gamma': 0.7068573438476171, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'colsample_bylevel': 0.5370223258670452, 'colsample_bynode': 0.6792328642721364, 'reg_alpha': 0.5793452976256486, 'reg_lambda': 8.631034258755935, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.7761750959192772.
# [I 2026-01-20 08:11:46,267] Trial 6 finished with value: 0.7745801820672383 and parameters: {'n_estimators': 4500, 'learning_rate': 0.021143813626634367, 'max_depth': 11, 'min_child_weight': 13, 'gamma': 0.8872127425763265, 'subsample': 0.7361074625809747, 'colsample_bytree': 0.5597971229691509, 'colsample_bylevel': 0.8566223936114975, 'colsample_bynode': 0.8803925243084487, 'reg_alpha': 2.8063859878474813, 'reg_lambda': 7.70967179954561, 'max_delta_step': 2, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 0.7761750959192772.
# [I 2026-01-20 08:17:14,352] Trial 7 finished with value: 0.7801923034428402 and parameters: {'n_estimators': 3000, 'learning_rate': 0.0128201004189169, 'max_depth': 6, 'min_child_weight': 13, 'gamma': 0.3143559810763267, 'subsample': 0.7542853455823514, 'colsample_bytree': 0.9537832369630466, 'colsample_bylevel': 0.6246461145744375, 'colsample_bynode': 0.7051914615178149, 'reg_alpha': 3.7777556927152434, 'reg_lambda': 2.2879816549162246, 'max_delta_step': 0, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 08:38:20,450] Trial 8 finished with value: 0.7601691964495378 and parameters: {'n_estimators': 8000, 'learning_rate': 0.06428658848831817, 'max_depth': 10, 'min_child_weight': 18, 'gamma': 0.8036720768991145, 'subsample': 0.5932850294430179, 'colsample_bytree': 0.9462794992449889, 'colsample_bylevel': 0.7696711209578253, 'colsample_bynode': 0.9037200775820313, 'reg_alpha': 4.480456499617466, 'reg_lambda': 3.1800347497186388, 'max_delta_step': 0, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 08:53:08,453] Trial 9 finished with value: 0.7523688454735714 and parameters: {'n_estimators': 7000, 'learning_rate': 0.07256556536786182, 'max_depth': 6, 'min_child_weight': 11, 'gamma': 0.417411003148779, 'subsample': 0.6110539052353652, 'colsample_bytree': 0.5599326836668415, 'colsample_bylevel': 0.668807585701814, 'colsample_bynode': 0.9714548519562596, 'reg_alpha': 1.6160146601037761, 'reg_lambda': 5.187906217433661, 'max_delta_step': 4, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 09:08:26,725] Trial 10 finished with value: 0.7685357968934088 and parameters: {'n_estimators': 4000, 'learning_rate': 0.036768352626888295, 'max_depth': 8, 'min_child_weight': 1, 'gamma': 0.6125547258948019, 'subsample': 0.808085372616097, 'colsample_bytree': 0.667347351120399, 'colsample_bylevel': 0.7950657347001129, 'colsample_bynode': 0.5382089284687879, 'reg_alpha': 4.961813327301684, 'reg_lambda': 2.5062456038305845, 'max_delta_step': 0, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 09:13:39,388] Trial 11 finished with value: 0.7681734202956587 and parameters: {'n_estimators': 3000, 'learning_rate': 0.029697097625138266, 'max_depth': 6, 'min_child_weight': 7, 'gamma': 0.22111761218072354, 'subsample': 0.506145149313478, 'colsample_bytree': 0.8811130448805917, 'colsample_bylevel': 0.6740824250449157, 'colsample_bynode': 0.5340601205851647, 'reg_alpha': 3.0453693171687224, 'reg_lambda': 0.3833947316286359, 'max_delta_step': 3, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 09:23:44,692] Trial 12 finished with value: 0.7767888010209126 and parameters: {'n_estimators': 3000, 'learning_rate': 0.010325175362672736, 'max_depth': 7, 'min_child_weight': 7, 'gamma': 0.5643700126830636, 'subsample': 0.6937986608862212, 'colsample_bytree': 0.883929406829195, 'colsample_bylevel': 0.6695070722352982, 'colsample_bynode': 0.7485426968054263, 'reg_alpha': 2.0672549001793947, 'reg_lambda': 2.1347469654790823, 'max_delta_step': 1, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 09:39:02,034] Trial 13 finished with value: 0.7722927285480006 and parameters: {'n_estimators': 4000, 'learning_rate': 0.010690692866183812, 'max_depth': 8, 'min_child_weight': 7, 'gamma': 0.5749815413356172, 'subsample': 0.7141670026382386, 'colsample_bytree': 0.8323089855073922, 'colsample_bylevel': 0.669200291429567, 'colsample_bynode': 0.7536977285976512, 'reg_alpha': 1.8698885287079228, 'reg_lambda': 3.296993330344698, 'max_delta_step': 1, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 09:55:13,805] Trial 14 finished with value: 0.7698219047697041 and parameters: {'n_estimators': 5500, 'learning_rate': 0.02527565072644974, 'max_depth': 7, 'min_child_weight': 15, 'gamma': 0.5278344772744845, 'subsample': 0.8499318904673885, 'colsample_bytree': 0.6639926607342311, 'colsample_bylevel': 0.6063151814651538, 'colsample_bynode': 0.7782511696546672, 'reg_alpha': 3.7917019096724456, 'reg_lambda': 1.7928297950613064, 'max_delta_step': 1, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 10:03:27,128] Trial 15 finished with value: 0.7644107427892788 and parameters: {'n_estimators': 3500, 'learning_rate': 0.04418145120946535, 'max_depth': 7, 'min_child_weight': 20, 'gamma': 0.2783373412812331, 'subsample': 0.699037231965785, 'colsample_bytree': 0.99905727259611, 'colsample_bylevel': 0.5130472064045203, 'colsample_bynode': 0.7070847955889696, 'reg_alpha': 1.1884849383054878, 'reg_lambda': 4.599862088745184, 'max_delta_step': 1, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 10:41:43,683] Trial 16 finished with value: 0.771069233894768 and parameters: {'n_estimators': 5000, 'learning_rate': 0.012617380066051991, 'max_depth': 9, 'min_child_weight': 9, 'gamma': 0.012255917793517146, 'subsample': 0.9397503979440349, 'colsample_bytree': 0.7148927164725545, 'colsample_bylevel': 0.7357488902403433, 'colsample_bynode': 0.8471577896044986, 'reg_alpha': 2.1805092922528253, 'reg_lambda': 3.627410982481339, 'max_delta_step': 0, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 11:20:47,154] Trial 17 finished with value: 0.7754384633958176 and parameters: {'n_estimators': 3500, 'learning_rate': 0.019202142309465965, 'max_depth': 12, 'min_child_weight': 4, 'gamma': 0.6850108203082976, 'subsample': 0.8034833015428839, 'colsample_bytree': 0.8347551699879654, 'colsample_bylevel': 0.9969213925248543, 'colsample_bynode': 0.5975118290673396, 'reg_alpha': 3.204069267936838, 'reg_lambda': 5.970446750394399, 'max_delta_step': 1, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 11:38:32,232] Trial 18 finished with value: 0.7738707342088814 and parameters: {'n_estimators': 6500, 'learning_rate': 0.010090944818458913, 'max_depth': 7, 'min_child_weight': 9, 'gamma': 0.9438658020309542, 'subsample': 0.6779194636199356, 'colsample_bytree': 0.9438040445121478, 'colsample_bylevel': 0.624585950087058, 'colsample_bynode': 0.7143091232729256, 'reg_alpha': 4.321947859390871, 'reg_lambda': 1.2029092178895047, 'max_delta_step': 0, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 11:56:39,282] Trial 19 finished with value: 0.764615675839311 and parameters: {'n_estimators': 4500, 'learning_rate': 0.051402024507244556, 'max_depth': 9, 'min_child_weight': 4, 'gamma': 0.5147196998556315, 'subsample': 0.8974242519002456, 'colsample_bytree': 0.8625807748497069, 'colsample_bylevel': 0.7305883778847561, 'colsample_bynode': 0.8170064962868606, 'reg_alpha': 1.1964299328914105, 'reg_lambda': 2.124294843606222, 'max_delta_step': 2, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:12:16,784] Trial 20 finished with value: 0.7724373840643433 and parameters: {'n_estimators': 3500, 'learning_rate': 0.020358083670878237, 'max_depth': 8, 'min_child_weight': 16, 'gamma': 0.11923527136624823, 'subsample': 0.7902334466382219, 'colsample_bytree': 0.7451307630048076, 'colsample_bylevel': 0.8147672630481991, 'colsample_bynode': 0.5930850531149676, 'reg_alpha': 2.3415426202983762, 'reg_lambda': 2.686088065446536, 'max_delta_step': 1, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:18:56,225] Trial 21 finished with value: 0.7780984172674035 and parameters: {'n_estimators': 3000, 'learning_rate': 0.013546940583258876, 'max_depth': 6, 'min_child_weight': 7, 'gamma': 0.37332260863556355, 'subsample': 0.6571369511070104, 'colsample_bytree': 0.9243935298529543, 'colsample_bylevel': 0.645833212546373, 'colsample_bynode': 0.6126275668133333, 'reg_alpha': 2.6613641378946697, 'reg_lambda': 1.1143249371885113, 'max_delta_step': 4, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:25:35,601] Trial 22 finished with value: 0.777650575785121 and parameters: {'n_estimators': 3000, 'learning_rate': 0.01339471885485554, 'max_depth': 6, 'min_child_weight': 9, 'gamma': 0.34660424217691854, 'subsample': 0.6669013199381703, 'colsample_bytree': 0.9243643494664352, 'colsample_bylevel': 0.637015579253436, 'colsample_bynode': 0.7268798817416571, 'reg_alpha': 2.3337623711810425, 'reg_lambda': 1.0290898056491267, 'max_delta_step': 3, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:33:16,097] Trial 23 finished with value: 0.7768004465313585 and parameters: {'n_estimators': 3500, 'learning_rate': 0.013756407318478608, 'max_depth': 6, 'min_child_weight': 9, 'gamma': 0.3240856370538882, 'subsample': 0.5476646329847751, 'colsample_bytree': 0.9372687581751299, 'colsample_bylevel': 0.6253241703407553, 'colsample_bynode': 0.6111303518610623, 'reg_alpha': 3.4671030127412905, 'reg_lambda': 0.6938422910961264, 'max_delta_step': 3, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:43:21,464] Trial 24 finished with value: 0.7714256577005779 and parameters: {'n_estimators': 4500, 'learning_rate': 0.01860556452037228, 'max_depth': 6, 'min_child_weight': 10, 'gamma': 0.21357875035270485, 'subsample': 0.6561429403930797, 'colsample_bytree': 0.9732092885911948, 'colsample_bylevel': 0.5600820629403223, 'colsample_bynode': 0.7053866788727527, 'reg_alpha': 2.5481323696305522, 'reg_lambda': 1.1058022741774927, 'max_delta_step': 4, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:52:56,901] Trial 25 finished with value: 0.777597257468525 and parameters: {'n_estimators': 3000, 'learning_rate': 0.012888068803631839, 'max_depth': 7, 'min_child_weight': 13, 'gamma': 0.37989965876278775, 'subsample': 0.7505026631019919, 'colsample_bytree': 0.9195103461940342, 'colsample_bylevel': 0.7068458766566168, 'colsample_bynode': 0.5474431296585539, 'reg_alpha': 4.310589482794664, 'reg_lambda': 0.05458575377313224, 'max_delta_step': 3, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 12:59:52,563] Trial 26 finished with value: 0.7680136345334279 and parameters: {'n_estimators': 4000, 'learning_rate': 0.025734677551538375, 'max_depth': 6, 'min_child_weight': 5, 'gamma': 0.4468613607674416, 'subsample': 0.5530858032682439, 'colsample_bytree': 0.7957787285443174, 'colsample_bylevel': 0.5010361324798532, 'colsample_bynode': 0.7391767949656513, 'reg_alpha': 3.1450823392877076, 'reg_lambda': 3.713953367179958, 'max_delta_step': 5, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 13:11:38,972] Trial 27 finished with value: 0.7649751086667906 and parameters: {'n_estimators': 3500, 'learning_rate': 0.023745499579804274, 'max_depth': 7, 'min_child_weight': 6, 'gamma': 0.240075460435281, 'subsample': 0.6196955680959305, 'colsample_bytree': 0.9682406296505512, 'colsample_bylevel': 0.6134554307514047, 'colsample_bynode': 0.5013339806386407, 'reg_alpha': 1.4059453243769457, 'reg_lambda': 1.049891100408785, 'max_delta_step': 4, 'grow_policy': 'lossguide'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 13:20:24,072] Trial 28 finished with value: 0.7711337033647798 and parameters: {'n_estimators': 5000, 'learning_rate': 0.017205716590086458, 'max_depth': 6, 'min_child_weight': 2, 'gamma': 0.34228705984433616, 'subsample': 0.6733526351356526, 'colsample_bytree': 0.9050515830467485, 'colsample_bylevel': 0.6413909563912533, 'colsample_bynode': 0.6706460710674502, 'reg_alpha': 3.944201692293592, 'reg_lambda': 1.7234938188793612, 'max_delta_step': 2, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
# [I 2026-01-20 13:38:59,190] Trial 29 finished with value: 0.7720375777103616 and parameters: {'n_estimators': 5500, 'learning_rate': 0.012568540642339716, 'max_depth': 8, 'min_child_weight': 12, 'gamma': 0.15655003990024918, 'subsample': 0.7278457667510323, 'colsample_bytree': 0.846488540635656, 'colsample_bylevel': 0.571010455642094, 'colsample_bynode': 0.7824353199031403, 'reg_alpha': 3.491272437962527, 'reg_lambda': 0.25750290430447875, 'max_delta_step': 5, 'grow_policy': 'depthwise'}. Best is trial 7 with value: 0.7801923034428402.
#
# Mejor AUC XGBoost: 0.78019
# Mejores parámetros XGBoost:
#   - n_estimators: 3000
#   - learning_rate: 0.0128201004189169
#   - max_depth: 6
#   - min_child_weight: 13
#   - gamma: 0.3143559810763267
#   - subsample: 0.7542853455823514
#   - colsample_bytree: 0.9537832369630466
#   - colsample_bylevel: 0.6246461145744375
#   - colsample_bynode: 0.7051914615178149
#   - reg_alpha: 3.7777556927152434
#   - reg_lambda: 2.2879816549162246
#   - max_delta_step: 0
#   - grow_policy: depthwise

# %%
# Optimizar LightGBM
study_lightgbm = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    study_name='lightgbm_optimization'
)
study_lightgbm.optimize(objective_lightgbm, n_trials=30, show_progress_bar=True)

print(f"\nMejor AUC LightGBM: {study_lightgbm.best_value:.5f}")
# Out:
# [I 2026-01-20 13:50:13,263] A new study created in memory with name: lightgbm_optimization
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2026-01-20 14:52:28,542] Trial 0 finished with value: 0.7611518255053991 and parameters: {'boosting_type': 'dart', 'n_estimators': 7000, 'learning_rate': 0.03968793330444373, 'num_leaves': 66, 'max_depth': 7, 'min_child_samples': 15, 'min_child_weight': 2.9154431891537547, 'subsample': 0.8005575058716043, 'colsample_bytree': 0.8540362888980227, 'reg_alpha': 0.10292247147901223, 'reg_lambda': 9.699098521619943, 'drop_rate': 0.41622132040021087}. Best is trial 0 with value: 0.7611518255053991.
# [I 2026-01-20 15:11:11,817] Trial 1 finished with value: 0.7619415989237929 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 4000, 'learning_rate': 0.02014847788415866, 'num_leaves': 149, 'max_depth': 9, 'min_child_samples': 36, 'min_child_weight': 0.2801635158716261, 'subsample': 0.569746930326021, 'colsample_bytree': 0.6460723242676091, 'reg_alpha': 1.8318092164684585, 'reg_lambda': 4.56069984217036}. Best is trial 1 with value: 0.7619415989237929.
# [I 2026-01-20 15:21:34,794] Trial 2 finished with value: 0.7574499362025884 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 5500, 'learning_rate': 0.03912141628549695, 'num_leaves': 41, 'max_depth': 10, 'min_child_samples': 25, 'min_child_weight': 0.0018205657658407262, 'subsample': 0.9744427686266666, 'colsample_bytree': 0.9828160165372797, 'reg_alpha': 4.041986740582305, 'reg_lambda': 3.0461376917337066}. Best is trial 1 with value: 0.7619415989237929.
# [I 2026-01-20 15:58:44,445] Trial 3 finished with value: 0.7791459736405948 and parameters: {'boosting_type': 'dart', 'n_estimators': 5000, 'learning_rate': 0.01324458134009936, 'num_leaves': 142, 'max_depth': 6, 'min_child_samples': 92, 'min_child_weight': 0.010842262717330166, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'reg_alpha': 2.600340105889054, 'reg_lambda': 5.4671027934327965, 'drop_rate': 0.09242722776276352}. Best is trial 3 with value: 0.7791459736405948.
# [I 2026-01-20 16:15:53,879] Trial 4 finished with value: 0.7598926412886093 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 8000, 'learning_rate': 0.07849235338159358, 'num_leaves': 165, 'max_depth': 12, 'min_child_samples': 18, 'min_child_weight': 0.006080390190296602, 'subsample': 0.522613644455269, 'colsample_bytree': 0.6626651653816322, 'reg_alpha': 1.9433864484474102, 'reg_lambda': 2.713490317738959}. Best is trial 3 with value: 0.7791459736405948.
# [I 2026-01-20 16:27:24,953] Trial 5 finished with value: 0.7629908662818896 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 4500, 'learning_rate': 0.03488960745139221, 'num_leaves': 62, 'max_depth': 11, 'min_child_samples': 16, 'min_child_weight': 8.862326508576253, 'subsample': 0.8861223846483287, 'colsample_bytree': 0.5993578407670862, 'reg_alpha': 0.027610585618011996, 'reg_lambda': 8.154614284548341}. Best is trial 3 with value: 0.7791459736405948.
# [I 2026-01-20 17:29:07,983] Trial 6 finished with value: 0.7797183502148917 and parameters: {'boosting_type': 'dart', 'n_estimators': 7000, 'learning_rate': 0.011858906685575274, 'num_leaves': 111, 'max_depth': 6, 'min_child_samples': 88, 'min_child_weight': 0.3113095956122124, 'subsample': 0.6654490124263246, 'colsample_bytree': 0.5317791751430119, 'reg_alpha': 1.554911608578311, 'reg_lambda': 3.2518332202674705, 'drop_rate': 0.36480308916903204}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 19:11:15,949] Trial 7 finished with value: 0.7739641123791814 and parameters: {'boosting_type': 'dart', 'n_estimators': 5500, 'learning_rate': 0.013170256885255107, 'num_leaves': 191, 'max_depth': 11, 'min_child_samples': 61, 'min_child_weight': 1.2130221181165162, 'subsample': 0.7468977981821954, 'colsample_bytree': 0.7613664146909971, 'reg_alpha': 2.137705091792748, 'reg_lambda': 0.2541912674409519, 'drop_rate': 0.053945713496652226}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 20:14:01,600] Trial 8 finished with value: 0.7683014567466863 and parameters: {'boosting_type': 'dart', 'n_estimators': 4500, 'learning_rate': 0.0322530426717912, 'num_leaves': 235, 'max_depth': 7, 'min_child_samples': 47, 'min_child_weight': 1.0524574681335637, 'subsample': 0.6143990827458112, 'colsample_bytree': 0.5384899549143964, 'reg_alpha': 1.4487572645688402, 'reg_lambda': 1.6122128725400442, 'drop_rate': 0.46484882617128653}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 20:34:50,603] Trial 9 finished with value: 0.7578570145142987 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 7500, 'learning_rate': 0.06363148766597145, 'num_leaves': 72, 'max_depth': 12, 'min_child_samples': 59, 'min_child_weight': 1.6973078532467012, 'subsample': 0.9480456499617467, 'colsample_bytree': 0.6590017374859319, 'reg_alpha': 0.5502596226383838, 'reg_lambda': 2.279351625419417}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 21:15:26,162] Trial 10 finished with value: 0.7792397007505205 and parameters: {'boosting_type': 'dart', 'n_estimators': 3000, 'learning_rate': 0.01017530226929883, 'num_leaves': 109, 'max_depth': 8, 'min_child_samples': 92, 'min_child_weight': 0.049091386717014754, 'subsample': 0.680055955997896, 'colsample_bytree': 0.517163833781648, 'reg_alpha': 3.47078400629919, 'reg_lambda': 5.904746895937297, 'drop_rate': 0.286435383666738}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 21:59:43,485] Trial 11 finished with value: 0.778635275174665 and parameters: {'boosting_type': 'dart', 'n_estimators': 3000, 'learning_rate': 0.010390365830373175, 'num_leaves': 102, 'max_depth': 8, 'min_child_samples': 100, 'min_child_weight': 0.06830108219444722, 'subsample': 0.6937971020319804, 'colsample_bytree': 0.5322584844252825, 'reg_alpha': 3.5285988359244316, 'reg_lambda': 6.090738634337445, 'drop_rate': 0.2798558791104245}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 22:59:14,480] Trial 12 finished with value: 0.7778237357537972 and parameters: {'boosting_type': 'dart', 'n_estimators': 6500, 'learning_rate': 0.01837053065838271, 'num_leaves': 108, 'max_depth': 6, 'min_child_samples': 80, 'min_child_weight': 0.056561467651267516, 'subsample': 0.6478451088877598, 'colsample_bytree': 0.5127747474052717, 'reg_alpha': 4.772091754397456, 'reg_lambda': 6.882295119501993, 'drop_rate': 0.2632488437893557}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-20 23:42:27,352] Trial 13 finished with value: 0.7755809423119129 and parameters: {'boosting_type': 'dart', 'n_estimators': 3000, 'learning_rate': 0.019705235104148178, 'num_leaves': 112, 'max_depth': 8, 'min_child_samples': 78, 'min_child_weight': 0.21032344126681068, 'subsample': 0.701882002686556, 'colsample_bytree': 0.7472223931930824, 'reg_alpha': 2.9685570544727704, 'reg_lambda': 4.1190779787558505, 'drop_rate': 0.3355246490933297}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 01:13:22,800] Trial 14 finished with value: 0.776518817763415 and parameters: {'boosting_type': 'dart', 'n_estimators': 6500, 'learning_rate': 0.010897701684889073, 'num_leaves': 187, 'max_depth': 8, 'min_child_samples': 79, 'min_child_weight': 0.025118072910840242, 'subsample': 0.6369859578936006, 'colsample_bytree': 0.5708123963283183, 'reg_alpha': 1.077763015647315, 'reg_lambda': 7.214699913654475, 'drop_rate': 0.1752700937847227}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 02:26:35,388] Trial 15 finished with value: 0.7734657538850183 and parameters: {'boosting_type': 'dart', 'n_estimators': 6500, 'learning_rate': 0.01589217412823818, 'num_leaves': 129, 'max_depth': 7, 'min_child_samples': 91, 'min_child_weight': 0.27012091394989934, 'subsample': 0.7531961634731409, 'colsample_bytree': 0.7700475100567968, 'reg_alpha': 3.270347035055493, 'reg_lambda': 3.87352785723598, 'drop_rate': 0.34477306811015773}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 03:08:37,855] Trial 16 finished with value: 0.7775113350473952 and parameters: {'boosting_type': 'dart', 'n_estimators': 3500, 'learning_rate': 0.023822973671271962, 'num_leaves': 87, 'max_depth': 9, 'min_child_samples': 69, 'min_child_weight': 0.0228851671815262, 'subsample': 0.5675321810922475, 'colsample_bytree': 0.591514922691938, 'reg_alpha': 4.116470996721787, 'reg_lambda': 0.5754271725775824, 'drop_rate': 0.19340805335450012}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 04:17:47,998] Trial 17 finished with value: 0.7768024326596641 and parameters: {'boosting_type': 'dart', 'n_estimators': 8000, 'learning_rate': 0.010179708598579333, 'num_leaves': 173, 'max_depth': 6, 'min_child_samples': 99, 'min_child_weight': 0.4610024523545475, 'subsample': 0.6933145661944938, 'colsample_bytree': 0.8956055235559708, 'reg_alpha': 2.6511226521425613, 'reg_lambda': 8.907208636325072, 'drop_rate': 0.3717887378779443}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 05:02:19,582] Trial 18 finished with value: 0.778351166542828 and parameters: {'boosting_type': 'dart', 'n_estimators': 6000, 'learning_rate': 0.02490291520289202, 'num_leaves': 31, 'max_depth': 7, 'min_child_samples': 87, 'min_child_weight': 0.10844131463585038, 'subsample': 0.5007639843888329, 'colsample_bytree': 0.5072538518740635, 'reg_alpha': 1.0144585761251557, 'reg_lambda': 5.170184826599058, 'drop_rate': 0.4928150248322979}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 07:05:11,033] Trial 19 finished with value: 0.7724572975485198 and parameters: {'boosting_type': 'dart', 'n_estimators': 7000, 'learning_rate': 0.01413017342061617, 'num_leaves': 221, 'max_depth': 9, 'min_child_samples': 71, 'min_child_weight': 0.0016583271392830781, 'subsample': 0.8058899647617433, 'colsample_bytree': 0.6123586109068486, 'reg_alpha': 3.802156900743202, 'reg_lambda': 6.4053013336563, 'drop_rate': 0.19997381012169593}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 07:59:49,668] Trial 20 finished with value: 0.7628484296238436 and parameters: {'boosting_type': 'dart', 'n_estimators': 4000, 'learning_rate': 0.0514617477729381, 'num_leaves': 124, 'max_depth': 8, 'min_child_samples': 48, 'min_child_weight': 0.005086500149536632, 'subsample': 0.7603413221119385, 'colsample_bytree': 0.8187525294291718, 'reg_alpha': 4.92052824121266, 'reg_lambda': 3.5495012327114486, 'drop_rate': 0.30293928992616187}. Best is trial 6 with value: 0.7797183502148917.
# [I 2026-01-21 08:32:13,771] Trial 21 finished with value: 0.779833705677911 and parameters: {'boosting_type': 'dart', 'n_estimators': 5000, 'learning_rate': 0.012851135515313751, 'num_leaves': 144, 'max_depth': 6, 'min_child_samples': 93, 'min_child_weight': 0.015319929533934594, 'subsample': 0.8649042227954797, 'colsample_bytree': 0.6881096156908384, 'reg_alpha': 2.515093068318215, 'reg_lambda': 4.881182050082884, 'drop_rate': 0.01707357538235943}. Best is trial 21 with value: 0.779833705677911.
# [I 2026-01-21 08:48:46,370] Trial 22 finished with value: 0.7808740335943063 and parameters: {'boosting_type': 'dart', 'n_estimators': 5000, 'learning_rate': 0.012294910796044946, 'num_leaves': 92, 'max_depth': 6, 'min_child_samples': 85, 'min_child_weight': 0.03173000093786445, 'subsample': 0.874615224292602, 'colsample_bytree': 0.5561467583303041, 'reg_alpha': 2.2713869947255474, 'reg_lambda': 4.8813744666008105, 'drop_rate': 0.00381033104925191}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 09:12:50,778] Trial 23 finished with value: 0.7796579451302525 and parameters: {'boosting_type': 'dart', 'n_estimators': 5000, 'learning_rate': 0.016370104860020662, 'num_leaves': 80, 'max_depth': 6, 'min_child_samples': 85, 'min_child_weight': 0.014521369166209738, 'subsample': 0.8983671969013654, 'colsample_bytree': 0.7107953478288436, 'reg_alpha': 2.213518169728205, 'reg_lambda': 4.821975707532958, 'drop_rate': 0.0092993677957964}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 09:53:03,671] Trial 24 finished with value: 0.7752844725792846 and parameters: {'boosting_type': 'dart', 'n_estimators': 5000, 'learning_rate': 0.02412309088253616, 'num_leaves': 153, 'max_depth': 6, 'min_child_samples': 70, 'min_child_weight': 0.00517734583792423, 'subsample': 0.8960270040624966, 'colsample_bytree': 0.7087712309080184, 'reg_alpha': 1.7279597411595593, 'reg_lambda': 1.9011731652943844, 'drop_rate': 0.10008337219312866}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 10:41:08,868] Trial 25 finished with value: 0.7798532292072964 and parameters: {'boosting_type': 'dart', 'n_estimators': 6000, 'learning_rate': 0.012633414684913236, 'num_leaves': 93, 'max_depth': 7, 'min_child_samples': 100, 'min_child_weight': 0.12730377445187113, 'subsample': 0.8671554062883008, 'colsample_bytree': 0.5624990883207687, 'reg_alpha': 1.4333607076480184, 'reg_lambda': 3.030419775127621, 'drop_rate': 0.012678299219713363}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 10:54:42,481] Trial 26 finished with value: 0.7519783466102551 and parameters: {'boosting_type': 'gbdt', 'n_estimators': 6000, 'learning_rate': 0.0996055610712437, 'num_leaves': 93, 'max_depth': 7, 'min_child_samples': 98, 'min_child_weight': 0.10782613779352675, 'subsample': 0.8579492344001379, 'colsample_bytree': 0.5657823984477985, 'reg_alpha': 1.1273024048612363, 'reg_lambda': 1.3774924444206236}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 11:36:50,027] Trial 27 finished with value: 0.7799323163889913 and parameters: {'boosting_type': 'dart', 'n_estimators': 6000, 'learning_rate': 0.015659857295037136, 'num_leaves': 49, 'max_depth': 7, 'min_child_samples': 82, 'min_child_weight': 0.03582384312914168, 'subsample': 0.9332234630232505, 'colsample_bytree': 0.7108205000426832, 'reg_alpha': 2.822487643752052, 'reg_lambda': 4.350049327341754, 'drop_rate': 0.01596369701360298}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 12:28:26,464] Trial 28 finished with value: 0.7792708604687233 and parameters: {'boosting_type': 'dart', 'n_estimators': 6000, 'learning_rate': 0.015462314545979546, 'num_leaves': 53, 'max_depth': 7, 'min_child_samples': 82, 'min_child_weight': 0.031119790800285305, 'subsample': 0.9380268055790325, 'colsample_bytree': 0.6163251081546904, 'reg_alpha': 2.990457455530489, 'reg_lambda': 4.177804844691705, 'drop_rate': 0.11443295391443813}. Best is trial 22 with value: 0.7808740335943063.
# [I 2026-01-21 13:10:21,985] Trial 29 finished with value: 0.7724485684649008 and parameters: {'boosting_type': 'dart', 'n_estimators': 5500, 'learning_rate': 0.027227561391687197, 'num_leaves': 56, 'max_depth': 7, 'min_child_samples': 75, 'min_child_weight': 0.10319180254400313, 'subsample': 0.932680378864141, 'colsample_bytree': 0.8507312415487857, 'reg_alpha': 0.5850903633893798, 'reg_lambda': 2.5850996518202978, 'drop_rate': 0.056521043086118467}. Best is trial 22 with value: 0.7808740335943063.
#
# Mejor AUC LightGBM: 0.78087

# %%
best_catboost_params = study_catboost.best_params.copy()

best_catboost_params.update({
    'loss_function': 'Logloss',
    'eval_metric': 'AUC',
    'auto_class_weights': 'Balanced',
    'cat_features': cat_features,
    'task_type': 'GPU',
    'random_seed': 42,
    'verbose': 0,
})

# %%
# Preparar parámetros XGBoost
best_xgboost_params = study_xgboost.best_params.copy()

best_xgboost_params.update({
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'scale_pos_weight': scale_pos_weight,
    'tree_method': 'hist',
    'random_state': 42,
    'n_jobs': -1,
    'verbose': None,
    'enable_categorical': True,
})

# %%
# Preparar parámetros LightGBM
best_lightgbm_params = study_lightgbm.best_params.copy()
best_lightgbm_params.update({
    'objective': 'binary',
    'metric': 'auc',
    'scale_pos_weight': scale_pos_weight,
    'random_state': 42,
    'n_jobs': -1,
    'device': 'gpu',
    'verbosity': -1,
})

# %%
# Crear modelos
catboost_best = CatBoostClassifier(**best_catboost_params)
xgboost_best = XGBClassifier(**best_xgboost_params)
lightgbm_best = LGBMClassifier(**best_lightgbm_params)

# %%
# Obtener predicciones OOF para el meta-modelo
cat_oof = get_oof_predictions(catboost_best, X_train, y_train, cat_features=cat_features, n_folds=5)
# Out:
# Warning: less than 75% GPU memory available for training. Free: 5974 Total: 8187.5
# Default metric period is 5 because AUC is/are not implemented for GPU
# Warning: less than 75% GPU memory available for training. Free: 5974 Total: 8187.5
# Default metric period is 5 because AUC is/are not implemented for GPU
# Warning: less than 75% GPU memory available for training. Free: 5974 Total: 8187.5
# Default metric period is 5 because AUC is/are not implemented for GPU
# Warning: less than 75% GPU memory available for training. Free: 5974 Total: 8187.5
# Default metric period is 5 because AUC is/are not implemented for GPU
# Warning: less than 75% GPU memory available for training. Free: 5974 Total: 8187.5
# Default metric period is 5 because AUC is/are not implemented for GPU

# %%
import xgboost as xgb

_original = xgb.config.set_config

def patched_set_config(**kwargs):
    if "verbosity" in kwargs and kwargs["verbosity"] == -1:
        kwargs["verbosity"] = 0
    return _original(**kwargs)

xgb.config.set_config = patched_set_config

# %%
xgb_oof = get_oof_predictions(xgboost_best, X_train, y_train, n_folds=5)

# %%
lgb_oof = get_oof_predictions(lightgbm_best, X_train, y_train, n_folds=5)

# %%
print(f"\nAUC individual en OOF:")
print(f"  CatBoost:  {roc_auc_score(y_train, cat_oof):.5f}")
print(f"  XGBoost:   {roc_auc_score(y_train, xgb_oof):.5f}")
print(f"  LightGBM:  {roc_auc_score(y_train, lgb_oof):.5f}")
# Out:
# AUC individual en OOF:
#   CatBoost:  0.78512
#   XGBoost:   0.78025
#   LightGBM:  0.78110

# %%
# Optimizar pesos del meta-modelo
study_meta = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42),
    study_name='meta_model_optimization'
)
study_meta.optimize(
    lambda trial: objective_meta_model(trial, cat_oof, xgb_oof, lgb_oof),
    n_trials=10000,
    show_progress_bar=True
)

# Obtener pesos óptimos y normalizar
best_cat_weight = study_meta.best_params['cat_weight']
best_xgb_weight = study_meta.best_params['xgb_weight']
best_lgb_weight = study_meta.best_params['lgb_weight']
total_weight = best_cat_weight + best_xgb_weight + best_lgb_weight
best_cat_weight /= total_weight
best_xgb_weight /= total_weight
best_lgb_weight /= total_weight

print(f"\n✓ Mejor AUC Meta-modelo: {study_meta.best_value:.5f}")
print(f"Pesos óptimos:")
print(f"  - CatBoost: {best_cat_weight:.4f}")
print(f"  - XGBoost:  {best_xgb_weight:.4f}")
print(f"  - LightGBM: {best_lgb_weight:.4f}")
# Out:
# [I 2026-01-21 15:41:02,027] A new study created in memory with name: meta_model_optimization
#   0%|          | 0/10000 [00:00<?, ?it/s]
# [I 2026-01-21 15:41:02,092] Trial 0 finished with value: 0.7824601824207192 and parameters: {'cat_weight': 0.3745401188473625, 'xgb_weight': 0.9507143064099162, 'lgb_weight': 0.7319939418114051}. Best is trial 0 with value: 0.7824601824207192.
# [I 2026-01-21 15:41:02,143] Trial 1 finished with value: 0.7849349742898282 and parameters: {'cat_weight': 0.5986584841970366, 'xgb_weight': 0.15601864044243652, 'lgb_weight': 0.15599452033620265}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,198] Trial 2 finished with value: 0.781141551232299 and parameters: {'cat_weight': 0.05808361216819946, 'xgb_weight': 0.8661761457749352, 'lgb_weight': 0.6011150117432088}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,248] Trial 3 finished with value: 0.7835191958444124 and parameters: {'cat_weight': 0.7080725777960455, 'xgb_weight': 0.020584494295802447, 'lgb_weight': 0.9699098521619943}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,304] Trial 4 finished with value: 0.784785761255803 and parameters: {'cat_weight': 0.8324426408004217, 'xgb_weight': 0.21233911067827616, 'lgb_weight': 0.18182496720710062}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,358] Trial 5 finished with value: 0.7832723642866722 and parameters: {'cat_weight': 0.18340450985343382, 'xgb_weight': 0.3042422429595377, 'lgb_weight': 0.5247564316322378}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,411] Trial 6 finished with value: 0.784145847105824 and parameters: {'cat_weight': 0.43194501864211576, 'xgb_weight': 0.2912291401980419, 'lgb_weight': 0.6118528947223795}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,461] Trial 7 finished with value: 0.7833138350322268 and parameters: {'cat_weight': 0.13949386065204183, 'xgb_weight': 0.29214464853521815, 'lgb_weight': 0.3663618432936917}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,516] Trial 8 finished with value: 0.783351526004282 and parameters: {'cat_weight': 0.45606998421703593, 'xgb_weight': 0.7851759613930136, 'lgb_weight': 0.19967378215835974}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,569] Trial 9 finished with value: 0.7838273575872688 and parameters: {'cat_weight': 0.5142344384136116, 'xgb_weight': 0.5924145688620425, 'lgb_weight': 0.046450412719997725}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,623] Trial 10 finished with value: 0.7838909128019794 and parameters: {'cat_weight': 0.9535902538878209, 'xgb_weight': 0.0059971829558173595, 'lgb_weight': 0.007547319316293211}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,676] Trial 11 finished with value: 0.784879127975998 and parameters: {'cat_weight': 0.8288336063575795, 'xgb_weight': 0.1729022657899977, 'lgb_weight': 0.29627578881975064}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,734] Trial 12 finished with value: 0.7843145638241338 and parameters: {'cat_weight': 0.6744350192942545, 'xgb_weight': 0.5678197402963622, 'lgb_weight': 0.33479517622323646}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,791] Trial 13 finished with value: 0.7849337888808356 and parameters: {'cat_weight': 0.6437127366238236, 'xgb_weight': 0.17028488967556443, 'lgb_weight': 0.3560912233349938}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,847] Trial 14 finished with value: 0.7845460383877713 and parameters: {'cat_weight': 0.623081954558961, 'xgb_weight': 0.43435627175641134, 'lgb_weight': 0.16206935166275674}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,899] Trial 15 finished with value: 0.7844057107054849 and parameters: {'cat_weight': 0.30228038740911745, 'xgb_weight': 0.1198019643955826, 'lgb_weight': 0.4165827199181282}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:02,956] Trial 16 finished with value: 0.7845253545476889 and parameters: {'cat_weight': 0.5375151554918499, 'xgb_weight': 0.4433323340544336, 'lgb_weight': 0.24400525716599852}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,012] Trial 17 finished with value: 0.784658775446575 and parameters: {'cat_weight': 0.7908357982212785, 'xgb_weight': 0.11063964488719155, 'lgb_weight': 0.110489714504896}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,070] Trial 18 finished with value: 0.7844900163430704 and parameters: {'cat_weight': 0.9621272730652257, 'xgb_weight': 0.3960769555525766, 'lgb_weight': 0.4812884929660226}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,126] Trial 19 finished with value: 0.7833560296678377 and parameters: {'cat_weight': 0.553165764374762, 'xgb_weight': 0.6557921315873975, 'lgb_weight': 0.7359801622155637}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,186] Trial 20 finished with value: 0.7849223142915985 and parameters: {'cat_weight': 0.7356055517089795, 'xgb_weight': 0.208258708649442, 'lgb_weight': 0.26405718660443406}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,239] Trial 21 finished with value: 0.7849194836520026 and parameters: {'cat_weight': 0.7385695255290723, 'xgb_weight': 0.21768981409865903, 'lgb_weight': 0.2622561797147315}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,298] Trial 22 finished with value: 0.7848297730206313 and parameters: {'cat_weight': 0.612365171182527, 'xgb_weight': 0.10444233109991569, 'lgb_weight': 0.09737830364311223}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,348] Trial 23 finished with value: 0.7846961756938826 and parameters: {'cat_weight': 0.8796139267265123, 'xgb_weight': 0.3543445459143488, 'lgb_weight': 0.4195291910426963}. Best is trial 1 with value: 0.7849349742898282.
# [I 2026-01-21 15:41:03,409] Trial 24 finished with value: 0.7849688235958451 and parameters: {'cat_weight': 0.6162252680200304, 'xgb_weight': 0.22999165524278348, 'lgb_weight': 0.3208501786198171}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,466] Trial 25 finished with value: 0.7849045395897359 and parameters: {'cat_weight': 0.6162446319538263, 'xgb_weight': 0.059330551767035, 'lgb_weight': 0.36898864942678844}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,524] Trial 26 finished with value: 0.7849568128105476 and parameters: {'cat_weight': 0.3469797936237101, 'xgb_weight': 0.16137751915706258, 'lgb_weight': 0.13299022573726732}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,575] Trial 27 finished with value: 0.7836707679366149 and parameters: {'cat_weight': 0.30235194918403413, 'xgb_weight': 0.5222798038979592, 'lgb_weight': 0.15479927072900695}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,635] Trial 28 finished with value: 0.7846266886624723 and parameters: {'cat_weight': 0.31987257359688775, 'xgb_weight': 0.275040636812384, 'lgb_weight': 0.10338058582544762}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,689] Trial 29 finished with value: 0.7849547940722434 and parameters: {'cat_weight': 0.39233602875646933, 'xgb_weight': 0.1008854648940968, 'lgb_weight': 0.05068922821999705}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,745] Trial 30 finished with value: 0.7848195909553655 and parameters: {'cat_weight': 0.3680657066577092, 'xgb_weight': 0.06048970678675826, 'lgb_weight': 0.013179214380923565}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,797] Trial 31 finished with value: 0.7847247743184472 and parameters: {'cat_weight': 0.21328333563112228, 'xgb_weight': 0.10493687876174197, 'lgb_weight': 0.07654402183078775}. Best is trial 24 with value: 0.7849688235958451.
# [I 2026-01-21 15:41:03,855] Trial 32 finished with value: 0.7849887685591451 and parameters: {'cat_weight': 0.4164183777000785, 'xgb_weight': 0.16213397766080334, 'lgb_weight': 0.1805945590611888}. Best is trial 32 with value: 0.7849887685591451.
# [I 2026-01-21 15:41:03,910] Trial 33 finished with value: 0.7827978235830614 and parameters: {'cat_weight': 0.42060331495623166, 'xgb_weight': 0.9701518322796903, 'lgb_weight': 0.2200043019530704}. Best is trial 32 with value: 0.7849887685591451.
# [I 2026-01-21 15:41:03,967] Trial 34 finished with value: 0.7844879009921198 and parameters: {'cat_weight': 0.35616939485146176, 'xgb_weight': 0.3606791970055566, 'lgb_weight': 0.13036062419905614}. Best is trial 32 with value: 0.7849887685591451.
# [I 2026-01-21 15:41:04,019] Trial 35 finished with value: 0.7827870460286938 and parameters: {'cat_weight': 0.2618157942944278, 'xgb_weight': 0.2409422213352442, 'lgb_weight': 0.9309781571936997}. Best is trial 32 with value: 0.7849887685591451.
# [I 2026-01-21 15:41:04,076] Trial 36 finished with value: 0.783641535462473 and parameters: {'cat_weight': 0.0500278630140335, 'xgb_weight': 0.05713755012701835, 'lgb_weight': 0.047815711689724275}. Best is trial 32 with value: 0.7849887685591451.
# [I 2026-01-21 15:41:04,133] Trial 37 finished with value: 0.7850111205802959 and parameters: {'cat_weight': 0.4459586460129908, 'xgb_weight': 0.14621560719619475, 'lgb_weight': 0.2013636209228829}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,192] Trial 38 finished with value: 0.7848019966065112 and parameters: {'cat_weight': 0.4781962706995161, 'xgb_weight': 0.3330648551059788, 'lgb_weight': 0.2043680386426407}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,243] Trial 39 finished with value: 0.7836081095946456 and parameters: {'cat_weight': 0.138230177449284, 'xgb_weight': 0.16156988260761893, 'lgb_weight': 0.29872801107701036}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,299] Trial 40 finished with value: 0.7845290108385918 and parameters: {'cat_weight': 0.4998433359681436, 'xgb_weight': 0.24764675530710362, 'lgb_weight': 0.4980407943317858}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,356] Trial 41 finished with value: 0.7849683742630608 and parameters: {'cat_weight': 0.4157887714950553, 'xgb_weight': 0.1782245645917237, 'lgb_weight': 0.17575465480851363}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,413] Trial 42 finished with value: 0.7849487588574031 and parameters: {'cat_weight': 0.5718101530808917, 'xgb_weight': 0.1990609783354621, 'lgb_weight': 0.1767408955318142}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,466] Trial 43 finished with value: 0.7849679526685324 and parameters: {'cat_weight': 0.4435904486990322, 'xgb_weight': 0.1473859240452684, 'lgb_weight': 0.30673521336766596}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,524] Trial 44 finished with value: 0.7847091632780284 and parameters: {'cat_weight': 0.4415091150402175, 'xgb_weight': 0.0004822680601653806, 'lgb_weight': 0.418462337546318}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,579] Trial 45 finished with value: 0.7847846695125739 and parameters: {'cat_weight': 0.4077088449333517, 'xgb_weight': 0.2866456621506891, 'lgb_weight': 0.32007372707435355}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,637] Trial 46 finished with value: 0.7843072232088824 and parameters: {'cat_weight': 0.48146305333054384, 'xgb_weight': 0.13608873442560554, 'lgb_weight': 0.5845949160778339}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,688] Trial 47 finished with value: 0.7849870893678793 and parameters: {'cat_weight': 0.5737588919066687, 'xgb_weight': 0.05543875036420315, 'lgb_weight': 0.23054009354850027}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,745] Trial 48 finished with value: 0.7849014322724419 and parameters: {'cat_weight': 0.681570104043777, 'xgb_weight': 0.04381472496234751, 'lgb_weight': 0.24862030258800655}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,800] Trial 49 finished with value: 0.7832977569298251 and parameters: {'cat_weight': 0.5775914665386952, 'xgb_weight': 0.8895564194661054, 'lgb_weight': 0.21897015988863155}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,858] Trial 50 finished with value: 0.7837383512041328 and parameters: {'cat_weight': 0.545164564469589, 'xgb_weight': 0.7213209128916718, 'lgb_weight': 0.380547401211471}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,910] Trial 51 finished with value: 0.7849828041421358 and parameters: {'cat_weight': 0.5190487537734103, 'xgb_weight': 0.18766119902613207, 'lgb_weight': 0.2790267141949358}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:04,968] Trial 52 finished with value: 0.7849667862031993 and parameters: {'cat_weight': 0.503925807228392, 'xgb_weight': 0.19445880818788425, 'lgb_weight': 0.18259904028387894}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:05,023] Trial 53 finished with value: 0.7849494762627909 and parameters: {'cat_weight': 0.6579563740416228, 'xgb_weight': 0.24312113453834155, 'lgb_weight': 0.27885198392479926}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:05,081] Trial 54 finished with value: 0.7849570459542923 and parameters: {'cat_weight': 0.5278324388519338, 'xgb_weight': 0.03201617922188124, 'lgb_weight': 0.1610482525397756}. Best is trial 37 with value: 0.7850111205802959.
# [I 2026-01-21 15:41:05,135] Trial 55 finished with value: 0.7850447652173749 and parameters: {'cat_weight': 0.47541202400003957, 'xgb_weight': 0.07266733183796902, 'lgb_weight': 0.22087526017414644}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,190] Trial 56 finished with value: 0.7849864293990544 and parameters: {'cat_weight': 0.5901955580819284, 'xgb_weight': 0.0816650385206194, 'lgb_weight': 0.2314939615689811}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,246] Trial 57 finished with value: 0.7849948888961596 and parameters: {'cat_weight': 0.5821143916958307, 'xgb_weight': 0.08288066214855122, 'lgb_weight': 0.2386748227478264}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,304] Trial 58 finished with value: 0.7849927471782462 and parameters: {'cat_weight': 0.5818946006213659, 'xgb_weight': 0.08181770801185904, 'lgb_weight': 0.23361312648385796}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,356] Trial 59 finished with value: 0.7840310851272088 and parameters: {'cat_weight': 0.7039923918581836, 'xgb_weight': 0.08134885051927769, 'lgb_weight': 0.7625658160608287}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,415] Trial 60 finished with value: 0.7849607339362557 and parameters: {'cat_weight': 0.47095534520613264, 'xgb_weight': 0.01760013441135095, 'lgb_weight': 0.13087718441865065}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,464] Trial 61 finished with value: 0.7850035723778118 and parameters: {'cat_weight': 0.562833222131945, 'xgb_weight': 0.07875133123235198, 'lgb_weight': 0.2321812973553165}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,525] Trial 62 finished with value: 0.7849934259835721 and parameters: {'cat_weight': 0.5644453856605931, 'xgb_weight': 0.13301818255819728, 'lgb_weight': 0.20543658495593548}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,593] Trial 63 finished with value: 0.7849824541214685 and parameters: {'cat_weight': 0.5415372288899032, 'xgb_weight': 0.12739968344454303, 'lgb_weight': 0.3391136994259204}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,676] Trial 64 finished with value: 0.784620336487111 and parameters: {'cat_weight': 0.7360519678096638, 'xgb_weight': 0.0814561626148922, 'lgb_weight': 0.08133287279375853}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,758] Trial 65 finished with value: 0.7849492583897941 and parameters: {'cat_weight': 0.6305567672457394, 'xgb_weight': 0.12480452084157219, 'lgb_weight': 0.2016511887369867}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,824] Trial 66 finished with value: 0.7850209789118024 and parameters: {'cat_weight': 0.4595737651931466, 'xgb_weight': 0.005936728369469596, 'lgb_weight': 0.25602213598025464}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,879] Trial 67 finished with value: 0.7848334258352769 and parameters: {'cat_weight': 0.6534689925089942, 'xgb_weight': 0.007540349625884804, 'lgb_weight': 0.3824426921482089}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:05,942] Trial 68 finished with value: 0.7846448076766364 and parameters: {'cat_weight': 0.7723628829189568, 'xgb_weight': 0.03325116876125616, 'lgb_weight': 0.463192175303912}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,009] Trial 69 finished with value: 0.7850318984845902 and parameters: {'cat_weight': 0.4542216849011833, 'xgb_weight': 0.09048053772258405, 'lgb_weight': 0.2588744917504248}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,077] Trial 70 finished with value: 0.7849851986685666 and parameters: {'cat_weight': 0.38741318626678467, 'xgb_weight': 0.09522528353779125, 'lgb_weight': 0.279563721531611}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,131] Trial 71 finished with value: 0.785034423319627 and parameters: {'cat_weight': 0.49718565664850695, 'xgb_weight': 0.08089640191215906, 'lgb_weight': 0.2464759338848742}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,186] Trial 72 finished with value: 0.7850156638426407 and parameters: {'cat_weight': 0.4872962356006116, 'xgb_weight': 0.13074373273053186, 'lgb_weight': 0.26104435789462105}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,240] Trial 73 finished with value: 0.7849709634634353 and parameters: {'cat_weight': 0.4527192945883037, 'xgb_weight': 0.032962115157695454, 'lgb_weight': 0.33754792828167957}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,297] Trial 74 finished with value: 0.7850318073475091 and parameters: {'cat_weight': 0.4949222647930469, 'xgb_weight': 0.06494831797634021, 'lgb_weight': 0.26101602828896875}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,347] Trial 75 finished with value: 0.7850071806344678 and parameters: {'cat_weight': 0.48502150209459477, 'xgb_weight': 0.0002790619143299422, 'lgb_weight': 0.2604147672009904}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,406] Trial 76 finished with value: 0.7850273663782523 and parameters: {'cat_weight': 0.49897921219555363, 'xgb_weight': 0.05207954419894027, 'lgb_weight': 0.26926565367775857}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,464] Trial 77 finished with value: 0.7850057220872074 and parameters: {'cat_weight': 0.4588302691900485, 'xgb_weight': 0.11147387011164558, 'lgb_weight': 0.29527095732665265}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,524] Trial 78 finished with value: 0.7848188628199558 and parameters: {'cat_weight': 0.3573382426122878, 'xgb_weight': 0.052364742056309616, 'lgb_weight': 0.35669288443161273}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,576] Trial 79 finished with value: 0.7846908533303236 and parameters: {'cat_weight': 0.5074831021993125, 'xgb_weight': 0.1492340869943739, 'lgb_weight': 0.4491233496204927}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,632] Trial 80 finished with value: 0.7846229015112357 and parameters: {'cat_weight': 0.32749896614822055, 'xgb_weight': 0.03091241445485065, 'lgb_weight': 0.3931613279168726}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,686] Trial 81 finished with value: 0.7850143094925726 and parameters: {'cat_weight': 0.4905903728102996, 'xgb_weight': 0.012556858260899313, 'lgb_weight': 0.2647699804933536}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,744] Trial 82 finished with value: 0.7850377944085917 and parameters: {'cat_weight': 0.4339628869070813, 'xgb_weight': 0.05481524894817132, 'lgb_weight': 0.2592281001538713}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,796] Trial 83 finished with value: 0.7849710489040295 and parameters: {'cat_weight': 0.3847956334749658, 'xgb_weight': 0.04918649604503462, 'lgb_weight': 0.309496095153722}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,852] Trial 84 finished with value: 0.7850319692127755 and parameters: {'cat_weight': 0.4271755053325864, 'xgb_weight': 0.0641961174997051, 'lgb_weight': 0.2655208250785683}. Best is trial 55 with value: 0.7850447652173749.
# [I 2026-01-21 15:41:06,906] Trial 85 finished with value: 0.785052043280276 and parameters: {'cat_weight': 0.42743288449110967, 'xgb_weight': 0.06519550836876473, 'lgb_weight': 0.14167981417336134}. Best is trial 85 with value: 0.785052043280276.
# [I 2026-01-21 15:41:06,965] Trial 86 finished with value: 0.7837657980527435 and parameters: {'cat_weight': 0.42687269555516905, 'xgb_weight': 0.6043371983713466, 'lgb_weight': 0.13903415239755273}. Best is trial 85 with value: 0.785052043280276.
# [I 2026-01-21 15:41:07,017] Trial 87 finished with value: 0.784977051862726 and parameters: {'cat_weight': 0.2639156945469501, 'xgb_weight': 0.06194976063972615, 'lgb_weight': 0.10610025598653708}. Best is trial 85 with value: 0.785052043280276.
# [I 2026-01-21 15:41:07,073] Trial 88 finished with value: 0.7850523614689215 and parameters: {'cat_weight': 0.4006598312312528, 'xgb_weight': 0.10407002557169556, 'lgb_weight': 0.1559503036166084}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,131] Trial 89 finished with value: 0.7842667133169684 and parameters: {'cat_weight': 0.39837764726448766, 'xgb_weight': 0.1152084234196647, 'lgb_weight': 0.5507029914498446}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,189] Trial 90 finished with value: 0.7849235114828618 and parameters: {'cat_weight': 0.3711072253037626, 'xgb_weight': 0.16697765724332375, 'lgb_weight': 0.06966511120868601}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,242] Trial 91 finished with value: 0.7850509865171612 and parameters: {'cat_weight': 0.43302480858701103, 'xgb_weight': 0.06265345370743808, 'lgb_weight': 0.14653599647265914}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,298] Trial 92 finished with value: 0.7849825108799533 and parameters: {'cat_weight': 0.5181205184179954, 'xgb_weight': 0.10087738547647837, 'lgb_weight': 0.1400319325619015}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,350] Trial 93 finished with value: 0.7810191005185497 and parameters: {'cat_weight': 0.004069232418913271, 'xgb_weight': 0.06326336276636904, 'lgb_weight': 0.02191535205273154}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,411] Trial 94 finished with value: 0.7850482585064764 and parameters: {'cat_weight': 0.42539223232547035, 'xgb_weight': 0.10284935004511192, 'lgb_weight': 0.1597232944241834}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,468] Trial 95 finished with value: 0.7848432544560768 and parameters: {'cat_weight': 0.3358130763698553, 'xgb_weight': 0.2089211423656041, 'lgb_weight': 0.16569388703628074}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,525] Trial 96 finished with value: 0.7849146146183528 and parameters: {'cat_weight': 0.2994225771457789, 'xgb_weight': 0.11187691854215316, 'lgb_weight': 0.18136514185693012}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,578] Trial 97 finished with value: 0.784129149157273 and parameters: {'cat_weight': 0.4209586984232603, 'xgb_weight': 0.48433816889352577, 'lgb_weight': 0.10952160928149902}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,636] Trial 98 finished with value: 0.7849668754836696 and parameters: {'cat_weight': 0.4354622496555538, 'xgb_weight': 0.18093194527157863, 'lgb_weight': 0.15302225015493548}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,688] Trial 99 finished with value: 0.7850355378593833 and parameters: {'cat_weight': 0.3784889809407767, 'xgb_weight': 0.0971019947080046, 'lgb_weight': 0.21147136634447025}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,745] Trial 100 finished with value: 0.7850431582979088 and parameters: {'cat_weight': 0.40274309947791287, 'xgb_weight': 0.09607576477272056, 'lgb_weight': 0.21300114489434274}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,801] Trial 101 finished with value: 0.7839298693472444 and parameters: {'cat_weight': 0.39482146985427224, 'xgb_weight': 0.15097726077310683, 'lgb_weight': 0.6680283751807288}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,857] Trial 102 finished with value: 0.785046531825742 and parameters: {'cat_weight': 0.3745463443237491, 'xgb_weight': 0.09550049079205425, 'lgb_weight': 0.194023018848396}. Best is trial 88 with value: 0.7850523614689215.
# [I 2026-01-21 15:41:07,911] Trial 103 finished with value: 0.7850776957152955 and parameters: {'cat_weight': 0.3412939894587609, 'xgb_weight': 0.02985533877789153, 'lgb_weight': 0.19310137999199214}. Best is trial 103 with value: 0.7850776957152955.
# [I 2026-01-21 15:41:07,969] Trial 104 finished with value: 0.7849435626643058 and parameters: {'cat_weight': 0.28046723901934034, 'xgb_weight': 0.0349670645709495, 'lgb_weight': 0.19117434228151717}. Best is trial 103 with value: 0.7850776957152955.
# [I 2026-01-21 15:41:08,025] Trial 105 finished with value: 0.7850178120974965 and parameters: {'cat_weight': 0.3528764080904748, 'xgb_weight': 0.10269357500467796, 'lgb_weight': 0.20817952285084848}. Best is trial 103 with value: 0.7850776957152955.
# [I 2026-01-21 15:41:08,082] Trial 106 finished with value: 0.7850851192144962 and parameters: {'cat_weight': 0.31629372976049586, 'xgb_weight': 0.026478745517572087, 'lgb_weight': 0.11363688011554891}. Best is trial 106 with value: 0.7850851192144962.
# [I 2026-01-21 15:41:08,136] Trial 107 finished with value: 0.7850851286268374 and parameters: {'cat_weight': 0.315898048593771, 'xgb_weight': 0.024541504168326265, 'lgb_weight': 0.1168312118147343}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,195] Trial 108 finished with value: 0.7849658223514333 and parameters: {'cat_weight': 0.23456301007981092, 'xgb_weight': 0.019991498914710165, 'lgb_weight': 0.08059236261326654}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,246] Trial 109 finished with value: 0.785081001114331 and parameters: {'cat_weight': 0.31170215026653597, 'xgb_weight': 0.025825581870563788, 'lgb_weight': 0.1231523672711039}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,305] Trial 110 finished with value: 0.7850779325736479 and parameters: {'cat_weight': 0.30963331139627676, 'xgb_weight': 0.024100817227670462, 'lgb_weight': 0.11966032538205965}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,358] Trial 111 finished with value: 0.7850782927952187 and parameters: {'cat_weight': 0.31020307276866, 'xgb_weight': 0.021733495656482964, 'lgb_weight': 0.12283571825944284}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,416] Trial 112 finished with value: 0.7850837587195546 and parameters: {'cat_weight': 0.3156573918837116, 'xgb_weight': 0.021455011980555744, 'lgb_weight': 0.11874588465991659}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,467] Trial 113 finished with value: 0.7849496500969735 and parameters: {'cat_weight': 0.31092669420937896, 'xgb_weight': 0.03137680861645001, 'lgb_weight': 0.04434706916669082}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,526] Trial 114 finished with value: 0.784908560998798 and parameters: {'cat_weight': 0.20347435076824422, 'xgb_weight': 0.01807171722763274, 'lgb_weight': 0.09433254428878987}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,581] Trial 115 finished with value: 0.7849901740605062 and parameters: {'cat_weight': 0.2801461072968409, 'xgb_weight': 0.042977011193935585, 'lgb_weight': 0.060035308847728265}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,637] Trial 116 finished with value: 0.7850715098386635 and parameters: {'cat_weight': 0.33442071241180876, 'xgb_weight': 0.0004067410605751269, 'lgb_weight': 0.12093628574201361}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,689] Trial 117 finished with value: 0.7849629056792549 and parameters: {'cat_weight': 0.24456484072100523, 'xgb_weight': 0.005680935767563247, 'lgb_weight': 0.12155256074320797}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,746] Trial 118 finished with value: 0.7850575334339819 and parameters: {'cat_weight': 0.33824339761331507, 'xgb_weight': 0.020610563840715267, 'lgb_weight': 0.08989577883593353}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,802] Trial 119 finished with value: 0.7848468403521424 and parameters: {'cat_weight': 0.2870935764233605, 'xgb_weight': 0.022893362436721257, 'lgb_weight': 0.029893032886605997}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,860] Trial 120 finished with value: 0.7845152023012341 and parameters: {'cat_weight': 0.3293442408104147, 'xgb_weight': 0.0018000706648550052, 'lgb_weight': 0.0037470463211797256}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,913] Trial 121 finished with value: 0.7850687692077539 and parameters: {'cat_weight': 0.3129068791217625, 'xgb_weight': 0.04043452981190483, 'lgb_weight': 0.09151795693719339}. Best is trial 107 with value: 0.7850851286268374.
# [I 2026-01-21 15:41:08,975] Trial 122 finished with value: 0.7850995062184164 and parameters: {'cat_weight': 0.34194768646810214, 'xgb_weight': 0.03585740907624605, 'lgb_weight': 0.12048478529452444}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,032] Trial 123 finished with value: 0.7850790415083929 and parameters: {'cat_weight': 0.3416774196320248, 'xgb_weight': 0.039518674190807304, 'lgb_weight': 0.09464741955925422}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,088] Trial 124 finished with value: 0.7850742299202331 and parameters: {'cat_weight': 0.3440878809140388, 'xgb_weight': 0.03731677930040389, 'lgb_weight': 0.09354243600568593}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,141] Trial 125 finished with value: 0.7850723694264565 and parameters: {'cat_weight': 0.31403951671970154, 'xgb_weight': 0.036665685831533096, 'lgb_weight': 0.09397912249232418}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,201] Trial 126 finished with value: 0.7850850848572369 and parameters: {'cat_weight': 0.31427909304745755, 'xgb_weight': 0.039694910396722946, 'lgb_weight': 0.11518622957679484}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,256] Trial 127 finished with value: 0.781660938224526 and parameters: {'cat_weight': 0.15437229149721152, 'xgb_weight': 0.7875007477861327, 'lgb_weight': 0.12174873671509676}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,313] Trial 128 finished with value: 0.7849689738217095 and parameters: {'cat_weight': 0.2584567441110306, 'xgb_weight': 0.035877224229325815, 'lgb_weight': 0.059681260583439324}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,364] Trial 129 finished with value: 0.7850424958077272 and parameters: {'cat_weight': 0.3009908939374963, 'xgb_weight': 0.0035987938243506254, 'lgb_weight': 0.11119637161127718}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,427] Trial 130 finished with value: 0.7849493249186887 and parameters: {'cat_weight': 0.349658130024136, 'xgb_weight': 0.04142951105005575, 'lgb_weight': 0.04424943845206718}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,483] Trial 131 finished with value: 0.785072166551531 and parameters: {'cat_weight': 0.3166635817918792, 'xgb_weight': 0.04034886659576879, 'lgb_weight': 0.09068154562171699}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,540] Trial 132 finished with value: 0.7849303363417073 and parameters: {'cat_weight': 0.22625364477818133, 'xgb_weight': 0.02366004702002243, 'lgb_weight': 0.11386195213215662}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,592] Trial 133 finished with value: 0.7850000165319413 and parameters: {'cat_weight': 0.26817146404423864, 'xgb_weight': 0.046721044624620164, 'lgb_weight': 0.07613096198564775}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,651] Trial 134 finished with value: 0.7850760608315889 and parameters: {'cat_weight': 0.32003916151552375, 'xgb_weight': 0.06984258555944903, 'lgb_weight': 0.12614880892096253}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,706] Trial 135 finished with value: 0.785051780850968 and parameters: {'cat_weight': 0.31142159951170034, 'xgb_weight': 0.07479845810714836, 'lgb_weight': 0.0957440507482279}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,763] Trial 136 finished with value: 0.7848259616789228 and parameters: {'cat_weight': 0.2893083286013008, 'xgb_weight': 0.023822755905143295, 'lgb_weight': 0.025685199656440075}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,815] Trial 137 finished with value: 0.78491894575526 and parameters: {'cat_weight': 0.2471787667543681, 'xgb_weight': 0.07587076650905969, 'lgb_weight': 0.07219885768568646}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,871] Trial 138 finished with value: 0.7850973819915773 and parameters: {'cat_weight': 0.3536864399304019, 'xgb_weight': 0.049197218607843304, 'lgb_weight': 0.13575294183270922}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,928] Trial 139 finished with value: 0.7850888062126322 and parameters: {'cat_weight': 0.3610488806820496, 'xgb_weight': 0.06414807423907812, 'lgb_weight': 0.13271577593851935}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:09,989] Trial 140 finished with value: 0.7850916111649816 and parameters: {'cat_weight': 0.359539346895531, 'xgb_weight': 0.05963686155351375, 'lgb_weight': 0.13701665346836936}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,042] Trial 141 finished with value: 0.7850934023825442 and parameters: {'cat_weight': 0.3561414031452268, 'xgb_weight': 0.059068218839570134, 'lgb_weight': 0.14103772848538626}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,100] Trial 142 finished with value: 0.785090352278411 and parameters: {'cat_weight': 0.35372999727830523, 'xgb_weight': 0.06752916726786794, 'lgb_weight': 0.1356044771033574}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,155] Trial 143 finished with value: 0.7850863362222074 and parameters: {'cat_weight': 0.36551917348414487, 'xgb_weight': 0.05240108369217812, 'lgb_weight': 0.17253752801490482}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,211] Trial 144 finished with value: 0.7850861200867675 and parameters: {'cat_weight': 0.3751259131074737, 'xgb_weight': 0.055276318316124416, 'lgb_weight': 0.16404227925144668}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,264] Trial 145 finished with value: 0.785016396962106 and parameters: {'cat_weight': 0.3755399199593591, 'xgb_weight': 0.13010388223152256, 'lgb_weight': 0.17344431507862615}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,330] Trial 146 finished with value: 0.785090204860025 and parameters: {'cat_weight': 0.3634500450134266, 'xgb_weight': 0.06013437382176493, 'lgb_weight': 0.1434982267471842}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,386] Trial 147 finished with value: 0.7850884630250031 and parameters: {'cat_weight': 0.36788587363914566, 'xgb_weight': 0.05954178333098273, 'lgb_weight': 0.1460188837027227}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,445] Trial 148 finished with value: 0.7850746611744881 and parameters: {'cat_weight': 0.3729941024177581, 'xgb_weight': 0.08259375883706097, 'lgb_weight': 0.14892364380353135}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,498] Trial 149 finished with value: 0.7850866568630964 and parameters: {'cat_weight': 0.3603448455598673, 'xgb_weight': 0.059533244317102864, 'lgb_weight': 0.16674030949499666}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,560] Trial 150 finished with value: 0.7850270428025651 and parameters: {'cat_weight': 0.36666567099539327, 'xgb_weight': 0.12050925658066641, 'lgb_weight': 0.16846847463552977}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,616] Trial 151 finished with value: 0.785090252609806 and parameters: {'cat_weight': 0.3608311209253761, 'xgb_weight': 0.06264652580223315, 'lgb_weight': 0.14067290959572978}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,675] Trial 152 finished with value: 0.7850909099760233 and parameters: {'cat_weight': 0.3572674337434537, 'xgb_weight': 0.06346828305221666, 'lgb_weight': 0.13824084845920454}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,728] Trial 153 finished with value: 0.7850915503396265 and parameters: {'cat_weight': 0.3593441125174128, 'xgb_weight': 0.06072085098395026, 'lgb_weight': 0.14212157822775942}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,786] Trial 154 finished with value: 0.7850896715720574 and parameters: {'cat_weight': 0.35681819142611837, 'xgb_weight': 0.0655852843485749, 'lgb_weight': 0.14506223589186096}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,842] Trial 155 finished with value: 0.7850880068416214 and parameters: {'cat_weight': 0.3588232801811932, 'xgb_weight': 0.06739697106830884, 'lgb_weight': 0.14584177004537896}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,899] Trial 156 finished with value: 0.7850831366367182 and parameters: {'cat_weight': 0.3572843717119688, 'xgb_weight': 0.06650923008433811, 'lgb_weight': 0.16557268917844983}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:10,951] Trial 157 finished with value: 0.7844336912042682 and parameters: {'cat_weight': 0.3888140994785487, 'xgb_weight': 0.39460016576452034, 'lgb_weight': 0.14596416509179852}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,013] Trial 158 finished with value: 0.7845664065660185 and parameters: {'cat_weight': 0.9979032910021784, 'xgb_weight': 0.11920897942724902, 'lgb_weight': 0.18624570870817359}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,068] Trial 159 finished with value: 0.7850616773962212 and parameters: {'cat_weight': 0.4082999074876976, 'xgb_weight': 0.08429177084963939, 'lgb_weight': 0.14495937774059847}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,126] Trial 160 finished with value: 0.785080559722259 and parameters: {'cat_weight': 0.36305048550920765, 'xgb_weight': 0.06546817767881286, 'lgb_weight': 0.1727178141440663}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,180] Trial 161 finished with value: 0.7850937935916374 and parameters: {'cat_weight': 0.3588823450550098, 'xgb_weight': 0.05537461758985983, 'lgb_weight': 0.14034123728502113}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,242] Trial 162 finished with value: 0.78506531980285 and parameters: {'cat_weight': 0.38744914647375495, 'xgb_weight': 0.09018017047797966, 'lgb_weight': 0.1434117429787603}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,299] Trial 163 finished with value: 0.7850894809074247 and parameters: {'cat_weight': 0.36259089789317145, 'xgb_weight': 0.05581682613612102, 'lgb_weight': 0.16248400178441436}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,356] Trial 164 finished with value: 0.784995939851588 and parameters: {'cat_weight': 0.3509647393536692, 'xgb_weight': 0.14097311216500377, 'lgb_weight': 0.14087824800881213}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,410] Trial 165 finished with value: 0.7835014261117379 and parameters: {'cat_weight': 0.4035694388322697, 'xgb_weight': 0.060889047542405955, 'lgb_weight': 0.8133502515855711}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,473] Trial 166 finished with value: 0.785054323204511 and parameters: {'cat_weight': 0.355755861121401, 'xgb_weight': 0.08630788562757441, 'lgb_weight': 0.18569324397705045}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,532] Trial 167 finished with value: 0.7850491187769374 and parameters: {'cat_weight': 0.3915104007085394, 'xgb_weight': 0.10764877526070318, 'lgb_weight': 0.15828804189590204}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,594] Trial 168 finished with value: 0.7850774936602769 and parameters: {'cat_weight': 0.35881661464833753, 'xgb_weight': 0.08266647110496364, 'lgb_weight': 0.13504470891834122}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,647] Trial 169 finished with value: 0.785078057237394 and parameters: {'cat_weight': 0.3364670057237109, 'xgb_weight': 0.05858615319789909, 'lgb_weight': 0.1778253132243451}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,712] Trial 170 finished with value: 0.7850190659084247 and parameters: {'cat_weight': 0.37171385018902525, 'xgb_weight': 0.11844806633160815, 'lgb_weight': 0.1964072676732457}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,769] Trial 171 finished with value: 0.7850839741823424 and parameters: {'cat_weight': 0.3753643500645034, 'xgb_weight': 0.0630915580671193, 'lgb_weight': 0.16045910726282053}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,831] Trial 172 finished with value: 0.7850722693647484 and parameters: {'cat_weight': 0.39732466101864244, 'xgb_weight': 0.0544057184970779, 'lgb_weight': 0.14026451523069303}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,884] Trial 173 finished with value: 0.7850581432526476 and parameters: {'cat_weight': 0.3367363855439302, 'xgb_weight': 0.08995142570672483, 'lgb_weight': 0.16201949786368067}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,946] Trial 174 finished with value: 0.7850830592273655 and parameters: {'cat_weight': 0.3621049988969242, 'xgb_weight': 0.055469472025438366, 'lgb_weight': 0.17772520150197388}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:11,997] Trial 175 finished with value: 0.7826981075750926 and parameters: {'cat_weight': 0.4116451842976989, 'xgb_weight': 0.9986874709649204, 'lgb_weight': 0.21653992481630285}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,063] Trial 176 finished with value: 0.7850759538991213 and parameters: {'cat_weight': 0.37713641522630015, 'xgb_weight': 0.07898168086151874, 'lgb_weight': 0.13864578052165138}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,121] Trial 177 finished with value: 0.7828447651445876 and parameters: {'cat_weight': 0.34037680708015666, 'xgb_weight': 0.05569897314501938, 'lgb_weight': 0.9935628686602365}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,183] Trial 178 finished with value: 0.7850612934757937 and parameters: {'cat_weight': 0.35743106219542525, 'xgb_weight': 0.09314697409264677, 'lgb_weight': 0.15954188904492136}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,244] Trial 179 finished with value: 0.7850401861115885 and parameters: {'cat_weight': 0.3885778415506166, 'xgb_weight': 0.10729464136402594, 'lgb_weight': 0.1905451041550711}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,306] Trial 180 finished with value: 0.7850312668876264 and parameters: {'cat_weight': 0.29107913180057665, 'xgb_weight': 0.052972160218009344, 'lgb_weight': 0.13315054079292252}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,359] Trial 181 finished with value: 0.7850861303390626 and parameters: {'cat_weight': 0.3320821109923712, 'xgb_weight': 0.07362727833505714, 'lgb_weight': 0.10370645261526404}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,418] Trial 182 finished with value: 0.7850817345330833 and parameters: {'cat_weight': 0.33478242849782697, 'xgb_weight': 0.07164930594795339, 'lgb_weight': 0.1560073520343537}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,476] Trial 183 finished with value: 0.7850767818508025 and parameters: {'cat_weight': 0.3597498767674983, 'xgb_weight': 0.05183996347973124, 'lgb_weight': 0.10467090560434464}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,534] Trial 184 finished with value: 0.7850594314485133 and parameters: {'cat_weight': 0.4082148531512081, 'xgb_weight': 0.07321000130596825, 'lgb_weight': 0.13159924251234953}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,589] Trial 185 finished with value: 0.7845531874523086 and parameters: {'cat_weight': 0.33503624899167495, 'xgb_weight': 0.31347189181905843, 'lgb_weight': 0.07179401825120595}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,651] Trial 186 finished with value: 0.7850063444919136 and parameters: {'cat_weight': 0.3814114872601322, 'xgb_weight': 0.13396591090544394, 'lgb_weight': 0.1059974417717269}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,708] Trial 187 finished with value: 0.7850459092981926 and parameters: {'cat_weight': 0.35473638115418876, 'xgb_weight': 0.10083835653470988, 'lgb_weight': 0.17141890885650934}. Best is trial 122 with value: 0.7850995062184164.
# [I 2026-01-21 15:41:12,765] Trial 188 finished with value: 0.7851024856009676 and parameters: {'cat_weight': 0.331188225691261, 'xgb_weight': 0.048591850328585935, 'lgb_weight': 0.14957904036337513}. Best is trial 188 with value: 0.7851024856009676.
# [I 2026-01-21 15:41:12,824] Trial 189 finished with value: 0.7850119086214231 and parameters: {'cat_weight': 0.2813497954289389, 'xgb_weight': 4.5433701627767276e-05, 'lgb_weight': 0.10725295719274702}. Best is trial 188 with value: 0.7851024856009676.
# [I 2026-01-21 15:41:12,889] Trial 190 finished with value: 0.7833339463647991 and parameters: {'cat_weight': 0.3330120225627498, 'xgb_weight': 0.6546626417613581, 'lgb_weight': 0.13242820188325435}. Best is trial 188 with value: 0.7851024856009676.
# [I 2026-01-21 15:41:12,950] Trial 191 finished with value: 0.7850900814647596 and parameters: {'cat_weight': 0.3719631488524765, 'xgb_weight': 0.04728121571813624, 'lgb_weight': 0.15333110945802522}. Best is trial 188 with value: 0.7851024856009676.
# ...
# [I 2026-01-21 16:02:48,650] Trial 9937 finished with value: 0.7834578862702878 and parameters: {'cat_weight': 0.3801463207048932, 'xgb_weight': 0.016367535098659465, 'lgb_weight': 0.7901250408518685}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:48,829] Trial 9938 finished with value: 0.7847755074599587 and parameters: {'cat_weight': 0.5596679341137323, 'xgb_weight': 0.00013482110919530582, 'lgb_weight': 0.1159045522616344}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:49,006] Trial 9939 finished with value: 0.7849931559469303 and parameters: {'cat_weight': 0.3080254993558462, 'xgb_weight': 0.09476824536855336, 'lgb_weight': 0.15908132685792029}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:49,193] Trial 9940 finished with value: 0.7850919396273648 and parameters: {'cat_weight': 0.33088527934679146, 'xgb_weight': 0.043522164398402924, 'lgb_weight': 0.0960752436340147}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:49,369] Trial 9941 finished with value: 0.7850907786960489 and parameters: {'cat_weight': 0.36307128205150396, 'xgb_weight': 0.02818933356547623, 'lgb_weight': 0.14823617029832034}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:49,554] Trial 9942 finished with value: 0.7850748554261374 and parameters: {'cat_weight': 0.3170867162676623, 'xgb_weight': 0.06558450631538809, 'lgb_weight': 0.1265761762069953}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:49,736] Trial 9943 finished with value: 0.7849770003882612 and parameters: {'cat_weight': 0.3440745072506014, 'xgb_weight': 0.04565906104226841, 'lgb_weight': 0.04798294298887208}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:49,913] Trial 9944 finished with value: 0.7843140189648395 and parameters: {'cat_weight': 0.14313893904955324, 'xgb_weight': 0.030033291759122185, 'lgb_weight': 0.16979702808391606}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:50,083] Trial 9945 finished with value: 0.7834682270696465 and parameters: {'cat_weight': 0.27613559899409157, 'xgb_weight': 0.017642382044149144, 'lgb_weight': 0.6336002542688162}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:50,281] Trial 9946 finished with value: 0.7850555066007288 and parameters: {'cat_weight': 0.3048141460146306, 'xgb_weight': 0.06263987485955734, 'lgb_weight': 0.10215571742436336}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:50,450] Trial 9947 finished with value: 0.783174732865577 and parameters: {'cat_weight': 0.33073200188678636, 'xgb_weight': 0.6645897713109673, 'lgb_weight': 0.06888470627937768}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:50,647] Trial 9948 finished with value: 0.7850751566214208 and parameters: {'cat_weight': 0.36314470502740914, 'xgb_weight': 0.08280076412671626, 'lgb_weight': 0.12543462151951723}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:50,816] Trial 9949 finished with value: 0.7836378994084832 and parameters: {'cat_weight': 0.34578187578897757, 'xgb_weight': 0.04647569923445682, 'lgb_weight': 0.7048363032981977}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:51,011] Trial 9950 finished with value: 0.7850437174836351 and parameters: {'cat_weight': 0.29534107222017053, 'xgb_weight': 0.01931145878614097, 'lgb_weight': 0.147227970117731}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:51,183] Trial 9951 finished with value: 0.785021215313475 and parameters: {'cat_weight': 0.3844871097308003, 'xgb_weight': 0.04336374957499722, 'lgb_weight': 0.08612445749036748}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:51,377] Trial 9952 finished with value: 0.785045965803303 and parameters: {'cat_weight': 0.3212070856460579, 'xgb_weight': 0.059546857709808956, 'lgb_weight': 0.1857611587669455}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:51,546] Trial 9953 finished with value: 0.7850904089829666 and parameters: {'cat_weight': 0.3433873784899411, 'xgb_weight': 0.029005656274880696, 'lgb_weight': 0.11298824047414519}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:51,739] Trial 9954 finished with value: 0.7850536776019116 and parameters: {'cat_weight': 0.3637244635141552, 'xgb_weight': 0.10451458574914001, 'lgb_weight': 0.14157824887939363}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:51,918] Trial 9955 finished with value: 0.7850547641847603 and parameters: {'cat_weight': 0.3102014212031851, 'xgb_weight': 0.01750645951587272, 'lgb_weight': 0.16824685105679865}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:52,097] Trial 9956 finished with value: 0.7850819533897962 and parameters: {'cat_weight': 0.33253006253447354, 'xgb_weight': 0.08220285318801486, 'lgb_weight': 0.121454810220684}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:52,266] Trial 9957 finished with value: 0.7849871621479441 and parameters: {'cat_weight': 0.27780366579736565, 'xgb_weight': 0.0570492401058092, 'lgb_weight': 0.14161834593211328}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:52,479] Trial 9958 finished with value: 0.7850451410301372 and parameters: {'cat_weight': 0.32147118254838986, 'xgb_weight': 0.03948717639008524, 'lgb_weight': 0.19824069867397312}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:52,663] Trial 9959 finished with value: 0.785068924523267 and parameters: {'cat_weight': 0.35164266379774045, 'xgb_weight': 0.019151259601599614, 'lgb_weight': 0.10910512328316098}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:52,870] Trial 9960 finished with value: 0.7849688495473346 and parameters: {'cat_weight': 0.44794813447847276, 'xgb_weight': 0.07108461280651145, 'lgb_weight': 0.08654251835795157}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:53,078] Trial 9961 finished with value: 0.7850334038799535 and parameters: {'cat_weight': 0.2966292400411017, 'xgb_weight': 0.04294168605073369, 'lgb_weight': 0.1537351164231482}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:53,280] Trial 9962 finished with value: 0.7845896894541963 and parameters: {'cat_weight': 0.7547939680102728, 'xgb_weight': 0.01644894307058909, 'lgb_weight': 0.12754140465035751}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:53,465] Trial 9963 finished with value: 0.7850842580399259 and parameters: {'cat_weight': 0.37872670656213625, 'xgb_weight': 0.03119518311180668, 'lgb_weight': 0.16865297053518774}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:53,651] Trial 9964 finished with value: 0.7850956196416211 and parameters: {'cat_weight': 0.3281065398980183, 'xgb_weight': 0.058121696875749765, 'lgb_weight': 0.10472855070507633}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:53,816] Trial 9965 finished with value: 0.7850707788463074 and parameters: {'cat_weight': 0.3575864415373297, 'xgb_weight': 0.08944095961533055, 'lgb_weight': 0.1392711324688221}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:54,010] Trial 9966 finished with value: 0.7850550299865022 and parameters: {'cat_weight': 0.30584354936775776, 'xgb_weight': 0.03375187422185217, 'lgb_weight': 0.15682024268429193}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:54,182] Trial 9967 finished with value: 0.7849775272832333 and parameters: {'cat_weight': 0.418890071339277, 'xgb_weight': 0.00025329539510038357, 'lgb_weight': 0.12276621771830182}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:54,424] Trial 9968 finished with value: 0.78493686903937 and parameters: {'cat_weight': 0.335089446483064, 'xgb_weight': 0.14486041820993067, 'lgb_weight': 0.21081460930283055}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:54,615] Trial 9969 finished with value: 0.7849486879615549 and parameters: {'cat_weight': 0.25620465132383463, 'xgb_weight': 0.07014137390588948, 'lgb_weight': 0.09896585747550811}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:54,835] Trial 9970 finished with value: 0.7850088270844062 and parameters: {'cat_weight': 0.2857866644012307, 'xgb_weight': 0.049040972563112684, 'lgb_weight': 0.06724854852272702}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:55,017] Trial 9971 finished with value: 0.7850531208961152 and parameters: {'cat_weight': 0.3921460364649042, 'xgb_weight': 0.01712628027962217, 'lgb_weight': 0.13629251161360012}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:55,213] Trial 9972 finished with value: 0.7850843215659754 and parameters: {'cat_weight': 0.36722050446089444, 'xgb_weight': 0.042407186329596926, 'lgb_weight': 0.18055481088253203}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:55,385] Trial 9973 finished with value: 0.7834595667727677 and parameters: {'cat_weight': 0.3156464377888061, 'xgb_weight': 0.0672542719155658, 'lgb_weight': 0.7286989615355094}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:55,577] Trial 9974 finished with value: 0.7850975710673224 and parameters: {'cat_weight': 0.34225881737790476, 'xgb_weight': 0.018507716186128162, 'lgb_weight': 0.1564122912176222}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:55,751] Trial 9975 finished with value: 0.7850682077170696 and parameters: {'cat_weight': 0.3258206651370095, 'xgb_weight': 0.00020557903614121242, 'lgb_weight': 0.11768498986179071}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:55,935] Trial 9976 finished with value: 0.7850474604569584 and parameters: {'cat_weight': 0.30289838879696945, 'xgb_weight': 0.054742877420011805, 'lgb_weight': 0.08363566827511265}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:56,116] Trial 9977 finished with value: 0.7850734149543097 and parameters: {'cat_weight': 0.35328877229370703, 'xgb_weight': 0.08802169340593799, 'lgb_weight': 0.1337468920256552}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:56,300] Trial 9978 finished with value: 0.7845916422256544 and parameters: {'cat_weight': 0.7335509197282722, 'xgb_weight': 0.031102560338706384, 'lgb_weight': 0.10540366373476767}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:56,467] Trial 9979 finished with value: 0.782534250486253 and parameters: {'cat_weight': 0.035012131183166595, 'xgb_weight': 0.04678658716545148, 'lgb_weight': 0.15507497436922169}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:56,651] Trial 9980 finished with value: 0.7846061167710943 and parameters: {'cat_weight': 0.33986377726823463, 'xgb_weight': 0.03269124601327941, 'lgb_weight': 0.40686532416514976}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:56,826] Trial 9981 finished with value: 0.7850421526027761 and parameters: {'cat_weight': 0.369358602336626, 'xgb_weight': 0.11298891203540933, 'lgb_weight': 0.12233909347491809}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:57,000] Trial 9982 finished with value: 0.7850345452161196 and parameters: {'cat_weight': 0.3154710285075728, 'xgb_weight': 0.06751253344052752, 'lgb_weight': 0.1755832595957992}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:57,171] Trial 9983 finished with value: 0.7850247795318211 and parameters: {'cat_weight': 0.28215305155023934, 'xgb_weight': 0.017365695818672006, 'lgb_weight': 0.13868561819041691}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:57,366] Trial 9984 finished with value: 0.7849220020467258 and parameters: {'cat_weight': 0.3344285185734262, 'xgb_weight': 0.051276282903960115, 'lgb_weight': 0.028243995772292738}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:57,533] Trial 9985 finished with value: 0.7850579069955494 and parameters: {'cat_weight': 0.3564443657526836, 'xgb_weight': 0.03131655917979224, 'lgb_weight': 0.0952875565196685}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:57,720] Trial 9986 finished with value: 0.7849924336096405 and parameters: {'cat_weight': 0.2990200300986212, 'xgb_weight': 0.0805527572816633, 'lgb_weight': 0.15779084033959634}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:57,892] Trial 9987 finished with value: 0.7843399757342119 and parameters: {'cat_weight': 0.31998542220840204, 'xgb_weight': 0.017113676475608883, 'lgb_weight': 0.4577948310383357}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:02:58,088] Trial 9988 finished with value: 0.7836567647550106 and parameters: {'cat_weight': 0.40014369971467867, 'xgb_weight': 0.6096181827373891, 'lgb_weight': 0.11689968448496868}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:04,075] Trial 9989 finished with value: 0.7850966208169612 and parameters: {'cat_weight': 0.34369485912147285, 'xgb_weight': 0.06042241792256421, 'lgb_weight': 0.13880076304256522}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:04,286] Trial 9990 finished with value: 0.7850775542695585 and parameters: {'cat_weight': 0.3776525949326925, 'xgb_weight': 0.042177978390674664, 'lgb_weight': 0.19193501269960933}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:04,495] Trial 9991 finished with value: 0.7850717811103858 and parameters: {'cat_weight': 0.3082620740788582, 'xgb_weight': 0.031894092727310155, 'lgb_weight': 0.10398831463469956}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:04,674] Trial 9992 finished with value: 0.785044407523401 and parameters: {'cat_weight': 0.3313285810219839, 'xgb_weight': 0.0958345630512503, 'lgb_weight': 0.16720049596591507}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:04,858] Trial 9993 finished with value: 0.7850913361622066 and parameters: {'cat_weight': 0.3577307037942752, 'xgb_weight': 0.05699301972012097, 'lgb_weight': 0.1269703898330817}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:05,038] Trial 9994 finished with value: 0.7849601783982537 and parameters: {'cat_weight': 0.27008577408848256, 'xgb_weight': 0.07999484481535335, 'lgb_weight': 0.07603538562377998}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:05,232] Trial 9995 finished with value: 0.784597770328234 and parameters: {'cat_weight': 0.28993882146119954, 'xgb_weight': 0.2409467666249412, 'lgb_weight': 0.1459524589411071}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:05,420] Trial 9996 finished with value: 0.785095021440325 and parameters: {'cat_weight': 0.326590785335334, 'xgb_weight': 0.019867436855781795, 'lgb_weight': 0.11710565367968752}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:05,608] Trial 9997 finished with value: 0.7851002483762693 and parameters: {'cat_weight': 0.3457289281063895, 'xgb_weight': 0.04795638435840655, 'lgb_weight': 0.14914331152383725}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:05,786] Trial 9998 finished with value: 0.7829804786100257 and parameters: {'cat_weight': 0.3090503769158087, 'xgb_weight': 0.6999867107074981, 'lgb_weight': 0.09226672150178236}. Best is trial 1435 with value: 0.785109413664121.
# [I 2026-01-21 16:03:05,968] Trial 9999 finished with value: 0.7850824000086835 and parameters: {'cat_weight': 0.3673309395482046, 'xgb_weight': 0.017006126337146658, 'lgb_weight': 0.17443516513634297}. Best is trial 1435 with value: 0.785109413664121.
#
# ✓ Mejor AUC Meta-modelo: 0.78511
# Pesos óptimos:
#   - CatBoost: 0.6576
#   - XGBoost:  0.0682
#   - LightGBM: 0.2742

# %%
#params with better auc
#xgb
xgboost_params = {
    # Objective y métrica
    'objective': 'binary:logistic',
    'eval_metric': 'aucpr',  # AUCPR es mejor para desbalanceo


    # Parámetros de boosting - MÁS AGRESIVOS
    'n_estimators': 3000,  # Reducir de 5000 (early stopping lo maneja)
    'learning_rate': 0.01,  # Más bajo = más refinado
    'max_depth': 6,  # Aumentar de 5 (más capacidad)

    # Regularización - BALANCEADA
    'min_child_weight': 5,  # Reducir de 7 (menos restrictivo)
    'gamma': 0.2,  # Reducir de 0.3
    'subsample': 0.8,  # Aumentar de 0.7
    'colsample_bytree': 0.8,  # Aumentar de 0.7
    'colsample_bylevel': 0.8,  # Aumentar de 0.7
    'colsample_bynode': 0.8,  # NUEVO: muestreo por nodo

    # Regularización L1/L2 - MÁS SUAVE
    'reg_alpha': 0.5,  # Reducir de 1.0
    'reg_lambda': 2.0,  # Reducir de 3.0

    # Parámetros adicionales IMPORTANTES
    'max_delta_step': 1,  # Ayuda con desbalanceo extremo
    'tree_method': 'hist',
    'grow_policy': 'depthwise',  # vs lossguide

    # Sampling method para desbalanceo
    'sampling_method': 'gradient_based',  # Alternativa: 'uniform'

    # Control
    'random_state': 42,
    'n_jobs': -1,
    'device': 'cuda',
      # Reducir de 300 (más rápido)
    'verbosity': 1,
    'enable_categorical': True,
}

catboost_params = {
    'loss_function': 'Logloss',
    'eval_metric': 'PRAUC',

    'scale_pos_weight': scale_pos_weight * 0.9,

    # Boosting
    'iterations': 4000,
    'learning_rate': 0.025,
    'depth': 6,

    # Regularización (compensa falta de rsm)
    'l2_leaf_reg': 8.0,
    'random_strength': 2,

    # Bootstrap
    'bootstrap_type': 'Bayesian',
    'bagging_temperature': 0.5,

    # Growing
    'grow_policy': 'SymmetricTree',
    'min_data_in_leaf': 30,

    # Categóricas
    'cat_features': cat_features,
    'one_hot_max_size': 10,

    # GPU
    'task_type': 'GPU',
    'devices': '0',

    # Control
    'random_seed': 42,

    'verbose': 100,}

# %%
# Entrenar modelos finales
catboost_final = CatBoostClassifier(**catboost_params)
catboost_final.fit(X_train, y_train, cat_features=cat_features, verbose=0)
# Out:
# Warning: less than 75% GPU memory available for training. Free: 6040 Total: 8187.5
# Default metric period is 5 because PRAUC is/are not implemented for GPU
# Metric PRAUC is not implemented on GPU. Will use CPU for metric computation, this could significantly affect learning time

# %%
xgboost_final = XGBClassifier(**xgboost_params)
xgboost_final.fit(X_train, y_train, verbose=0)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.8, colsample_bynode=0.8, colsample_bytree=0.8,
#               device='cuda', early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='aucpr', feature_types=None,
#               feature_weights=None, gamma=0.2, grow_policy='depthwise',
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=1, max_depth=6,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=3000,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
lightgbm_final = LGBMClassifier(**best_lightgbm_params)
lightgbm_final.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='dart', colsample_bytree=0.5561467583303041,
#                device='gpu', drop_rate=0.00381033104925191,
#                learning_rate=0.012294910796044946, max_depth=6, metric='auc',
#                min_child_samples=85, min_child_weight=0.03173000093786445,
#                n_estimators=5000, n_jobs=-1, num_leaves=92, objective='binary',
#                random_state=42, reg_alpha=2.2713869947255474,
#                reg_lambda=4.8813744666008105,
#                scale_pos_weight=10.547343714220288, subsample=0.874615224292602,
#                verbosity=-1)

# %%
# Predicciones en test
test_cat_preds = catboost_final.predict_proba(X_test)[:, 1]
test_xgb_preds = xgboost_final.predict_proba(X_test)[:, 1]
test_lgb_preds = lightgbm_final.predict_proba(X_test)[:, 1]

# Meta-predicción con pesos optimizados
final_predictions = (best_cat_weight * test_cat_preds +
                     best_xgb_weight * test_xgb_preds +
                     best_lgb_weight * test_lgb_preds)

# %%
# Métricas
print("\n" + "="*80)
print("RESULTADOS EN TEST SET")
print("="*80)
print(f"\nAUC CatBoost:  {roc_auc_score(y_test, test_cat_preds):.5f}")
print(f"AUC XGBoost:   {roc_auc_score(y_test, test_xgb_preds):.5f}")
print(f"AUC LGBM:      {roc_auc_score(y_test, test_lgb_preds):.5f}")
print(f"AUC STACKING:  {roc_auc_score(y_test, final_predictions):.5f}")


# ============================================================================
# OPTIMIZACIÓN DE THRESHOLD
# ============================================================================

print("\n" + "="*80)
print("OPTIMIZACIÓN DE THRESHOLD")
print("="*80)

cost_FN = 10000  # Costo de no detectar un default
cost_FP = 1000   # Costo de rechazar un buen cliente

thresholds = np.linspace(0, 1, 101)
losses = []

for t in thresholds:
    y_pred = (final_predictions >= t).astype(int)
    FP = np.sum((y_test == 0) & (y_pred == 1))
    FN = np.sum((y_test == 1) & (y_pred == 0))
    loss = FP * cost_FP + FN * cost_FN
    losses.append(loss)

#optimal_threshold = thresholds[np.argmin(losses)]
optimal_threshold = thresholds[np.argmin(losses)]
min_loss = min(losses)

print(f"\n💰 Análisis de Costos:")
print(f"Threshold óptimo: {optimal_threshold:.4f}")
print(f"Pérdida mínima: ${min_loss:,.0f}")

# Predicciones con threshold optimizado
y_test_pred = (final_predictions >= optimal_threshold).astype(int)

# Confusion matrix
TP = np.sum((y_test == 1) & (y_test_pred == 1))
FP = np.sum((y_test == 0) & (y_test_pred == 1))
TN = np.sum((y_test == 0) & (y_test_pred == 0))
FN = np.sum((y_test == 1) & (y_test_pred == 0))

FPR = FP / (FP + TN) if (FP + TN) > 0 else 0
TPR = TP / (TP + FN) if (TP + FN) > 0 else 0
Precision = TP / (TP + FP) if (TP + FP) > 0 else 0

print(f"\n📈 Métricas de Clasificación (threshold={optimal_threshold:.4f}):")
print(f"FPR (False Positive Rate): {FPR:.4f}")
print(f"TPR (Recall): {TPR:.4f}")
print(f"Precision: {Precision:.4f}")

print(f"\n📋 Classification Report:")
print(classification_report(y_test, y_test_pred, target_names=['No Default', 'Default']))

cm = confusion_matrix(y_test, y_test_pred)
print(f"\n📊 Matriz de Confusión:")
print(f"                 Predicho")
print(f"               No Def  Default")
print(f"Real No Def    {cm[0, 0]:6d}   {cm[0, 1]:6d}")
print(f"Real Default   {cm[1, 0]:6d}   {cm[1, 1]:6d}")

# Análisis financiero
total_cost_optimal = FP * cost_FP + FN * cost_FN
total_cost_default = np.sum(y_test == 1) * cost_FN
savings = total_cost_default - total_cost_optimal

print(f"\n💵 Análisis Financiero:")
print(f"Costo total (threshold óptimo): ${total_cost_optimal:,.0f}")
print(f"Costo si rechazamos a todos: ${total_cost_default:,.0f}")
print(f"Ahorro con el modelo: ${savings:,.0f} ({(savings/total_cost_default)*100:.1f}%)")
print(f"\nFalsos Positivos: {FP} (costo: ${FP * cost_FP:,.0f})")
print(f"Falsos Negativos: {FN} (costo: ${FN * cost_FN:,.0f})")

print("\n" + "="*80)
print("OPTIMIZACIÓN COMPLETADA")
print("="*80)
# Out:
# ================================================================================
# RESULTADOS EN TEST SET
# ================================================================================
#
# AUC CatBoost:  0.78369
# AUC XGBoost:   0.78523
# AUC LGBM:      0.78533
# AUC STACKING:  0.78644
#
# ================================================================================
# OPTIMIZACIÓN DE THRESHOLD
# ================================================================================
#
# 💰 Análisis de Costos:
# Threshold óptimo: 0.0600
# Pérdida mínima: $25,725,000
#
# 📈 Métricas de Clasificación (threshold=0.0600):
# FPR (False Positive Rate): 0.3481
# TPR (Recall): 0.7781
# Precision: 0.1749
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#   No Default       0.97      0.65      0.78     46061
#      Default       0.17      0.78      0.29      4367
#
#     accuracy                           0.66     50428
#    macro avg       0.57      0.71      0.53     50428
# weighted avg       0.90      0.66      0.74     50428
#
#
# 📊 Matriz de Confusión:
#                  Predicho
#                No Def  Default
# Real No Def     30026    16035
# Real Default      969     3398
#
# 💵 Análisis Financiero:
# Costo total (threshold óptimo): $25,725,000
# Costo si rechazamos a todos: $43,670,000
# Ahorro con el modelo: $17,945,000 (41.1%)
#
# Falsos Positivos: 16035 (costo: $16,035,000)
# Falsos Negativos: 969 (costo: $9,690,000)
#
# ================================================================================
# OPTIMIZACIÓN COMPLETADA
# ================================================================================

# %%
#try a logistic regression
# Crea un DataFrame con las predicciones OOF
X_train_meta = pd.DataFrame({
    'cat': cat_oof,
    'xgb': xgb_oof,
    'lgb': lgb_oof
})

# Predicciones para el conjunto de TEST (usando los modelos ya entrenados)
test_cat = catboost_final.predict_proba(X_test)[:, 1]
test_xgb = xgboost_final.predict_proba(X_test)[:, 1]
test_lgb = lightgbm_final.predict_proba(X_test)[:, 1]

X_test_meta = pd.DataFrame({
    'cat': test_cat,
    'xgb': test_xgb,
    'lgb': test_lgb
})

# Entrena el Meta-Modelo (Logistic Regression es ideal aquí)
meta_model = LogisticRegression()
meta_model.fit(X_train_meta, y_train)

# Predicción final Stacked
final_predictions = meta_model.predict_proba(X_test_meta)[:, 1]

print(f"AUC FINAL: {roc_auc_score(y_test, final_predictions):.5f}")
# Out:
# AUC FINAL: 0.78644
