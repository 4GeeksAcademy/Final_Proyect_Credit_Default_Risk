# %%
import pandas as pd

# %%
df_bureau = pd.read_csv('../data/raw/bureau.csv')
df_bureau_balance = pd.read_csv('../data/raw/bureau_balance.csv')
df_credit_card_balance = pd.read_csv('../data/raw/credit_card_balance.csv')
df_installments_payments = pd.read_csv('../data/raw/installments_payments.csv')
df_POS_CASH_balance = pd.read_csv('../data/raw/POS_CASH_balance.csv')
df_previous_application = pd.read_csv('../data/raw/previous_application.csv')
df_sample_submission = pd.read_csv('../data/raw/sample_submission.csv')
