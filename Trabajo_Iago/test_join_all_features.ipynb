# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
import shap

# %%
app_train = pd.read_csv('../data/raw/application_tr.csv')
app_test = pd.read_csv('../data/raw/application_ts.csv')
bureau = pd.read_csv('../data/raw/bureau.csv')
bureau_balance = pd.read_csv('../data/raw/bureau_balance.csv')
previous = pd.read_csv('../data/raw/previous_application.csv')
pos_cash = pd.read_csv('../data/raw/POS_CASH_balance.csv')
credit_card = pd.read_csv('../data/raw/credit_card_balance.csv')
installments = pd.read_csv('../data/raw/installments_payments.csv')

# %%
bureau_full = bureau.merge(
    bureau_balance,
    on="SK_ID_BUREAU",
    how="left")

# %%
bureau_features = (
    bureau_full
    .groupby("SK_ID_CURR")
    .agg(
        bureau_loans=("SK_ID_BUREAU", "nunique"),
        bureau_days_credit_mean=("DAYS_CREDIT", "mean"),
        bureau_days_credit_min=("DAYS_CREDIT", "min"),
        bureau_credit_sum=("AMT_CREDIT_SUM", "sum"),
        bureau_credit_active=("CREDIT_ACTIVE", lambda x: (x == "Active").sum()),
        bureau_months_reported=("MONTHS_BALANCE", "count")
    )
    .reset_index()
)

bureau_features.to_parquet("../data/interim/bureau_features.parquet")

# %%
prev_features = (
    previous
    .groupby("SK_ID_CURR")
    .agg(
        prev_apps=("SK_ID_PREV", "nunique"),
        prev_amt_mean=("AMT_APPLICATION", "mean"),
        prev_amt_max=("AMT_APPLICATION", "max"),
        prev_refused=("NAME_CONTRACT_STATUS", lambda x: (x == "Refused").sum()),
        prev_approved=("NAME_CONTRACT_STATUS", lambda x: (x == "Approved").sum()),
        prev_days_decision_mean=("DAYS_DECISION", "mean")
    )
    .reset_index()
)

prev_features.to_parquet("../data/interim/prev_features.parquet")

# %%
installments["late"] = (
    installments["DAYS_ENTRY_PAYMENT"] > installments["DAYS_INSTALMENT"]
)

inst_features = (
    installments
    .groupby("SK_ID_CURR")
    .agg(
        inst_count=("SK_ID_PREV", "count"),
        inst_late_ratio=("late", "mean"),
        inst_payment_sum=("AMT_PAYMENT", "sum"),
        inst_instalment_sum=("AMT_INSTALMENT", "sum"),
        inst_payment_ratio=("AMT_PAYMENT", lambda x: x.sum())
    )
    .reset_index()
)

inst_features.to_parquet("../data/interim/installments_features.parquet")

# %%
pos_features = (
    pos_cash
    .groupby("SK_ID_CURR")
    .agg(
        pos_loans=("SK_ID_PREV", "nunique"),
        pos_months=("MONTHS_BALANCE", "count"),
        pos_dpd_mean=("SK_DPD", "mean"),
        pos_dpd_def_mean=("SK_DPD_DEF", "mean")
    )
    .reset_index()
)

pos_features.to_parquet("../data/interim/pos_features.parquet")

# %%
cc_features = (
    credit_card
    .groupby("SK_ID_CURR")
    .agg(
        cc_loans=("SK_ID_PREV", "nunique"),
        cc_balance_mean=("AMT_BALANCE", "mean"),
        cc_limit_mean=("AMT_CREDIT_LIMIT_ACTUAL", "mean"),
        cc_utilization=("AMT_BALANCE", "mean")
    )
    .reset_index()
)

cc_features.to_parquet("../data/interim/cc_features.parquet")

# %%
df_train = (
    app_train
    .merge(bureau_features, on="SK_ID_CURR", how="left")
    .merge(prev_features, on="SK_ID_CURR", how="left")
    .merge(inst_features, on="SK_ID_CURR", how="left")
    .merge(pos_features, on="SK_ID_CURR", how="left")
    .merge(cc_features, on="SK_ID_CURR", how="left")
)

df_train.to_parquet("../data/interim/train_final.parquet")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 147 entries, SK_ID_CURR to cc_utilization
# dtypes: float64(90), int64(41), object(16)
# memory usage: 344.9+ MB

# %%
df_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#    ...  inst_instalment_sum inst_payment_ratio pos_loans pos_months  \
# 0  ...           219625.695         219625.695       1.0       19.0
# 1  ...          1618864.650        1618864.650       3.0       28.0
# 2  ...            21288.465          21288.465       1.0        4.0
# 3  ...          1007153.415        1007153.415       3.0       21.0
# 4  ...           835985.340         806127.975       5.0       66.0
#
#   pos_dpd_mean pos_dpd_def_mean  cc_loans  cc_balance_mean  cc_limit_mean  \
# 0          0.0              0.0       NaN              NaN            NaN
# 1          0.0              0.0       NaN              NaN            NaN
# 2          0.0              0.0       NaN              NaN            NaN
# 3          0.0              0.0       1.0              0.0       270000.0
# 4          0.0              0.0       NaN              NaN            NaN
#
#    cc_utilization
# 0             NaN
# 1             NaN
# 2             NaN
# 3             0.0
# 4             NaN
#
# [5 rows x 147 columns]

# %%
TARGET = "TARGET"
y = df_train[TARGET]
X = df_train.drop(columns=[TARGET])

# %%
cat_cols = X.select_dtypes(include=["object"]).columns
num_cols = X.select_dtypes(exclude=["object"]).columns

print(f"Categóricas: {len(cat_cols)}")
print(f"Numéricas: {len(num_cols)}")
# Out:
# Categóricas: 16
# Numéricas: 130

# %%
num_imputer = SimpleImputer(strategy="mean") #change median for mean
cat_imputer = SimpleImputer(strategy="constant", fill_value="missing")

X[num_cols] = num_imputer.fit_transform(X[num_cols])
X[cat_cols] = cat_imputer.fit_transform(X[cat_cols])

# %%
X = pd.get_dummies(X, columns=cat_cols, drop_first=True)

# %%
print(X.isna().sum().sum())  # must be 0
print(X.shape)
# Out:
# 0
# (307511, 260)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=X_train.columns,
    index=X_train.index
)

X_val = pd.DataFrame(
    scaler.transform(X_val),
    columns=X_val.columns,
    index=X_val.index
)

# %%
'''
This library needs sklearn 1.3.2
and imblearn 0.11.0
'''

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline


# Combine over and under sampling
over = SMOTE(sampling_strategy=0.3)
under = RandomUnderSampler(sampling_strategy=0.7)
steps = [('over', over), ('under', under)]
pipeline = ImbPipeline(steps=steps)
X_train, y_train = pipeline.fit_resample(X_train, y_train)

# %%
X_train.shape
# Out:
# (164764, 260)

# %%
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif

'''
#F-score (lineal)
selector_f = SelectKBest(score_func=f_classif, k=150)
X_train_f = selector_f.fit_transform(X_train, y_train)
'''

#Mutual Information (no lineal)
selector_mi = SelectKBest(score_func=mutual_info_classif, k=150)
X_train_mi = selector_mi.fit_transform(X_train, y_train)

#Intersection
#features_f = X_train.columns[selector_f.get_support()].tolist()
features_mi = X_train.columns[selector_mi.get_support()].tolist()
#features_common = list(set(features_f) & set(features_mi))


X_train = X_train[features_mi]
X_val = X_val[features_mi]

print(f"Selected features: {len(features_mi)}")
# Out:
# Selected features: 150

# %%
neg = (y_train == 0).sum()
pos = (y_train == 1).sum()

scale = neg / pos

# %%
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'tree_method': 'hist',

    # core
    'learning_rate': 0.03,
    'n_estimators': 5500,
    'max_depth': 6,
    'min_child_weight': 20,

    # sampling
    'subsample': 0.8,
    'colsample_bytree': 0.8,

    # imbalance
    'scale_pos_weight': 1,

    # regularization
    'reg_alpha': 0.5,
    'reg_lambda': 2.0,
    'gamma': 1.0,
}


xgb_model = XGBClassifier(**params, n_jobs=-1, random_state=42,  early_stopping_rounds=300)

# %%
xgb_model.fit(
    X_train,
    y_train,
    eval_set=[(X_val, y_val)],
    verbose=True)
# Out:
# [0]	validation_0-auc:0.62459
# [1]	validation_0-auc:0.67602
# [2]	validation_0-auc:0.68206
# [3]	validation_0-auc:0.68703
# [4]	validation_0-auc:0.68993
# [5]	validation_0-auc:0.69405
# [6]	validation_0-auc:0.69456
# [7]	validation_0-auc:0.70023
# [8]	validation_0-auc:0.70373
# [9]	validation_0-auc:0.70418
# [10]	validation_0-auc:0.70551
# [11]	validation_0-auc:0.70572
# [12]	validation_0-auc:0.70738
# [13]	validation_0-auc:0.70774
# [14]	validation_0-auc:0.70810
# [15]	validation_0-auc:0.70922
# [16]	validation_0-auc:0.71058
# [17]	validation_0-auc:0.71184
# [18]	validation_0-auc:0.71236
# [19]	validation_0-auc:0.71252
# [20]	validation_0-auc:0.71273
# [21]	validation_0-auc:0.71372
# [22]	validation_0-auc:0.71410
# [23]	validation_0-auc:0.71499
# [24]	validation_0-auc:0.71464
# [25]	validation_0-auc:0.71613
# [26]	validation_0-auc:0.71647
# [27]	validation_0-auc:0.71755
# [28]	validation_0-auc:0.71794
# [29]	validation_0-auc:0.71894
# [30]	validation_0-auc:0.71970
# [31]	validation_0-auc:0.72034
# [32]	validation_0-auc:0.72097
# [33]	validation_0-auc:0.72183
# [34]	validation_0-auc:0.72241
# [35]	validation_0-auc:0.72298
# [36]	validation_0-auc:0.72358
# [37]	validation_0-auc:0.72410
# [38]	validation_0-auc:0.72426
# [39]	validation_0-auc:0.72464
# [40]	validation_0-auc:0.72526
# [41]	validation_0-auc:0.72594
# [42]	validation_0-auc:0.72659
# [43]	validation_0-auc:0.72718
# [44]	validation_0-auc:0.72747
# [45]	validation_0-auc:0.72775
# [46]	validation_0-auc:0.72824
# [47]	validation_0-auc:0.72865
# [48]	validation_0-auc:0.72897
# [49]	validation_0-auc:0.72963
# [50]	validation_0-auc:0.72988
# [51]	validation_0-auc:0.73029
# [52]	validation_0-auc:0.73058
# [53]	validation_0-auc:0.73068
# [54]	validation_0-auc:0.73102
# [55]	validation_0-auc:0.73173
# [56]	validation_0-auc:0.73207
# [57]	validation_0-auc:0.73240
# [58]	validation_0-auc:0.73277
# [59]	validation_0-auc:0.73295
# [60]	validation_0-auc:0.73311
# [61]	validation_0-auc:0.73359
# [62]	validation_0-auc:0.73368
# [63]	validation_0-auc:0.73411
# [64]	validation_0-auc:0.73437
# [65]	validation_0-auc:0.73471
# [66]	validation_0-auc:0.73515
# [67]	validation_0-auc:0.73540
# [68]	validation_0-auc:0.73565
# [69]	validation_0-auc:0.73613
# [70]	validation_0-auc:0.73660
# [71]	validation_0-auc:0.73675
# [72]	validation_0-auc:0.73696
# [73]	validation_0-auc:0.73720
# [74]	validation_0-auc:0.73754
# [75]	validation_0-auc:0.73796
# [76]	validation_0-auc:0.73825
# [77]	validation_0-auc:0.73845
# [78]	validation_0-auc:0.73866
# [79]	validation_0-auc:0.73878
# [80]	validation_0-auc:0.73905
# [81]	validation_0-auc:0.73934
# [82]	validation_0-auc:0.73948
# [83]	validation_0-auc:0.73965
# [84]	validation_0-auc:0.74020
# [85]	validation_0-auc:0.74049
# [86]	validation_0-auc:0.74079
# [87]	validation_0-auc:0.74089
# [88]	validation_0-auc:0.74131
# [89]	validation_0-auc:0.74139
# [90]	validation_0-auc:0.74155
# [91]	validation_0-auc:0.74194
# [92]	validation_0-auc:0.74212
# [93]	validation_0-auc:0.74234
# [94]	validation_0-auc:0.74267
# [95]	validation_0-auc:0.74297
# [96]	validation_0-auc:0.74326
# [97]	validation_0-auc:0.74347
# [98]	validation_0-auc:0.74373
# [99]	validation_0-auc:0.74395
# [100]	validation_0-auc:0.74414
# [101]	validation_0-auc:0.74444
# [102]	validation_0-auc:0.74474
# [103]	validation_0-auc:0.74498
# [104]	validation_0-auc:0.74533
# [105]	validation_0-auc:0.74554
# [106]	validation_0-auc:0.74584
# [107]	validation_0-auc:0.74612
# [108]	validation_0-auc:0.74633
# [109]	validation_0-auc:0.74650
# [110]	validation_0-auc:0.74674
# [111]	validation_0-auc:0.74697
# [112]	validation_0-auc:0.74712
# [113]	validation_0-auc:0.74728
# [114]	validation_0-auc:0.74761
# [115]	validation_0-auc:0.74782
# [116]	validation_0-auc:0.74809
# [117]	validation_0-auc:0.74821
# [118]	validation_0-auc:0.74843
# [119]	validation_0-auc:0.74863
# [120]	validation_0-auc:0.74878
# [121]	validation_0-auc:0.74892
# [122]	validation_0-auc:0.74915
# [123]	validation_0-auc:0.74953
# [124]	validation_0-auc:0.74978
# [125]	validation_0-auc:0.74998
# [126]	validation_0-auc:0.75023
# [127]	validation_0-auc:0.75048
# [128]	validation_0-auc:0.75060
# [129]	validation_0-auc:0.75070
# [130]	validation_0-auc:0.75083
# [131]	validation_0-auc:0.75095
# [132]	validation_0-auc:0.75114
# [133]	validation_0-auc:0.75131
# [134]	validation_0-auc:0.75145
# [135]	validation_0-auc:0.75170
# [136]	validation_0-auc:0.75178
# [137]	validation_0-auc:0.75187
# [138]	validation_0-auc:0.75205
# [139]	validation_0-auc:0.75221
# [140]	validation_0-auc:0.75243
# [141]	validation_0-auc:0.75260
# [142]	validation_0-auc:0.75277
# [143]	validation_0-auc:0.75294
# [144]	validation_0-auc:0.75312
# [145]	validation_0-auc:0.75328
# [146]	validation_0-auc:0.75346
# [147]	validation_0-auc:0.75367
# [148]	validation_0-auc:0.75376
# [149]	validation_0-auc:0.75387
# [150]	validation_0-auc:0.75401
# [151]	validation_0-auc:0.75413
# [152]	validation_0-auc:0.75420
# [153]	validation_0-auc:0.75431
# [154]	validation_0-auc:0.75442
# [155]	validation_0-auc:0.75454
# [156]	validation_0-auc:0.75473
# [157]	validation_0-auc:0.75493
# [158]	validation_0-auc:0.75506
# [159]	validation_0-auc:0.75516
# [160]	validation_0-auc:0.75538
# [161]	validation_0-auc:0.75553
# [162]	validation_0-auc:0.75564
# [163]	validation_0-auc:0.75575
# [164]	validation_0-auc:0.75591
# [165]	validation_0-auc:0.75600
# [166]	validation_0-auc:0.75605
# [167]	validation_0-auc:0.75621
# [168]	validation_0-auc:0.75639
# [169]	validation_0-auc:0.75662
# [170]	validation_0-auc:0.75668
# [171]	validation_0-auc:0.75678
# [172]	validation_0-auc:0.75687
# [173]	validation_0-auc:0.75716
# [174]	validation_0-auc:0.75723
# [175]	validation_0-auc:0.75726
# [176]	validation_0-auc:0.75741
# [177]	validation_0-auc:0.75747
# [178]	validation_0-auc:0.75757
# [179]	validation_0-auc:0.75769
# [180]	validation_0-auc:0.75790
# [181]	validation_0-auc:0.75798
# [182]	validation_0-auc:0.75805
# [183]	validation_0-auc:0.75816
# [184]	validation_0-auc:0.75827
# [185]	validation_0-auc:0.75835
# [186]	validation_0-auc:0.75851
# [187]	validation_0-auc:0.75865
# [188]	validation_0-auc:0.75875
# [189]	validation_0-auc:0.75885
# [190]	validation_0-auc:0.75901
# [191]	validation_0-auc:0.75911
# [192]	validation_0-auc:0.75927
# [193]	validation_0-auc:0.75934
# [194]	validation_0-auc:0.75940
# [195]	validation_0-auc:0.75954
# [196]	validation_0-auc:0.75963
# [197]	validation_0-auc:0.75974
# [198]	validation_0-auc:0.75977
# [199]	validation_0-auc:0.75981
# [200]	validation_0-auc:0.75994
# [201]	validation_0-auc:0.76006
# [202]	validation_0-auc:0.76012
# [203]	validation_0-auc:0.76017
# [204]	validation_0-auc:0.76025
# [205]	validation_0-auc:0.76031
# [206]	validation_0-auc:0.76038
# [207]	validation_0-auc:0.76040
# [208]	validation_0-auc:0.76055
# [209]	validation_0-auc:0.76059
# [210]	validation_0-auc:0.76065
# [211]	validation_0-auc:0.76078
# [212]	validation_0-auc:0.76081
# [213]	validation_0-auc:0.76086
# [214]	validation_0-auc:0.76089
# [215]	validation_0-auc:0.76111
# [216]	validation_0-auc:0.76115
# [217]	validation_0-auc:0.76119
# [218]	validation_0-auc:0.76129
# [219]	validation_0-auc:0.76139
# [220]	validation_0-auc:0.76143
# [221]	validation_0-auc:0.76149
# [222]	validation_0-auc:0.76164
# [223]	validation_0-auc:0.76172
# [224]	validation_0-auc:0.76176
# [225]	validation_0-auc:0.76182
# [226]	validation_0-auc:0.76194
# [227]	validation_0-auc:0.76195
# [228]	validation_0-auc:0.76211
# [229]	validation_0-auc:0.76213
# [230]	validation_0-auc:0.76219
# [231]	validation_0-auc:0.76221
# [232]	validation_0-auc:0.76229
# [233]	validation_0-auc:0.76236
# [234]	validation_0-auc:0.76241
# [235]	validation_0-auc:0.76248
# [236]	validation_0-auc:0.76252
# [237]	validation_0-auc:0.76262
# [238]	validation_0-auc:0.76270
# [239]	validation_0-auc:0.76281
# [240]	validation_0-auc:0.76285
# [241]	validation_0-auc:0.76291
# [242]	validation_0-auc:0.76296
# [243]	validation_0-auc:0.76303
# [244]	validation_0-auc:0.76311
# [245]	validation_0-auc:0.76316
# [246]	validation_0-auc:0.76320
# [247]	validation_0-auc:0.76327
# [248]	validation_0-auc:0.76334
# [249]	validation_0-auc:0.76340
# [250]	validation_0-auc:0.76351
# [251]	validation_0-auc:0.76352
# [252]	validation_0-auc:0.76355
# [253]	validation_0-auc:0.76364
# [254]	validation_0-auc:0.76370
# [255]	validation_0-auc:0.76378
# [256]	validation_0-auc:0.76383
# [257]	validation_0-auc:0.76393
# [258]	validation_0-auc:0.76402
# [259]	validation_0-auc:0.76405
# [260]	validation_0-auc:0.76409
# [261]	validation_0-auc:0.76413
# [262]	validation_0-auc:0.76415
# [263]	validation_0-auc:0.76419
# [264]	validation_0-auc:0.76426
# [265]	validation_0-auc:0.76432
# [266]	validation_0-auc:0.76433
# [267]	validation_0-auc:0.76437
# [268]	validation_0-auc:0.76443
# [269]	validation_0-auc:0.76448
# [270]	validation_0-auc:0.76457
# [271]	validation_0-auc:0.76460
# [272]	validation_0-auc:0.76460
# [273]	validation_0-auc:0.76464
# [274]	validation_0-auc:0.76467
# [275]	validation_0-auc:0.76475
# [276]	validation_0-auc:0.76478
# [277]	validation_0-auc:0.76485
# [278]	validation_0-auc:0.76489
# [279]	validation_0-auc:0.76500
# [280]	validation_0-auc:0.76502
# [281]	validation_0-auc:0.76511
# [282]	validation_0-auc:0.76513
# [283]	validation_0-auc:0.76515
# [284]	validation_0-auc:0.76519
# [285]	validation_0-auc:0.76522
# [286]	validation_0-auc:0.76525
# [287]	validation_0-auc:0.76528
# [288]	validation_0-auc:0.76534
# [289]	validation_0-auc:0.76536
# [290]	validation_0-auc:0.76549
# [291]	validation_0-auc:0.76554
# [292]	validation_0-auc:0.76555
# [293]	validation_0-auc:0.76556
# [294]	validation_0-auc:0.76560
# [295]	validation_0-auc:0.76568
# [296]	validation_0-auc:0.76572
# [297]	validation_0-auc:0.76578
# [298]	validation_0-auc:0.76583
# [299]	validation_0-auc:0.76586
# [300]	validation_0-auc:0.76590
# [301]	validation_0-auc:0.76598
# [302]	validation_0-auc:0.76604
# [303]	validation_0-auc:0.76608
# [304]	validation_0-auc:0.76616
# [305]	validation_0-auc:0.76619
# [306]	validation_0-auc:0.76620
# [307]	validation_0-auc:0.76625
# [308]	validation_0-auc:0.76627
# [309]	validation_0-auc:0.76635
# [310]	validation_0-auc:0.76640
# [311]	validation_0-auc:0.76646
# [312]	validation_0-auc:0.76650
# [313]	validation_0-auc:0.76652
# [314]	validation_0-auc:0.76653
# [315]	validation_0-auc:0.76655
# [316]	validation_0-auc:0.76656
# [317]	validation_0-auc:0.76662
# [318]	validation_0-auc:0.76666
# [319]	validation_0-auc:0.76670
# [320]	validation_0-auc:0.76673
# [321]	validation_0-auc:0.76683
# [322]	validation_0-auc:0.76692
# [323]	validation_0-auc:0.76697
# [324]	validation_0-auc:0.76699
# [325]	validation_0-auc:0.76707
# [326]	validation_0-auc:0.76712
# [327]	validation_0-auc:0.76711
# [328]	validation_0-auc:0.76714
# [329]	validation_0-auc:0.76718
# [330]	validation_0-auc:0.76722
# [331]	validation_0-auc:0.76726
# [332]	validation_0-auc:0.76729
# [333]	validation_0-auc:0.76733
# [334]	validation_0-auc:0.76739
# [335]	validation_0-auc:0.76741
# [336]	validation_0-auc:0.76742
# [337]	validation_0-auc:0.76744
# [338]	validation_0-auc:0.76749
# [339]	validation_0-auc:0.76755
# [340]	validation_0-auc:0.76759
# [341]	validation_0-auc:0.76763
# [342]	validation_0-auc:0.76766
# [343]	validation_0-auc:0.76769
# [344]	validation_0-auc:0.76772
# [345]	validation_0-auc:0.76775
# [346]	validation_0-auc:0.76779
# [347]	validation_0-auc:0.76794
# [348]	validation_0-auc:0.76801
# [349]	validation_0-auc:0.76806
# [350]	validation_0-auc:0.76807
# [351]	validation_0-auc:0.76810
# [352]	validation_0-auc:0.76810
# [353]	validation_0-auc:0.76813
# [354]	validation_0-auc:0.76814
# [355]	validation_0-auc:0.76816
# [356]	validation_0-auc:0.76816
# [357]	validation_0-auc:0.76816
# [358]	validation_0-auc:0.76822
# [359]	validation_0-auc:0.76824
# [360]	validation_0-auc:0.76827
# [361]	validation_0-auc:0.76833
# [362]	validation_0-auc:0.76833
# [363]	validation_0-auc:0.76836
# [364]	validation_0-auc:0.76840
# [365]	validation_0-auc:0.76841
# [366]	validation_0-auc:0.76850
# [367]	validation_0-auc:0.76853
# [368]	validation_0-auc:0.76856
# [369]	validation_0-auc:0.76857
# [370]	validation_0-auc:0.76858
# [371]	validation_0-auc:0.76860
# [372]	validation_0-auc:0.76869
# [373]	validation_0-auc:0.76872
# [374]	validation_0-auc:0.76875
# [375]	validation_0-auc:0.76878
# [376]	validation_0-auc:0.76881
# [377]	validation_0-auc:0.76880
# [378]	validation_0-auc:0.76880
# [379]	validation_0-auc:0.76882
# [380]	validation_0-auc:0.76886
# [381]	validation_0-auc:0.76891
# [382]	validation_0-auc:0.76893
# [383]	validation_0-auc:0.76895
# [384]	validation_0-auc:0.76897
# [385]	validation_0-auc:0.76905
# [386]	validation_0-auc:0.76909
# [387]	validation_0-auc:0.76912
# [388]	validation_0-auc:0.76915
# [389]	validation_0-auc:0.76917
# [390]	validation_0-auc:0.76918
# [391]	validation_0-auc:0.76919
# [392]	validation_0-auc:0.76924
# [393]	validation_0-auc:0.76928
# [394]	validation_0-auc:0.76929
# [395]	validation_0-auc:0.76929
# [396]	validation_0-auc:0.76928
# [397]	validation_0-auc:0.76928
# [398]	validation_0-auc:0.76934
# [399]	validation_0-auc:0.76936
# [400]	validation_0-auc:0.76934
# [401]	validation_0-auc:0.76934
# [402]	validation_0-auc:0.76946
# [403]	validation_0-auc:0.76947
# [404]	validation_0-auc:0.76949
# [405]	validation_0-auc:0.76950
# [406]	validation_0-auc:0.76954
# [407]	validation_0-auc:0.76958
# [408]	validation_0-auc:0.76964
# [409]	validation_0-auc:0.76967
# [410]	validation_0-auc:0.76966
# [411]	validation_0-auc:0.76974
# [412]	validation_0-auc:0.76976
# [413]	validation_0-auc:0.76983
# [414]	validation_0-auc:0.76992
# [415]	validation_0-auc:0.76996
# [416]	validation_0-auc:0.76997
# [417]	validation_0-auc:0.76998
# [418]	validation_0-auc:0.76999
# [419]	validation_0-auc:0.77000
# [420]	validation_0-auc:0.77005
# [421]	validation_0-auc:0.77005
# [422]	validation_0-auc:0.77004
# [423]	validation_0-auc:0.77006
# [424]	validation_0-auc:0.77010
# [425]	validation_0-auc:0.77015
# [426]	validation_0-auc:0.77026
# [427]	validation_0-auc:0.77029
# [428]	validation_0-auc:0.77034
# [429]	validation_0-auc:0.77039
# [430]	validation_0-auc:0.77042
# [431]	validation_0-auc:0.77043
# [432]	validation_0-auc:0.77045
# [433]	validation_0-auc:0.77046
# [434]	validation_0-auc:0.77048
# [435]	validation_0-auc:0.77049
# [436]	validation_0-auc:0.77050
# [437]	validation_0-auc:0.77052
# [438]	validation_0-auc:0.77055
# [439]	validation_0-auc:0.77057
# [440]	validation_0-auc:0.77057
# [441]	validation_0-auc:0.77059
# [442]	validation_0-auc:0.77062
# [443]	validation_0-auc:0.77063
# [444]	validation_0-auc:0.77064
# [445]	validation_0-auc:0.77065
# [446]	validation_0-auc:0.77065
# [447]	validation_0-auc:0.77069
# [448]	validation_0-auc:0.77072
# [449]	validation_0-auc:0.77073
# [450]	validation_0-auc:0.77075
# [451]	validation_0-auc:0.77082
# [452]	validation_0-auc:0.77084
# [453]	validation_0-auc:0.77087
# [454]	validation_0-auc:0.77090
# [455]	validation_0-auc:0.77093
# [456]	validation_0-auc:0.77096
# [457]	validation_0-auc:0.77100
# [458]	validation_0-auc:0.77102
# [459]	validation_0-auc:0.77106
# [460]	validation_0-auc:0.77108
# [461]	validation_0-auc:0.77112
# [462]	validation_0-auc:0.77114
# [463]	validation_0-auc:0.77116
# [464]	validation_0-auc:0.77116
# [465]	validation_0-auc:0.77116
# [466]	validation_0-auc:0.77120
# [467]	validation_0-auc:0.77127
# [468]	validation_0-auc:0.77127
# [469]	validation_0-auc:0.77129
# [470]	validation_0-auc:0.77127
# [471]	validation_0-auc:0.77129
# [472]	validation_0-auc:0.77129
# [473]	validation_0-auc:0.77135
# [474]	validation_0-auc:0.77137
# [475]	validation_0-auc:0.77145
# [476]	validation_0-auc:0.77146
# [477]	validation_0-auc:0.77147
# [478]	validation_0-auc:0.77148
# [479]	validation_0-auc:0.77148
# [480]	validation_0-auc:0.77150
# [481]	validation_0-auc:0.77153
# [482]	validation_0-auc:0.77155
# [483]	validation_0-auc:0.77160
# [484]	validation_0-auc:0.77162
# [485]	validation_0-auc:0.77166
# [486]	validation_0-auc:0.77169
# [487]	validation_0-auc:0.77174
# [488]	validation_0-auc:0.77173
# [489]	validation_0-auc:0.77179
# [490]	validation_0-auc:0.77181
# [491]	validation_0-auc:0.77184
# [492]	validation_0-auc:0.77183
# [493]	validation_0-auc:0.77181
# [494]	validation_0-auc:0.77182
# [495]	validation_0-auc:0.77180
# [496]	validation_0-auc:0.77181
# [497]	validation_0-auc:0.77182
# [498]	validation_0-auc:0.77181
# [499]	validation_0-auc:0.77181
# [500]	validation_0-auc:0.77181
# [501]	validation_0-auc:0.77186
# [502]	validation_0-auc:0.77187
# [503]	validation_0-auc:0.77189
# [504]	validation_0-auc:0.77190
# [505]	validation_0-auc:0.77192
# [506]	validation_0-auc:0.77197
# [507]	validation_0-auc:0.77198
# [508]	validation_0-auc:0.77199
# [509]	validation_0-auc:0.77199
# [510]	validation_0-auc:0.77201
# [511]	validation_0-auc:0.77200
# [512]	validation_0-auc:0.77205
# [513]	validation_0-auc:0.77205
# [514]	validation_0-auc:0.77204
# [515]	validation_0-auc:0.77204
# [516]	validation_0-auc:0.77205
# [517]	validation_0-auc:0.77206
# [518]	validation_0-auc:0.77209
# [519]	validation_0-auc:0.77206
# [520]	validation_0-auc:0.77207
# [521]	validation_0-auc:0.77208
# [522]	validation_0-auc:0.77208
# [523]	validation_0-auc:0.77210
# [524]	validation_0-auc:0.77211
# [525]	validation_0-auc:0.77213
# [526]	validation_0-auc:0.77215
# [527]	validation_0-auc:0.77221
# [528]	validation_0-auc:0.77224
# [529]	validation_0-auc:0.77227
# [530]	validation_0-auc:0.77229
# [531]	validation_0-auc:0.77232
# [532]	validation_0-auc:0.77233
# [533]	validation_0-auc:0.77233
# [534]	validation_0-auc:0.77234
# [535]	validation_0-auc:0.77235
# [536]	validation_0-auc:0.77240
# [537]	validation_0-auc:0.77241
# [538]	validation_0-auc:0.77245
# [539]	validation_0-auc:0.77245
# [540]	validation_0-auc:0.77248
# [541]	validation_0-auc:0.77252
# [542]	validation_0-auc:0.77254
# [543]	validation_0-auc:0.77255
# [544]	validation_0-auc:0.77258
# [545]	validation_0-auc:0.77256
# [546]	validation_0-auc:0.77258
# [547]	validation_0-auc:0.77258
# [548]	validation_0-auc:0.77260
# [549]	validation_0-auc:0.77262
# [550]	validation_0-auc:0.77261
# [551]	validation_0-auc:0.77263
# [552]	validation_0-auc:0.77265
# [553]	validation_0-auc:0.77265
# [554]	validation_0-auc:0.77270
# [555]	validation_0-auc:0.77274
# [556]	validation_0-auc:0.77278
# [557]	validation_0-auc:0.77278
# [558]	validation_0-auc:0.77281
# [559]	validation_0-auc:0.77285
# [560]	validation_0-auc:0.77283
# [561]	validation_0-auc:0.77281
# [562]	validation_0-auc:0.77284
# [563]	validation_0-auc:0.77284
# [564]	validation_0-auc:0.77283
# [565]	validation_0-auc:0.77283
# [566]	validation_0-auc:0.77285
# [567]	validation_0-auc:0.77288
# [568]	validation_0-auc:0.77290
# [569]	validation_0-auc:0.77294
# [570]	validation_0-auc:0.77296
# [571]	validation_0-auc:0.77297
# [572]	validation_0-auc:0.77296
# [573]	validation_0-auc:0.77296
# [574]	validation_0-auc:0.77298
# [575]	validation_0-auc:0.77300
# [576]	validation_0-auc:0.77298
# [577]	validation_0-auc:0.77299
# [578]	validation_0-auc:0.77300
# [579]	validation_0-auc:0.77302
# [580]	validation_0-auc:0.77302
# [581]	validation_0-auc:0.77302
# [582]	validation_0-auc:0.77305
# [583]	validation_0-auc:0.77305
# [584]	validation_0-auc:0.77309
# [585]	validation_0-auc:0.77309
# [586]	validation_0-auc:0.77311
# [587]	validation_0-auc:0.77311
# [588]	validation_0-auc:0.77314
# [589]	validation_0-auc:0.77313
# [590]	validation_0-auc:0.77315
# [591]	validation_0-auc:0.77314
# [592]	validation_0-auc:0.77318
# [593]	validation_0-auc:0.77318
# [594]	validation_0-auc:0.77318
# [595]	validation_0-auc:0.77324
# [596]	validation_0-auc:0.77323
# [597]	validation_0-auc:0.77323
# [598]	validation_0-auc:0.77324
# [599]	validation_0-auc:0.77326
# [600]	validation_0-auc:0.77333
# [601]	validation_0-auc:0.77331
# [602]	validation_0-auc:0.77332
# [603]	validation_0-auc:0.77334
# [604]	validation_0-auc:0.77336
# [605]	validation_0-auc:0.77337
# [606]	validation_0-auc:0.77336
# [607]	validation_0-auc:0.77337
# [608]	validation_0-auc:0.77336
# [609]	validation_0-auc:0.77337
# [610]	validation_0-auc:0.77337
# [611]	validation_0-auc:0.77338
# [612]	validation_0-auc:0.77338
# [613]	validation_0-auc:0.77340
# [614]	validation_0-auc:0.77341
# [615]	validation_0-auc:0.77341
# [616]	validation_0-auc:0.77339
# [617]	validation_0-auc:0.77337
# [618]	validation_0-auc:0.77338
# [619]	validation_0-auc:0.77339
# [620]	validation_0-auc:0.77340
# [621]	validation_0-auc:0.77343
# [622]	validation_0-auc:0.77342
# [623]	validation_0-auc:0.77341
# [624]	validation_0-auc:0.77340
# [625]	validation_0-auc:0.77342
# [626]	validation_0-auc:0.77344
# [627]	validation_0-auc:0.77343
# [628]	validation_0-auc:0.77345
# [629]	validation_0-auc:0.77346
# [630]	validation_0-auc:0.77347
# [631]	validation_0-auc:0.77349
# [632]	validation_0-auc:0.77350
# [633]	validation_0-auc:0.77353
# [634]	validation_0-auc:0.77354
# [635]	validation_0-auc:0.77358
# [636]	validation_0-auc:0.77357
# [637]	validation_0-auc:0.77357
# [638]	validation_0-auc:0.77355
# [639]	validation_0-auc:0.77357
# [640]	validation_0-auc:0.77359
# [641]	validation_0-auc:0.77363
# [642]	validation_0-auc:0.77365
# [643]	validation_0-auc:0.77363
# [644]	validation_0-auc:0.77363
# [645]	validation_0-auc:0.77362
# [646]	validation_0-auc:0.77364
# [647]	validation_0-auc:0.77367
# [648]	validation_0-auc:0.77368
# [649]	validation_0-auc:0.77371
# [650]	validation_0-auc:0.77371
# [651]	validation_0-auc:0.77371
# [652]	validation_0-auc:0.77369
# [653]	validation_0-auc:0.77370
# [654]	validation_0-auc:0.77369
# [655]	validation_0-auc:0.77370
# [656]	validation_0-auc:0.77370
# [657]	validation_0-auc:0.77370
# [658]	validation_0-auc:0.77369
# [659]	validation_0-auc:0.77373
# [660]	validation_0-auc:0.77373
# [661]	validation_0-auc:0.77373
# [662]	validation_0-auc:0.77374
# [663]	validation_0-auc:0.77374
# [664]	validation_0-auc:0.77380
# [665]	validation_0-auc:0.77380
# [666]	validation_0-auc:0.77379
# [667]	validation_0-auc:0.77381
# [668]	validation_0-auc:0.77383
# [669]	validation_0-auc:0.77383
# [670]	validation_0-auc:0.77388
# [671]	validation_0-auc:0.77387
# [672]	validation_0-auc:0.77388
# [673]	validation_0-auc:0.77390
# [674]	validation_0-auc:0.77391
# [675]	validation_0-auc:0.77391
# [676]	validation_0-auc:0.77391
# [677]	validation_0-auc:0.77392
# [678]	validation_0-auc:0.77395
# [679]	validation_0-auc:0.77393
# [680]	validation_0-auc:0.77394
# [681]	validation_0-auc:0.77393
# [682]	validation_0-auc:0.77394
# [683]	validation_0-auc:0.77393
# [684]	validation_0-auc:0.77393
# [685]	validation_0-auc:0.77393
# [686]	validation_0-auc:0.77393
# [687]	validation_0-auc:0.77393
# [688]	validation_0-auc:0.77396
# [689]	validation_0-auc:0.77396
# [690]	validation_0-auc:0.77398
# [691]	validation_0-auc:0.77400
# [692]	validation_0-auc:0.77400
# [693]	validation_0-auc:0.77402
# [694]	validation_0-auc:0.77403
# [695]	validation_0-auc:0.77404
# [696]	validation_0-auc:0.77405
# [697]	validation_0-auc:0.77407
# [698]	validation_0-auc:0.77406
# [699]	validation_0-auc:0.77406
# [700]	validation_0-auc:0.77407
# [701]	validation_0-auc:0.77409
# [702]	validation_0-auc:0.77410
# [703]	validation_0-auc:0.77411
# [704]	validation_0-auc:0.77415
# [705]	validation_0-auc:0.77415
# [706]	validation_0-auc:0.77418
# [707]	validation_0-auc:0.77420
# [708]	validation_0-auc:0.77419
# [709]	validation_0-auc:0.77421
# [710]	validation_0-auc:0.77425
# [711]	validation_0-auc:0.77425
# [712]	validation_0-auc:0.77423
# [713]	validation_0-auc:0.77425
# [714]	validation_0-auc:0.77425
# [715]	validation_0-auc:0.77427
# [716]	validation_0-auc:0.77428
# [717]	validation_0-auc:0.77430
# [718]	validation_0-auc:0.77433
# [719]	validation_0-auc:0.77433
# [720]	validation_0-auc:0.77432
# [721]	validation_0-auc:0.77433
# [722]	validation_0-auc:0.77434
# [723]	validation_0-auc:0.77436
# [724]	validation_0-auc:0.77437
# [725]	validation_0-auc:0.77437
# [726]	validation_0-auc:0.77436
# [727]	validation_0-auc:0.77437
# [728]	validation_0-auc:0.77438
# [729]	validation_0-auc:0.77442
# [730]	validation_0-auc:0.77443
# [731]	validation_0-auc:0.77445
# [732]	validation_0-auc:0.77446
# [733]	validation_0-auc:0.77450
# [734]	validation_0-auc:0.77450
# [735]	validation_0-auc:0.77452
# [736]	validation_0-auc:0.77450
# [737]	validation_0-auc:0.77452
# [738]	validation_0-auc:0.77454
# [739]	validation_0-auc:0.77456
# [740]	validation_0-auc:0.77456
# [741]	validation_0-auc:0.77456
# [742]	validation_0-auc:0.77456
# [743]	validation_0-auc:0.77458
# [744]	validation_0-auc:0.77458
# [745]	validation_0-auc:0.77462
# [746]	validation_0-auc:0.77463
# [747]	validation_0-auc:0.77466
# [748]	validation_0-auc:0.77468
# [749]	validation_0-auc:0.77469
# [750]	validation_0-auc:0.77470
# [751]	validation_0-auc:0.77470
# [752]	validation_0-auc:0.77472
# [753]	validation_0-auc:0.77472
# [754]	validation_0-auc:0.77471
# [755]	validation_0-auc:0.77472
# [756]	validation_0-auc:0.77472
# [757]	validation_0-auc:0.77473
# [758]	validation_0-auc:0.77475
# [759]	validation_0-auc:0.77475
# [760]	validation_0-auc:0.77476
# [761]	validation_0-auc:0.77482
# [762]	validation_0-auc:0.77482
# [763]	validation_0-auc:0.77479
# [764]	validation_0-auc:0.77478
# [765]	validation_0-auc:0.77479
# [766]	validation_0-auc:0.77481
# [767]	validation_0-auc:0.77483
# [768]	validation_0-auc:0.77481
# [769]	validation_0-auc:0.77483
# [770]	validation_0-auc:0.77482
# [771]	validation_0-auc:0.77484
# [772]	validation_0-auc:0.77485
# [773]	validation_0-auc:0.77486
# [774]	validation_0-auc:0.77486
# [775]	validation_0-auc:0.77485
# [776]	validation_0-auc:0.77486
# [777]	validation_0-auc:0.77486
# [778]	validation_0-auc:0.77487
# [779]	validation_0-auc:0.77487
# [780]	validation_0-auc:0.77487
# [781]	validation_0-auc:0.77485
# [782]	validation_0-auc:0.77485
# [783]	validation_0-auc:0.77486
# [784]	validation_0-auc:0.77486
# [785]	validation_0-auc:0.77487
# [786]	validation_0-auc:0.77486
# [787]	validation_0-auc:0.77488
# [788]	validation_0-auc:0.77489
# [789]	validation_0-auc:0.77489
# [790]	validation_0-auc:0.77487
# [791]	validation_0-auc:0.77484
# [792]	validation_0-auc:0.77485
# [793]	validation_0-auc:0.77485
# [794]	validation_0-auc:0.77487
# [795]	validation_0-auc:0.77487
# [796]	validation_0-auc:0.77491
# [797]	validation_0-auc:0.77493
# [798]	validation_0-auc:0.77494
# [799]	validation_0-auc:0.77494
# [800]	validation_0-auc:0.77494
# [801]	validation_0-auc:0.77494
# [802]	validation_0-auc:0.77496
# [803]	validation_0-auc:0.77497
# [804]	validation_0-auc:0.77499
# [805]	validation_0-auc:0.77499
# [806]	validation_0-auc:0.77504
# [807]	validation_0-auc:0.77504
# [808]	validation_0-auc:0.77505
# [809]	validation_0-auc:0.77506
# [810]	validation_0-auc:0.77507
# [811]	validation_0-auc:0.77508
# [812]	validation_0-auc:0.77509
# [813]	validation_0-auc:0.77509
# [814]	validation_0-auc:0.77511
# [815]	validation_0-auc:0.77513
# [816]	validation_0-auc:0.77512
# [817]	validation_0-auc:0.77515
# [818]	validation_0-auc:0.77518
# [819]	validation_0-auc:0.77518
# [820]	validation_0-auc:0.77519
# [821]	validation_0-auc:0.77517
# [822]	validation_0-auc:0.77520
# [823]	validation_0-auc:0.77519
# [824]	validation_0-auc:0.77522
# [825]	validation_0-auc:0.77522
# [826]	validation_0-auc:0.77520
# [827]	validation_0-auc:0.77521
# [828]	validation_0-auc:0.77523
# [829]	validation_0-auc:0.77522
# [830]	validation_0-auc:0.77522
# [831]	validation_0-auc:0.77523
# [832]	validation_0-auc:0.77523
# [833]	validation_0-auc:0.77524
# [834]	validation_0-auc:0.77524
# [835]	validation_0-auc:0.77526
# [836]	validation_0-auc:0.77523
# [837]	validation_0-auc:0.77524
# [838]	validation_0-auc:0.77523
# [839]	validation_0-auc:0.77525
# [840]	validation_0-auc:0.77524
# [841]	validation_0-auc:0.77524
# [842]	validation_0-auc:0.77523
# [843]	validation_0-auc:0.77524
# [844]	validation_0-auc:0.77524
# [845]	validation_0-auc:0.77525
# [846]	validation_0-auc:0.77522
# [847]	validation_0-auc:0.77525
# [848]	validation_0-auc:0.77526
# [849]	validation_0-auc:0.77526
# [850]	validation_0-auc:0.77525
# [851]	validation_0-auc:0.77525
# [852]	validation_0-auc:0.77530
# [853]	validation_0-auc:0.77531
# [854]	validation_0-auc:0.77532
# [855]	validation_0-auc:0.77531
# [856]	validation_0-auc:0.77532
# [857]	validation_0-auc:0.77531
# [858]	validation_0-auc:0.77531
# [859]	validation_0-auc:0.77530
# [860]	validation_0-auc:0.77528
# [861]	validation_0-auc:0.77528
# [862]	validation_0-auc:0.77533
# [863]	validation_0-auc:0.77535
# [864]	validation_0-auc:0.77537
# [865]	validation_0-auc:0.77537
# [866]	validation_0-auc:0.77537
# [867]	validation_0-auc:0.77539
# [868]	validation_0-auc:0.77539
# [869]	validation_0-auc:0.77539
# [870]	validation_0-auc:0.77540
# [871]	validation_0-auc:0.77543
# [872]	validation_0-auc:0.77542
# [873]	validation_0-auc:0.77542
# [874]	validation_0-auc:0.77542
# [875]	validation_0-auc:0.77544
# [876]	validation_0-auc:0.77544
# [877]	validation_0-auc:0.77548
# [878]	validation_0-auc:0.77549
# [879]	validation_0-auc:0.77551
# [880]	validation_0-auc:0.77552
# [881]	validation_0-auc:0.77553
# [882]	validation_0-auc:0.77551
# [883]	validation_0-auc:0.77550
# [884]	validation_0-auc:0.77551
# [885]	validation_0-auc:0.77551
# [886]	validation_0-auc:0.77555
# [887]	validation_0-auc:0.77556
# [888]	validation_0-auc:0.77555
# [889]	validation_0-auc:0.77556
# [890]	validation_0-auc:0.77558
# [891]	validation_0-auc:0.77557
# [892]	validation_0-auc:0.77556
# [893]	validation_0-auc:0.77555
# [894]	validation_0-auc:0.77556
# [895]	validation_0-auc:0.77556
# [896]	validation_0-auc:0.77559
# [897]	validation_0-auc:0.77560
# [898]	validation_0-auc:0.77562
# [899]	validation_0-auc:0.77562
# [900]	validation_0-auc:0.77561
# [901]	validation_0-auc:0.77562
# [902]	validation_0-auc:0.77561
# [903]	validation_0-auc:0.77562
# [904]	validation_0-auc:0.77564
# [905]	validation_0-auc:0.77563
# [906]	validation_0-auc:0.77564
# [907]	validation_0-auc:0.77566
# [908]	validation_0-auc:0.77566
# [909]	validation_0-auc:0.77566
# [910]	validation_0-auc:0.77566
# [911]	validation_0-auc:0.77566
# [912]	validation_0-auc:0.77565
# [913]	validation_0-auc:0.77566
# [914]	validation_0-auc:0.77568
# [915]	validation_0-auc:0.77568
# [916]	validation_0-auc:0.77569
# [917]	validation_0-auc:0.77567
# [918]	validation_0-auc:0.77567
# [919]	validation_0-auc:0.77568
# [920]	validation_0-auc:0.77570
# [921]	validation_0-auc:0.77572
# [922]	validation_0-auc:0.77572
# [923]	validation_0-auc:0.77571
# [924]	validation_0-auc:0.77571
# [925]	validation_0-auc:0.77571
# [926]	validation_0-auc:0.77574
# [927]	validation_0-auc:0.77574
# [928]	validation_0-auc:0.77574
# [929]	validation_0-auc:0.77576
# [930]	validation_0-auc:0.77576
# [931]	validation_0-auc:0.77576
# [932]	validation_0-auc:0.77575
# [933]	validation_0-auc:0.77575
# [934]	validation_0-auc:0.77576
# [935]	validation_0-auc:0.77574
# [936]	validation_0-auc:0.77574
# [937]	validation_0-auc:0.77572
# [938]	validation_0-auc:0.77575
# [939]	validation_0-auc:0.77576
# [940]	validation_0-auc:0.77576
# [941]	validation_0-auc:0.77575
# [942]	validation_0-auc:0.77574
# [943]	validation_0-auc:0.77574
# [944]	validation_0-auc:0.77575
# [945]	validation_0-auc:0.77573
# [946]	validation_0-auc:0.77575
# [947]	validation_0-auc:0.77573
# [948]	validation_0-auc:0.77574
# [949]	validation_0-auc:0.77574
# [950]	validation_0-auc:0.77574
# [951]	validation_0-auc:0.77574
# [952]	validation_0-auc:0.77576
# [953]	validation_0-auc:0.77576
# [954]	validation_0-auc:0.77575
# [955]	validation_0-auc:0.77573
# [956]	validation_0-auc:0.77574
# [957]	validation_0-auc:0.77574
# [958]	validation_0-auc:0.77574
# [959]	validation_0-auc:0.77573
# [960]	validation_0-auc:0.77575
# [961]	validation_0-auc:0.77574
# [962]	validation_0-auc:0.77571
# [963]	validation_0-auc:0.77569
# [964]	validation_0-auc:0.77568
# [965]	validation_0-auc:0.77567
# [966]	validation_0-auc:0.77568
# [967]	validation_0-auc:0.77568
# [968]	validation_0-auc:0.77570
# [969]	validation_0-auc:0.77570
# [970]	validation_0-auc:0.77572
# [971]	validation_0-auc:0.77572
# [972]	validation_0-auc:0.77572
# [973]	validation_0-auc:0.77573
# [974]	validation_0-auc:0.77572
# [975]	validation_0-auc:0.77571
# [976]	validation_0-auc:0.77570
# [977]	validation_0-auc:0.77572
# [978]	validation_0-auc:0.77572
# [979]	validation_0-auc:0.77570
# [980]	validation_0-auc:0.77571
# [981]	validation_0-auc:0.77571
# [982]	validation_0-auc:0.77571
# [983]	validation_0-auc:0.77571
# [984]	validation_0-auc:0.77572
# [985]	validation_0-auc:0.77573
# [986]	validation_0-auc:0.77574
# [987]	validation_0-auc:0.77573
# [988]	validation_0-auc:0.77576
# [989]	validation_0-auc:0.77577
# [990]	validation_0-auc:0.77577
# [991]	validation_0-auc:0.77577
# [992]	validation_0-auc:0.77577
# [993]	validation_0-auc:0.77578
# [994]	validation_0-auc:0.77580
# [995]	validation_0-auc:0.77581
# [996]	validation_0-auc:0.77580
# [997]	validation_0-auc:0.77581
# [998]	validation_0-auc:0.77583
# [999]	validation_0-auc:0.77585
# [1000]	validation_0-auc:0.77586
# [1001]	validation_0-auc:0.77586
# [1002]	validation_0-auc:0.77586
# [1003]	validation_0-auc:0.77586
# [1004]	validation_0-auc:0.77587
# [1005]	validation_0-auc:0.77589
# [1006]	validation_0-auc:0.77589
# [1007]	validation_0-auc:0.77589
# [1008]	validation_0-auc:0.77589
# [1739]	validation_0-auc:0.77585
# [1740]	validation_0-auc:0.77587
# [1741]	validation_0-auc:0.77587
# [1742]	validation_0-auc:0.77587
# [1743]	validation_0-auc:0.77586
# [1744]	validation_0-auc:0.77585
# [1745]	validation_0-auc:0.77585
# [1746]	validation_0-auc:0.77586
# [1747]	validation_0-auc:0.77586
# [1748]	validation_0-auc:0.77587
# [1749]	validation_0-auc:0.77586
# [1750]	validation_0-auc:0.77586
# [1751]	validation_0-auc:0.77586
# [1752]	validation_0-auc:0.77583
# [1753]	validation_0-auc:0.77583
# [1754]	validation_0-auc:0.77584
# [1755]	validation_0-auc:0.77586
# [1756]	validation_0-auc:0.77588
# [1757]	validation_0-auc:0.77589
# [1758]	validation_0-auc:0.77587
# [1759]	validation_0-auc:0.77587
# [1760]	validation_0-auc:0.77587
# [1761]	validation_0-auc:0.77585
# [1762]	validation_0-auc:0.77586
# [1763]	validation_0-auc:0.77586
# [1764]	validation_0-auc:0.77587
# [1765]	validation_0-auc:0.77586
# [1766]	validation_0-auc:0.77587
# [1767]	validation_0-auc:0.77587
# [1768]	validation_0-auc:0.77586
# [1769]	validation_0-auc:0.77585
# [1770]	validation_0-auc:0.77587
# [1771]	validation_0-auc:0.77586
# [1772]	validation_0-auc:0.77587
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=300,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=1.0, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=20, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=5500,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
'''
#search optim threshold
from sklearn.metrics import roc_curve
import numpy as np

y_val_proba = xgb_model.predict_proba(X_val)[:, 1]
fpr, tpr, thresholds = roc_curve(y_val, y_val_proba)

# finds threshold max (TPR - FPR)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print(f"Optimal Threshold: {optimal_threshold:.3f}")
'''
# Out:
# '\n#search optim threshold\nfrom sklearn.metrics import roc_curve\nimport numpy as np\n\ny_val_proba = xgb_model.predict_proba(X_val)[:, 1]\nfpr, tpr, thresholds = roc_curve(y_val, y_val_proba)\n\n# finds threshold max (TPR - FPR)\noptimal_idx = np.argmax(tpr - fpr)\noptimal_threshold = thresholds[optimal_idx]\nprint(f"Optimal Threshold: {optimal_threshold:.3f}")\n'

# %%
#optimal f1 threshold
from sklearn.metrics import f1_score
import numpy as np

y_val_proba = xgb_model.predict_proba(X_val)[:, 1]

thresholds = np.linspace(0.05, 0.6, 100)
f1_scores = [f1_score(y_val, y_val_proba >= t) for t in thresholds]

optimal_threshold = thresholds[np.argmax(f1_scores)]

print(f"Optimal Threshold (F1): {optimal_threshold:.3f}")
# Out:
# Optimal Threshold (F1): 0.339

# %%
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, roc_curve

y_val_pred = xgb_model.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_val_pred)

adj_threshold = optimal_threshold + 0.02

y_val_pred = (y_val_pred >= adj_threshold).astype(int)

classification_report = classification_report(y_val, y_val_pred)

print(f"AUC validación: {auc:.5f}")
print(classification_report)
# Out:
# AUC validación: 0.77639
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93     56538
#            1       0.30      0.37      0.33      4965
#
#     accuracy                           0.88     61503
#    macro avg       0.62      0.65      0.63     61503
# weighted avg       0.89      0.88      0.88     61503
