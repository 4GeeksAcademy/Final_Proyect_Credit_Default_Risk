# %%
from class_processor_clients import process_client, predict, explain, process_new_client

# %%
client = process_client(100135, 10000, 'Revolving loans')
print(client)
# Out:
#   NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0    Revolving loans           M            N               Y           0.0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# 0          135000.0     10000.0      26271.0         319500.0   Unaccompanied
#
#    ... approval_ext prev_apps_log experience_score cc_util_ext  cc_util_risk  \
# 0  ...     0.120107      2.564949         1.317361         0.0           0.0
#
#    good_behavior_score  good_behavior_ext  net_score  net_score_ext  \
# 0             0.081197           0.058514   0.000611        0.00044
#
#    final_score
# 0     0.596763
#
# [1 rows x 325 columns]

# %%
prediction = predict(client)
print(prediction)
# Out:
# [[0.54245937 0.45754063]]

# %%
top, bottom = explain(client)
print('top')
print(top)
print('bottom')
print(bottom)
# Out:
# top
#                             feature                          value      shap
# 1                       CODE_GENDER                              M  0.181546
# 90      bureau_debt_to_credit_ratio                       0.723387  0.157634
# 39                     EXT_SOURCE_1                            0.0  0.104373
# 169  prev_credit_down_payment_ratio                            0.0  0.088339
# 11              NAME_EDUCATION_TYPE  Secondary / secondary special  0.067403
# 187        monthly_payment_capacity                     -75365.805  0.055327
# 305                     EXTm_d_risk                       5.669758  0.050906
# 282                        EXTm_emp                       0.302325  0.050182
# 161     prev_weighted_refused_ratio                       0.333333  0.041437
# 172           prev_yield_group_high                            1.0  0.040458
# bottom
#                             feature            value      shap
# ...

# %%
import sys
import os

sys.path.append(os.path.abspath('../front'))

from functions import *

# %%
user = new_user(1231445, 1000, 'Revolving loans')
print(user)
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 29450    Revolving loans           F            N               Y
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 29450             1          112500.0        1000      21375.0
#
#        AMT_GOODS_PRICE NAME_TYPE_SUITE  ... approval_ext prev_apps_log  \
# 29450         225000.0   Unaccompanied  ...          0.0           0.0
#
#       experience_score cc_util_ext  cc_util_risk  good_behavior_score  \
# 29450              0.0         0.0           0.0                  0.0
#
#        good_behavior_ext  net_score  net_score_ext  final_score
# 29450                0.0        0.0            0.0          0.0
#
# [1 rows x 325 columns]

# %%
user = search_user(100135, 10000, 'Revolving loans')
print(user)
# Out:
#    NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 99    Revolving loans           M            N               Y             0
#
#     AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 99          135000.0     10000.0      26271.0         319500.0
#
#    NAME_TYPE_SUITE  ... approval_ext prev_apps_log experience_score  \
# 99   Unaccompanied  ...     0.120107      2.564949         1.317361
#
#    cc_util_ext  cc_util_risk  good_behavior_score  good_behavior_ext  \
# 99         0.0           0.0             0.081197           0.058514
#
#     net_score  net_score_ext  final_score
# 99   0.000611        0.00044     0.568527
#
# [1 rows x 325 columns]

# %%
print(predict(user))
# Out:
# [[0.45012306 0.54987694]]

# %%
print(explain(user))
# Out:
# (                            feature                          value      shap
# 1                       CODE_GENDER                              M  0.163274
# 90      bureau_debt_to_credit_ratio                       0.723387  0.145837
# 265                        goods_cr                        0.81673  0.110666
# 39                     EXT_SOURCE_1                            NaN  0.109575
# 169  prev_credit_down_payment_ratio                            0.0  0.070935
# 11              NAME_EDUCATION_TYPE  Secondary / secondary special  0.068363
# 263                           cr_an                      14.890716  0.056164
# 305                     EXTm_d_risk                       5.669758  0.051551
# 8                   AMT_GOODS_PRICE                       319500.0  0.048018
# 282                        EXTm_emp                       0.302325  0.047448,                             feature            value      shap
# 202  ext_source_payment_interaction         0.376291 -0.260980
# ...
